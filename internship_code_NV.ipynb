# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("NV_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    YogaSix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city region    zip  ...  \
# 0                 4020 Schiff Dr        Las Vegas     NV  89103  ...
# 1       3401 S Sammy Davis Jr Dr        Las Vegas     NV  89109  ...
# 2            9 W Charleston Blvd        Las Vegas     NV  89102  ...
# 3             2664 S Highland Dr        Las Vegas     NV  89109  ...
# 4      2475 W Cheyenne Ave # 110  North Las Vegas     NV  89032  ...
# ...                          ...              ...    ...    ...  ...
# 12210                        NaN              NaN    NaN    NaN  ...
# 12211                        NaN              NaN    NaN    NaN  ...
# 12212                        NaN              NaN    NaN    NaN  ...
# 12213              115 Baker Ave            Baker     NV  89311  ...
# 12214       500 Hidden Canyon Rd            Baker     NV  89311  ...
#
#       instagram_average_comments  ads_yelp ads_facebook ads_instagram  \
# 0                          237.0       NaN          NaN           NaN
# 1                            9.0       NaN          NaN           NaN
# 2                            NaN       NaN          NaN           NaN
# 3                            NaN       NaN          NaN           NaN
# 4                            6.0       NaN          NaN           NaN
# ...                          ...       ...          ...           ...
# 12210                        NaN       NaN          NaN           NaN
# 12211                        NaN       NaN          NaN           NaN
# 12212                        NaN       NaN          NaN           NaN
# 12213                        2.0       NaN          NaN           NaN
# 12214                        2.0       NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 12210           NaN         NaN
# 12211           NaN         NaN
# 12212           NaN         NaN
# 12213           NaN         NaN
# 12214           NaN         NaN
#
#                                                   g_maps  g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...       unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...         claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...       unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...         claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...         claimed
# ...                                                  ...             ...
# 12210                                                NaN             NaN
# 12211                                                NaN             NaN
# 12212                                                NaN             NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...         claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...         claimed
#
#        search_keyword  search_city
# 0         Boxing Club    Las Vegas
# 1         Boxing Club    Las Vegas
# 2         Boxing Club    Las Vegas
# 3         Boxing Club    Las Vegas
# 4         Boxing Club    Las Vegas
# ...               ...          ...
# 12210     Yoga Studio    Sutcliffe
# 12211     Yoga Studio    Sutcliffe
# 12212     Yoga Studio    Sutcliffe
# 12213     Yoga Studio        Baker
# 12214     Yoga Studio        Baker
#
# [12215 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('AL','')
df['First Name'] = df['First Name'].str.replace('Al','')
df['First Name'] = df['First Name'].str.replace('Alabama','')
df
# Out:
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city region    zip  ... ads_yelp  \
# 0                 4020 Schiff Dr        Las Vegas     NV  89103  ...      NaN
# 1       3401 S Sammy Davis Jr Dr        Las Vegas     NV  89109  ...      NaN
# 2            9 W Charleston Blvd        Las Vegas     NV  89102  ...      NaN
# 3             2664 S Highland Dr        Las Vegas     NV  89109  ...      NaN
# 4      2475 W Cheyenne Ave # 110  North Las Vegas     NV  89032  ...      NaN
# ...                          ...              ...    ...    ...  ...      ...
# 12210                        NaN              NaN    NaN    NaN  ...      NaN
# 12211                        NaN              NaN    NaN    NaN  ...      NaN
# 12212                        NaN              NaN    NaN    NaN  ...      NaN
# 12213              115 Baker Ave            Baker     NV  89311  ...      NaN
# 12214       500 Hidden Canyon Rd            Baker     NV  89311  ...      NaN
#
#        ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN           NaN         NaN
# 1               NaN           NaN           NaN         NaN
# 2               NaN           NaN           NaN         NaN
# 3               NaN           NaN           NaN         NaN
# 4               NaN           NaN           NaN         NaN
# ...             ...           ...           ...         ...
# 12210           NaN           NaN           NaN         NaN
# 12211           NaN           NaN           NaN         NaN
# 12212           NaN           NaN           NaN         NaN
# 12213           NaN           NaN           NaN         NaN
# 12214           NaN           NaN           NaN         NaN
#
#                                                   g_maps  g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...       unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...         claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...       unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...         claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...         claimed
# ...                                                  ...             ...
# 12210                                                NaN             NaN
# 12211                                                NaN             NaN
# 12212                                                NaN             NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...         claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...         claimed
#
#        search_keyword  search_city                                 First Name
# 0         Boxing Club    Las Vegas                         Mayweather Boxing
# 1         Boxing Club    Las Vegas                       City Athletic Boxing
# 2         Boxing Club    Las Vegas                    Johnny Toccos Ringside
# 3         Boxing Club    Las Vegas                              Barrys Boxing
# 4         Boxing Club    Las Vegas                     Richard Steele Boxing
# ...               ...          ...                                        ...
# 12210     Yoga Studio    Sutcliffe                       Reformation Movement
# 12211     Yoga Studio    Sutcliffe              North Peak Climbing & Fitness
# 12212     Yoga Studio    Sutcliffe                                    Yogasix
# 12213     Yoga Studio        Baker  Stargazer Inn & Bristlecone General Store
# 12214     Yoga Studio        Baker                      Hidden Canyon Retreat
#
# [12215 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city region    zip  ... ads_yelp  \
# 0                 4020 Schiff Dr        Las Vegas     NV  89103  ...      NaN
# 1       3401 S Sammy Davis Jr Dr        Las Vegas     NV  89109  ...      NaN
# 2            9 W Charleston Blvd        Las Vegas     NV  89102  ...      NaN
# 3             2664 S Highland Dr        Las Vegas     NV  89109  ...      NaN
# 4      2475 W Cheyenne Ave # 110  North Las Vegas     NV  89032  ...      NaN
# ...                          ...              ...    ...    ...  ...      ...
# 12210                        NaN              NaN    NaN    NaN  ...      NaN
# 12211                        NaN              NaN    NaN    NaN  ...      NaN
# 12212                        NaN              NaN    NaN    NaN  ...      NaN
# 12213              115 Baker Ave            Baker     NV  89311  ...      NaN
# 12214       500 Hidden Canyon Rd            Baker     NV  89311  ...      NaN
#
#        ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN           NaN         NaN
# 1               NaN           NaN           NaN         NaN
# 2               NaN           NaN           NaN         NaN
# 3               NaN           NaN           NaN         NaN
# 4               NaN           NaN           NaN         NaN
# ...             ...           ...           ...         ...
# 12210           NaN           NaN           NaN         NaN
# 12211           NaN           NaN           NaN         NaN
# 12212           NaN           NaN           NaN         NaN
# 12213           NaN           NaN           NaN         NaN
# 12214           NaN           NaN           NaN         NaN
#
#                                                   g_maps  g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...       unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...         claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...       unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...         claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...         claimed
# ...                                                  ...             ...
# 12210                                                NaN             NaN
# 12211                                                NaN             NaN
# 12212                                                NaN             NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...         claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...         claimed
#
#        search_keyword  search_city                                 First Name
# 0         Boxing Club    Las Vegas                         Mayweather Boxing
# 1         Boxing Club    Las Vegas                       City Athletic Boxing
# 2         Boxing Club    Las Vegas                    Johnny Toccos Ringside
# 3         Boxing Club    Las Vegas                              Barrys Boxing
# 4         Boxing Club    Las Vegas                     Richard Steele Boxing
# ...               ...          ...                                        ...
# 12210     Yoga Studio    Sutcliffe                       Reformation Movement
# 12211     Yoga Studio    Sutcliffe              North Peak Climbing & Fitness
# 12212     Yoga Studio    Sutcliffe                                    Yogasix
# 12213     Yoga Studio        Baker  Stargazer Inn & Bristlecone General Store
# 12214     Yoga Studio        Baker                      Hidden Canyon Retreat
#
# [12215 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city region    zip  ...  \
# 0                 4020 Schiff Dr        Las Vegas     NV  89103  ...
# 1       3401 S Sammy Davis Jr Dr        Las Vegas     NV  89109  ...
# 2            9 W Charleston Blvd        Las Vegas     NV  89102  ...
# 3             2664 S Highland Dr        Las Vegas     NV  89109  ...
# 4      2475 W Cheyenne Ave # 110  North Las Vegas     NV  89032  ...
# ...                          ...              ...    ...    ...  ...
# 12210                        NaN              NaN    NaN    NaN  ...
# 12211                        NaN              NaN    NaN    NaN  ...
# 12212                        NaN              NaN    NaN    NaN  ...
# 12213              115 Baker Ave            Baker     NV  89311  ...
# 12214       500 Hidden Canyon Rd            Baker     NV  89311  ...
#
#       ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0              NaN            NaN           NaN         NaN
# 1              NaN            NaN           NaN         NaN
# 2              NaN            NaN           NaN         NaN
# 3              NaN            NaN           NaN         NaN
# 4              NaN            NaN           NaN         NaN
# ...            ...            ...           ...         ...
# 12210          NaN            NaN           NaN         NaN
# 12211          NaN            NaN           NaN         NaN
# 12212          NaN            NaN           NaN         NaN
# 12213          NaN            NaN           NaN         NaN
# 12214          NaN            NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...      unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...        claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...      unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...        claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...        claimed
# ...                                                  ...            ...
# 12210                                                NaN            NaN
# 12211                                                NaN            NaN
# 12212                                                NaN            NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...        claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...        claimed
#
#        search_keyword  search_city                                 First Name  \
# 0         Boxing Club    Las Vegas                         Mayweather Boxing
# 1         Boxing Club    Las Vegas                       City Athletic Boxing
# 2         Boxing Club    Las Vegas                    Johnny Toccos Ringside
# 3         Boxing Club    Las Vegas                              Barrys Boxing
# 4         Boxing Club    Las Vegas                     Richard Steele Boxing
# ...               ...          ...                                        ...
# 12210     Yoga Studio    Sutcliffe                       Reformation Movement
# 12211     Yoga Studio    Sutcliffe              North Peak Climbing & Fitness
# 12212     Yoga Studio    Sutcliffe                                    Yogasix
# 12213     Yoga Studio        Baker  Stargazer Inn & Bristlecone General Store
# 12214     Yoga Studio        Baker                      Hidden Canyon Retreat
#
#        Business Type
# 0                NaT
# 1                NaT
# 2                NaT
# 3                NaT
# 4                NaT
# ...              ...
# 12210            NaT
# 12211            NaT
# 12212            NaT
# 12213            NaT
# 12214            NaT
#
# [12215 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city region    zip  ...  \
# 0                 4020 Schiff Dr        Las Vegas     NV  89103  ...
# 1       3401 S Sammy Davis Jr Dr        Las Vegas     NV  89109  ...
# 2            9 W Charleston Blvd        Las Vegas     NV  89102  ...
# 3             2664 S Highland Dr        Las Vegas     NV  89109  ...
# 4      2475 W Cheyenne Ave # 110  North Las Vegas     NV  89032  ...
# ...                          ...              ...    ...    ...  ...
# 12210                        NaN              NaN    NaN    NaN  ...
# 12211                        NaN              NaN    NaN    NaN  ...
# 12212                        NaN              NaN    NaN    NaN  ...
# 12213              115 Baker Ave            Baker     NV  89311  ...
# 12214       500 Hidden Canyon Rd            Baker     NV  89311  ...
#
#       ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0              NaN            NaN           NaN         NaN
# 1              NaN            NaN           NaN         NaN
# 2              NaN            NaN           NaN         NaN
# 3              NaN            NaN           NaN         NaN
# 4              NaN            NaN           NaN         NaN
# ...            ...            ...           ...         ...
# 12210          NaN            NaN           NaN         NaN
# 12211          NaN            NaN           NaN         NaN
# 12212          NaN            NaN           NaN         NaN
# 12213          NaN            NaN           NaN         NaN
# 12214          NaN            NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...      unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...        claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...      unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...        claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...        claimed
# ...                                                  ...            ...
# 12210                                                NaN            NaN
# 12211                                                NaN            NaN
# 12212                                                NaN            NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...        claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...        claimed
#
#        search_keyword  search_city                                 First Name  \
# 0         Boxing Club    Las Vegas                         Mayweather Boxing
# 1         Boxing Club    Las Vegas                       City Athletic Boxing
# 2         Boxing Club    Las Vegas                    Johnny Toccos Ringside
# 3         Boxing Club    Las Vegas                              Barrys Boxing
# 4         Boxing Club    Las Vegas                     Richard Steele Boxing
# ...               ...          ...                                        ...
# 12210     Yoga Studio    Sutcliffe                       Reformation Movement
# 12211     Yoga Studio    Sutcliffe              North Peak Climbing & Fitness
# 12212     Yoga Studio    Sutcliffe                                    Yogasix
# 12213     Yoga Studio        Baker  Stargazer Inn & Bristlecone General Store
# 12214     Yoga Studio        Baker                      Hidden Canyon Retreat
#
#        Business Type
# 0            General
# 1            General
# 2            General
# 3            General
# 4            General
# ...              ...
# 12210        General
# 12211        General
# 12212        General
# 12213        General
# 12214        General
#
# [12215 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city region    zip  ...  \
# 0                 4020 Schiff Dr        Las Vegas     NV  89103  ...
# 1       3401 S Sammy Davis Jr Dr        Las Vegas     NV  89109  ...
# 2            9 W Charleston Blvd        Las Vegas     NV  89102  ...
# 3             2664 S Highland Dr        Las Vegas     NV  89109  ...
# 4      2475 W Cheyenne Ave # 110  North Las Vegas     NV  89032  ...
# ...                          ...              ...    ...    ...  ...
# 12210                        NaN              NaN    NaN    NaN  ...
# 12211                        NaN              NaN    NaN    NaN  ...
# 12212                        NaN              NaN    NaN    NaN  ...
# 12213              115 Baker Ave            Baker     NV  89311  ...
# 12214       500 Hidden Canyon Rd            Baker     NV  89311  ...
#
#       ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0              NaN            NaN           NaN         NaN
# 1              NaN            NaN           NaN         NaN
# 2              NaN            NaN           NaN         NaN
# 3              NaN            NaN           NaN         NaN
# 4              NaN            NaN           NaN         NaN
# ...            ...            ...           ...         ...
# 12210          NaN            NaN           NaN         NaN
# 12211          NaN            NaN           NaN         NaN
# 12212          NaN            NaN           NaN         NaN
# 12213          NaN            NaN           NaN         NaN
# 12214          NaN            NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...      unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...        claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...      unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...        claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...        claimed
# ...                                                  ...            ...
# 12210                                                NaN            NaN
# 12211                                                NaN            NaN
# 12212                                                NaN            NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...        claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...        claimed
#
#        search_keyword  search_city                                 First Name  \
# 0         Boxing Club    Las Vegas                         Mayweather Boxing
# 1         Boxing Club    Las Vegas                       City Athletic Boxing
# 2         Boxing Club    Las Vegas                    Johnny Toccos Ringside
# 3         Boxing Club    Las Vegas                              Barrys Boxing
# 4         Boxing Club    Las Vegas                     Richard Steele Boxing
# ...               ...          ...                                        ...
# 12210     Yoga Studio    Sutcliffe                       Reformation Movement
# 12211     Yoga Studio    Sutcliffe              North Peak Climbing & Fitness
# 12212     Yoga Studio    Sutcliffe                                    Yogasix
# 12213     Yoga Studio        Baker  Stargazer Inn & Bristlecone General Store
# 12214     Yoga Studio        Baker                      Hidden Canyon Retreat
#
#        Business Type
# 0             Boxing
# 1             Boxing
# 2            fitness
# 3             Boxing
# 4             Boxing
# ...              ...
# 12210        General
# 12211        Fitness
# 12212           Yoga
# 12213        General
# 12214        General
#
# [12215 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                                 First Name  \
# 0            Boxing                         Mayweather Boxing
# 1            Boxing                       City Athletic Boxing
# 2           fitness                    Johnny Toccos Ringside
# 3            Boxing                              Barrys Boxing
# 4            Boxing                     Richard Steele Boxing
# ...             ...                                        ...
# 12210       General                       Reformation Movement
# 12211       Fitness              North Peak Climbing & Fitness
# 12212          Yoga                                    Yogasix
# 12213       General  Stargazer Inn & Bristlecone General Store
# 12214       General                      Hidden Canyon Retreat
#
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city  ...  \
# 0                 4020 Schiff Dr        Las Vegas  ...
# 1       3401 S Sammy Davis Jr Dr        Las Vegas  ...
# 2            9 W Charleston Blvd        Las Vegas  ...
# 3             2664 S Highland Dr        Las Vegas  ...
# 4      2475 W Cheyenne Ave # 110  North Las Vegas  ...
# ...                          ...              ...  ...
# 12210                        NaN              NaN  ...
# 12211                        NaN              NaN  ...
# 12212                        NaN              NaN  ...
# 12213              115 Baker Ave            Baker  ...
# 12214       500 Hidden Canyon Rd            Baker  ...
#
#       instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                          237.0      NaN          NaN            NaN
# 1                            9.0      NaN          NaN            NaN
# 2                            NaN      NaN          NaN            NaN
# 3                            NaN      NaN          NaN            NaN
# 4                            6.0      NaN          NaN            NaN
# ...                          ...      ...          ...            ...
# 12210                        NaN      NaN          NaN            NaN
# 12211                        NaN      NaN          NaN            NaN
# 12212                        NaN      NaN          NaN            NaN
# 12213                        2.0      NaN          NaN            NaN
# 12214                        2.0      NaN          NaN            NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 12210           NaN         NaN
# 12211           NaN         NaN
# 12212           NaN         NaN
# 12213           NaN         NaN
# 12214           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...      unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...        claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...      unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...        claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...        claimed
# ...                                                  ...            ...
# 12210                                                NaN            NaN
# 12211                                                NaN            NaN
# 12212                                                NaN            NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...        claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...        claimed
#
#        search_keyword  search_city
# 0         Boxing Club    Las Vegas
# 1         Boxing Club    Las Vegas
# 2         Boxing Club    Las Vegas
# 3         Boxing Club    Las Vegas
# 4         Boxing Club    Las Vegas
# ...               ...          ...
# 12210     Yoga Studio    Sutcliffe
# 12211     Yoga Studio    Sutcliffe
# 12212     Yoga Studio    Sutcliffe
# 12213     Yoga Studio        Baker
# 12214     Yoga Studio        Baker
#
# [12215 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                                 First Name  \
# 0            Boxing                         Mayweather Boxing
# 1            Boxing                       City Athletic Boxing
# 2           fitness                    Johnny Toccos Ringside
# 3            Boxing                              Barrys Boxing
# 4            Boxing                     Richard Steele Boxing
# ...             ...                                        ...
# 12210       General                       Reformation Movement
# 12211       Fitness              North Peak Climbing & Fitness
# 12212          Yoga                                    Yogasix
# 12213       General  Stargazer Inn & Bristlecone General Store
# 12214       General                      Hidden Canyon Retreat
#
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city  ...  \
# 0                 4020 Schiff Dr        Las Vegas  ...
# 1       3401 S Sammy Davis Jr Dr        Las Vegas  ...
# 2            9 W Charleston Blvd        Las Vegas  ...
# 3             2664 S Highland Dr        Las Vegas  ...
# 4      2475 W Cheyenne Ave # 110  North Las Vegas  ...
# ...                          ...              ...  ...
# 12210                        NaN              NaN  ...
# 12211                        NaN              NaN  ...
# 12212                        NaN              NaN  ...
# 12213              115 Baker Ave            Baker  ...
# 12214       500 Hidden Canyon Rd            Baker  ...
#
#       instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                          237.0      NaN          NaN            NaN
# 1                            9.0      NaN          NaN            NaN
# 2                            NaN      NaN          NaN            NaN
# 3                            NaN      NaN          NaN            NaN
# 4                            6.0      NaN          NaN            NaN
# ...                          ...      ...          ...            ...
# 12210                        NaN      NaN          NaN            NaN
# 12211                        NaN      NaN          NaN            NaN
# 12212                        NaN      NaN          NaN            NaN
# 12213                        2.0      NaN          NaN            NaN
# 12214                        2.0      NaN          NaN            NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 12210           NaN         NaN
# 12211           NaN         NaN
# 12212           NaN         NaN
# 12213           NaN         NaN
# 12214           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...      unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...        claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...      unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...        claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...        claimed
# ...                                                  ...            ...
# 12210                                                NaN            NaN
# 12211                                                NaN            NaN
# 12212                                                NaN            NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...        claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...        claimed
#
#        search_keyword  search_city
# 0         Boxing Club    Las Vegas
# 1         Boxing Club    Las Vegas
# 2         Boxing Club    Las Vegas
# 3         Boxing Club    Las Vegas
# 4         Boxing Club    Las Vegas
# ...               ...          ...
# 12210     Yoga Studio    Sutcliffe
# 12211     Yoga Studio    Sutcliffe
# 12212     Yoga Studio    Sutcliffe
# 12213     Yoga Studio        Baker
# 12214     Yoga Studio        Baker
#
# [12215 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                                 First Name  \
# 0            Boxing                         Mayweather Boxing
# 1            Boxing                       City Athletic Boxing
# 2           fitness                    Johnny Toccos Ringside
# 3            Boxing                              Barrys Boxing
# 4            Boxing                     Richard Steele Boxing
# ...             ...                                        ...
# 12210       General                       Reformation Movement
# 12211       Fitness              North Peak Climbing & Fitness
# 12212          Yoga                                    Yogasix
# 12213       General  Stargazer Inn & Bristlecone General Store
# 12214       General                      Hidden Canyon Retreat
#
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city  ...  \
# 0                 4020 Schiff Dr        Las Vegas  ...
# 1       3401 S Sammy Davis Jr Dr        Las Vegas  ...
# 2            9 W Charleston Blvd        Las Vegas  ...
# 3             2664 S Highland Dr        Las Vegas  ...
# 4      2475 W Cheyenne Ave # 110  North Las Vegas  ...
# ...                          ...              ...  ...
# 12210                        NaN              NaN  ...
# 12211                        NaN              NaN  ...
# 12212                        NaN              NaN  ...
# 12213              115 Baker Ave            Baker  ...
# 12214       500 Hidden Canyon Rd            Baker  ...
#
#       instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                          237.0      NaN          NaN            NaN
# 1                            9.0      NaN          NaN            NaN
# 2                            NaN      NaN          NaN            NaN
# 3                            NaN      NaN          NaN            NaN
# 4                            6.0      NaN          NaN            NaN
# ...                          ...      ...          ...            ...
# 12210                        NaN      NaN          NaN            NaN
# 12211                        NaN      NaN          NaN            NaN
# 12212                        NaN      NaN          NaN            NaN
# 12213                        2.0      NaN          NaN            NaN
# 12214                        2.0      NaN          NaN            NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 12210           NaN         NaN
# 12211           NaN         NaN
# 12212           NaN         NaN
# 12213           NaN         NaN
# 12214           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...      unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...        claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...      unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...        claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...        claimed
# ...                                                  ...            ...
# 12210                                                NaN            NaN
# 12211                                                NaN            NaN
# 12212                                                NaN            NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...        claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...        claimed
#
#        search_keyword  search_city
# 0         Boxing Club    Las Vegas
# 1         Boxing Club    Las Vegas
# 2         Boxing Club    Las Vegas
# 3         Boxing Club    Las Vegas
# 4         Boxing Club    Las Vegas
# ...               ...          ...
# 12210     Yoga Studio    Sutcliffe
# 12211     Yoga Studio    Sutcliffe
# 12212     Yoga Studio    Sutcliffe
# 12213     Yoga Studio        Baker
# 12214     Yoga Studio        Baker
#
# [12215 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                                 First Name  \
# 0            Boxing                         Mayweather Boxing
# 1            Boxing                       City Athletic Boxing
# 2           fitness                    Johnny Toccos Ringside
# 3            Boxing                              Barrys Boxing
# 4            Boxing                     Richard Steele Boxing
# ...             ...                                        ...
# 12210       General                       Reformation Movement
# 12211       Fitness              North Peak Climbing & Fitness
# 12212          Yoga                                    Yogasix
# 12213       General  Stargazer Inn & Bristlecone General Store
# 12214       General                      Hidden Canyon Retreat
#
#                                             name         phone  \
# 0                         Mayweather Boxing Club  1.616338e+10
# 1                           City Athletic Boxing  1.702376e+10
# 2                     Johnny Toccos Ringside Gym  1.702596e+10
# 3                                  Barrys Boxing  1.702368e+10
# 4                     Richard Steele Boxing Club  1.702638e+10
# ...                                          ...           ...
# 12210                       Reformation Movement           NaN
# 12211              North Peak Climbing & Fitness           NaN
# 12212                                    Yogasix           NaN
# 12213  Stargazer Inn & Bristlecone General Store  1.775235e+10
# 12214                      Hidden Canyon Retreat  1.775235e+10
#
#                                   email     email_host  \
# 0      contact@mayweatherpromotions.com      yahoo.com
# 1          cityathleticboxing@gmail.com     google.com
# 2                                   NaN            NaN
# 3               info@barrysboxing.vegas  rackspace.com
# 4        refereerichardsteele@gmail.com     google.com
# ...                                 ...            ...
# 12210                               NaN            NaN
# 12211                               NaN            NaN
# 12212                               NaN            NaN
# 12213         stargazernevada@gmail.com     google.com
# 12214         hcrreservations@gmail.com     google.com
#
#                                     website    category  \
# 0      http://www.mayweatherpromotions.com/  Boxing Gym
# 1            http://cityathleticboxing.com/  Boxing Gym
# 2        https://www.johnnytoccoboxing.com/  Boxing Gym
# 3            http://www.barrysboxing.vegas/  Boxing Gym
# 4      https://richardsteelefoundation.org/  Boxing Gym
# ...                                     ...         ...
# 12210                                   NaN         NaN
# 12211                                   NaN         NaN
# 12212                                   NaN         NaN
# 12213       http://www.stargazernevada.com/       Hotel
# 12214   http://www.hiddencanyonretreat.com/       Motel
#
#                          address             city  ... ads_yelp ads_facebook  \
# 0                 4020 Schiff Dr        Las Vegas  ...      NaN          NaN
# 1       3401 S Sammy Davis Jr Dr        Las Vegas  ...      NaN          NaN
# 2            9 W Charleston Blvd        Las Vegas  ...      NaN          NaN
# 3             2664 S Highland Dr        Las Vegas  ...      NaN          NaN
# 4      2475 W Cheyenne Ave # 110  North Las Vegas  ...      NaN          NaN
# ...                          ...              ...  ...      ...          ...
# 12210                        NaN              NaN  ...      NaN          NaN
# 12211                        NaN              NaN  ...      NaN          NaN
# 12212                        NaN              NaN  ...      NaN          NaN
# 12213              115 Baker Ave            Baker  ...      NaN          NaN
# 12214       500 Hidden Canyon Rd            Baker  ...      NaN          NaN
#
#       ads_instagram  ads_messenger ads_adwords  \
# 0               NaN            NaN         NaN
# 1               NaN            NaN         NaN
# 2               NaN            NaN         NaN
# 3               NaN            NaN         NaN
# 4               NaN            NaN         NaN
# ...             ...            ...         ...
# 12210           NaN            NaN         NaN
# 12211           NaN            NaN         NaN
# 12212           NaN            NaN         NaN
# 12213           NaN            NaN         NaN
# 12214           NaN            NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Mayweather+...      unclaimed
# 1      https://maps.google.com/maps/place/City+Athlet...        claimed
# 2      https://maps.google.com/maps/place/Johnny+Tocc...      unclaimed
# 3      https://maps.google.com/maps/place/Barrys+Boxi...        claimed
# 4      https://maps.google.com/maps/place/Richard+Ste...        claimed
# ...                                                  ...            ...
# 12210                                                NaN            NaN
# 12211                                                NaN            NaN
# 12212                                                NaN            NaN
# 12213  https://maps.google.com/maps/place/Stargazer+I...        claimed
# 12214  https://maps.google.com/maps/place/Hidden+Cany...        claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club    Las Vegas
# 1        Boxing Club    Las Vegas
# 2        Boxing Club    Las Vegas
# 3        Boxing Club    Las Vegas
# 4        Boxing Club    Las Vegas
# ...              ...          ...
# 12210    Yoga Studio    Sutcliffe
# 12211    Yoga Studio    Sutcliffe
# 12212    Yoga Studio    Sutcliffe
# 12213    Yoga Studio        Baker
# 12214    Yoga Studio        Baker
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 12210  I saw your B2 page on Facebook. You guys have ...
# 12211  I saw your B2 page on Facebook. You guys have ...
# 12212  I saw your B2 page on Facebook. You guys have ...
# 12213  I saw B2 has a near perfect rating on Google. ...
# 12214  I saw B2 has a near perfect rating on Google. ...
#
# [12215 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('NV_combined_leads_duplicates_removed_semiclean.csv', index = False)
