# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("SD_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                   name        phone  \
# 0     PEAK Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15th Round Boxing  16059418200
# 4               GreatLIFE 10th & Mable  16052750994
# ...                                ...          ...
# 6775                            tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city region  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls     SD
# 1            Martial arts school        909 E 8th St  Sioux Falls     SD
# 2                            Gym      1216 E 57th St  Sioux Falls     SD
# 3                            Gym      5403 W 41st St  Sioux Falls     SD
# 4                            Gym      1703 E 10th St  Sioux Falls     SD
# ...                          ...                 ...          ...    ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark     SD
# 6776                       Lodge  42563 168th Street        Clark     SD
# 6777                  Car dealer      30320 Ford Ave      Tyndall     SD
# 6778                  Car dealer           406 SD-50      Tyndall     SD
# 6779      City government office      110 E 17th Ave      Tyndall     SD
#
#         zip  ... instagram_average_comments ads_yelp ads_facebook  \
# 0     57103  ...                        NaN      NaN          NaN
# 1     57103  ...                        NaN      NaN          NaN
# 2     57108  ...                          7      NaN          NaN
# 3     57106  ...                          3      NaN          NaN
# 4     57103  ...                        NaN      NaN          NaN
# ...     ...  ...                        ...      ...          ...
# 6775  57225  ...                        NaN      NaN          NaN
# 6776  57225  ...                        NaN      NaN          NaN
# 6777  57066  ...                        NaN      NaN          NaN
# 6778  57066  ...                        NaN      NaN          NaN
# 6779  57066  ...                        NaN      NaN          NaN
#
#      ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN         NaN
# 1              NaN           NaN         NaN
# 2              NaN           NaN           1
# 3              NaN           NaN         NaN
# 4              NaN           NaN         NaN
# ...            ...           ...         ...
# 6775           NaN           NaN         NaN
# 6776           NaN           NaN         NaN
# 6777           NaN           NaN         NaN
# 6778           NaN           NaN         NaN
# 6779           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club  Sioux Falls
# 1       Boxing Club  Sioux Falls
# 2       Boxing Club  Sioux Falls
# 3       Boxing Club  Sioux Falls
# 4       Boxing Club  Sioux Falls
# ...             ...          ...
# 6775    Yoga Studio        Clark
# 6776    Yoga Studio        Clark
# 6777    Yoga Studio      Tyndall
# 6778    Yoga Studio      Tyndall
# 6779    Yoga Studio      Tyndall
#
# [6780 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('SD','')
df['First Name'] = df['First Name'].str.replace('Sd','')
df['First Name'] = df['First Name'].str.replace('South Dakota','')
df
# Out:
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city region  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls     SD
# 1            Martial arts school        909 E 8th St  Sioux Falls     SD
# 2                            Gym      1216 E 57th St  Sioux Falls     SD
# 3                            Gym      5403 W 41st St  Sioux Falls     SD
# 4                            Gym      1703 E 10th St  Sioux Falls     SD
# ...                          ...                 ...          ...    ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark     SD
# 6776                       Lodge  42563 168th Street        Clark     SD
# 6777                  Car dealer      30320 Ford Ave      Tyndall     SD
# 6778                  Car dealer           406 SD-50      Tyndall     SD
# 6779      City government office      110 E 17th Ave      Tyndall     SD
#
#         zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0     57103  ...      NaN          NaN           NaN           NaN
# 1     57103  ...      NaN          NaN           NaN           NaN
# 2     57108  ...      NaN          NaN           NaN           NaN
# 3     57106  ...      NaN          NaN           NaN           NaN
# 4     57103  ...      NaN          NaN           NaN           NaN
# ...     ...  ...      ...          ...           ...           ...
# 6775  57225  ...      NaN          NaN           NaN           NaN
# 6776  57225  ...      NaN          NaN           NaN           NaN
# 6777  57066  ...      NaN          NaN           NaN           NaN
# 6778  57066  ...      NaN          NaN           NaN           NaN
# 6779  57066  ...      NaN          NaN           NaN           NaN
#
#      ads_adwords                                             g_maps  \
# 0            NaN  https://maps.google.com/maps/place/PEAK+Perfor...
# 1            NaN  https://maps.google.com/maps/place/Next+Edge+A...
# 2              1  https://maps.google.com/maps/place/9Round+East...
# 3            NaN                     https://g.page/15throundboxing
# 4            NaN  https://maps.google.com/maps/place/GreatLIFE+1...
# ...          ...                                                ...
# 6775         NaN  https://maps.google.com/maps/place/tccapr/@44....
# 6776         NaN  https://maps.google.com/maps/place/Oak+Tree+Lo...
# 6777         NaN                      https://g.page/countryfordinc
# 6778         NaN  https://maps.google.com/maps/place/Tyndall+Mot...
# 6779         NaN  https://maps.google.com/maps/place/Tyndall+Lig...
#
#      g_maps_claimed search_keyword  search_city  \
# 0           claimed    Boxing Club  Sioux Falls
# 1           claimed    Boxing Club  Sioux Falls
# 2           claimed    Boxing Club  Sioux Falls
# 3           claimed    Boxing Club  Sioux Falls
# 4           claimed    Boxing Club  Sioux Falls
# ...             ...            ...          ...
# 6775      unclaimed    Yoga Studio        Clark
# 6776        claimed    Yoga Studio        Clark
# 6777        claimed    Yoga Studio      Tyndall
# 6778        claimed    Yoga Studio      Tyndall
# 6779      unclaimed    Yoga Studio      Tyndall
#
#                             First Name
# 0     Peak Performance Training Center
# 1                           Next Edge
# 2                         9Round East
# 3                    15Th Round Boxing
# 4               Greatlife 10Th & Mable
# ...                                ...
# 6775                            Tccapr
# 6776                    Oak Tree Lodge
# 6777                 Country Ford Inc.
# 6778                Tyndall Motors Inc
# 6779       Tyndall Light & Water Plant
#
# [6780 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city region  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls     SD
# 1            Martial arts school        909 E 8th St  Sioux Falls     SD
# 2                            Gym      1216 E 57th St  Sioux Falls     SD
# 3                            Gym      5403 W 41st St  Sioux Falls     SD
# 4                            Gym      1703 E 10th St  Sioux Falls     SD
# ...                          ...                 ...          ...    ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark     SD
# 6776                       Lodge  42563 168th Street        Clark     SD
# 6777                  Car dealer      30320 Ford Ave      Tyndall     SD
# 6778                  Car dealer           406 SD-50      Tyndall     SD
# 6779      City government office      110 E 17th Ave      Tyndall     SD
#
#         zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0     57103  ...      NaN          NaN           NaN           NaN
# 1     57103  ...      NaN          NaN           NaN           NaN
# 2     57108  ...      NaN          NaN           NaN           NaN
# 3     57106  ...      NaN          NaN           NaN           NaN
# 4     57103  ...      NaN          NaN           NaN           NaN
# ...     ...  ...      ...          ...           ...           ...
# 6775  57225  ...      NaN          NaN           NaN           NaN
# 6776  57225  ...      NaN          NaN           NaN           NaN
# 6777  57066  ...      NaN          NaN           NaN           NaN
# 6778  57066  ...      NaN          NaN           NaN           NaN
# 6779  57066  ...      NaN          NaN           NaN           NaN
#
#      ads_adwords                                             g_maps  \
# 0            NaN  https://maps.google.com/maps/place/PEAK+Perfor...
# 1            NaN  https://maps.google.com/maps/place/Next+Edge+A...
# 2              1  https://maps.google.com/maps/place/9Round+East...
# 3            NaN                     https://g.page/15throundboxing
# 4            NaN  https://maps.google.com/maps/place/GreatLIFE+1...
# ...          ...                                                ...
# 6775         NaN  https://maps.google.com/maps/place/tccapr/@44....
# 6776         NaN  https://maps.google.com/maps/place/Oak+Tree+Lo...
# 6777         NaN                      https://g.page/countryfordinc
# 6778         NaN  https://maps.google.com/maps/place/Tyndall+Mot...
# 6779         NaN  https://maps.google.com/maps/place/Tyndall+Lig...
#
#      g_maps_claimed search_keyword  search_city  \
# 0           claimed    Boxing Club  Sioux Falls
# 1           claimed    Boxing Club  Sioux Falls
# 2           claimed    Boxing Club  Sioux Falls
# 3           claimed    Boxing Club  Sioux Falls
# 4           claimed    Boxing Club  Sioux Falls
# ...             ...            ...          ...
# 6775      unclaimed    Yoga Studio        Clark
# 6776        claimed    Yoga Studio        Clark
# 6777        claimed    Yoga Studio      Tyndall
# 6778        claimed    Yoga Studio      Tyndall
# 6779      unclaimed    Yoga Studio      Tyndall
#
#                             First Name
# 0     Peak Performance Training Center
# 1                           Next Edge
# 2                         9Round East
# 3                    15Th Round Boxing
# 4               Greatlife 10Th & Mable
# ...                                ...
# 6775                            Tccapr
# 6776                    Oak Tree Lodge
# 6777                 Country Ford Inc.
# 6778                Tyndall Motors Inc
# 6779       Tyndall Light & Water Plant
#
# [6780 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city region  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls     SD
# 1            Martial arts school        909 E 8th St  Sioux Falls     SD
# 2                            Gym      1216 E 57th St  Sioux Falls     SD
# 3                            Gym      5403 W 41st St  Sioux Falls     SD
# 4                            Gym      1703 E 10th St  Sioux Falls     SD
# ...                          ...                 ...          ...    ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark     SD
# 6776                       Lodge  42563 168th Street        Clark     SD
# 6777                  Car dealer      30320 Ford Ave      Tyndall     SD
# 6778                  Car dealer           406 SD-50      Tyndall     SD
# 6779      City government office      110 E 17th Ave      Tyndall     SD
#
#         zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     57103  ...          NaN           NaN           NaN         NaN
# 1     57103  ...          NaN           NaN           NaN         NaN
# 2     57108  ...          NaN           NaN           NaN           1
# 3     57106  ...          NaN           NaN           NaN         NaN
# 4     57103  ...          NaN           NaN           NaN         NaN
# ...     ...  ...          ...           ...           ...         ...
# 6775  57225  ...          NaN           NaN           NaN         NaN
# 6776  57225  ...          NaN           NaN           NaN         NaN
# 6777  57066  ...          NaN           NaN           NaN         NaN
# 6778  57066  ...          NaN           NaN           NaN         NaN
# 6779  57066  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city                        First Name  \
# 0       Boxing Club  Sioux Falls  Peak Performance Training Center
# 1       Boxing Club  Sioux Falls                        Next Edge
# 2       Boxing Club  Sioux Falls                      9Round East
# 3       Boxing Club  Sioux Falls                 15Th Round Boxing
# 4       Boxing Club  Sioux Falls            Greatlife 10Th & Mable
# ...             ...          ...                               ...
# 6775    Yoga Studio        Clark                            Tccapr
# 6776    Yoga Studio        Clark                    Oak Tree Lodge
# 6777    Yoga Studio      Tyndall                 Country Ford Inc.
# 6778    Yoga Studio      Tyndall                Tyndall Motors Inc
# 6779    Yoga Studio      Tyndall       Tyndall Light & Water Plant
#
#      Business Type
# 0              NaT
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
# ...            ...
# 6775           NaT
# 6776           NaT
# 6777           NaT
# 6778           NaT
# 6779           NaT
#
# [6780 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city region  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls     SD
# 1            Martial arts school        909 E 8th St  Sioux Falls     SD
# 2                            Gym      1216 E 57th St  Sioux Falls     SD
# 3                            Gym      5403 W 41st St  Sioux Falls     SD
# 4                            Gym      1703 E 10th St  Sioux Falls     SD
# ...                          ...                 ...          ...    ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark     SD
# 6776                       Lodge  42563 168th Street        Clark     SD
# 6777                  Car dealer      30320 Ford Ave      Tyndall     SD
# 6778                  Car dealer           406 SD-50      Tyndall     SD
# 6779      City government office      110 E 17th Ave      Tyndall     SD
#
#         zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     57103  ...          NaN           NaN           NaN         NaN
# 1     57103  ...          NaN           NaN           NaN         NaN
# 2     57108  ...          NaN           NaN           NaN           1
# 3     57106  ...          NaN           NaN           NaN         NaN
# 4     57103  ...          NaN           NaN           NaN         NaN
# ...     ...  ...          ...           ...           ...         ...
# 6775  57225  ...          NaN           NaN           NaN         NaN
# 6776  57225  ...          NaN           NaN           NaN         NaN
# 6777  57066  ...          NaN           NaN           NaN         NaN
# 6778  57066  ...          NaN           NaN           NaN         NaN
# 6779  57066  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city                        First Name  \
# 0       Boxing Club  Sioux Falls  Peak Performance Training Center
# 1       Boxing Club  Sioux Falls                        Next Edge
# 2       Boxing Club  Sioux Falls                      9Round East
# 3       Boxing Club  Sioux Falls                 15Th Round Boxing
# 4       Boxing Club  Sioux Falls            Greatlife 10Th & Mable
# ...             ...          ...                               ...
# 6775    Yoga Studio        Clark                            Tccapr
# 6776    Yoga Studio        Clark                    Oak Tree Lodge
# 6777    Yoga Studio      Tyndall                 Country Ford Inc.
# 6778    Yoga Studio      Tyndall                Tyndall Motors Inc
# 6779    Yoga Studio      Tyndall       Tyndall Light & Water Plant
#
#      Business Type
# 0          General
# 1          General
# 2          General
# 3          General
# 4          General
# ...            ...
# 6775       General
# 6776       General
# 6777       General
# 6778       General
# 6779       General
#
# [6780 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city region  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls     SD
# 1            Martial arts school        909 E 8th St  Sioux Falls     SD
# 2                            Gym      1216 E 57th St  Sioux Falls     SD
# 3                            Gym      5403 W 41st St  Sioux Falls     SD
# 4                            Gym      1703 E 10th St  Sioux Falls     SD
# ...                          ...                 ...          ...    ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark     SD
# 6776                       Lodge  42563 168th Street        Clark     SD
# 6777                  Car dealer      30320 Ford Ave      Tyndall     SD
# 6778                  Car dealer           406 SD-50      Tyndall     SD
# 6779      City government office      110 E 17th Ave      Tyndall     SD
#
#         zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     57103  ...          NaN           NaN           NaN         NaN
# 1     57103  ...          NaN           NaN           NaN         NaN
# 2     57108  ...          NaN           NaN           NaN           1
# 3     57106  ...          NaN           NaN           NaN         NaN
# 4     57103  ...          NaN           NaN           NaN         NaN
# ...     ...  ...          ...           ...           ...         ...
# 6775  57225  ...          NaN           NaN           NaN         NaN
# 6776  57225  ...          NaN           NaN           NaN         NaN
# 6777  57066  ...          NaN           NaN           NaN         NaN
# 6778  57066  ...          NaN           NaN           NaN         NaN
# 6779  57066  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city                        First Name  \
# 0       Boxing Club  Sioux Falls  Peak Performance Training Center
# 1       Boxing Club  Sioux Falls                        Next Edge
# 2       Boxing Club  Sioux Falls                      9Round East
# 3       Boxing Club  Sioux Falls                 15Th Round Boxing
# 4       Boxing Club  Sioux Falls            Greatlife 10Th & Mable
# ...             ...          ...                               ...
# 6775    Yoga Studio        Clark                            Tccapr
# 6776    Yoga Studio        Clark                    Oak Tree Lodge
# 6777    Yoga Studio      Tyndall                 Country Ford Inc.
# 6778    Yoga Studio      Tyndall                Tyndall Motors Inc
# 6779    Yoga Studio      Tyndall       Tyndall Light & Water Plant
#
#      Business Type
# 0          General
# 1          General
# 2          fitness
# 3           Boxing
# 4          General
# ...            ...
# 6775       General
# 6776       General
# 6777       General
# 6778       General
# 6779       General
#
# [6780 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#      Business Type                        First Name  \
# 0          General  Peak Performance Training Center
# 1          General                        Next Edge
# 2          fitness                      9Round East
# 3           Boxing                 15Th Round Boxing
# 4          General            Greatlife 10Th & Mable
# ...            ...                               ...
# 6775       General                            Tccapr
# 6776       General                    Oak Tree Lodge
# 6777       General                 Country Ford Inc.
# 6778       General                Tyndall Motors Inc
# 6779       General       Tyndall Light & Water Plant
#
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city  ...  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls  ...
# 1            Martial arts school        909 E 8th St  Sioux Falls  ...
# 2                            Gym      1216 E 57th St  Sioux Falls  ...
# 3                            Gym      5403 W 41st St  Sioux Falls  ...
# 4                            Gym      1703 E 10th St  Sioux Falls  ...
# ...                          ...                 ...          ...  ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark  ...
# 6776                       Lodge  42563 168th Street        Clark  ...
# 6777                  Car dealer      30320 Ford Ave      Tyndall  ...
# 6778                  Car dealer           406 SD-50      Tyndall  ...
# 6779      City government office      110 E 17th Ave      Tyndall  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                           NaN      NaN          NaN           NaN
# 1                           NaN      NaN          NaN           NaN
# 2                             7      NaN          NaN           NaN
# 3                             3      NaN          NaN           NaN
# 4                           NaN      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 6775                        NaN      NaN          NaN           NaN
# 6776                        NaN      NaN          NaN           NaN
# 6777                        NaN      NaN          NaN           NaN
# 6778                        NaN      NaN          NaN           NaN
# 6779                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN           1
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 6775           NaN         NaN
# 6776           NaN         NaN
# 6777           NaN         NaN
# 6778           NaN         NaN
# 6779           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club  Sioux Falls
# 1       Boxing Club  Sioux Falls
# 2       Boxing Club  Sioux Falls
# 3       Boxing Club  Sioux Falls
# 4       Boxing Club  Sioux Falls
# ...             ...          ...
# 6775    Yoga Studio        Clark
# 6776    Yoga Studio        Clark
# 6777    Yoga Studio      Tyndall
# 6778    Yoga Studio      Tyndall
# 6779    Yoga Studio      Tyndall
#
# [6780 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#      Business Type                        First Name  \
# 0          General  Peak Performance Training Center
# 1          General                        Next Edge
# 2          fitness                      9Round East
# 3           Boxing                 15Th Round Boxing
# 4          General            Greatlife 10Th & Mable
# ...            ...                               ...
# 6775       General                            Tccapr
# 6776       General                    Oak Tree Lodge
# 6777       General                  Country Ford Inc
# 6778       General                Tyndall Motors Inc
# 6779       General       Tyndall Light & Water Plant
#
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778                Tyndall Motors Inc  16055893441
# 6779       Tyndall Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city  ...  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls  ...
# 1            Martial arts school        909 E 8th St  Sioux Falls  ...
# 2                            Gym      1216 E 57th St  Sioux Falls  ...
# 3                            Gym      5403 W 41st St  Sioux Falls  ...
# 4                            Gym      1703 E 10th St  Sioux Falls  ...
# ...                          ...                 ...          ...  ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark  ...
# 6776                       Lodge  42563 168th Street        Clark  ...
# 6777                  Car dealer      30320 Ford Ave      Tyndall  ...
# 6778                  Car dealer           406 SD-50      Tyndall  ...
# 6779      City government office      110 E 17th Ave      Tyndall  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                           NaN      NaN          NaN           NaN
# 1                           NaN      NaN          NaN           NaN
# 2                             7      NaN          NaN           NaN
# 3                             3      NaN          NaN           NaN
# 4                           NaN      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 6775                        NaN      NaN          NaN           NaN
# 6776                        NaN      NaN          NaN           NaN
# 6777                        NaN      NaN          NaN           NaN
# 6778                        NaN      NaN          NaN           NaN
# 6779                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN           1
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 6775           NaN         NaN
# 6776           NaN         NaN
# 6777           NaN         NaN
# 6778           NaN         NaN
# 6779           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club  Sioux Falls
# 1       Boxing Club  Sioux Falls
# 2       Boxing Club  Sioux Falls
# 3       Boxing Club  Sioux Falls
# 4       Boxing Club  Sioux Falls
# ...             ...          ...
# 6775    Yoga Studio        Clark
# 6776    Yoga Studio        Clark
# 6777    Yoga Studio      Tyndall
# 6778    Yoga Studio      Tyndall
# 6779    Yoga Studio      Tyndall
#
# [6780 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#      Business Type                        First Name  \
# 0          General  Peak Performance Training Center
# 1          General                        Next Edge
# 2          fitness                      9Round East
# 3           Boxing                 15Th Round Boxing
# 4          General            Greatlife 10Th & Mable
# ...            ...                               ...
# 6775       General                            Tccapr
# 6776       General                    Oak Tree Lodge
# 6777       General                  Country Ford Inc
# 6778       General                        Motors Inc
# 6779       General               Light & Water Plant
#
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778              (Tyndall) Motors Inc  16055893441
# 6779     (Tyndall) Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city  ...  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls  ...
# 1            Martial arts school        909 E 8th St  Sioux Falls  ...
# 2                            Gym      1216 E 57th St  Sioux Falls  ...
# 3                            Gym      5403 W 41st St  Sioux Falls  ...
# 4                            Gym      1703 E 10th St  Sioux Falls  ...
# ...                          ...                 ...          ...  ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark  ...
# 6776                       Lodge  42563 168th Street        Clark  ...
# 6777                  Car dealer      30320 Ford Ave      Tyndall  ...
# 6778                  Car dealer           406 SD-50      Tyndall  ...
# 6779      City government office      110 E 17th Ave      Tyndall  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                           NaN      NaN          NaN           NaN
# 1                           NaN      NaN          NaN           NaN
# 2                             7      NaN          NaN           NaN
# 3                             3      NaN          NaN           NaN
# 4                           NaN      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 6775                        NaN      NaN          NaN           NaN
# 6776                        NaN      NaN          NaN           NaN
# 6777                        NaN      NaN          NaN           NaN
# 6778                        NaN      NaN          NaN           NaN
# 6779                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN           1
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 6775           NaN         NaN
# 6776           NaN         NaN
# 6777           NaN         NaN
# 6778           NaN         NaN
# 6779           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club  Sioux Falls
# 1       Boxing Club  Sioux Falls
# 2       Boxing Club  Sioux Falls
# 3       Boxing Club  Sioux Falls
# 4       Boxing Club  Sioux Falls
# ...             ...          ...
# 6775    Yoga Studio        Clark
# 6776    Yoga Studio        Clark
# 6777    Yoga Studio      Tyndall
# 6778    Yoga Studio      Tyndall
# 6779    Yoga Studio      Tyndall
#
# [6780 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#      Business Type                        First Name  \
# 0          General  Peak Performance Training Center
# 1          General                        Next Edge
# 2          fitness                      9Round East
# 3           Boxing                 15Th Round Boxing
# 4          General            Greatlife 10Th & Mable
# ...            ...                               ...
# 6775       General                            Tccapr
# 6776       General                    Oak Tree Lodge
# 6777       General                  Country Ford Inc
# 6778       General                        Motors Inc
# 6779       General               Light & Water Plant
#
#                                   name        phone  \
# 0     Peak Performance Training Center  16052719699
# 1                    Next Edge Academy  16053216105
# 2                      9Round East Gym  16053593522
# 3                    15Th Round Boxing  16059418200
# 4               Greatlife 10Th & Mable  16052750994
# ...                                ...          ...
# 6775                            Tccapr  16055304559
# 6776                    Oak Tree Lodge  13035204249
# 6777                 Country Ford Inc.  16055893362
# 6778              (Tyndall) Motors Inc  16055893441
# 6779     (Tyndall) Light & Water Plant  16055893481
#
#                             email     email_host  \
# 0                tigertkd@msn.com    outlook.com
# 1       nextedgeacademy@gmail.com     google.com
# 2      fernando.yemail@9round.com  rackspace.com
# 3                             NaN            NaN
# 4     franchise@joingreatlife.com    outlook.com
# ...                           ...            ...
# 6775     punisher1313@hotmail.com    outlook.com
# 6776       jeremy@oaktreefarm.com     google.com
# 6777         shawnboese@gmail.com     google.com
# 6778                          NaN            NaN
# 6779                          NaN            NaN
#
#                                                 website  \
# 0                               https://www.sfpptc.com/
# 1                       http://www.nextedgeacademy.com/
# 2                   https://www.9round.com/SiouxFallsSD
# 3                           http://15throundboxing.com/
# 4     https://joingreatlife.com/greatlife-fitness-cl...
# ...                                                 ...
# 6775                                https://tccapr.com/
# 6776                        http://www.oaktreefarm.com/
# 6777                       https://www.tyndallford.com/
# 6778                     https://www.tyndallmotors.com/
# 6779                                                NaN
#
#                         category             address         city  ...  \
# 0            Martial arts school      3216 E 10th St  Sioux Falls  ...
# 1            Martial arts school        909 E 8th St  Sioux Falls  ...
# 2                            Gym      1216 E 57th St  Sioux Falls  ...
# 3                            Gym      5403 W 41st St  Sioux Falls  ...
# 4                            Gym      1703 E 10th St  Sioux Falls  ...
# ...                          ...                 ...          ...  ...
# 6775  Physical Fitness Programme       202 1st Ave E        Clark  ...
# 6776                       Lodge  42563 168th Street        Clark  ...
# 6777                  Car dealer      30320 Ford Ave      Tyndall  ...
# 6778                  Car dealer           406 SD-50      Tyndall  ...
# 6779      City government office      110 E 17th Ave      Tyndall  ...
#
#      ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         NaN          NaN           NaN           NaN         NaN
# 1         NaN          NaN           NaN           NaN         NaN
# 2         NaN          NaN           NaN           NaN           1
# 3         NaN          NaN           NaN           NaN         NaN
# 4         NaN          NaN           NaN           NaN         NaN
# ...       ...          ...           ...           ...         ...
# 6775      NaN          NaN           NaN           NaN         NaN
# 6776      NaN          NaN           NaN           NaN         NaN
# 6777      NaN          NaN           NaN           NaN         NaN
# 6778      NaN          NaN           NaN           NaN         NaN
# 6779      NaN          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/PEAK+Perfor...        claimed
# 1     https://maps.google.com/maps/place/Next+Edge+A...        claimed
# 2     https://maps.google.com/maps/place/9Round+East...        claimed
# 3                        https://g.page/15throundboxing        claimed
# 4     https://maps.google.com/maps/place/GreatLIFE+1...        claimed
# ...                                                 ...            ...
# 6775  https://maps.google.com/maps/place/tccapr/@44....      unclaimed
# 6776  https://maps.google.com/maps/place/Oak+Tree+Lo...        claimed
# 6777                      https://g.page/countryfordinc        claimed
# 6778  https://maps.google.com/maps/place/Tyndall+Mot...        claimed
# 6779  https://maps.google.com/maps/place/Tyndall+Lig...      unclaimed
#
#      search_keyword  search_city  \
# 0       Boxing Club  Sioux Falls
# 1       Boxing Club  Sioux Falls
# 2       Boxing Club  Sioux Falls
# 3       Boxing Club  Sioux Falls
# 4       Boxing Club  Sioux Falls
# ...             ...          ...
# 6775    Yoga Studio        Clark
# 6776    Yoga Studio        Clark
# 6777    Yoga Studio      Tyndall
# 6778    Yoga Studio      Tyndall
# 6779    Yoga Studio      Tyndall
#
#                                             Icebreakers
# 0     I saw your B2 star rating on Facebook. Really ...
# 1     I saw B2 has a near perfect rating on Google. ...
# 2     I saw B2 has a near perfect rating on Google. ...
# 3     I saw B2 has a perfect rating on Google. 5 sta...
# 4     I saw B2 has a near perfect rating on Google. ...
# ...                                                 ...
# 6775  I was looking at the B2 website on my phone an...
# 6776  I saw B2 has a near perfect rating on Google. ...
# 6777  I saw B2 has a near perfect rating on Google. ...
# 6778  I was looking at the B2 website on my phone an...
# 6779  I saw your B2 page on Facebook. You guys have ...
#
# [6780 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('SD_combined_leads_duplicates_removed_semiclean.csv', index = False)
