# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("WI_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                          name        phone  \
# 0                              AMC Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             MKE Boxing Club  14145016367
# 3                              Roufusport MMA  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    YWCA  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga and Meditation - CLOSED  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#       region    zip  ... instagram_average_comments ads_yelp ads_facebook  \
# 0         WI  53207  ...                        NaN      NaN          NaN
# 1         WI  53215  ...                        NaN      NaN          NaN
# 2         WI  53208  ...                        NaN      NaN          NaN
# 3         WI  53213  ...                          1      NaN          NaN
# 4         WI  53219  ...                        NaN      NaN          NaN
# ...      ...    ...  ...                        ...      ...          ...
# 16270     WI  53546  ...                        NaN      NaN          NaN
# 16271     IL  60050  ...                        NaN      NaN          NaN
# 16272     WI  53558  ...                        NaN      NaN          NaN
# 16273     WI  53558  ...                        NaN      NaN          NaN
# 16274     WI  53147  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 16270           NaN           NaN         NaN
# 16271           NaN           NaN         NaN
# 16272           NaN           NaN         NaN
# 16273           NaN           NaN         NaN
# 16274           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword search_city
# 0        Boxing Club   Milwaukee
# 1        Boxing Club   Milwaukee
# 2        Boxing Club   Milwaukee
# 3        Boxing Club   Milwaukee
# 4        Boxing Club   Milwaukee
# ...              ...         ...
# 16270    Yoga Studio  Evansville
# 16271    Yoga Studio  Evansville
# 16272    Yoga Studio  Evansville
# 16273    Yoga Studio  Evansville
# 16274    Yoga Studio  Evansville
#
# [16275 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('WI','')
df['First Name'] = df['First Name'].str.replace('Wi','')
df['First Name'] = df['First Name'].str.replace('Wisconsin','')
df
# Out:
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         WI  53207  ...      NaN          NaN           NaN           NaN
# 1         WI  53215  ...      NaN          NaN           NaN           NaN
# 2         WI  53208  ...      NaN          NaN           NaN           NaN
# 3         WI  53213  ...      NaN          NaN           NaN           NaN
# 4         WI  53219  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 16270     WI  53546  ...      NaN          NaN           NaN           NaN
# 16271     IL  60050  ...      NaN          NaN           NaN           NaN
# 16272     WI  53558  ...      NaN          NaN           NaN           NaN
# 16273     WI  53558  ...      NaN          NaN           NaN           NaN
# 16274     WI  53147  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/AMC+Boxing+...
# 1             NaN  https://maps.google.com/maps/place/Del+Porter+...
# 2             NaN                      https://g.page/sixpointboxing
# 3             NaN  https://maps.google.com/maps/place/Roufusport+...
# 4             NaN  https://maps.google.com/maps/place/Six+Points+...
# ...           ...                                                ...
# 16270         NaN  https://maps.google.com/maps/place/YWCA/@42.65...
# 16271         NaN  https://maps.google.com/maps/place/Bliss+Yoga/...
# 16272         NaN  https://maps.google.com/maps/place/Free+Soul+Y...
# 16273         NaN  https://maps.google.com/maps/place/Side+Pony+Y...
# 16274         NaN                          https://g.page/PurityYoga
#
#       g_maps_claimed search_keyword search_city  \
# 0            claimed    Boxing Club   Milwaukee
# 1            claimed    Boxing Club   Milwaukee
# 2            claimed    Boxing Club   Milwaukee
# 3            claimed    Boxing Club   Milwaukee
# 4          unclaimed    Boxing Club   Milwaukee
# ...              ...            ...         ...
# 16270      unclaimed    Yoga Studio  Evansville
# 16271        claimed    Yoga Studio  Evansville
# 16272      unclaimed    Yoga Studio  Evansville
# 16273      unclaimed    Yoga Studio  Evansville
# 16274        claimed    Yoga Studio  Evansville
#
#                                    First Name
# 0                                 Amc Boxing
# 1                         Del Porter Pavilion
# 2                                 Mke Boxing
# 3                              Roufusport Mma
# 4                          Six Points Boxing
# ...                                       ...
# 16270                                    Ywca
# 16271                              Bliss Yoga
# 16272  Free Soul Yoga And Meditation - Closed
# 16273                          Side Pony Yogi
# 16274   Purity Yoga-Healing & Wellness Center
#
# [16275 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         WI  53207  ...      NaN          NaN           NaN           NaN
# 1         WI  53215  ...      NaN          NaN           NaN           NaN
# 2         WI  53208  ...      NaN          NaN           NaN           NaN
# 3         WI  53213  ...      NaN          NaN           NaN           NaN
# 4         WI  53219  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 16270     WI  53546  ...      NaN          NaN           NaN           NaN
# 16271     IL  60050  ...      NaN          NaN           NaN           NaN
# 16272     WI  53558  ...      NaN          NaN           NaN           NaN
# 16273     WI  53558  ...      NaN          NaN           NaN           NaN
# 16274     WI  53147  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/AMC+Boxing+...
# 1             NaN  https://maps.google.com/maps/place/Del+Porter+...
# 2             NaN                      https://g.page/sixpointboxing
# 3             NaN  https://maps.google.com/maps/place/Roufusport+...
# 4             NaN  https://maps.google.com/maps/place/Six+Points+...
# ...           ...                                                ...
# 16270         NaN  https://maps.google.com/maps/place/YWCA/@42.65...
# 16271         NaN  https://maps.google.com/maps/place/Bliss+Yoga/...
# 16272         NaN  https://maps.google.com/maps/place/Free+Soul+Y...
# 16273         NaN  https://maps.google.com/maps/place/Side+Pony+Y...
# 16274         NaN                          https://g.page/PurityYoga
#
#       g_maps_claimed search_keyword search_city  \
# 0            claimed    Boxing Club   Milwaukee
# 1            claimed    Boxing Club   Milwaukee
# 2            claimed    Boxing Club   Milwaukee
# 3            claimed    Boxing Club   Milwaukee
# 4          unclaimed    Boxing Club   Milwaukee
# ...              ...            ...         ...
# 16270      unclaimed    Yoga Studio  Evansville
# 16271        claimed    Yoga Studio  Evansville
# 16272      unclaimed    Yoga Studio  Evansville
# 16273      unclaimed    Yoga Studio  Evansville
# 16274        claimed    Yoga Studio  Evansville
#
#                                    First Name
# 0                                 Amc Boxing
# 1                         Del Porter Pavilion
# 2                                 Mke Boxing
# 3                              Roufusport Mma
# 4                          Six Points Boxing
# ...                                       ...
# 16270                                    Ywca
# 16271                              Bliss Yoga
# 16272  Free Soul Yoga And Meditation - Closed
# 16273                          Side Pony Yogi
# 16274   Purity Yoga-Healing & Wellness Center
#
# [16275 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         WI  53207  ...          NaN           NaN           NaN         NaN
# 1         WI  53215  ...          NaN           NaN           NaN         NaN
# 2         WI  53208  ...          NaN           NaN           NaN         NaN
# 3         WI  53213  ...          NaN           NaN           NaN         NaN
# 4         WI  53219  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 16270     WI  53546  ...          NaN           NaN           NaN         NaN
# 16271     IL  60050  ...          NaN           NaN           NaN         NaN
# 16272     WI  53558  ...          NaN           NaN           NaN         NaN
# 16273     WI  53558  ...          NaN           NaN           NaN         NaN
# 16274     WI  53147  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword search_city                              First Name  \
# 0        Boxing Club   Milwaukee                             Amc Boxing
# 1        Boxing Club   Milwaukee                     Del Porter Pavilion
# 2        Boxing Club   Milwaukee                             Mke Boxing
# 3        Boxing Club   Milwaukee                          Roufusport Mma
# 4        Boxing Club   Milwaukee                      Six Points Boxing
# ...              ...         ...                                     ...
# 16270    Yoga Studio  Evansville                                    Ywca
# 16271    Yoga Studio  Evansville                              Bliss Yoga
# 16272    Yoga Studio  Evansville  Free Soul Yoga And Meditation - Closed
# 16273    Yoga Studio  Evansville                          Side Pony Yogi
# 16274    Yoga Studio  Evansville   Purity Yoga-Healing & Wellness Center
#
#       Business Type
# 0               NaT
# 1               NaT
# 2               NaT
# 3               NaT
# 4               NaT
# ...             ...
# 16270           NaT
# 16271           NaT
# 16272           NaT
# 16273           NaT
# 16274           NaT
#
# [16275 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         WI  53207  ...          NaN           NaN           NaN         NaN
# 1         WI  53215  ...          NaN           NaN           NaN         NaN
# 2         WI  53208  ...          NaN           NaN           NaN         NaN
# 3         WI  53213  ...          NaN           NaN           NaN         NaN
# 4         WI  53219  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 16270     WI  53546  ...          NaN           NaN           NaN         NaN
# 16271     IL  60050  ...          NaN           NaN           NaN         NaN
# 16272     WI  53558  ...          NaN           NaN           NaN         NaN
# 16273     WI  53558  ...          NaN           NaN           NaN         NaN
# 16274     WI  53147  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword search_city                              First Name  \
# 0        Boxing Club   Milwaukee                             Amc Boxing
# 1        Boxing Club   Milwaukee                     Del Porter Pavilion
# 2        Boxing Club   Milwaukee                             Mke Boxing
# 3        Boxing Club   Milwaukee                          Roufusport Mma
# 4        Boxing Club   Milwaukee                      Six Points Boxing
# ...              ...         ...                                     ...
# 16270    Yoga Studio  Evansville                                    Ywca
# 16271    Yoga Studio  Evansville                              Bliss Yoga
# 16272    Yoga Studio  Evansville  Free Soul Yoga And Meditation - Closed
# 16273    Yoga Studio  Evansville                          Side Pony Yogi
# 16274    Yoga Studio  Evansville   Purity Yoga-Healing & Wellness Center
#
#       Business Type
# 0           General
# 1           General
# 2           General
# 3           General
# 4           General
# ...             ...
# 16270       General
# 16271       General
# 16272       General
# 16273       General
# 16274       General
#
# [16275 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         WI  53207  ...          NaN           NaN           NaN         NaN
# 1         WI  53215  ...          NaN           NaN           NaN         NaN
# 2         WI  53208  ...          NaN           NaN           NaN         NaN
# 3         WI  53213  ...          NaN           NaN           NaN         NaN
# 4         WI  53219  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 16270     WI  53546  ...          NaN           NaN           NaN         NaN
# 16271     IL  60050  ...          NaN           NaN           NaN         NaN
# 16272     WI  53558  ...          NaN           NaN           NaN         NaN
# 16273     WI  53558  ...          NaN           NaN           NaN         NaN
# 16274     WI  53147  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword search_city                              First Name  \
# 0        Boxing Club   Milwaukee                             Amc Boxing
# 1        Boxing Club   Milwaukee                     Del Porter Pavilion
# 2        Boxing Club   Milwaukee                             Mke Boxing
# 3        Boxing Club   Milwaukee                          Roufusport Mma
# 4        Boxing Club   Milwaukee                      Six Points Boxing
# ...              ...         ...                                     ...
# 16270    Yoga Studio  Evansville                                    Ywca
# 16271    Yoga Studio  Evansville                              Bliss Yoga
# 16272    Yoga Studio  Evansville  Free Soul Yoga And Meditation - Closed
# 16273    Yoga Studio  Evansville                          Side Pony Yogi
# 16274    Yoga Studio  Evansville   Purity Yoga-Healing & Wellness Center
#
#       Business Type
# 0            Boxing
# 1           General
# 2            Boxing
# 3           General
# 4            Boxing
# ...             ...
# 16270       General
# 16271          Yoga
# 16272          Yoga
# 16273       General
# 16274          Yoga
#
# [16275 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                              First Name  \
# 0            Boxing                             Amc Boxing
# 1           General                     Del Porter Pavilion
# 2            Boxing                             Mke Boxing
# 3           General                          Roufusport Mma
# 4            Boxing                      Six Points Boxing
# ...             ...                                     ...
# 16270       General                                    Ywca
# 16271          Yoga                              Bliss Yoga
# 16272          Yoga  Free Soul Yoga And Meditation - Closed
# 16273       General                          Side Pony Yogi
# 16274          Yoga   Purity Yoga-Healing & Wellness Center
#
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                        NaN      NaN          NaN           NaN
# 1      ...                        NaN      NaN          NaN           NaN
# 2      ...                        NaN      NaN          NaN           NaN
# 3      ...                          1      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 16270  ...                        NaN      NaN          NaN           NaN
# 16271  ...                        NaN      NaN          NaN           NaN
# 16272  ...                        NaN      NaN          NaN           NaN
# 16273  ...                        NaN      NaN          NaN           NaN
# 16274  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 16270           NaN         NaN
# 16271           NaN         NaN
# 16272           NaN         NaN
# 16273           NaN         NaN
# 16274           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword search_city
# 0        Boxing Club   Milwaukee
# 1        Boxing Club   Milwaukee
# 2        Boxing Club   Milwaukee
# 3        Boxing Club   Milwaukee
# 4        Boxing Club   Milwaukee
# ...              ...         ...
# 16270    Yoga Studio  Evansville
# 16271    Yoga Studio  Evansville
# 16272    Yoga Studio  Evansville
# 16273    Yoga Studio  Evansville
# 16274    Yoga Studio  Evansville
#
# [16275 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                             First Name  \
# 0            Boxing                            Amc Boxing
# 1           General                    Del Porter Pavilion
# 2            Boxing                            Mke Boxing
# 3           General                         Roufusport Mma
# 4            Boxing                     Six Points Boxing
# ...             ...                                    ...
# 16270       General                                   Ywca
# 16271          Yoga                             Bliss Yoga
# 16272          Yoga  Free Soul Yoga And Meditation  Closed
# 16273       General                         Side Pony Yogi
# 16274          Yoga   Purity YogaHealing & Wellness Center
#
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                        NaN      NaN          NaN           NaN
# 1      ...                        NaN      NaN          NaN           NaN
# 2      ...                        NaN      NaN          NaN           NaN
# 3      ...                          1      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 16270  ...                        NaN      NaN          NaN           NaN
# 16271  ...                        NaN      NaN          NaN           NaN
# 16272  ...                        NaN      NaN          NaN           NaN
# 16273  ...                        NaN      NaN          NaN           NaN
# 16274  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 16270           NaN         NaN
# 16271           NaN         NaN
# 16272           NaN         NaN
# 16273           NaN         NaN
# 16274           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword search_city
# 0        Boxing Club   Milwaukee
# 1        Boxing Club   Milwaukee
# 2        Boxing Club   Milwaukee
# 3        Boxing Club   Milwaukee
# 4        Boxing Club   Milwaukee
# ...              ...         ...
# 16270    Yoga Studio  Evansville
# 16271    Yoga Studio  Evansville
# 16272    Yoga Studio  Evansville
# 16273    Yoga Studio  Evansville
# 16274    Yoga Studio  Evansville
#
# [16275 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                             First Name  \
# 0            Boxing                            Amc Boxing
# 1           General                    Del Porter Pavilion
# 2            Boxing                            Mke Boxing
# 3           General                         Roufusport Mma
# 4            Boxing                     Six Points Boxing
# ...             ...                                    ...
# 16270       General                                   Ywca
# 16271          Yoga                             Bliss Yoga
# 16272          Yoga  Free Soul Yoga And Meditation  Closed
# 16273       General                         Side Pony Yogi
# 16274          Yoga   Purity YogaHealing & Wellness Center
#
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                        NaN      NaN          NaN           NaN
# 1      ...                        NaN      NaN          NaN           NaN
# 2      ...                        NaN      NaN          NaN           NaN
# 3      ...                          1      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 16270  ...                        NaN      NaN          NaN           NaN
# 16271  ...                        NaN      NaN          NaN           NaN
# 16272  ...                        NaN      NaN          NaN           NaN
# 16273  ...                        NaN      NaN          NaN           NaN
# 16274  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 16270           NaN         NaN
# 16271           NaN         NaN
# 16272           NaN         NaN
# 16273           NaN         NaN
# 16274           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword search_city
# 0        Boxing Club   Milwaukee
# 1        Boxing Club   Milwaukee
# 2        Boxing Club   Milwaukee
# 3        Boxing Club   Milwaukee
# 4        Boxing Club   Milwaukee
# ...              ...         ...
# 16270    Yoga Studio  Evansville
# 16271    Yoga Studio  Evansville
# 16272    Yoga Studio  Evansville
# 16273    Yoga Studio  Evansville
# 16274    Yoga Studio  Evansville
#
# [16275 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                             First Name  \
# 0            Boxing                            Amc Boxing
# 1           General                    Del Porter Pavilion
# 2            Boxing                            Mke Boxing
# 3           General                         Roufusport Mma
# 4            Boxing                     Six Points Boxing
# ...             ...                                    ...
# 16270       General                                   Ywca
# 16271          Yoga                             Bliss Yoga
# 16272          Yoga  Free Soul Yoga And Meditation  Closed
# 16273       General                         Side Pony Yogi
# 16274          Yoga   Purity YogaHealing & Wellness Center
#
#                                          name        phone  \
# 0                              Amc Boxing Gym  14143771506
# 1                         Del Porter Pavilion  14143758563
# 2                             Mke Boxing Club  14145016367
# 3                              Roufusport Mma  14144535425
# 4                      Six Points Boxing Club  14145016367
# ...                                       ...          ...
# 16270                                    Ywca  16087525445
# 16271                              Bliss Yoga  17735057305
# 16272  Free Soul Yoga And Meditation - Closed  16082280337
# 16273                          Side Pony Yogi  16085762619
# 16274   Purity Yoga-Healing & Wellness Center  12625015703
#
#                                email   email_host  \
# 0       amcboxingmilwaukee@gmail.com   google.com
# 1               abcinc1960@gmail.com   google.com
# 2                 kyle@awakenlmt.com   google.com
# 3            training@roufusport.com  godaddy.com
# 4                                NaN          NaN
# ...                              ...          ...
# 16270        msimpson@ywcarockco.com  outlook.com
# 16271           blissyoga1@yahoo.com    yahoo.com
# 16272                            NaN          NaN
# 16273                            NaN          NaN
# 16274  purityoga@sarahserviceslg.com   google.com
#
#                                                  website  \
# 0                    https://amcboxinggym.business.site/
# 1                     http://aceboxingclub.org/index.php
# 2                            http://www.forwrd.training/
# 3                                 http://roufusport.com/
# 4                         http://www.sixpointboxing.com/
# ...                                                  ...
# 16270  https://www.ywcarockcounty.org/homepage/get-in...
# 16271                   http://www.blissyogamchenry.com/
# 16272                                                NaN
# 16273                                                NaN
# 16274                                                NaN
#
#                       category                       address         city  \
# 0                   Boxing Gym  2612 S Greeley St Suite #124    Milwaukee
# 1                   Boxing Gym                2160 S 10th St    Milwaukee
# 2                   Boxing Gym            2210 W Clybourn St    Milwaukee
# 3          Martial arts school                       N th St    Milwaukee
# 4                   Boxing Gym                2050 S 55th St   West Allis
# ...                        ...                           ...          ...
# 16270  Non-profit organisation          1735 S Washington St   Janesville
# 16271                     Yoga                  3931 Main St      McHenry
# 16272              Yoga studio           4705 Dale Curtin Dr    McFarland
# 16273              Yoga studio                4358 Jordan Dr    McFarland
# 16274          Yoga instructor        N3219 Co Trunk H Ste C  Lake Geneva
#
#        ... ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0      ...      NaN          NaN           NaN           NaN         NaN
# 1      ...      NaN          NaN           NaN           NaN         NaN
# 2      ...      NaN          NaN           NaN           NaN         NaN
# 3      ...      NaN          NaN           NaN           NaN         NaN
# 4      ...      NaN          NaN           NaN           NaN         NaN
# ...    ...      ...          ...           ...           ...         ...
# 16270  ...      NaN          NaN           NaN           NaN         NaN
# 16271  ...      NaN          NaN           NaN           NaN         NaN
# 16272  ...      NaN          NaN           NaN           NaN         NaN
# 16273  ...      NaN          NaN           NaN           NaN         NaN
# 16274  ...      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/AMC+Boxing+...        claimed
# 1      https://maps.google.com/maps/place/Del+Porter+...        claimed
# 2                          https://g.page/sixpointboxing        claimed
# 3      https://maps.google.com/maps/place/Roufusport+...        claimed
# 4      https://maps.google.com/maps/place/Six+Points+...      unclaimed
# ...                                                  ...            ...
# 16270  https://maps.google.com/maps/place/YWCA/@42.65...      unclaimed
# 16271  https://maps.google.com/maps/place/Bliss+Yoga/...        claimed
# 16272  https://maps.google.com/maps/place/Free+Soul+Y...      unclaimed
# 16273  https://maps.google.com/maps/place/Side+Pony+Y...      unclaimed
# 16274                          https://g.page/PurityYoga        claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club    Milwaukee
# 1        Boxing Club    Milwaukee
# 2        Boxing Club    Milwaukee
# 3        Boxing Club    Milwaukee
# 4        Boxing Club    Milwaukee
# ...              ...          ...
# 16270    Yoga Studio   Evansville
# 16271    Yoga Studio   Evansville
# 16272    Yoga Studio   Evansville
# 16273    Yoga Studio   Evansville
# 16274    Yoga Studio   Evansville
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a perfect rating on Google. 5 sta...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw your B2 star rating on Facebook. Really ...
# ...                                                  ...
# 16270  I saw B2 has a near perfect rating on Google. ...
# 16271  I saw B2 has a near perfect rating on Google. ...
# 16272  I saw your B2 page on Facebook. You guys have ...
# 16273  I saw your B2 page on Facebook. You guys have ...
# 16274  I saw B2 has a perfect rating on Google. 5 sta...
#
# [16275 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('WI_combined_leads_duplicates_removed_semiclean.csv', index = False)
