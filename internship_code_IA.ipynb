# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("IA_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      TITLE Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home of Des Moines M...  15156614782
# 4                                          RoundKick Gym  15152765254
# ...                                                  ...          ...
# 11623                        McCreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#       region    zip  ... instagram_average_comments ads_yelp ads_facebook  \
# 0         IA  50317  ...                        NaN      NaN          NaN
# 1         IA  50266  ...                          3      NaN          NaN
# 2         IA  50309  ...                        NaN      NaN          NaN
# 3         IA  50327  ...                        NaN      NaN          NaN
# 4         IA  50322  ...                        NaN      NaN          NaN
# ...      ...    ...  ...                        ...      ...          ...
# 11623     IA  50220  ...                        NaN      NaN          NaN
# 11624     IA  50312  ...                        NaN      NaN          NaN
# 11625     IA  51537  ...                        NaN      NaN          NaN
# 11626     IA  51537  ...                          1      NaN          NaN
# 11627     IA  51537  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 11623           NaN           NaN         NaN
# 11624           NaN           NaN         NaN
# 11625           NaN           NaN         NaN
# 11626           NaN           NaN         NaN
# 11627           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
# [11628 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('IA','')
df['First Name'] = df['First Name'].str.replace('Ia','')
df['First Name'] = df['First Name'].str.replace('Iowa','')
df
# Out:
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      Title Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of Des Moines M...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         IA  50317  ...      NaN          NaN           NaN           NaN
# 1         IA  50266  ...      NaN          NaN           NaN           NaN
# 2         IA  50309  ...      NaN          NaN           NaN           NaN
# 3         IA  50327  ...      NaN          NaN           NaN           NaN
# 4         IA  50322  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 11623     IA  50220  ...      NaN          NaN           NaN           NaN
# 11624     IA  50312  ...      NaN          NaN           NaN           NaN
# 11625     IA  51537  ...      NaN          NaN           NaN           NaN
# 11626     IA  51537  ...      NaN          NaN           NaN           NaN
# 11627     IA  51537  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN                          https://g.page/sedmboxing
# 1               1        https://g.page/title-boxing-west-des-moines
# 2             NaN  https://maps.google.com/maps/place/Talon+Muay+...
# 3             NaN  https://maps.google.com/maps/place/Porcellis+T...
# 4             NaN  https://maps.google.com/maps/place/RoundKick+G...
# ...           ...                                                ...
# 11623         NaN  https://maps.google.com/maps/place/McCreary+Co...
# 11624         NaN  https://maps.google.com/maps/place/Roots+Prena...
# 11625         NaN               https://g.page/StillWaterYoga-Harlan
# 11626         NaN               https://g.page/StillWaterYoga-Harlan
# 11627         NaN                                                NaN
#
#       g_maps_claimed search_keyword      search_city  \
# 0            claimed    Boxing Club       Des Moines
# 1            claimed    Boxing Club       Des Moines
# 2            claimed    Boxing Club       Des Moines
# 3            claimed    Boxing Club       Des Moines
# 4            claimed    Boxing Club       Des Moines
# ...              ...            ...              ...
# 11623      unclaimed    Yoga Studio            Perry
# 11624        claimed    Yoga Studio  Windsor Heights
# 11625        claimed    Yoga Studio           Harlan
# 11626        claimed    Yoga Studio           Harlan
# 11627            NaN    Yoga Studio           Harlan
#
#                                               First Name
# 0                           Southeast Des Moines Boxing
# 1                          Title Boxing  West Des Moines
# 2                                        Talon Muay Thai
# 3      Porcellis Training Center Home Of Des Moines M...
# 4                                             Roundkick
# ...                                                  ...
# 11623                        Mccreary Community Building
# 11624                                Roots Prenatal Yoga
# 11625                                   Still Water Yoga
# 11626                                   Still Water Yoga
# 11627                                           Studio H
#
# [11628 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      Title Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of Des Moines M...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         IA  50317  ...      NaN          NaN           NaN           NaN
# 1         IA  50266  ...      NaN          NaN           NaN           NaN
# 2         IA  50309  ...      NaN          NaN           NaN           NaN
# 3         IA  50327  ...      NaN          NaN           NaN           NaN
# 4         IA  50322  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 11623     IA  50220  ...      NaN          NaN           NaN           NaN
# 11624     IA  50312  ...      NaN          NaN           NaN           NaN
# 11625     IA  51537  ...      NaN          NaN           NaN           NaN
# 11626     IA  51537  ...      NaN          NaN           NaN           NaN
# 11627     IA  51537  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN                          https://g.page/sedmboxing
# 1               1        https://g.page/title-boxing-west-des-moines
# 2             NaN  https://maps.google.com/maps/place/Talon+Muay+...
# 3             NaN  https://maps.google.com/maps/place/Porcellis+T...
# 4             NaN  https://maps.google.com/maps/place/RoundKick+G...
# ...           ...                                                ...
# 11623         NaN  https://maps.google.com/maps/place/McCreary+Co...
# 11624         NaN  https://maps.google.com/maps/place/Roots+Prena...
# 11625         NaN               https://g.page/StillWaterYoga-Harlan
# 11626         NaN               https://g.page/StillWaterYoga-Harlan
# 11627         NaN                                                NaN
#
#       g_maps_claimed search_keyword      search_city  \
# 0            claimed    Boxing Club       Des Moines
# 1            claimed    Boxing Club       Des Moines
# 2            claimed    Boxing Club       Des Moines
# 3            claimed    Boxing Club       Des Moines
# 4            claimed    Boxing Club       Des Moines
# ...              ...            ...              ...
# 11623      unclaimed    Yoga Studio            Perry
# 11624        claimed    Yoga Studio  Windsor Heights
# 11625        claimed    Yoga Studio           Harlan
# 11626        claimed    Yoga Studio           Harlan
# 11627            NaN    Yoga Studio           Harlan
#
#                                               First Name
# 0                           Southeast Des Moines Boxing
# 1                          Title Boxing  West Des Moines
# 2                                        Talon Muay Thai
# 3      Porcellis Training Center Home Of Des Moines M...
# 4                                             Roundkick
# ...                                                  ...
# 11623                        Mccreary Community Building
# 11624                                Roots Prenatal Yoga
# 11625                                   Still Water Yoga
# 11626                                   Still Water Yoga
# 11627                                           Studio H
#
# [11628 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      Title Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of Des Moines M...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         IA  50317  ...          NaN           NaN           NaN         NaN
# 1         IA  50266  ...          NaN           NaN           NaN           1
# 2         IA  50309  ...          NaN           NaN           NaN         NaN
# 3         IA  50327  ...          NaN           NaN           NaN         NaN
# 4         IA  50322  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 11623     IA  50220  ...          NaN           NaN           NaN         NaN
# 11624     IA  50312  ...          NaN           NaN           NaN         NaN
# 11625     IA  51537  ...          NaN           NaN           NaN         NaN
# 11626     IA  51537  ...          NaN           NaN           NaN         NaN
# 11627     IA  51537  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city  \
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
#                                               First Name Business Type
# 0                           Southeast Des Moines Boxing            NaT
# 1                          Title Boxing  West Des Moines           NaT
# 2                                        Talon Muay Thai           NaT
# 3      Porcellis Training Center Home Of Des Moines M...           NaT
# 4                                             Roundkick            NaT
# ...                                                  ...           ...
# 11623                        Mccreary Community Building           NaT
# 11624                                Roots Prenatal Yoga           NaT
# 11625                                   Still Water Yoga           NaT
# 11626                                   Still Water Yoga           NaT
# 11627                                           Studio H           NaT
#
# [11628 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      Title Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of Des Moines M...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         IA  50317  ...          NaN           NaN           NaN         NaN
# 1         IA  50266  ...          NaN           NaN           NaN           1
# 2         IA  50309  ...          NaN           NaN           NaN         NaN
# 3         IA  50327  ...          NaN           NaN           NaN         NaN
# 4         IA  50322  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 11623     IA  50220  ...          NaN           NaN           NaN         NaN
# 11624     IA  50312  ...          NaN           NaN           NaN         NaN
# 11625     IA  51537  ...          NaN           NaN           NaN         NaN
# 11626     IA  51537  ...          NaN           NaN           NaN         NaN
# 11627     IA  51537  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city  \
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
#                                               First Name Business Type
# 0                           Southeast Des Moines Boxing        General
# 1                          Title Boxing  West Des Moines       General
# 2                                        Talon Muay Thai       General
# 3      Porcellis Training Center Home Of Des Moines M...       General
# 4                                             Roundkick        General
# ...                                                  ...           ...
# 11623                        Mccreary Community Building       General
# 11624                                Roots Prenatal Yoga       General
# 11625                                   Still Water Yoga       General
# 11626                                   Still Water Yoga       General
# 11627                                           Studio H       General
#
# [11628 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      Title Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of Des Moines M...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         IA  50317  ...          NaN           NaN           NaN         NaN
# 1         IA  50266  ...          NaN           NaN           NaN           1
# 2         IA  50309  ...          NaN           NaN           NaN         NaN
# 3         IA  50327  ...          NaN           NaN           NaN         NaN
# 4         IA  50322  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 11623     IA  50220  ...          NaN           NaN           NaN         NaN
# 11624     IA  50312  ...          NaN           NaN           NaN         NaN
# 11625     IA  51537  ...          NaN           NaN           NaN         NaN
# 11626     IA  51537  ...          NaN           NaN           NaN         NaN
# 11627     IA  51537  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city  \
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
#                                               First Name Business Type
# 0                           Southeast Des Moines Boxing         Boxing
# 1                          Title Boxing  West Des Moines        Boxing
# 2                                        Talon Muay Thai     Muay Thai
# 3      Porcellis Training Center Home Of Des Moines M...     Wrestling
# 4                                             Roundkick        fitness
# ...                                                  ...           ...
# 11623                        Mccreary Community Building       General
# 11624                                Roots Prenatal Yoga          Yoga
# 11625                                   Still Water Yoga          Yoga
# 11626                                   Still Water Yoga          Yoga
# 11627                                           Studio H       General
#
# [11628 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                       Southeast Des Moines Boxing
# 1            Boxing                      Title Boxing  West Des Moines
# 2         Muay Thai                                    Talon Muay Thai
# 3         Wrestling  Porcellis Training Center Home Of Des Moines M...
# 4           fitness                                         Roundkick
# ...             ...                                                ...
# 11623       General                        Mccreary Community Building
# 11624          Yoga                                Roots Prenatal Yoga
# 11625          Yoga                                   Still Water Yoga
# 11626          Yoga                                   Still Water Yoga
# 11627       General                                           Studio H
#
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      Title Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of Des Moines M...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                        NaN      NaN          NaN           NaN
# 1      ...                          3      NaN          NaN           NaN
# 2      ...                        NaN      NaN          NaN           NaN
# 3      ...                        NaN      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 11623  ...                        NaN      NaN          NaN           NaN
# 11624  ...                        NaN      NaN          NaN           NaN
# 11625  ...                        NaN      NaN          NaN           NaN
# 11626  ...                          1      NaN          NaN           NaN
# 11627  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 11623           NaN         NaN
# 11624           NaN         NaN
# 11625           NaN         NaN
# 11626           NaN         NaN
# 11627           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
# [11628 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                       Southeast Des Moines Boxing
# 1            Boxing                      Title Boxing  West Des Moines
# 2         Muay Thai                                    Talon Muay Thai
# 3         Wrestling  Porcellis Training Center Home Of Des Moines M...
# 4           fitness                                         Roundkick
# ...             ...                                                ...
# 11623       General                        Mccreary Community Building
# 11624          Yoga                                Roots Prenatal Yoga
# 11625          Yoga                                   Still Water Yoga
# 11626          Yoga                                   Still Water Yoga
# 11627       General                                           Studio H
#
#                                                     name        phone  \
# 0                       Southeast Des Moines Boxing Club  15156894496
# 1                      Title Boxing Club West Des Moines  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of Des Moines M...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                        NaN      NaN          NaN           NaN
# 1      ...                          3      NaN          NaN           NaN
# 2      ...                        NaN      NaN          NaN           NaN
# 3      ...                        NaN      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 11623  ...                        NaN      NaN          NaN           NaN
# 11624  ...                        NaN      NaN          NaN           NaN
# 11625  ...                        NaN      NaN          NaN           NaN
# 11626  ...                          1      NaN          NaN           NaN
# 11627  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 11623           NaN         NaN
# 11624           NaN         NaN
# 11625           NaN         NaN
# 11626           NaN         NaN
# 11627           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
# [11628 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                                 Southeast  Boxing
# 1            Boxing                                Title Boxing  West
# 2         Muay Thai                                    Talon Muay Thai
# 3         Wrestling  Porcellis Training Center Home Of  Mma  & Team...
# 4           fitness                                         Roundkick
# ...             ...                                                ...
# 11623       General                        Mccreary Community Building
# 11624          Yoga                                Roots Prenatal Yoga
# 11625          Yoga                                   Still Water Yoga
# 11626          Yoga                                   Still Water Yoga
# 11627       General                                           Studio H
#
#                                                     name        phone  \
# 0                     Southeast (Des Moines) Boxing Club  15156894496
# 1                    Title Boxing Club West (Des Moines)  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of (Des Moines)...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                        NaN      NaN          NaN           NaN
# 1      ...                          3      NaN          NaN           NaN
# 2      ...                        NaN      NaN          NaN           NaN
# 3      ...                        NaN      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 11623  ...                        NaN      NaN          NaN           NaN
# 11624  ...                        NaN      NaN          NaN           NaN
# 11625  ...                        NaN      NaN          NaN           NaN
# 11626  ...                          1      NaN          NaN           NaN
# 11627  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 11623           NaN         NaN
# 11624           NaN         NaN
# 11625           NaN         NaN
# 11626           NaN         NaN
# 11627           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
# [11628 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                                 Southeast  Boxing
# 1            Boxing                                Title Boxing  West
# 2         Muay Thai                                    Talon Muay Thai
# 3         Wrestling  Porcellis Training Center Home Of  Mma  & Team...
# 4           fitness                                         Roundkick
# ...             ...                                                ...
# 11623       General                        Mccreary Community Building
# 11624          Yoga                                Roots Prenatal Yoga
# 11625          Yoga                                   Still Water Yoga
# 11626          Yoga                                   Still Water Yoga
# 11627       General                                           Studio H
#
#                                                     name        phone  \
# 0                     Southeast (Des Moines) Boxing Club  15156894496
# 1                    Title Boxing Club West (Des Moines)  15154934486
# 2                                        Talon Muay Thai  15152502357
# 3      Porcellis Training Center Home Of (Des Moines)...  15156614782
# 4                                          Roundkick Gym  15152765254
# ...                                                  ...          ...
# 11623                        Mccreary Community Building  15154655621
# 11624                                Roots Prenatal Yoga  15152022584
# 11625                                   Still Water Yoga  18774799642
# 11626                                   Still Water Yoga  18774799642
# 11627                                           Studio H  19498128489
#
#                                   email     email_host  \
# 0              sedmboxingclub@gmail.com     google.com
# 1          elmhurst@titleboxingclub.com  rackspace.com
# 2              rhonda@talonmuaythai.com    opensrs.com
# 3      info@porcellistrainingcenter.com       zoho.com
# 4                 info@roundkickgym.com    godaddy.com
# ...                                 ...            ...
# 11623         sven.peterson@perryia.org     google.com
# 11624                               NaN            NaN
# 11625           notshyyymaids@gmail.com     google.com
# 11626        megan@yogabystillwater.com    outlook.com
# 11627            studioharlan@gmail.com     google.com
#
#                                                  website  \
# 0      https://southeastdesmoinesboxingclub.wordpress...
# 1        https://titleboxingclub.com/west-des-moines-ia/
# 2                             https://talonmuaythai.com/
# 3                http://www.porcellistrainingcenter.com/
# 4                           http://www.roundkickgym.com/
# ...                                                  ...
# 11623        http://www.perryia.org/mccreary-center.html
# 11624                                                NaN
# 11625              https://visibook.com/yogabystillwater
# 11626                       http://yogabystillwater.com/
# 11627                                                NaN
#
#                    category                         address             city  \
# 0               Boxing club                   1414 Maury St       Des Moines
# 1                Boxing Gym  9500 University Ave Suite 1105  West Des Moines
# 2      Muay Thai boxing gym             601 SW 9th St ste d       Des Moines
# 3       Martial arts school                5160 NE 12th Ave    Pleasant Hill
# 4      Muay Thai boxing gym                   4421 112th St        Urbandale
# ...                     ...                             ...              ...
# 11623      Community centre                  1800 Pattee St            Perry
# 11624           Yoga studio                     736 37th St       Des Moines
# 11625       Wellness Centre                     1205 7th St           Harlan
# 11626       Wellness Centre                    713 Court St           Harlan
# 11627          Dance School                     1123 7th St           Harlan
#
#        ... ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0      ...      NaN          NaN           NaN           NaN         NaN
# 1      ...      NaN          NaN           NaN           NaN           1
# 2      ...      NaN          NaN           NaN           NaN         NaN
# 3      ...      NaN          NaN           NaN           NaN         NaN
# 4      ...      NaN          NaN           NaN           NaN         NaN
# ...    ...      ...          ...           ...           ...         ...
# 11623  ...      NaN          NaN           NaN           NaN         NaN
# 11624  ...      NaN          NaN           NaN           NaN         NaN
# 11625  ...      NaN          NaN           NaN           NaN         NaN
# 11626  ...      NaN          NaN           NaN           NaN         NaN
# 11627  ...      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                              https://g.page/sedmboxing        claimed
# 1            https://g.page/title-boxing-west-des-moines        claimed
# 2      https://maps.google.com/maps/place/Talon+Muay+...        claimed
# 3      https://maps.google.com/maps/place/Porcellis+T...        claimed
# 4      https://maps.google.com/maps/place/RoundKick+G...        claimed
# ...                                                  ...            ...
# 11623  https://maps.google.com/maps/place/McCreary+Co...      unclaimed
# 11624  https://maps.google.com/maps/place/Roots+Prena...        claimed
# 11625               https://g.page/StillWaterYoga-Harlan        claimed
# 11626               https://g.page/StillWaterYoga-Harlan        claimed
# 11627                                                NaN            NaN
#
#       search_keyword      search_city  \
# 0        Boxing Club       Des Moines
# 1        Boxing Club       Des Moines
# 2        Boxing Club       Des Moines
# 3        Boxing Club       Des Moines
# 4        Boxing Club       Des Moines
# ...              ...              ...
# 11623    Yoga Studio            Perry
# 11624    Yoga Studio  Windsor Heights
# 11625    Yoga Studio           Harlan
# 11626    Yoga Studio           Harlan
# 11627    Yoga Studio           Harlan
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a perfect rating on Google. 5 sta...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 11623  I saw B2 has a near perfect rating on Google. ...
# 11624  I saw B2 has a perfect rating on Google. 5 sta...
# 11625  I was looking at the B2 website on my phone an...
# 11626  I saw your B2 star rating on Facebook. Really ...
# 11627  I saw your B2 star rating on Facebook. Really ...
#
# [11628 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('IA_combined_leads_duplicates_removed_semiclean.csv', index = False)
