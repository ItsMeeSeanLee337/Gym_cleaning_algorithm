# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("MN_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      TITLE Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#       region    zip  ... instagram_average_comments ads_yelp ads_facebook  \
# 0         MN  55408  ...                          1      NaN          NaN
# 1         MN  55419  ...                          3      NaN          NaN
# 2         MN  55412  ...                          3      NaN          NaN
# 3         MN  55407  ...                          1      NaN          NaN
# 4         MN  55421  ...                        NaN      NaN          NaN
# ...      ...    ...  ...                        ...      ...          ...
# 14292     MN  55114  ...                          1      NaN          NaN
# 14293     MN  55407  ...                        NaN      NaN          NaN
# 14294     MN  55304  ...                        NaN      NaN          NaN
# 14295     MN  55304  ...                          1      NaN          NaN
# 14296     MN  55304  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 14292           NaN           NaN         NaN
# 14293           NaN           NaN         NaN
# 14294           NaN           NaN         NaN
# 14295           NaN           NaN         NaN
# 14296           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Minneapolis
# 1        Boxing Club  Minneapolis
# 2        Boxing Club  Minneapolis
# 3        Boxing Club  Minneapolis
# 4        Boxing Club  Minneapolis
# ...              ...          ...
# 14292    Yoga Studio   St Anthony
# 14293    Yoga Studio   St Anthony
# 14294    Yoga Studio     Ham Lake
# 14295    Yoga Studio     Ham Lake
# 14296    Yoga Studio     Ham Lake
#
# [14297 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('MN','')
df['First Name'] = df['First Name'].str.replace('Mn','')
df['First Name'] = df['First Name'].str.replace('Minnesota','')
df
# Out:
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      Title Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle Of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         MN  55408  ...      NaN          NaN           NaN           NaN
# 1         MN  55419  ...      NaN          NaN           NaN           NaN
# 2         MN  55412  ...      NaN          NaN           NaN           NaN
# 3         MN  55407  ...      NaN          NaN           NaN           NaN
# 4         MN  55421  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 14292     MN  55114  ...      NaN          NaN           NaN           NaN
# 14293     MN  55407  ...      NaN          NaN           NaN           NaN
# 14294     MN  55304  ...      NaN          NaN           NaN           NaN
# 14295     MN  55304  ...      NaN          NaN           NaN           NaN
# 14296     MN  55304  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Minneapolis...
# 1               1  https://maps.google.com/maps/place/TITLE+Boxin...
# 2             NaN  https://maps.google.com/maps/place/Northside+B...
# 3             NaN  https://maps.google.com/maps/place/Circle+of+D...
# 4             NaN  https://maps.google.com/maps/place/Golden+Glov...
# ...           ...                                                ...
# 14292         NaN  https://maps.google.com/maps/place/Vandalia+To...
# 14293         NaN  https://maps.google.com/maps/place/Hiawatha+Yo...
# 14294         NaN  https://maps.google.com/maps/place/Fitaholic+F...
# 14295         NaN  https://maps.google.com/maps/place/The+Warehou...
# 14296         NaN                 https://g.page/latitude-studios-co
#
#       g_maps_claimed search_keyword  search_city  \
# 0            claimed    Boxing Club  Minneapolis
# 1            claimed    Boxing Club  Minneapolis
# 2          unclaimed    Boxing Club  Minneapolis
# 3            claimed    Boxing Club  Minneapolis
# 4            claimed    Boxing Club  Minneapolis
# ...              ...            ...          ...
# 14292      unclaimed    Yoga Studio   St Anthony
# 14293      unclaimed    Yoga Studio   St Anthony
# 14294        claimed    Yoga Studio     Ham Lake
# 14295        claimed    Yoga Studio     Ham Lake
# 14296        claimed    Yoga Studio     Ham Lake
#
#                                 First Name
# 0                      Minneapolis Boxing
# 1      Title Boxing  Minneapolis Southwest
# 2                        Northside Boxing
# 3                 Circle Of Discipline Inc
# 4                 Golden Gloves Firehouse
# ...                                    ...
# 14292                       Vandalia Tower
# 14293                        Hiawatha Yoga
# 14294         Fitaholic Fitness - Ham Lake
# 14295                        The Warehouse
# 14296                  Latitude Studios Co
#
# [14297 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      Title Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle Of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         MN  55408  ...      NaN          NaN           NaN           NaN
# 1         MN  55419  ...      NaN          NaN           NaN           NaN
# 2         MN  55412  ...      NaN          NaN           NaN           NaN
# 3         MN  55407  ...      NaN          NaN           NaN           NaN
# 4         MN  55421  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 14292     MN  55114  ...      NaN          NaN           NaN           NaN
# 14293     MN  55407  ...      NaN          NaN           NaN           NaN
# 14294     MN  55304  ...      NaN          NaN           NaN           NaN
# 14295     MN  55304  ...      NaN          NaN           NaN           NaN
# 14296     MN  55304  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Minneapolis...
# 1               1  https://maps.google.com/maps/place/TITLE+Boxin...
# 2             NaN  https://maps.google.com/maps/place/Northside+B...
# 3             NaN  https://maps.google.com/maps/place/Circle+of+D...
# 4             NaN  https://maps.google.com/maps/place/Golden+Glov...
# ...           ...                                                ...
# 14292         NaN  https://maps.google.com/maps/place/Vandalia+To...
# 14293         NaN  https://maps.google.com/maps/place/Hiawatha+Yo...
# 14294         NaN  https://maps.google.com/maps/place/Fitaholic+F...
# 14295         NaN  https://maps.google.com/maps/place/The+Warehou...
# 14296         NaN                 https://g.page/latitude-studios-co
#
#       g_maps_claimed search_keyword  search_city  \
# 0            claimed    Boxing Club  Minneapolis
# 1            claimed    Boxing Club  Minneapolis
# 2          unclaimed    Boxing Club  Minneapolis
# 3            claimed    Boxing Club  Minneapolis
# 4            claimed    Boxing Club  Minneapolis
# ...              ...            ...          ...
# 14292      unclaimed    Yoga Studio   St Anthony
# 14293      unclaimed    Yoga Studio   St Anthony
# 14294        claimed    Yoga Studio     Ham Lake
# 14295        claimed    Yoga Studio     Ham Lake
# 14296        claimed    Yoga Studio     Ham Lake
#
#                                 First Name
# 0                      Minneapolis Boxing
# 1      Title Boxing  Minneapolis Southwest
# 2                        Northside Boxing
# 3                 Circle Of Discipline Inc
# 4                 Golden Gloves Firehouse
# ...                                    ...
# 14292                       Vandalia Tower
# 14293                        Hiawatha Yoga
# 14294         Fitaholic Fitness - Ham Lake
# 14295                            Warehouse
# 14296                  Latitude Studios Co
#
# [14297 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      Title Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle Of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         MN  55408  ...          NaN           NaN           NaN         NaN
# 1         MN  55419  ...          NaN           NaN           NaN           1
# 2         MN  55412  ...          NaN           NaN           NaN         NaN
# 3         MN  55407  ...          NaN           NaN           NaN         NaN
# 4         MN  55421  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 14292     MN  55114  ...          NaN           NaN           NaN         NaN
# 14293     MN  55407  ...          NaN           NaN           NaN         NaN
# 14294     MN  55304  ...          NaN           NaN           NaN         NaN
# 14295     MN  55304  ...          NaN           NaN           NaN         NaN
# 14296     MN  55304  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city                           First Name  \
# 0        Boxing Club  Minneapolis                  Minneapolis Boxing
# 1        Boxing Club  Minneapolis  Title Boxing  Minneapolis Southwest
# 2        Boxing Club  Minneapolis                    Northside Boxing
# 3        Boxing Club  Minneapolis             Circle Of Discipline Inc
# 4        Boxing Club  Minneapolis             Golden Gloves Firehouse
# ...              ...          ...                                  ...
# 14292    Yoga Studio   St Anthony                       Vandalia Tower
# 14293    Yoga Studio   St Anthony                        Hiawatha Yoga
# 14294    Yoga Studio     Ham Lake         Fitaholic Fitness - Ham Lake
# 14295    Yoga Studio     Ham Lake                            Warehouse
# 14296    Yoga Studio     Ham Lake                  Latitude Studios Co
#
#       Business Type
# 0               NaT
# 1               NaT
# 2               NaT
# 3               NaT
# 4               NaT
# ...             ...
# 14292           NaT
# 14293           NaT
# 14294           NaT
# 14295           NaT
# 14296           NaT
#
# [14297 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      Title Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle Of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         MN  55408  ...          NaN           NaN           NaN         NaN
# 1         MN  55419  ...          NaN           NaN           NaN           1
# 2         MN  55412  ...          NaN           NaN           NaN         NaN
# 3         MN  55407  ...          NaN           NaN           NaN         NaN
# 4         MN  55421  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 14292     MN  55114  ...          NaN           NaN           NaN         NaN
# 14293     MN  55407  ...          NaN           NaN           NaN         NaN
# 14294     MN  55304  ...          NaN           NaN           NaN         NaN
# 14295     MN  55304  ...          NaN           NaN           NaN         NaN
# 14296     MN  55304  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city                           First Name  \
# 0        Boxing Club  Minneapolis                  Minneapolis Boxing
# 1        Boxing Club  Minneapolis  Title Boxing  Minneapolis Southwest
# 2        Boxing Club  Minneapolis                    Northside Boxing
# 3        Boxing Club  Minneapolis             Circle Of Discipline Inc
# 4        Boxing Club  Minneapolis             Golden Gloves Firehouse
# ...              ...          ...                                  ...
# 14292    Yoga Studio   St Anthony                       Vandalia Tower
# 14293    Yoga Studio   St Anthony                        Hiawatha Yoga
# 14294    Yoga Studio     Ham Lake         Fitaholic Fitness - Ham Lake
# 14295    Yoga Studio     Ham Lake                            Warehouse
# 14296    Yoga Studio     Ham Lake                  Latitude Studios Co
#
#       Business Type
# 0           General
# 1           General
# 2           General
# 3           General
# 4           General
# ...             ...
# 14292       General
# 14293       General
# 14294       General
# 14295       General
# 14296       General
#
# [14297 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      Title Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle Of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         MN  55408  ...          NaN           NaN           NaN         NaN
# 1         MN  55419  ...          NaN           NaN           NaN           1
# 2         MN  55412  ...          NaN           NaN           NaN         NaN
# 3         MN  55407  ...          NaN           NaN           NaN         NaN
# 4         MN  55421  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 14292     MN  55114  ...          NaN           NaN           NaN         NaN
# 14293     MN  55407  ...          NaN           NaN           NaN         NaN
# 14294     MN  55304  ...          NaN           NaN           NaN         NaN
# 14295     MN  55304  ...          NaN           NaN           NaN         NaN
# 14296     MN  55304  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city                           First Name  \
# 0        Boxing Club  Minneapolis                  Minneapolis Boxing
# 1        Boxing Club  Minneapolis  Title Boxing  Minneapolis Southwest
# 2        Boxing Club  Minneapolis                    Northside Boxing
# 3        Boxing Club  Minneapolis             Circle Of Discipline Inc
# 4        Boxing Club  Minneapolis             Golden Gloves Firehouse
# ...              ...          ...                                  ...
# 14292    Yoga Studio   St Anthony                       Vandalia Tower
# 14293    Yoga Studio   St Anthony                        Hiawatha Yoga
# 14294    Yoga Studio     Ham Lake         Fitaholic Fitness - Ham Lake
# 14295    Yoga Studio     Ham Lake                            Warehouse
# 14296    Yoga Studio     Ham Lake                  Latitude Studios Co
#
#       Business Type
# 0            Boxing
# 1            Boxing
# 2            Boxing
# 3           General
# 4           fitness
# ...             ...
# 14292       General
# 14293          Yoga
# 14294       Fitness
# 14295       General
# 14296       General
#
# [14297 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                           First Name  \
# 0            Boxing                  Minneapolis Boxing
# 1            Boxing  Title Boxing  Minneapolis Southwest
# 2            Boxing                    Northside Boxing
# 3           General             Circle Of Discipline Inc
# 4           fitness             Golden Gloves Firehouse
# ...             ...                                  ...
# 14292       General                       Vandalia Tower
# 14293          Yoga                        Hiawatha Yoga
# 14294       Fitness         Fitaholic Fitness - Ham Lake
# 14295       General                            Warehouse
# 14296       General                  Latitude Studios Co
#
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      Title Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle Of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                          1      NaN          NaN           NaN
# 1      ...                          3      NaN          NaN           NaN
# 2      ...                          3      NaN          NaN           NaN
# 3      ...                          1      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 14292  ...                          1      NaN          NaN           NaN
# 14293  ...                        NaN      NaN          NaN           NaN
# 14294  ...                        NaN      NaN          NaN           NaN
# 14295  ...                          1      NaN          NaN           NaN
# 14296  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 14292           NaN         NaN
# 14293           NaN         NaN
# 14294           NaN         NaN
# 14295           NaN         NaN
# 14296           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Minneapolis
# 1        Boxing Club  Minneapolis
# 2        Boxing Club  Minneapolis
# 3        Boxing Club  Minneapolis
# 4        Boxing Club  Minneapolis
# ...              ...          ...
# 14292    Yoga Studio   St Anthony
# 14293    Yoga Studio   St Anthony
# 14294    Yoga Studio     Ham Lake
# 14295    Yoga Studio     Ham Lake
# 14296    Yoga Studio     Ham Lake
#
# [14297 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                           First Name  \
# 0            Boxing                  Minneapolis Boxing
# 1            Boxing  Title Boxing  Minneapolis Southwest
# 2            Boxing                    Northside Boxing
# 3           General             Circle Of Discipline Inc
# 4           fitness             Golden Gloves Firehouse
# ...             ...                                  ...
# 14292       General                       Vandalia Tower
# 14293          Yoga                        Hiawatha Yoga
# 14294       Fitness          Fitaholic Fitness  Ham Lake
# 14295       General                            Warehouse
# 14296       General                  Latitude Studios Co
#
#                                           name        phone  \
# 0                      Minneapolis Boxing Club  12183405379
# 1      Title Boxing Club Minneapolis Southwest  16128221964
# 2                        Northside Boxing Club  16123674453
# 3                     Circle Of Discipline Inc  16127211549
# 4                  Golden Gloves Firehouse Gym  16125166600
# ...                                        ...          ...
# 14292                           Vandalia Tower  16123349434
# 14293                            Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - Ham Lake  16122394010
# 14295                            The Warehouse  17632700567
# 14296                      Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                          1      NaN          NaN           NaN
# 1      ...                          3      NaN          NaN           NaN
# 2      ...                          3      NaN          NaN           NaN
# 3      ...                          1      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 14292  ...                          1      NaN          NaN           NaN
# 14293  ...                        NaN      NaN          NaN           NaN
# 14294  ...                        NaN      NaN          NaN           NaN
# 14295  ...                          1      NaN          NaN           NaN
# 14296  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 14292           NaN         NaN
# 14293           NaN         NaN
# 14294           NaN         NaN
# 14295           NaN         NaN
# 14296           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Minneapolis
# 1        Boxing Club  Minneapolis
# 2        Boxing Club  Minneapolis
# 3        Boxing Club  Minneapolis
# 4        Boxing Club  Minneapolis
# ...              ...          ...
# 14292    Yoga Studio   St Anthony
# 14293    Yoga Studio   St Anthony
# 14294    Yoga Studio     Ham Lake
# 14295    Yoga Studio     Ham Lake
# 14296    Yoga Studio     Ham Lake
#
# [14297 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                First Name  \
# 0            Boxing                   Boxing
# 1            Boxing  Title Boxing   Southwest
# 2            Boxing         Northside Boxing
# 3           General  Circle Of Discipline Inc
# 4           fitness  Golden Gloves Firehouse
# ...             ...                       ...
# 14292       General            Vandalia Tower
# 14293          Yoga             Hiawatha Yoga
# 14294       Fitness       Fitaholic Fitness
# 14295       General                 Warehouse
# 14296       General       Latitude Studios Co
#
#                                             name        phone  \
# 0                      (Minneapolis) Boxing Club  12183405379
# 1      Title Boxing Club (Minneapolis) Southwest  16128221964
# 2                          Northside Boxing Club  16123674453
# 3                       Circle Of Discipline Inc  16127211549
# 4                    Golden Gloves Firehouse Gym  16125166600
# ...                                          ...          ...
# 14292                             Vandalia Tower  16123349434
# 14293                              Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - (Ham Lake)  16122394010
# 14295                              The Warehouse  17632700567
# 14296                        Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#        ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0      ...                          1      NaN          NaN           NaN
# 1      ...                          3      NaN          NaN           NaN
# 2      ...                          3      NaN          NaN           NaN
# 3      ...                          1      NaN          NaN           NaN
# 4      ...                        NaN      NaN          NaN           NaN
# ...    ...                        ...      ...          ...           ...
# 14292  ...                          1      NaN          NaN           NaN
# 14293  ...                        NaN      NaN          NaN           NaN
# 14294  ...                        NaN      NaN          NaN           NaN
# 14295  ...                          1      NaN          NaN           NaN
# 14296  ...                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 14292           NaN         NaN
# 14293           NaN         NaN
# 14294           NaN         NaN
# 14295           NaN         NaN
# 14296           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Minneapolis
# 1        Boxing Club  Minneapolis
# 2        Boxing Club  Minneapolis
# 3        Boxing Club  Minneapolis
# 4        Boxing Club  Minneapolis
# ...              ...          ...
# 14292    Yoga Studio   St Anthony
# 14293    Yoga Studio   St Anthony
# 14294    Yoga Studio     Ham Lake
# 14295    Yoga Studio     Ham Lake
# 14296    Yoga Studio     Ham Lake
#
# [14297 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                First Name  \
# 0            Boxing                   Boxing
# 1            Boxing  Title Boxing   Southwest
# 2            Boxing         Northside Boxing
# 3           General  Circle Of Discipline Inc
# 4           fitness  Golden Gloves Firehouse
# ...             ...                       ...
# 14292       General            Vandalia Tower
# 14293          Yoga             Hiawatha Yoga
# 14294       Fitness       Fitaholic Fitness
# 14295       General                 Warehouse
# 14296       General       Latitude Studios Co
#
#                                             name        phone  \
# 0                      (Minneapolis) Boxing Club  12183405379
# 1      Title Boxing Club (Minneapolis) Southwest  16128221964
# 2                          Northside Boxing Club  16123674453
# 3                       Circle Of Discipline Inc  16127211549
# 4                    Golden Gloves Firehouse Gym  16125166600
# ...                                          ...          ...
# 14292                             Vandalia Tower  16123349434
# 14293                              Hiawatha Yoga  16127229312
# 14294             Fitaholic Fitness - (Ham Lake)  16122394010
# 14295                              The Warehouse  17632700567
# 14296                        Latitude Studios Co  16513698995
#
#                                     email     email_host  \
# 0         heidi@minneapolisboxingclub.com     google.com
# 1          wickerpark@titleboxingclub.com  rackspace.com
# 2               hello@northsideboxing.org     google.com
# 3                  circlebarnum@gmail.com     google.com
# 4      lorourkebusinessservices@gmail.com     google.com
# ...                                   ...            ...
# 14292                 joe@first-first.com     google.com
# 14293                                 NaN            NaN
# 14294       woodbury@fitaholicfitness.com     google.com
# 14295           info@thewarehouse.fitness     google.com
# 14296          andyb@latitude-studios.com     google.com
#
#                                                  website  \
# 0                      http://minneapolisboxingclub.com/
# 1      https://titleboxingclub.com/minneapolis-southw...
# 2                           https://northsideboxing.org/
# 3                     http://www.circleofdiscipline.org/
# 4                           https://orourkestrategy.com/
# ...                                                  ...
# 14292             http://first-first.com/places/vandalia
# 14293                                                NaN
# 14294                   http://www.fitaholicfitness.com/
# 14295                  https://www.thewarehouse.fitness/
# 14296                  https://www.latitude-studios.com/
#
#                    category                       address              city  \
# 0                Boxing Gym             2905 Garfield Ave       Minneapolis
# 1                       Gym            5450 Lyndale Ave S       Minneapolis
# 2                       Gym               1704 N 33rd Ave       Minneapolis
# 3          Community centre                 801 SE 9th St       Minneapolis
# 4                Boxing Gym                555 Mill St NE  Columbia Heights
# ...                     ...                           ...               ...
# 14292       Business Centre               550 Vandalia St           St Paul
# 14293           Yoga studio                2223 E 35th St       Minneapolis
# 14294                   Gym          13352 Aberdeen St NE          Ham Lake
# 14295                   Gym      14050 Lincoln St NE #400          Ham Lake
# 14296  Construction Company  14665 Buchanan St NE Suite 3          Ham Lake
#
#        ... ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0      ...      NaN          NaN           NaN           NaN         NaN
# 1      ...      NaN          NaN           NaN           NaN           1
# 2      ...      NaN          NaN           NaN           NaN         NaN
# 3      ...      NaN          NaN           NaN           NaN         NaN
# 4      ...      NaN          NaN           NaN           NaN         NaN
# ...    ...      ...          ...           ...           ...         ...
# 14292  ...      NaN          NaN           NaN           NaN         NaN
# 14293  ...      NaN          NaN           NaN           NaN         NaN
# 14294  ...      NaN          NaN           NaN           NaN         NaN
# 14295  ...      NaN          NaN           NaN           NaN         NaN
# 14296  ...      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Minneapolis...        claimed
# 1      https://maps.google.com/maps/place/TITLE+Boxin...        claimed
# 2      https://maps.google.com/maps/place/Northside+B...      unclaimed
# 3      https://maps.google.com/maps/place/Circle+of+D...        claimed
# 4      https://maps.google.com/maps/place/Golden+Glov...        claimed
# ...                                                  ...            ...
# 14292  https://maps.google.com/maps/place/Vandalia+To...      unclaimed
# 14293  https://maps.google.com/maps/place/Hiawatha+Yo...      unclaimed
# 14294  https://maps.google.com/maps/place/Fitaholic+F...        claimed
# 14295  https://maps.google.com/maps/place/The+Warehou...        claimed
# 14296                 https://g.page/latitude-studios-co        claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club  Minneapolis
# 1        Boxing Club  Minneapolis
# 2        Boxing Club  Minneapolis
# 3        Boxing Club  Minneapolis
# 4        Boxing Club  Minneapolis
# ...              ...          ...
# 14292    Yoga Studio   St Anthony
# 14293    Yoga Studio   St Anthony
# 14294    Yoga Studio     Ham Lake
# 14295    Yoga Studio     Ham Lake
# 14296    Yoga Studio     Ham Lake
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 14292  I saw B2 has a near perfect rating on Google. ...
# 14293  I saw B2 has a perfect rating on Google. 5 sta...
# 14294  I saw B2 has a near perfect rating on Google. ...
# 14295  I saw B2 has a perfect rating on Google. 5 sta...
# 14296  I saw B2 has a perfect rating on Google. 5 sta...
#
# [14297 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('MN_combined_leads_duplicates_removed_semiclean.csv', index = False)
