# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("CO_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,11,16,17,18,19,20,21,36,37,38,39,40,41,43,44,45,46,47,48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      TOS Boxing Gym    13032468749
# 2                       Tao of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt force training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For the Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city region    zip  ... instagram_average_comments ads_yelp  \
# 0         Denver     CO  80219  ...                          8      NaN
# 1      Englewood     CO  80110  ...                        NaN      NaN
# 2         Denver     CO  80218  ...                          1      NaN
# 3         Denver     CO  80231  ...                          2      NaN
# 4         Denver     CO  80216  ...                        NaN      NaN
# ...          ...    ...    ...  ...                        ...      ...
# 22900     Denver     CO  80206  ...                        NaN      NaN
# 22901  Littleton     CO  80120  ...                        NaN      NaN
# 22902  Evergreen     CO     CO  ...                        NaN      NaN
# 22903  Littleton     CO  80127  ...                        NaN      NaN
# 22904   Morrison     CO  80465  ...                        NaN      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN         NaN
# ...            ...           ...           ...         ...
# 22900          NaN           NaN           NaN         NaN
# 22901          NaN           NaN           NaN         NaN
# 22902          NaN           NaN           NaN         NaN
# 22903          NaN           NaN           NaN         NaN
# 22904          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Topeira+Box...        claimed
# 1      https://maps.google.com/maps/place/TOS+Boxing+...        claimed
# 2      https://maps.google.com/maps/place/Tao+of+Boxi...        claimed
# 3      https://maps.google.com/maps/place/Bring+It+Ba...        claimed
# 4      https://maps.google.com/maps/place/Blunt+force...        claimed
# ...                                                  ...            ...
# 22900                    https://g.page/unlock-bodyworks        claimed
# 22901                                                NaN            NaN
# 22902  https://maps.google.com/maps/place/For+the+Joy...      unclaimed
# 22903                     https://g.page/MBSpa-Littleton        claimed
# 22904  https://maps.google.com/maps/place/Blue+Sky+Fi...      unclaimed
#
#       search_keyword      search_city
# 0        Boxing Club           Denver
# 1        Boxing Club           Denver
# 2        Boxing Club           Denver
# 3        Boxing Club           Denver
# 4        Boxing Club           Denver
# ...              ...              ...
# 22900    Yoga Studio  Roxborough Park
# 22901    Yoga Studio  Roxborough Park
# 22902    Yoga Studio  Roxborough Park
# 22903    Yoga Studio  Roxborough Park
# 22904    Yoga Studio  Roxborough Park
#
# [22905 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('CO','')
df['First Name'] = df['First Name'].str.replace('Co','')
df['First Name'] = df['First Name'].str.replace('Colorado','')
df
# Out:
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city region    zip  ... ads_yelp ads_facebook ads_instagram  \
# 0         Denver     CO  80219  ...      NaN          NaN           NaN
# 1      Englewood     CO  80110  ...      NaN          NaN           NaN
# 2         Denver     CO  80218  ...      NaN          NaN           NaN
# 3         Denver     CO  80231  ...      NaN          NaN           NaN
# 4         Denver     CO  80216  ...      NaN          NaN           NaN
# ...          ...    ...    ...  ...      ...          ...           ...
# 22900     Denver     CO  80206  ...      NaN          NaN           NaN
# 22901  Littleton     CO  80120  ...      NaN          NaN           NaN
# 22902  Evergreen     CO     CO  ...      NaN          NaN           NaN
# 22903  Littleton     CO  80127  ...      NaN          NaN           NaN
# 22904   Morrison     CO  80465  ...      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 22900           NaN         NaN
# 22901           NaN         NaN
# 22902           NaN         NaN
# 22903           NaN         NaN
# 22904           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Topeira+Box...        claimed
# 1      https://maps.google.com/maps/place/TOS+Boxing+...        claimed
# 2      https://maps.google.com/maps/place/Tao+of+Boxi...        claimed
# 3      https://maps.google.com/maps/place/Bring+It+Ba...        claimed
# 4      https://maps.google.com/maps/place/Blunt+force...        claimed
# ...                                                  ...            ...
# 22900                    https://g.page/unlock-bodyworks        claimed
# 22901                                                NaN            NaN
# 22902  https://maps.google.com/maps/place/For+the+Joy...      unclaimed
# 22903                     https://g.page/MBSpa-Littleton        claimed
# 22904  https://maps.google.com/maps/place/Blue+Sky+Fi...      unclaimed
#
#       search_keyword      search_city                      First Name
# 0        Boxing Club           Denver                 Topeira Boxing
# 1        Boxing Club           Denver                     Tos Boxing
# 2        Boxing Club           Denver                   Tao Of Boxing
# 3        Boxing Club           Denver  Bring It Back Boxing & Fitness
# 4        Boxing Club           Denver            Blunt Force Training
# ...              ...              ...                             ...
# 22900    Yoga Studio  Roxborough Park                Unlock Bodyworks
# 22901    Yoga Studio  Roxborough Park                    Karen Korona
# 22902    Yoga Studio  Roxborough Park                For The Joy Yoga
# 22903    Yoga Studio  Roxborough Park                   Mind Body Spa
# 22904    Yoga Studio  Roxborough Park                Blue Sky Fitness
#
# [22905 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city region    zip  ... ads_yelp ads_facebook ads_instagram  \
# 0         Denver     CO  80219  ...      NaN          NaN           NaN
# 1      Englewood     CO  80110  ...      NaN          NaN           NaN
# 2         Denver     CO  80218  ...      NaN          NaN           NaN
# 3         Denver     CO  80231  ...      NaN          NaN           NaN
# 4         Denver     CO  80216  ...      NaN          NaN           NaN
# ...          ...    ...    ...  ...      ...          ...           ...
# 22900     Denver     CO  80206  ...      NaN          NaN           NaN
# 22901  Littleton     CO  80120  ...      NaN          NaN           NaN
# 22902  Evergreen     CO     CO  ...      NaN          NaN           NaN
# 22903  Littleton     CO  80127  ...      NaN          NaN           NaN
# 22904   Morrison     CO  80465  ...      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 22900           NaN         NaN
# 22901           NaN         NaN
# 22902           NaN         NaN
# 22903           NaN         NaN
# 22904           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Topeira+Box...        claimed
# 1      https://maps.google.com/maps/place/TOS+Boxing+...        claimed
# 2      https://maps.google.com/maps/place/Tao+of+Boxi...        claimed
# 3      https://maps.google.com/maps/place/Bring+It+Ba...        claimed
# 4      https://maps.google.com/maps/place/Blunt+force...        claimed
# ...                                                  ...            ...
# 22900                    https://g.page/unlock-bodyworks        claimed
# 22901                                                NaN            NaN
# 22902  https://maps.google.com/maps/place/For+the+Joy...      unclaimed
# 22903                     https://g.page/MBSpa-Littleton        claimed
# 22904  https://maps.google.com/maps/place/Blue+Sky+Fi...      unclaimed
#
#       search_keyword      search_city                      First Name
# 0        Boxing Club           Denver                 Topeira Boxing
# 1        Boxing Club           Denver                     Tos Boxing
# 2        Boxing Club           Denver                   Tao Of Boxing
# 3        Boxing Club           Denver  Bring It Back Boxing & Fitness
# 4        Boxing Club           Denver            Blunt Force Training
# ...              ...              ...                             ...
# 22900    Yoga Studio  Roxborough Park                Unlock Bodyworks
# 22901    Yoga Studio  Roxborough Park                    Karen Korona
# 22902    Yoga Studio  Roxborough Park                For The Joy Yoga
# 22903    Yoga Studio  Roxborough Park                   Mind Body Spa
# 22904    Yoga Studio  Roxborough Park                Blue Sky Fitness
#
# [22905 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city region    zip  ... ads_facebook ads_instagram ads_messenger  \
# 0         Denver     CO  80219  ...          NaN           NaN           NaN
# 1      Englewood     CO  80110  ...          NaN           NaN           NaN
# 2         Denver     CO  80218  ...          NaN           NaN           NaN
# 3         Denver     CO  80231  ...          NaN           NaN           NaN
# 4         Denver     CO  80216  ...          NaN           NaN           NaN
# ...          ...    ...    ...  ...          ...           ...           ...
# 22900     Denver     CO  80206  ...          NaN           NaN           NaN
# 22901  Littleton     CO  80120  ...          NaN           NaN           NaN
# 22902  Evergreen     CO     CO  ...          NaN           NaN           NaN
# 22903  Littleton     CO  80127  ...          NaN           NaN           NaN
# 22904   Morrison     CO  80465  ...          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Topeira+Box...
# 1             NaN  https://maps.google.com/maps/place/TOS+Boxing+...
# 2             NaN  https://maps.google.com/maps/place/Tao+of+Boxi...
# 3             NaN  https://maps.google.com/maps/place/Bring+It+Ba...
# 4             NaN  https://maps.google.com/maps/place/Blunt+force...
# ...           ...                                                ...
# 22900         NaN                    https://g.page/unlock-bodyworks
# 22901         NaN                                                NaN
# 22902         NaN  https://maps.google.com/maps/place/For+the+Joy...
# 22903         NaN                     https://g.page/MBSpa-Littleton
# 22904         NaN  https://maps.google.com/maps/place/Blue+Sky+Fi...
#
#       g_maps_claimed search_keyword      search_city  \
# 0            claimed    Boxing Club           Denver
# 1            claimed    Boxing Club           Denver
# 2            claimed    Boxing Club           Denver
# 3            claimed    Boxing Club           Denver
# 4            claimed    Boxing Club           Denver
# ...              ...            ...              ...
# 22900        claimed    Yoga Studio  Roxborough Park
# 22901            NaN    Yoga Studio  Roxborough Park
# 22902      unclaimed    Yoga Studio  Roxborough Park
# 22903        claimed    Yoga Studio  Roxborough Park
# 22904      unclaimed    Yoga Studio  Roxborough Park
#
#                            First Name Business Type
# 0                     Topeira Boxing            NaT
# 1                         Tos Boxing            NaT
# 2                       Tao Of Boxing           NaT
# 3      Bring It Back Boxing & Fitness           NaT
# 4                Blunt Force Training           NaT
# ...                               ...           ...
# 22900                Unlock Bodyworks           NaT
# 22901                    Karen Korona           NaT
# 22902                For The Joy Yoga           NaT
# 22903                   Mind Body Spa           NaT
# 22904                Blue Sky Fitness           NaT
#
# [22905 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city region    zip  ... ads_facebook ads_instagram ads_messenger  \
# 0         Denver     CO  80219  ...          NaN           NaN           NaN
# 1      Englewood     CO  80110  ...          NaN           NaN           NaN
# 2         Denver     CO  80218  ...          NaN           NaN           NaN
# 3         Denver     CO  80231  ...          NaN           NaN           NaN
# 4         Denver     CO  80216  ...          NaN           NaN           NaN
# ...          ...    ...    ...  ...          ...           ...           ...
# 22900     Denver     CO  80206  ...          NaN           NaN           NaN
# 22901  Littleton     CO  80120  ...          NaN           NaN           NaN
# 22902  Evergreen     CO     CO  ...          NaN           NaN           NaN
# 22903  Littleton     CO  80127  ...          NaN           NaN           NaN
# 22904   Morrison     CO  80465  ...          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Topeira+Box...
# 1             NaN  https://maps.google.com/maps/place/TOS+Boxing+...
# 2             NaN  https://maps.google.com/maps/place/Tao+of+Boxi...
# 3             NaN  https://maps.google.com/maps/place/Bring+It+Ba...
# 4             NaN  https://maps.google.com/maps/place/Blunt+force...
# ...           ...                                                ...
# 22900         NaN                    https://g.page/unlock-bodyworks
# 22901         NaN                                                NaN
# 22902         NaN  https://maps.google.com/maps/place/For+the+Joy...
# 22903         NaN                     https://g.page/MBSpa-Littleton
# 22904         NaN  https://maps.google.com/maps/place/Blue+Sky+Fi...
#
#       g_maps_claimed search_keyword      search_city  \
# 0            claimed    Boxing Club           Denver
# 1            claimed    Boxing Club           Denver
# 2            claimed    Boxing Club           Denver
# 3            claimed    Boxing Club           Denver
# 4            claimed    Boxing Club           Denver
# ...              ...            ...              ...
# 22900        claimed    Yoga Studio  Roxborough Park
# 22901            NaN    Yoga Studio  Roxborough Park
# 22902      unclaimed    Yoga Studio  Roxborough Park
# 22903        claimed    Yoga Studio  Roxborough Park
# 22904      unclaimed    Yoga Studio  Roxborough Park
#
#                            First Name Business Type
# 0                     Topeira Boxing        General
# 1                         Tos Boxing        General
# 2                       Tao Of Boxing       General
# 3      Bring It Back Boxing & Fitness       General
# 4                Blunt Force Training       General
# ...                               ...           ...
# 22900                Unlock Bodyworks       General
# 22901                    Karen Korona       General
# 22902                For The Joy Yoga       General
# 22903                   Mind Body Spa       General
# 22904                Blue Sky Fitness       General
#
# [22905 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city region    zip  ... ads_facebook ads_instagram ads_messenger  \
# 0         Denver     CO  80219  ...          NaN           NaN           NaN
# 1      Englewood     CO  80110  ...          NaN           NaN           NaN
# 2         Denver     CO  80218  ...          NaN           NaN           NaN
# 3         Denver     CO  80231  ...          NaN           NaN           NaN
# 4         Denver     CO  80216  ...          NaN           NaN           NaN
# ...          ...    ...    ...  ...          ...           ...           ...
# 22900     Denver     CO  80206  ...          NaN           NaN           NaN
# 22901  Littleton     CO  80120  ...          NaN           NaN           NaN
# 22902  Evergreen     CO     CO  ...          NaN           NaN           NaN
# 22903  Littleton     CO  80127  ...          NaN           NaN           NaN
# 22904   Morrison     CO  80465  ...          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Topeira+Box...
# 1             NaN  https://maps.google.com/maps/place/TOS+Boxing+...
# 2             NaN  https://maps.google.com/maps/place/Tao+of+Boxi...
# 3             NaN  https://maps.google.com/maps/place/Bring+It+Ba...
# 4             NaN  https://maps.google.com/maps/place/Blunt+force...
# ...           ...                                                ...
# 22900         NaN                    https://g.page/unlock-bodyworks
# 22901         NaN                                                NaN
# 22902         NaN  https://maps.google.com/maps/place/For+the+Joy...
# 22903         NaN                     https://g.page/MBSpa-Littleton
# 22904         NaN  https://maps.google.com/maps/place/Blue+Sky+Fi...
#
#       g_maps_claimed search_keyword      search_city  \
# 0            claimed    Boxing Club           Denver
# 1            claimed    Boxing Club           Denver
# 2            claimed    Boxing Club           Denver
# 3            claimed    Boxing Club           Denver
# 4            claimed    Boxing Club           Denver
# ...              ...            ...              ...
# 22900        claimed    Yoga Studio  Roxborough Park
# 22901            NaN    Yoga Studio  Roxborough Park
# 22902      unclaimed    Yoga Studio  Roxborough Park
# 22903        claimed    Yoga Studio  Roxborough Park
# 22904      unclaimed    Yoga Studio  Roxborough Park
#
#                            First Name Business Type
# 0                     Topeira Boxing         Boxing
# 1                         Tos Boxing         Boxing
# 2                       Tao Of Boxing        Boxing
# 3      Bring It Back Boxing & Fitness        Boxing
# 4                Blunt Force Training       General
# ...                               ...           ...
# 22900                Unlock Bodyworks       General
# 22901                    Karen Korona       General
# 22902                For The Joy Yoga          Yoga
# 22903                   Mind Body Spa       General
# 22904                Blue Sky Fitness       Fitness
#
# [22905 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                      First Name  \
# 0            Boxing                 Topeira Boxing
# 1            Boxing                     Tos Boxing
# 2            Boxing                   Tao Of Boxing
# 3            Boxing  Bring It Back Boxing & Fitness
# 4           General            Blunt Force Training
# ...             ...                             ...
# 22900       General                Unlock Bodyworks
# 22901       General                    Karen Korona
# 22902          Yoga                For The Joy Yoga
# 22903       General                   Mind Body Spa
# 22904       Fitness                Blue Sky Fitness
#
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city  ... instagram_average_comments ads_yelp ads_facebook  \
# 0         Denver  ...                          8      NaN          NaN
# 1      Englewood  ...                        NaN      NaN          NaN
# 2         Denver  ...                          1      NaN          NaN
# 3         Denver  ...                          2      NaN          NaN
# 4         Denver  ...                        NaN      NaN          NaN
# ...          ...  ...                        ...      ...          ...
# 22900     Denver  ...                        NaN      NaN          NaN
# 22901  Littleton  ...                        NaN      NaN          NaN
# 22902  Evergreen  ...                        NaN      NaN          NaN
# 22903  Littleton  ...                        NaN      NaN          NaN
# 22904   Morrison  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 22900           NaN           NaN         NaN
# 22901           NaN           NaN         NaN
# 22902           NaN           NaN         NaN
# 22903           NaN           NaN         NaN
# 22904           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Topeira+Box...        claimed
# 1      https://maps.google.com/maps/place/TOS+Boxing+...        claimed
# 2      https://maps.google.com/maps/place/Tao+of+Boxi...        claimed
# 3      https://maps.google.com/maps/place/Bring+It+Ba...        claimed
# 4      https://maps.google.com/maps/place/Blunt+force...        claimed
# ...                                                  ...            ...
# 22900                    https://g.page/unlock-bodyworks        claimed
# 22901                                                NaN            NaN
# 22902  https://maps.google.com/maps/place/For+the+Joy...      unclaimed
# 22903                     https://g.page/MBSpa-Littleton        claimed
# 22904  https://maps.google.com/maps/place/Blue+Sky+Fi...      unclaimed
#
#       search_keyword      search_city
# 0        Boxing Club           Denver
# 1        Boxing Club           Denver
# 2        Boxing Club           Denver
# 3        Boxing Club           Denver
# 4        Boxing Club           Denver
# ...              ...              ...
# 22900    Yoga Studio  Roxborough Park
# 22901    Yoga Studio  Roxborough Park
# 22902    Yoga Studio  Roxborough Park
# 22903    Yoga Studio  Roxborough Park
# 22904    Yoga Studio  Roxborough Park
#
# [22905 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                      First Name  \
# 0            Boxing                 Topeira Boxing
# 1            Boxing                     Tos Boxing
# 2            Boxing                   Tao Of Boxing
# 3            Boxing  Bring It Back Boxing & Fitness
# 4           General            Blunt Force Training
# ...             ...                             ...
# 22900       General                Unlock Bodyworks
# 22901       General                    Karen Korona
# 22902          Yoga                For The Joy Yoga
# 22903       General                   Mind Body Spa
# 22904       Fitness                Blue Sky Fitness
#
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city  ... instagram_average_comments ads_yelp ads_facebook  \
# 0         Denver  ...                          8      NaN          NaN
# 1      Englewood  ...                        NaN      NaN          NaN
# 2         Denver  ...                          1      NaN          NaN
# 3         Denver  ...                          2      NaN          NaN
# 4         Denver  ...                        NaN      NaN          NaN
# ...          ...  ...                        ...      ...          ...
# 22900     Denver  ...                        NaN      NaN          NaN
# 22901  Littleton  ...                        NaN      NaN          NaN
# 22902  Evergreen  ...                        NaN      NaN          NaN
# 22903  Littleton  ...                        NaN      NaN          NaN
# 22904   Morrison  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 22900           NaN           NaN         NaN
# 22901           NaN           NaN         NaN
# 22902           NaN           NaN         NaN
# 22903           NaN           NaN         NaN
# 22904           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Topeira+Box...        claimed
# 1      https://maps.google.com/maps/place/TOS+Boxing+...        claimed
# 2      https://maps.google.com/maps/place/Tao+of+Boxi...        claimed
# 3      https://maps.google.com/maps/place/Bring+It+Ba...        claimed
# 4      https://maps.google.com/maps/place/Blunt+force...        claimed
# ...                                                  ...            ...
# 22900                    https://g.page/unlock-bodyworks        claimed
# 22901                                                NaN            NaN
# 22902  https://maps.google.com/maps/place/For+the+Joy...      unclaimed
# 22903                     https://g.page/MBSpa-Littleton        claimed
# 22904  https://maps.google.com/maps/place/Blue+Sky+Fi...      unclaimed
#
#       search_keyword      search_city
# 0        Boxing Club           Denver
# 1        Boxing Club           Denver
# 2        Boxing Club           Denver
# 3        Boxing Club           Denver
# 4        Boxing Club           Denver
# ...              ...              ...
# 22900    Yoga Studio  Roxborough Park
# 22901    Yoga Studio  Roxborough Park
# 22902    Yoga Studio  Roxborough Park
# 22903    Yoga Studio  Roxborough Park
# 22904    Yoga Studio  Roxborough Park
#
# [22905 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                      First Name  \
# 0            Boxing                 Topeira Boxing
# 1            Boxing                     Tos Boxing
# 2            Boxing                   Tao Of Boxing
# 3            Boxing  Bring It Back Boxing & Fitness
# 4           General            Blunt Force Training
# ...             ...                             ...
# 22900       General                Unlock Bodyworks
# 22901       General                    Karen Korona
# 22902          Yoga                For The Joy Yoga
# 22903       General                   Mind Body Spa
# 22904       Fitness                Blue Sky Fitness
#
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city  ... instagram_average_comments ads_yelp ads_facebook  \
# 0         Denver  ...                          8      NaN          NaN
# 1      Englewood  ...                        NaN      NaN          NaN
# 2         Denver  ...                          1      NaN          NaN
# 3         Denver  ...                          2      NaN          NaN
# 4         Denver  ...                        NaN      NaN          NaN
# ...          ...  ...                        ...      ...          ...
# 22900     Denver  ...                        NaN      NaN          NaN
# 22901  Littleton  ...                        NaN      NaN          NaN
# 22902  Evergreen  ...                        NaN      NaN          NaN
# 22903  Littleton  ...                        NaN      NaN          NaN
# 22904   Morrison  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 22900           NaN           NaN         NaN
# 22901           NaN           NaN         NaN
# 22902           NaN           NaN         NaN
# 22903           NaN           NaN         NaN
# 22904           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Topeira+Box...        claimed
# 1      https://maps.google.com/maps/place/TOS+Boxing+...        claimed
# 2      https://maps.google.com/maps/place/Tao+of+Boxi...        claimed
# 3      https://maps.google.com/maps/place/Bring+It+Ba...        claimed
# 4      https://maps.google.com/maps/place/Blunt+force...        claimed
# ...                                                  ...            ...
# 22900                    https://g.page/unlock-bodyworks        claimed
# 22901                                                NaN            NaN
# 22902  https://maps.google.com/maps/place/For+the+Joy...      unclaimed
# 22903                     https://g.page/MBSpa-Littleton        claimed
# 22904  https://maps.google.com/maps/place/Blue+Sky+Fi...      unclaimed
#
#       search_keyword      search_city
# 0        Boxing Club           Denver
# 1        Boxing Club           Denver
# 2        Boxing Club           Denver
# 3        Boxing Club           Denver
# 4        Boxing Club           Denver
# ...              ...              ...
# 22900    Yoga Studio  Roxborough Park
# 22901    Yoga Studio  Roxborough Park
# 22902    Yoga Studio  Roxborough Park
# 22903    Yoga Studio  Roxborough Park
# 22904    Yoga Studio  Roxborough Park
#
# [22905 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                      First Name  \
# 0            Boxing                 Topeira Boxing
# 1            Boxing                     Tos Boxing
# 2            Boxing                   Tao Of Boxing
# 3            Boxing  Bring It Back Boxing & Fitness
# 4           General            Blunt Force Training
# ...             ...                             ...
# 22900       General                Unlock Bodyworks
# 22901       General                    Karen Korona
# 22902          Yoga                For The Joy Yoga
# 22903       General                   Mind Body Spa
# 22904       Fitness                Blue Sky Fitness
#
#                                  name          phone  \
# 0                 Topeira Boxing Club    17205327602
# 1                      Tos Boxing Gym    13032468749
# 2                       Tao Of Boxing    17209237928
# 3      Bring It Back Boxing & Fitness    17205884433
# 4                Blunt Force Training    17206631433
# ...                               ...            ...
# 22900                Unlock Bodyworks  17208197287.0
# 22901                    Karen Korona  13037389347.0
# 22902                For The Joy Yoga  13035133733.0
# 22903                   Mind Body Spa  13039335919.0
# 22904                Blue Sky Fitness  13039161460.0
#
#                              email           email_host  \
# 0         topeiraboxclub@gmail.com           google.com
# 1               info@tosboxing.com  inmotionhosting.com
# 2          jmontes@taoofboxing.com         bluehost.com
# 3      bringitbackboxing@gmail.com           google.com
# 4          tiffany@blunt-force.com           google.com
# ...                            ...                  ...
# 22900           ps.cross@yahoo.com            yahoo.com
# 22901        karen@karenkorona.com           google.com
# 22902    forthejoy.yoga@icloud.com           icloud.com
# 22903      mbholisticspa@gmail.com           google.com
# 22904                          NaN                  NaN
#
#                                            website  \
# 0                        http://topeiraboxing.com/
# 1                            http://tosboxing.com/
# 2                      http://www.taoofboxing.com/
# 3                   https://bringitbackboxing.com/
# 4                          http://blunt-force.com/
# ...                                            ...
# 22900             https://www.unlockbodyworks.com/
# 22901                      http://karenkorona.com/
# 22902                  https://www.forthejoy.yoga/
# 22903  https://mindbodyspa.wixsite.com/mindbodyspa
# 22904                                          NaN
#
#                          category                           address  \
# 0                      Boxing Gym                2702 W Alameda Ave
# 1                      Boxing Gym                3910 S Kalamath St
# 2      Physical Fitness Programme                 1331 E Colfax Ave
# 3                             Gym           8400 E Iliff Ave Unit 2
# 4                             Gym                     3993 Elati St
# ...                           ...                               ...
# 22900           Massage therapist                    815 E 17th Ave
# 22901                 Yoga studio                 1703 W Kettle Ave
# 22902                 Yoga studio               7824 Malamute Trail
# 22903             Massage Therapy  8321 Sangre De Cristo Rd Ste 204
# 22904            Personal trainer             7481 S Homesteader Dr
#
#             city  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         Denver  ...      NaN          NaN           NaN           NaN
# 1      Englewood  ...      NaN          NaN           NaN           NaN
# 2         Denver  ...      NaN          NaN           NaN           NaN
# 3         Denver  ...      NaN          NaN           NaN           NaN
# 4         Denver  ...      NaN          NaN           NaN           NaN
# ...          ...  ...      ...          ...           ...           ...
# 22900     Denver  ...      NaN          NaN           NaN           NaN
# 22901  Littleton  ...      NaN          NaN           NaN           NaN
# 22902  Evergreen  ...      NaN          NaN           NaN           NaN
# 22903  Littleton  ...      NaN          NaN           NaN           NaN
# 22904   Morrison  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Topeira+Box...
# 1             NaN  https://maps.google.com/maps/place/TOS+Boxing+...
# 2             NaN  https://maps.google.com/maps/place/Tao+of+Boxi...
# 3             NaN  https://maps.google.com/maps/place/Bring+It+Ba...
# 4             NaN  https://maps.google.com/maps/place/Blunt+force...
# ...           ...                                                ...
# 22900         NaN                    https://g.page/unlock-bodyworks
# 22901         NaN                                                NaN
# 22902         NaN  https://maps.google.com/maps/place/For+the+Joy...
# 22903         NaN                     https://g.page/MBSpa-Littleton
# 22904         NaN  https://maps.google.com/maps/place/Blue+Sky+Fi...
#
#       g_maps_claimed search_keyword      search_city  \
# 0            claimed    Boxing Club           Denver
# 1            claimed    Boxing Club           Denver
# 2            claimed    Boxing Club           Denver
# 3            claimed    Boxing Club           Denver
# 4            claimed    Boxing Club           Denver
# ...              ...            ...              ...
# 22900        claimed    Yoga Studio  Roxborough Park
# 22901            NaN    Yoga Studio  Roxborough Park
# 22902      unclaimed    Yoga Studio  Roxborough Park
# 22903        claimed    Yoga Studio  Roxborough Park
# 22904      unclaimed    Yoga Studio  Roxborough Park
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 22900  I saw B2 has a near perfect rating on Google. ...
# 22901  I saw your B2 star rating on Facebook. Really ...
# 22902  I saw B2 has a perfect rating on Google. 5 sta...
# 22903  I saw B2 has a perfect rating on Google. 5 sta...
# 22904  I saw your B2 page on Facebook. You guys have ...
#
# [22905 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('CO_combined_leads_duplicates_removed_semiclean.csv', index = False)
