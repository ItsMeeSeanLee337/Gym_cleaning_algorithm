# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("AR_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city region  \
# 0        Martial arts school         806 S Izard St  Little Rock     AR
# 1                Boxing club           800 W 8th St  Little Rock     AR
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock     AR
# 3        Martial arts school          1030 Front St       Conway     AR
# 4                     Boxing           1101 Mill St       Conway     AR
# ...                      ...                    ...          ...    ...
# 11126                 Health          1309 E 8th St     Danville     AR
# 11127    Vehicle repair shop            200 Main St     Danville     AR
# 11128             Government                  AR-10     Danville     AR
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock     AR
# 11130            Yoga studio         415 Fairfax Dr  Little Rock     AR
#
#          zip  ... instagram_average_comments ads_yelp ads_facebook  \
# 0      72202  ...                          2      NaN          NaN
# 1      72201  ...                        NaN      NaN          NaN
# 2      72202  ...                        NaN      NaN          NaN
# 3      72032  ...                          2      NaN          NaN
# 4      72032  ...                        NaN      NaN          NaN
# ...      ...  ...                        ...      ...          ...
# 11126  72833  ...                        NaN      NaN          NaN
# 11127  72833  ...                        NaN      NaN          NaN
# 11128  72833  ...                        NaN      NaN          NaN
# 11129  72205  ...                        NaN      NaN          NaN
# 11130  72205  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN           1
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 11126           NaN           NaN         NaN
# 11127           NaN           NaN         NaN
# 11128           NaN           NaN         NaN
# 11129           NaN           NaN         NaN
# 11130           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
# [11131 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('AR','')
df['First Name'] = df['First Name'].str.replace('Ar','')
df['First Name'] = df['First Name'].str.replace('Arkansas','')
df
# Out:
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas Boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city region  \
# 0        Martial arts school         806 S Izard St  Little Rock     AR
# 1                Boxing club           800 W 8th St  Little Rock     AR
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock     AR
# 3        Martial arts school          1030 Front St       Conway     AR
# 4                     Boxing           1101 Mill St       Conway     AR
# ...                      ...                    ...          ...    ...
# 11126                 Health          1309 E 8th St     Danville     AR
# 11127    Vehicle repair shop            200 Main St     Danville     AR
# 11128             Government                  AR-10     Danville     AR
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock     AR
# 11130            Yoga studio         415 Fairfax Dr  Little Rock     AR
#
#          zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0      72202  ...      NaN          NaN           NaN           NaN
# 1      72201  ...      NaN          NaN           NaN           NaN
# 2      72202  ...      NaN          NaN           NaN           NaN
# 3      72032  ...      NaN          NaN           NaN           NaN
# 4      72032  ...      NaN          NaN           NaN           NaN
# ...      ...  ...      ...          ...           ...           ...
# 11126  72833  ...      NaN          NaN           NaN           NaN
# 11127  72833  ...      NaN          NaN           NaN           NaN
# 11128  72833  ...      NaN          NaN           NaN           NaN
# 11129  72205  ...      NaN          NaN           NaN           NaN
# 11130  72205  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Westside+Mi...
# 1             NaN  https://maps.google.com/maps/place/Arkansas+bo...
# 2               1  https://maps.google.com/maps/place/Clubhaus+Fi...
# 3             NaN  https://maps.google.com/maps/place/Gravitas+Ma...
# 4             NaN  https://maps.google.com/maps/place/Gillespie+B...
# ...           ...                                                ...
# 11126         NaN  https://maps.google.com/maps/place/Yell+County...
# 11127         NaN  https://maps.google.com/maps/place/Blankenship...
# 11128         NaN  https://maps.google.com/maps/place/Usda+Servic...
# 11129         NaN  https://maps.google.com/maps/place/Sat+Nam+Yog...
# 11130         NaN  https://maps.google.com/maps/place/Viniyoga+Ar...
#
#       g_maps_claimed search_keyword                 search_city  \
# 0            claimed    Boxing Club                 Little Rock
# 1            claimed    Boxing Club                 Little Rock
# 2            claimed    Boxing Club                 Little Rock
# 3            claimed    Boxing Club                 Little Rock
# 4          unclaimed    Boxing Club                 Little Rock
# ...              ...            ...                         ...
# 11126      unclaimed    Yoga Studio                    Danville
# 11127        claimed    Yoga Studio                    Danville
# 11128      unclaimed    Yoga Studio                    Danville
# 11129        claimed    Yoga Studio  Little Rock Air Force Base
# 11130      unclaimed    Yoga Studio  Little Rock Air Force Base
#
#                               First Name
# 0                           Westside MMA
# 1                         kansas Boxing
# 2                           haus Fitness
# 3                    Gravitas Martial ts
# 4                       Gillespie Boxing
# ...                                  ...
# 11126  Yell County Health Unit- Danville
# 11127              Blankenships Pit Stop
# 11128                Usda Service Center
# 11129               Sat Nam Yoga Therapy
# 11130                    Viniyoga kansas
#
# [11131 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas Boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city region  \
# 0        Martial arts school         806 S Izard St  Little Rock     AR
# 1                Boxing club           800 W 8th St  Little Rock     AR
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock     AR
# 3        Martial arts school          1030 Front St       Conway     AR
# 4                     Boxing           1101 Mill St       Conway     AR
# ...                      ...                    ...          ...    ...
# 11126                 Health          1309 E 8th St     Danville     AR
# 11127    Vehicle repair shop            200 Main St     Danville     AR
# 11128             Government                  AR-10     Danville     AR
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock     AR
# 11130            Yoga studio         415 Fairfax Dr  Little Rock     AR
#
#          zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0      72202  ...      NaN          NaN           NaN           NaN
# 1      72201  ...      NaN          NaN           NaN           NaN
# 2      72202  ...      NaN          NaN           NaN           NaN
# 3      72032  ...      NaN          NaN           NaN           NaN
# 4      72032  ...      NaN          NaN           NaN           NaN
# ...      ...  ...      ...          ...           ...           ...
# 11126  72833  ...      NaN          NaN           NaN           NaN
# 11127  72833  ...      NaN          NaN           NaN           NaN
# 11128  72833  ...      NaN          NaN           NaN           NaN
# 11129  72205  ...      NaN          NaN           NaN           NaN
# 11130  72205  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Westside+Mi...
# 1             NaN  https://maps.google.com/maps/place/Arkansas+bo...
# 2               1  https://maps.google.com/maps/place/Clubhaus+Fi...
# 3             NaN  https://maps.google.com/maps/place/Gravitas+Ma...
# 4             NaN  https://maps.google.com/maps/place/Gillespie+B...
# ...           ...                                                ...
# 11126         NaN  https://maps.google.com/maps/place/Yell+County...
# 11127         NaN  https://maps.google.com/maps/place/Blankenship...
# 11128         NaN  https://maps.google.com/maps/place/Usda+Servic...
# 11129         NaN  https://maps.google.com/maps/place/Sat+Nam+Yog...
# 11130         NaN  https://maps.google.com/maps/place/Viniyoga+Ar...
#
#       g_maps_claimed search_keyword                 search_city  \
# 0            claimed    Boxing Club                 Little Rock
# 1            claimed    Boxing Club                 Little Rock
# 2            claimed    Boxing Club                 Little Rock
# 3            claimed    Boxing Club                 Little Rock
# 4          unclaimed    Boxing Club                 Little Rock
# ...              ...            ...                         ...
# 11126      unclaimed    Yoga Studio                    Danville
# 11127        claimed    Yoga Studio                    Danville
# 11128      unclaimed    Yoga Studio                    Danville
# 11129        claimed    Yoga Studio  Little Rock Air Force Base
# 11130      unclaimed    Yoga Studio  Little Rock Air Force Base
#
#                               First Name
# 0                           Westside MMA
# 1                         kansas Boxing
# 2                           haus Fitness
# 3                    Gravitas Martial ts
# 4                       Gillespie Boxing
# ...                                  ...
# 11126  Yell County Health Unit- Danville
# 11127              Blankenships Pit Stop
# 11128                Usda Service Center
# 11129               Sat Nam Yoga Therapy
# 11130                    Viniyoga kansas
#
# [11131 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas Boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city region  \
# 0        Martial arts school         806 S Izard St  Little Rock     AR
# 1                Boxing club           800 W 8th St  Little Rock     AR
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock     AR
# 3        Martial arts school          1030 Front St       Conway     AR
# 4                     Boxing           1101 Mill St       Conway     AR
# ...                      ...                    ...          ...    ...
# 11126                 Health          1309 E 8th St     Danville     AR
# 11127    Vehicle repair shop            200 Main St     Danville     AR
# 11128             Government                  AR-10     Danville     AR
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock     AR
# 11130            Yoga studio         415 Fairfax Dr  Little Rock     AR
#
#          zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0      72202  ...          NaN           NaN           NaN         NaN
# 1      72201  ...          NaN           NaN           NaN         NaN
# 2      72202  ...          NaN           NaN           NaN           1
# 3      72032  ...          NaN           NaN           NaN         NaN
# 4      72032  ...          NaN           NaN           NaN         NaN
# ...      ...  ...          ...           ...           ...         ...
# 11126  72833  ...          NaN           NaN           NaN         NaN
# 11127  72833  ...          NaN           NaN           NaN         NaN
# 11128  72833  ...          NaN           NaN           NaN         NaN
# 11129  72205  ...          NaN           NaN           NaN         NaN
# 11130  72205  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city  \
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
#                               First Name Business Type
# 0                           Westside MMA           NaT
# 1                         kansas Boxing            NaT
# 2                           haus Fitness           NaT
# 3                    Gravitas Martial ts           NaT
# 4                       Gillespie Boxing           NaT
# ...                                  ...           ...
# 11126  Yell County Health Unit- Danville           NaT
# 11127              Blankenships Pit Stop           NaT
# 11128                Usda Service Center           NaT
# 11129               Sat Nam Yoga Therapy           NaT
# 11130                    Viniyoga kansas           NaT
#
# [11131 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas Boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city region  \
# 0        Martial arts school         806 S Izard St  Little Rock     AR
# 1                Boxing club           800 W 8th St  Little Rock     AR
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock     AR
# 3        Martial arts school          1030 Front St       Conway     AR
# 4                     Boxing           1101 Mill St       Conway     AR
# ...                      ...                    ...          ...    ...
# 11126                 Health          1309 E 8th St     Danville     AR
# 11127    Vehicle repair shop            200 Main St     Danville     AR
# 11128             Government                  AR-10     Danville     AR
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock     AR
# 11130            Yoga studio         415 Fairfax Dr  Little Rock     AR
#
#          zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0      72202  ...          NaN           NaN           NaN         NaN
# 1      72201  ...          NaN           NaN           NaN         NaN
# 2      72202  ...          NaN           NaN           NaN           1
# 3      72032  ...          NaN           NaN           NaN         NaN
# 4      72032  ...          NaN           NaN           NaN         NaN
# ...      ...  ...          ...           ...           ...         ...
# 11126  72833  ...          NaN           NaN           NaN         NaN
# 11127  72833  ...          NaN           NaN           NaN         NaN
# 11128  72833  ...          NaN           NaN           NaN         NaN
# 11129  72205  ...          NaN           NaN           NaN         NaN
# 11130  72205  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city  \
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
#                               First Name Business Type
# 0                           Westside MMA       General
# 1                         kansas Boxing        General
# 2                           haus Fitness       General
# 3                    Gravitas Martial ts       General
# 4                       Gillespie Boxing       General
# ...                                  ...           ...
# 11126  Yell County Health Unit- Danville       General
# 11127              Blankenships Pit Stop       General
# 11128                Usda Service Center       General
# 11129               Sat Nam Yoga Therapy       General
# 11130                    Viniyoga kansas       General
#
# [11131 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas Boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city region  \
# 0        Martial arts school         806 S Izard St  Little Rock     AR
# 1                Boxing club           800 W 8th St  Little Rock     AR
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock     AR
# 3        Martial arts school          1030 Front St       Conway     AR
# 4                     Boxing           1101 Mill St       Conway     AR
# ...                      ...                    ...          ...    ...
# 11126                 Health          1309 E 8th St     Danville     AR
# 11127    Vehicle repair shop            200 Main St     Danville     AR
# 11128             Government                  AR-10     Danville     AR
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock     AR
# 11130            Yoga studio         415 Fairfax Dr  Little Rock     AR
#
#          zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0      72202  ...          NaN           NaN           NaN         NaN
# 1      72201  ...          NaN           NaN           NaN         NaN
# 2      72202  ...          NaN           NaN           NaN           1
# 3      72032  ...          NaN           NaN           NaN         NaN
# 4      72032  ...          NaN           NaN           NaN         NaN
# ...      ...  ...          ...           ...           ...         ...
# 11126  72833  ...          NaN           NaN           NaN         NaN
# 11127  72833  ...          NaN           NaN           NaN         NaN
# 11128  72833  ...          NaN           NaN           NaN         NaN
# 11129  72205  ...          NaN           NaN           NaN         NaN
# 11130  72205  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city  \
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
#                               First Name Business Type
# 0                           Westside MMA  Martial Arts
# 1                         kansas Boxing         Boxing
# 2                           haus Fitness       Fitness
# 3                    Gravitas Martial ts       General
# 4                       Gillespie Boxing        Boxing
# ...                                  ...           ...
# 11126  Yell County Health Unit- Danville       General
# 11127              Blankenships Pit Stop       General
# 11128                Usda Service Center       General
# 11129               Sat Nam Yoga Therapy          Yoga
# 11130                    Viniyoga kansas       General
#
# [11131 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                         First Name  \
# 0      Martial Arts                       Westside MMA
# 1            Boxing                     kansas Boxing
# 2           Fitness                       haus Fitness
# 3           General                Gravitas Martial ts
# 4            Boxing                   Gillespie Boxing
# ...             ...                                ...
# 11126       General  Yell County Health Unit- Danville
# 11127       General              Blankenships Pit Stop
# 11128       General                Usda Service Center
# 11129          Yoga               Sat Nam Yoga Therapy
# 11130       General                    Viniyoga kansas
#
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas Boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city  ...  \
# 0        Martial arts school         806 S Izard St  Little Rock  ...
# 1                Boxing club           800 W 8th St  Little Rock  ...
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock  ...
# 3        Martial arts school          1030 Front St       Conway  ...
# 4                     Boxing           1101 Mill St       Conway  ...
# ...                      ...                    ...          ...  ...
# 11126                 Health          1309 E 8th St     Danville  ...
# 11127    Vehicle repair shop            200 Main St     Danville  ...
# 11128             Government                  AR-10     Danville  ...
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock  ...
# 11130            Yoga studio         415 Fairfax Dr  Little Rock  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                              2      NaN          NaN           NaN
# 1                            NaN      NaN          NaN           NaN
# 2                            NaN      NaN          NaN           NaN
# 3                              2      NaN          NaN           NaN
# 4                            NaN      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 11126                        NaN      NaN          NaN           NaN
# 11127                        NaN      NaN          NaN           NaN
# 11128                        NaN      NaN          NaN           NaN
# 11129                        NaN      NaN          NaN           NaN
# 11130                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN           1
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 11126           NaN         NaN
# 11127           NaN         NaN
# 11128           NaN         NaN
# 11129           NaN         NaN
# 11130           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
# [11131 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                        First Name  \
# 0      Martial Arts                      Westside MMA
# 1            Boxing                    kansas Boxing
# 2           Fitness                      haus Fitness
# 3           General               Gravitas Martial ts
# 4            Boxing                  Gillespie Boxing
# ...             ...                               ...
# 11126       General  Yell County Health Unit Danville
# 11127       General             Blankenships Pit Stop
# 11128       General               Usda Service Center
# 11129          Yoga              Sat Nam Yoga Therapy
# 11130       General                   Viniyoga kansas
#
#                                     name        phone  \
# 0            Westside Mixed Martial Arts  15016633850
# 1                   Arkansas Boxing Club  15012405993
# 2                       Clubhaus Fitness  15019169587
# 3                  Gravitas Martial Arts  15012050186
# 4                       Gillespie Boxing  15012058604
# ...                                  ...          ...
# 11126  Yell County Health Unit- Danville  14794952741
# 11127              Blankenships Pit Stop  14794952686
# 11128                Usda Service Center  14794952441
# 11129               Sat Nam Yoga Therapy  14048087511
# 11130                  Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city  ...  \
# 0        Martial arts school         806 S Izard St  Little Rock  ...
# 1                Boxing club           800 W 8th St  Little Rock  ...
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock  ...
# 3        Martial arts school          1030 Front St       Conway  ...
# 4                     Boxing           1101 Mill St       Conway  ...
# ...                      ...                    ...          ...  ...
# 11126                 Health          1309 E 8th St     Danville  ...
# 11127    Vehicle repair shop            200 Main St     Danville  ...
# 11128             Government                  AR-10     Danville  ...
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock  ...
# 11130            Yoga studio         415 Fairfax Dr  Little Rock  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                              2      NaN          NaN           NaN
# 1                            NaN      NaN          NaN           NaN
# 2                            NaN      NaN          NaN           NaN
# 3                              2      NaN          NaN           NaN
# 4                            NaN      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 11126                        NaN      NaN          NaN           NaN
# 11127                        NaN      NaN          NaN           NaN
# 11128                        NaN      NaN          NaN           NaN
# 11129                        NaN      NaN          NaN           NaN
# 11130                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN           1
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 11126           NaN         NaN
# 11127           NaN         NaN
# 11128           NaN         NaN
# 11129           NaN         NaN
# 11130           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
# [11131 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                First Name  \
# 0      Martial Arts              Westside MMA
# 1            Boxing            kansas Boxing
# 2           Fitness              haus Fitness
# 3           General       Gravitas Martial ts
# 4            Boxing          Gillespie Boxing
# ...             ...                       ...
# 11126       General  Yell County Health Unit
# 11127       General     Blankenships Pit Stop
# 11128       General       Usda Service Center
# 11129          Yoga      Sat Nam Yoga Therapy
# 11130       General           Viniyoga kansas
#
#                                       name        phone  \
# 0              Westside Mixed Martial Arts  15016633850
# 1                     Arkansas Boxing Club  15012405993
# 2                         Clubhaus Fitness  15019169587
# 3                    Gravitas Martial Arts  15012050186
# 4                         Gillespie Boxing  15012058604
# ...                                    ...          ...
# 11126  Yell County Health Unit- (Danville)  14794952741
# 11127                Blankenships Pit Stop  14794952686
# 11128                  Usda Service Center  14794952441
# 11129                 Sat Nam Yoga Therapy  14048087511
# 11130                    Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city  ...  \
# 0        Martial arts school         806 S Izard St  Little Rock  ...
# 1                Boxing club           800 W 8th St  Little Rock  ...
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock  ...
# 3        Martial arts school          1030 Front St       Conway  ...
# 4                     Boxing           1101 Mill St       Conway  ...
# ...                      ...                    ...          ...  ...
# 11126                 Health          1309 E 8th St     Danville  ...
# 11127    Vehicle repair shop            200 Main St     Danville  ...
# 11128             Government                  AR-10     Danville  ...
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock  ...
# 11130            Yoga studio         415 Fairfax Dr  Little Rock  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                              2      NaN          NaN           NaN
# 1                            NaN      NaN          NaN           NaN
# 2                            NaN      NaN          NaN           NaN
# 3                              2      NaN          NaN           NaN
# 4                            NaN      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 11126                        NaN      NaN          NaN           NaN
# 11127                        NaN      NaN          NaN           NaN
# 11128                        NaN      NaN          NaN           NaN
# 11129                        NaN      NaN          NaN           NaN
# 11130                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN           1
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 11126           NaN         NaN
# 11127           NaN         NaN
# 11128           NaN         NaN
# 11129           NaN         NaN
# 11130           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
# [11131 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                First Name  \
# 0      Martial Arts              Westside MMA
# 1            Boxing            kansas Boxing
# 2           Fitness              haus Fitness
# 3           General       Gravitas Martial ts
# 4            Boxing          Gillespie Boxing
# ...             ...                       ...
# 11126       General  Yell County Health Unit
# 11127       General     Blankenships Pit Stop
# 11128       General       Usda Service Center
# 11129          Yoga      Sat Nam Yoga Therapy
# 11130       General           Viniyoga kansas
#
#                                       name        phone  \
# 0              Westside Mixed Martial Arts  15016633850
# 1                     Arkansas Boxing Club  15012405993
# 2                         Clubhaus Fitness  15019169587
# 3                    Gravitas Martial Arts  15012050186
# 4                         Gillespie Boxing  15012058604
# ...                                    ...          ...
# 11126  Yell County Health Unit- (Danville)  14794952741
# 11127                Blankenships Pit Stop  14794952686
# 11128                  Usda Service Center  14794952441
# 11129                 Sat Nam Yoga Therapy  14048087511
# 11130                    Viniyoga Arkansas  15016611121
#
#                                  email   email_host  \
# 0               rolijuju2000@yahoo.com    yahoo.com
# 1      diamondrockpromotions@gmail.com   google.com
# 2            elise@clubhausfitness.com  outlook.com
# 3                gravitasmma@gmail.com   google.com
# 4                                  NaN          NaN
# ...                                ...          ...
# 11126                              NaN          NaN
# 11127    blankenship.pitstop@gmail.com   google.com
# 11128                              NaN          NaN
# 11129   courtney@satnamyogatherapy.com   google.com
# 11130                              NaN          NaN
#
#                                                  website  \
# 0                                http://westsidemma.com/
# 1      https://www.diamondrockpromotions.com/central-...
# 2                        http://www.clubhausfitness.com/
# 3                            http://www.gravitasmma.com/
# 4                        http://www.gillespieboxing.com/
# ...                                                  ...
# 11126                                                NaN
# 11127                                                NaN
# 11128                                                NaN
# 11129                 https://www.satnamyogatherapy.com/
# 11130                                                NaN
#
#                     category                address         city  ...  \
# 0        Martial arts school         806 S Izard St  Little Rock  ...
# 1                Boxing club           800 W 8th St  Little Rock  ...
# 2      Fitness & Instruction  1207 Rebsamen Park Rd  Little Rock  ...
# 3        Martial arts school          1030 Front St       Conway  ...
# 4                     Boxing           1101 Mill St       Conway  ...
# ...                      ...                    ...          ...  ...
# 11126                 Health          1309 E 8th St     Danville  ...
# 11127    Vehicle repair shop            200 Main St     Danville  ...
# 11128             Government                  AR-10     Danville  ...
# 11129   Mental Health Clinic      5506 W Markham St  Little Rock  ...
# 11130            Yoga studio         415 Fairfax Dr  Little Rock  ...
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN         NaN
# 2          NaN          NaN           NaN           NaN           1
# 3          NaN          NaN           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN         NaN
# ...        ...          ...           ...           ...         ...
# 11126      NaN          NaN           NaN           NaN         NaN
# 11127      NaN          NaN           NaN           NaN         NaN
# 11128      NaN          NaN           NaN           NaN         NaN
# 11129      NaN          NaN           NaN           NaN         NaN
# 11130      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Westside+Mi...        claimed
# 1      https://maps.google.com/maps/place/Arkansas+bo...        claimed
# 2      https://maps.google.com/maps/place/Clubhaus+Fi...        claimed
# 3      https://maps.google.com/maps/place/Gravitas+Ma...        claimed
# 4      https://maps.google.com/maps/place/Gillespie+B...      unclaimed
# ...                                                  ...            ...
# 11126  https://maps.google.com/maps/place/Yell+County...      unclaimed
# 11127  https://maps.google.com/maps/place/Blankenship...        claimed
# 11128  https://maps.google.com/maps/place/Usda+Servic...      unclaimed
# 11129  https://maps.google.com/maps/place/Sat+Nam+Yog...        claimed
# 11130  https://maps.google.com/maps/place/Viniyoga+Ar...      unclaimed
#
#       search_keyword                 search_city  \
# 0        Boxing Club                 Little Rock
# 1        Boxing Club                 Little Rock
# 2        Boxing Club                 Little Rock
# 3        Boxing Club                 Little Rock
# 4        Boxing Club                 Little Rock
# ...              ...                         ...
# 11126    Yoga Studio                    Danville
# 11127    Yoga Studio                    Danville
# 11128    Yoga Studio                    Danville
# 11129    Yoga Studio  Little Rock Air Force Base
# 11130    Yoga Studio  Little Rock Air Force Base
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a perfect rating on Google. 5 sta...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a perfect rating on Google. 5 sta...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 11126  I saw your B2 page on Facebook. You guys have ...
# 11127  I saw B2 has a near perfect rating on Google. ...
# 11128  I saw your B2 page on Facebook. You guys have ...
# 11129  I saw B2 has a perfect rating on Google. 5 sta...
# 11130  I saw your B2 star rating on Facebook. Really ...
#
# [11131 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('AR_combined_leads_duplicates_removed_semiclean.csv', index = False)
