# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("MS_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts MMA Academy  16013165697
# 4                     Precision Martial Arts of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive and Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city region    zip  \
# 0         Kickboxing school  856 State St Suite E    Jackson     MS  39201
# 1               Boxing club   2420 Old Brandon Rd      Pearl     MS  39208
# 2                       Gym  856 State St Suite D    Jackson     MS  39201
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland     MS  39157
# 4       Martial arts school   624 Grants Ferry Rd    Flowood     MS  39232
# ...                     ...                   ...        ...    ...    ...
# 9125        Wellness Centre         838 Mill St A   Lucedale     MS  39452
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale     MS  39452
# 9127           Dance school           17252 MS-26   Lucedale     MS  39452
# 9128                 Church           18194 MS-26   Lucedale     MS  39452
# 9129  Fitness & Instruction       24980 State Ave    Elberta     AL  36530
#
#       ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0     ...                          1      NaN          NaN           NaN
# 1     ...                          2      NaN          NaN           NaN
# 2     ...                        NaN      NaN          NaN           NaN
# 3     ...                        NaN      NaN          NaN           NaN
# 4     ...                          2      NaN          NaN           NaN
# ...   ...                        ...      ...          ...           ...
# 9125  ...                        NaN      NaN          NaN           NaN
# 9126  ...                        NaN      NaN          NaN           NaN
# 9127  ...                        NaN      NaN          NaN           NaN
# 9128  ...                        NaN      NaN          NaN           NaN
# 9129  ...                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 9125           NaN         NaN
# 9126           NaN         NaN
# 9127           NaN         NaN
# 9128           NaN         NaN
# 9129           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
# [9130 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('MS','')
df['First Name'] = df['First Name'].str.replace('Ms','')
df['First Name'] = df['First Name'].str.replace('Mississippi','')
df
# Out:
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city region    zip  \
# 0         Kickboxing school  856 State St Suite E    Jackson     MS  39201
# 1               Boxing club   2420 Old Brandon Rd      Pearl     MS  39208
# 2                       Gym  856 State St Suite D    Jackson     MS  39201
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland     MS  39157
# 4       Martial arts school   624 Grants Ferry Rd    Flowood     MS  39232
# ...                     ...                   ...        ...    ...    ...
# 9125        Wellness Centre         838 Mill St A   Lucedale     MS  39452
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale     MS  39452
# 9127           Dance school           17252 MS-26   Lucedale     MS  39452
# 9128                 Church           18194 MS-26   Lucedale     MS  39452
# 9129  Fitness & Instruction       24980 State Ave    Elberta     AL  36530
#
#       ... ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...      NaN          NaN           NaN           NaN         NaN
# 1     ...      NaN          NaN           NaN           NaN         NaN
# 2     ...      NaN          NaN           NaN           NaN         NaN
# 3     ...      NaN          NaN           NaN           NaN         NaN
# 4     ...      NaN          NaN           NaN           NaN         NaN
# ...   ...      ...          ...           ...           ...         ...
# 9125  ...      NaN          NaN           NaN           NaN         NaN
# 9126  ...      NaN          NaN           NaN           NaN         NaN
# 9127  ...      NaN          NaN           NaN           NaN         NaN
# 9128  ...      NaN          NaN           NaN           NaN         NaN
# 9129  ...      NaN          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city  \
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
#                                              First Name
# 0                                      Boxers Rebellion
# 1                                         Pearl Boxing
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...
# 3                                    Marshall Arts Mma
# 4                     Precision Martial Arts Of Flowood
# ...                                                 ...
# 9125      George Regional Health System Wellness Center
# 9126                            Ascension Dive And Yoga
# 9127                              Premiere Dance Center
# 9128                   Lighthouse Worship Center U.P.C.
# 9129                                     Hut Of Elberta
#
# [9130 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city region    zip  \
# 0         Kickboxing school  856 State St Suite E    Jackson     MS  39201
# 1               Boxing club   2420 Old Brandon Rd      Pearl     MS  39208
# 2                       Gym  856 State St Suite D    Jackson     MS  39201
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland     MS  39157
# 4       Martial arts school   624 Grants Ferry Rd    Flowood     MS  39232
# ...                     ...                   ...        ...    ...    ...
# 9125        Wellness Centre         838 Mill St A   Lucedale     MS  39452
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale     MS  39452
# 9127           Dance school           17252 MS-26   Lucedale     MS  39452
# 9128                 Church           18194 MS-26   Lucedale     MS  39452
# 9129  Fitness & Instruction       24980 State Ave    Elberta     AL  36530
#
#       ... ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...      NaN          NaN           NaN           NaN         NaN
# 1     ...      NaN          NaN           NaN           NaN         NaN
# 2     ...      NaN          NaN           NaN           NaN         NaN
# 3     ...      NaN          NaN           NaN           NaN         NaN
# 4     ...      NaN          NaN           NaN           NaN         NaN
# ...   ...      ...          ...           ...           ...         ...
# 9125  ...      NaN          NaN           NaN           NaN         NaN
# 9126  ...      NaN          NaN           NaN           NaN         NaN
# 9127  ...      NaN          NaN           NaN           NaN         NaN
# 9128  ...      NaN          NaN           NaN           NaN         NaN
# 9129  ...      NaN          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city  \
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
#                                           First Name
# 0                                   Boxers Rebellion
# 1                                      Pearl Boxing
# 2     Compound Fitness Studios/Tyrone Hargro Sports
# 3                                 Marshall Arts Mma
# 4                  Precision Martial Arts Of Flowood
# ...                                              ...
# 9125   George Regional Health System Wellness Center
# 9126                         Ascension Dive And Yoga
# 9127                           Premiere Dance Center
# 9128                Lighthouse Worship Center U.P.C.
# 9129                                  Hut Of Elberta
#
# [9130 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city region    zip  \
# 0         Kickboxing school  856 State St Suite E    Jackson     MS  39201
# 1               Boxing club   2420 Old Brandon Rd      Pearl     MS  39208
# 2                       Gym  856 State St Suite D    Jackson     MS  39201
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland     MS  39157
# 4       Martial arts school   624 Grants Ferry Rd    Flowood     MS  39232
# ...                     ...                   ...        ...    ...    ...
# 9125        Wellness Centre         838 Mill St A   Lucedale     MS  39452
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale     MS  39452
# 9127           Dance school           17252 MS-26   Lucedale     MS  39452
# 9128                 Church           18194 MS-26   Lucedale     MS  39452
# 9129  Fitness & Instruction       24980 State Ave    Elberta     AL  36530
#
#       ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...          NaN           NaN           NaN         NaN
# 1     ...          NaN           NaN           NaN         NaN
# 2     ...          NaN           NaN           NaN         NaN
# 3     ...          NaN           NaN           NaN         NaN
# 4     ...          NaN           NaN           NaN         NaN
# ...   ...          ...           ...           ...         ...
# 9125  ...          NaN           NaN           NaN         NaN
# 9126  ...          NaN           NaN           NaN         NaN
# 9127  ...          NaN           NaN           NaN         NaN
# 9128  ...          NaN           NaN           NaN         NaN
# 9129  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city  \
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
#                                           First Name Business Type
# 0                                   Boxers Rebellion           NaT
# 1                                      Pearl Boxing            NaT
# 2     Compound Fitness Studios/Tyrone Hargro Sports            NaT
# 3                                 Marshall Arts Mma            NaT
# 4                  Precision Martial Arts Of Flowood           NaT
# ...                                              ...           ...
# 9125   George Regional Health System Wellness Center           NaT
# 9126                         Ascension Dive And Yoga           NaT
# 9127                           Premiere Dance Center           NaT
# 9128                Lighthouse Worship Center U.P.C.           NaT
# 9129                                  Hut Of Elberta           NaT
#
# [9130 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city region    zip  \
# 0         Kickboxing school  856 State St Suite E    Jackson     MS  39201
# 1               Boxing club   2420 Old Brandon Rd      Pearl     MS  39208
# 2                       Gym  856 State St Suite D    Jackson     MS  39201
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland     MS  39157
# 4       Martial arts school   624 Grants Ferry Rd    Flowood     MS  39232
# ...                     ...                   ...        ...    ...    ...
# 9125        Wellness Centre         838 Mill St A   Lucedale     MS  39452
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale     MS  39452
# 9127           Dance school           17252 MS-26   Lucedale     MS  39452
# 9128                 Church           18194 MS-26   Lucedale     MS  39452
# 9129  Fitness & Instruction       24980 State Ave    Elberta     AL  36530
#
#       ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...          NaN           NaN           NaN         NaN
# 1     ...          NaN           NaN           NaN         NaN
# 2     ...          NaN           NaN           NaN         NaN
# 3     ...          NaN           NaN           NaN         NaN
# 4     ...          NaN           NaN           NaN         NaN
# ...   ...          ...           ...           ...         ...
# 9125  ...          NaN           NaN           NaN         NaN
# 9126  ...          NaN           NaN           NaN         NaN
# 9127  ...          NaN           NaN           NaN         NaN
# 9128  ...          NaN           NaN           NaN         NaN
# 9129  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city  \
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
#                                           First Name Business Type
# 0                                   Boxers Rebellion       General
# 1                                      Pearl Boxing        General
# 2     Compound Fitness Studios/Tyrone Hargro Sports        General
# 3                                 Marshall Arts Mma        General
# 4                  Precision Martial Arts Of Flowood       General
# ...                                              ...           ...
# 9125   George Regional Health System Wellness Center       General
# 9126                         Ascension Dive And Yoga       General
# 9127                           Premiere Dance Center       General
# 9128                Lighthouse Worship Center U.P.C.       General
# 9129                                  Hut Of Elberta       General
#
# [9130 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city region    zip  \
# 0         Kickboxing school  856 State St Suite E    Jackson     MS  39201
# 1               Boxing club   2420 Old Brandon Rd      Pearl     MS  39208
# 2                       Gym  856 State St Suite D    Jackson     MS  39201
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland     MS  39157
# 4       Martial arts school   624 Grants Ferry Rd    Flowood     MS  39232
# ...                     ...                   ...        ...    ...    ...
# 9125        Wellness Centre         838 Mill St A   Lucedale     MS  39452
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale     MS  39452
# 9127           Dance school           17252 MS-26   Lucedale     MS  39452
# 9128                 Church           18194 MS-26   Lucedale     MS  39452
# 9129  Fitness & Instruction       24980 State Ave    Elberta     AL  36530
#
#       ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...          NaN           NaN           NaN         NaN
# 1     ...          NaN           NaN           NaN         NaN
# 2     ...          NaN           NaN           NaN         NaN
# 3     ...          NaN           NaN           NaN         NaN
# 4     ...          NaN           NaN           NaN         NaN
# ...   ...          ...           ...           ...         ...
# 9125  ...          NaN           NaN           NaN         NaN
# 9126  ...          NaN           NaN           NaN         NaN
# 9127  ...          NaN           NaN           NaN         NaN
# 9128  ...          NaN           NaN           NaN         NaN
# 9129  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city  \
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
#                                           First Name Business Type
# 0                                   Boxers Rebellion       General
# 1                                      Pearl Boxing         Boxing
# 2     Compound Fitness Studios/Tyrone Hargro Sports        Fitness
# 3                                 Marshall Arts Mma        General
# 4                  Precision Martial Arts Of Flowood  Martial Arts
# ...                                              ...           ...
# 9125   George Regional Health System Wellness Center       General
# 9126                         Ascension Dive And Yoga          Yoga
# 9127                           Premiere Dance Center       General
# 9128                Lighthouse Worship Center U.P.C.       General
# 9129                                  Hut Of Elberta       General
#
# [9130 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#      Business Type                                      First Name  \
# 0          General                                Boxers Rebellion
# 1           Boxing                                   Pearl Boxing
# 2          Fitness  Compound Fitness Studios/Tyrone Hargro Sports
# 3          General                              Marshall Arts Mma
# 4     Martial Arts               Precision Martial Arts Of Flowood
# ...            ...                                             ...
# 9125       General   George Regional Health System Wellness Center
# 9126          Yoga                         Ascension Dive And Yoga
# 9127       General                           Premiere Dance Center
# 9128       General                Lighthouse Worship Center U.P.C.
# 9129       General                                  Hut Of Elberta
#
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city  ...  \
# 0         Kickboxing school  856 State St Suite E    Jackson  ...
# 1               Boxing club   2420 Old Brandon Rd      Pearl  ...
# 2                       Gym  856 State St Suite D    Jackson  ...
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland  ...
# 4       Martial arts school   624 Grants Ferry Rd    Flowood  ...
# ...                     ...                   ...        ...  ...
# 9125        Wellness Centre         838 Mill St A   Lucedale  ...
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale  ...
# 9127           Dance school           17252 MS-26   Lucedale  ...
# 9128                 Church           18194 MS-26   Lucedale  ...
# 9129  Fitness & Instruction       24980 State Ave    Elberta  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                             1      NaN          NaN           NaN
# 1                             2      NaN          NaN           NaN
# 2                           NaN      NaN          NaN           NaN
# 3                           NaN      NaN          NaN           NaN
# 4                             2      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 9125                        NaN      NaN          NaN           NaN
# 9126                        NaN      NaN          NaN           NaN
# 9127                        NaN      NaN          NaN           NaN
# 9128                        NaN      NaN          NaN           NaN
# 9129                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 9125           NaN         NaN
# 9126           NaN         NaN
# 9127           NaN         NaN
# 9128           NaN         NaN
# 9129           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
# [9130 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#      Business Type                                     First Name  \
# 0          General                               Boxers Rebellion
# 1           Boxing                                  Pearl Boxing
# 2          Fitness  Compound Fitness StudiosTyrone Hargro Sports
# 3          General                             Marshall Arts Mma
# 4     Martial Arts              Precision Martial Arts Of Flowood
# ...            ...                                            ...
# 9125       General  George Regional Health System Wellness Center
# 9126          Yoga                        Ascension Dive And Yoga
# 9127       General                          Premiere Dance Center
# 9128       General                  Lighthouse Worship Center UPC
# 9129       General                                 Hut Of Elberta
#
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city  ...  \
# 0         Kickboxing school  856 State St Suite E    Jackson  ...
# 1               Boxing club   2420 Old Brandon Rd      Pearl  ...
# 2                       Gym  856 State St Suite D    Jackson  ...
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland  ...
# 4       Martial arts school   624 Grants Ferry Rd    Flowood  ...
# ...                     ...                   ...        ...  ...
# 9125        Wellness Centre         838 Mill St A   Lucedale  ...
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale  ...
# 9127           Dance school           17252 MS-26   Lucedale  ...
# 9128                 Church           18194 MS-26   Lucedale  ...
# 9129  Fitness & Instruction       24980 State Ave    Elberta  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                             1      NaN          NaN           NaN
# 1                             2      NaN          NaN           NaN
# 2                           NaN      NaN          NaN           NaN
# 3                           NaN      NaN          NaN           NaN
# 4                             2      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 9125                        NaN      NaN          NaN           NaN
# 9126                        NaN      NaN          NaN           NaN
# 9127                        NaN      NaN          NaN           NaN
# 9128                        NaN      NaN          NaN           NaN
# 9129                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 9125           NaN         NaN
# 9126           NaN         NaN
# 9127           NaN         NaN
# 9128           NaN         NaN
# 9129           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
# [9130 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#      Business Type                                     First Name  \
# 0          General                               Boxers Rebellion
# 1           Boxing                                  Pearl Boxing
# 2          Fitness  Compound Fitness StudiosTyrone Hargro Sports
# 3          General                             Marshall Arts Mma
# 4     Martial Arts              Precision Martial Arts Of Flowood
# ...            ...                                            ...
# 9125       General  George Regional Health System Wellness Center
# 9126          Yoga                        Ascension Dive And Yoga
# 9127       General                          Premiere Dance Center
# 9128       General                  Lighthouse Worship Center UPC
# 9129       General                                 Hut Of Elberta
#
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city  ...  \
# 0         Kickboxing school  856 State St Suite E    Jackson  ...
# 1               Boxing club   2420 Old Brandon Rd      Pearl  ...
# 2                       Gym  856 State St Suite D    Jackson  ...
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland  ...
# 4       Martial arts school   624 Grants Ferry Rd    Flowood  ...
# ...                     ...                   ...        ...  ...
# 9125        Wellness Centre         838 Mill St A   Lucedale  ...
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale  ...
# 9127           Dance school           17252 MS-26   Lucedale  ...
# 9128                 Church           18194 MS-26   Lucedale  ...
# 9129  Fitness & Instruction       24980 State Ave    Elberta  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                             1      NaN          NaN           NaN
# 1                             2      NaN          NaN           NaN
# 2                           NaN      NaN          NaN           NaN
# 3                           NaN      NaN          NaN           NaN
# 4                             2      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 9125                        NaN      NaN          NaN           NaN
# 9126                        NaN      NaN          NaN           NaN
# 9127                        NaN      NaN          NaN           NaN
# 9128                        NaN      NaN          NaN           NaN
# 9129                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 9125           NaN         NaN
# 9126           NaN         NaN
# 9127           NaN         NaN
# 9128           NaN         NaN
# 9129           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword search_city
# 0       Boxing Club     Jackson
# 1       Boxing Club     Jackson
# 2       Boxing Club     Jackson
# 3       Boxing Club     Jackson
# 4       Boxing Club     Jackson
# ...             ...         ...
# 9125    Yoga Studio    Lucedale
# 9126    Yoga Studio    Lucedale
# 9127    Yoga Studio    Lucedale
# 9128    Yoga Studio    Lucedale
# 9129    Yoga Studio    Lucedale
#
# [9130 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#      Business Type                                     First Name  \
# 0          General                               Boxers Rebellion
# 1           Boxing                                  Pearl Boxing
# 2          Fitness  Compound Fitness StudiosTyrone Hargro Sports
# 3          General                             Marshall Arts Mma
# 4     Martial Arts              Precision Martial Arts Of Flowood
# ...            ...                                            ...
# 9125       General  George Regional Health System Wellness Center
# 9126          Yoga                        Ascension Dive And Yoga
# 9127       General                          Premiere Dance Center
# 9128       General                  Lighthouse Worship Center UPC
# 9129       General                                 Hut Of Elberta
#
#                                                    name        phone  \
# 0                                      Boxers Rebellion  16015261882
# 1                                     Pearl Boxing Club  16015261882
# 2     The Compound Fitness Studios/Tyrone Hargro Spo...  16015222050
# 3                             Marshall Arts Mma Academy  16013165697
# 4                     Precision Martial Arts Of Flowood  16012028438
# ...                                                 ...          ...
# 9125      George Regional Health System Wellness Center  16017669001
# 9126                            Ascension Dive And Yoga  16017911828
# 9127                              Premiere Dance Center  16017915333
# 9128                   Lighthouse Worship Center U.P.C.  16019474330
# 9129                                     Hut Of Elberta  12519794374
#
#                               email      email_host  \
# 0        jeremy@boxersrebellion.com       yahoo.com
# 1        1pearlboxingclub@gmail.com      google.com
# 2                               NaN             NaN
# 3      marshall@marshallartsmma.com    bluehost.com
# 4      amitchellbjjstudio@gmail.com      google.com
# ...                             ...             ...
# 9125      cshows@georgeregional.com  proofpoint.com
# 9126                  ken@dive.yoga  siteground.com
# 9127  jenny@premieredancecenter.net     outlook.com
# 9128                            NaN             NaN
# 9129         hutofelberta@gmail.com      google.com
#
#                                                 website  \
# 0                      https://www.boxersrebellion.org/
# 1                           http://pearlboxingclub.org/
# 2     https://the-compound-fitness-studios.business....
# 3                       http://www.marshallartsmma.com/
# 4                   http://www.mississippijiujitsu.com/
# ...                                                 ...
# 9125  https://georgeregional.com/locations/the-welln...
# 9126                             https://www.dive.yoga/
# 9127                    http://premieredancecenter.net/
# 9128        http://www.lighthouseworshipcenterupci.com/
# 9129                            http://hutofelberta.com
#
#                    category               address       city  ... ads_yelp  \
# 0         Kickboxing school  856 State St Suite E    Jackson  ...      NaN
# 1               Boxing club   2420 Old Brandon Rd      Pearl  ...      NaN
# 2                       Gym  856 State St Suite D    Jackson  ...      NaN
# 3       Martial arts school    6530 Old Canton Rd  Ridgeland  ...      NaN
# 4       Martial arts school   624 Grants Ferry Rd    Flowood  ...      NaN
# ...                     ...                   ...        ...  ...      ...
# 9125        Wellness Centre         838 Mill St A   Lucedale  ...      NaN
# 9126            Yoga studio   5266 MS-613 Suite B   Lucedale  ...      NaN
# 9127           Dance school           17252 MS-26   Lucedale  ...      NaN
# 9128                 Church           18194 MS-26   Lucedale  ...      NaN
# 9129  Fitness & Instruction       24980 State Ave    Elberta  ...      NaN
#
#      ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0             NaN           NaN           NaN         NaN
# 1             NaN           NaN           NaN         NaN
# 2             NaN           NaN           NaN         NaN
# 3             NaN           NaN           NaN         NaN
# 4             NaN           NaN           NaN         NaN
# ...           ...           ...           ...         ...
# 9125          NaN           NaN           NaN         NaN
# 9126          NaN           NaN           NaN         NaN
# 9127          NaN           NaN           NaN         NaN
# 9128          NaN           NaN           NaN         NaN
# 9129          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                        https://g.page/boxersrebellion        claimed
# 1     https://maps.google.com/maps/place/Pearl+Boxin...        claimed
# 2                     https://g.page/thecompoundfitness        claimed
# 3     https://maps.google.com/maps/place/Marshall+Ar...        claimed
# 4                        https://g.page/flowoodjiujitsu        claimed
# ...                                                 ...            ...
# 9125  https://maps.google.com/maps/place/George+Regi...      unclaimed
# 9126  https://maps.google.com/maps/place/Ascension+D...        claimed
# 9127  https://maps.google.com/maps/place/Premiere+Da...        claimed
# 9128  https://maps.google.com/maps/place/Lighthouse+...      unclaimed
# 9129  https://maps.google.com/maps/place/Hut+of+Elbe...        claimed
#
#      search_keyword  search_city  \
# 0       Boxing Club      Jackson
# 1       Boxing Club      Jackson
# 2       Boxing Club      Jackson
# 3       Boxing Club      Jackson
# 4       Boxing Club      Jackson
# ...             ...          ...
# 9125    Yoga Studio     Lucedale
# 9126    Yoga Studio     Lucedale
# 9127    Yoga Studio     Lucedale
# 9128    Yoga Studio     Lucedale
# 9129    Yoga Studio     Lucedale
#
#                                             Icebreakers
# 0     I saw B2 has a perfect rating on Google. 5 sta...
# 1     I saw B2 has a perfect rating on Google. 5 sta...
# 2     I saw B2 has a perfect rating on Google. 5 sta...
# 3     I saw B2 has a near perfect rating on Google. ...
# 4     I saw B2 has a perfect rating on Google. 5 sta...
# ...                                                 ...
# 9125  I saw B2 has a near perfect rating on Google. ...
# 9126  I was looking at the B2 website on my phone an...
# 9127  I saw B2 has a perfect rating on Google. 5 sta...
# 9128  I saw B2 has a near perfect rating on Google. ...
# 9129  I saw B2 has a perfect rating on Google. 5 sta...
#
# [9130 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('MS_combined_leads_duplicates_removed_semiclean.csv', index = False)
