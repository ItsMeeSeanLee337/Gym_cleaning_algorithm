# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("WY_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute PINK GLOVES BOXING  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited LLC  1.877469e+10
# 4               RockBox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city region    zip  ...  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne     WY  82001  ...
# 1             509 W Lincolnway  Cheyenne     WY  82001  ...
# 2            619 S Greeley Hwy  Cheyenne     WY  82007  ...
# 3                510 W 20th St  Cheyenne     WY  82001  ...
# 4             1121 Old Town Ln  Cheyenne     WY  82009  ...
# ...                        ...       ...    ...    ...  ...
# 7437              3524 Burd Rd    Casper     WY  82601  ...
# 7438              14500 WY-220    Casper     WY  82604  ...
# 7439         218 E 7th St #106    Casper     WY  82601  ...
# 7440            301 W Cedar St   Rawlins     WY  82301  ...
# 7441      705 West Lincoln Hwy  Sinclair     WY  82334  ...
#
#      instagram_average_comments  ads_yelp ads_facebook ads_instagram  \
# 0                           NaN       NaN          NaN           NaN
# 1                           NaN       NaN          NaN           NaN
# 2                           NaN       NaN          NaN           NaN
# 3                           NaN       NaN          NaN           NaN
# 4                           1.0       NaN          1.0           NaN
# ...                         ...       ...          ...           ...
# 7437                        NaN       NaN          NaN           NaN
# 7438                        NaN       NaN          NaN           NaN
# 7439                        NaN       NaN          1.0           NaN
# 7440                        NaN       NaN          NaN           NaN
# 7441                        NaN       NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         1.0
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         1.0
# ...            ...         ...
# 7437           NaN         NaN
# 7438           NaN         NaN
# 7439           NaN         NaN
# 7440           NaN         NaN
# 7441           NaN         NaN
#
#                                                  g_maps  g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...         claimed
# 1     https://maps.google.com/maps/place/Arena+Train...         claimed
# 2        https://g.page/southside-slugger-s-boxing-club         claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...       unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...         claimed
# ...                                                 ...             ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...         claimed
# 7438                                    https://g.page/         claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...         claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...       unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...         claimed
#
#       search_keyword    search_city
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
# [7442 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('WY','')
df['First Name'] = df['First Name'].str.replace('Wy','')
df['First Name'] = df['First Name'].str.replace('Wyoming','')
df
# Out:
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4               Rockbox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city region    zip  ... ads_yelp  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne     WY  82001  ...      NaN
# 1             509 W Lincolnway  Cheyenne     WY  82001  ...      NaN
# 2            619 S Greeley Hwy  Cheyenne     WY  82007  ...      NaN
# 3                510 W 20th St  Cheyenne     WY  82001  ...      NaN
# 4             1121 Old Town Ln  Cheyenne     WY  82009  ...      NaN
# ...                        ...       ...    ...    ...  ...      ...
# 7437              3524 Burd Rd    Casper     WY  82601  ...      NaN
# 7438              14500 WY-220    Casper     WY  82604  ...      NaN
# 7439         218 E 7th St #106    Casper     WY  82601  ...      NaN
# 7440            301 W Cedar St   Rawlins     WY  82301  ...      NaN
# 7441      705 West Lincoln Hwy  Sinclair     WY  82334  ...      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         1.0
# 1              NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              1.0           NaN           NaN         1.0
# ...            ...           ...           ...         ...
# 7437           NaN           NaN           NaN         NaN
# 7438           NaN           NaN           NaN         NaN
# 7439           1.0           NaN           NaN         NaN
# 7440           NaN           NaN           NaN         NaN
# 7441           NaN           NaN           NaN         NaN
#
#                                                  g_maps  g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...         claimed
# 1     https://maps.google.com/maps/place/Arena+Train...         claimed
# 2        https://g.page/southside-slugger-s-boxing-club         claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...       unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...         claimed
# ...                                                 ...             ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...         claimed
# 7438                                    https://g.page/         claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...         claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...       unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...         claimed
#
#       search_keyword    search_city  \
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
#                                             First Name
# 0                 Mayweather Boxing + Fitness Cheyenne
# 1     Arena Training Instituteitute Pink Gloves Boxing
# 2                           Southside Sluggers Boxing
# 3                                     Scars Unlimited
# 4                    Rockbox Fitness Cheyenne Old Town
# ...                                                ...
# 7437                             Casper nastics Center
# 7438                           Bessemer Mountain Lodge
# 7439                             Dance Evolutions Inc.
# 7440                               Cedar Street Studio
# 7441                                      Su Casa Café
#
# [7442 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4               Rockbox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city region    zip  ... ads_yelp  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne     WY  82001  ...      NaN
# 1             509 W Lincolnway  Cheyenne     WY  82001  ...      NaN
# 2            619 S Greeley Hwy  Cheyenne     WY  82007  ...      NaN
# 3                510 W 20th St  Cheyenne     WY  82001  ...      NaN
# 4             1121 Old Town Ln  Cheyenne     WY  82009  ...      NaN
# ...                        ...       ...    ...    ...  ...      ...
# 7437              3524 Burd Rd    Casper     WY  82601  ...      NaN
# 7438              14500 WY-220    Casper     WY  82604  ...      NaN
# 7439         218 E 7th St #106    Casper     WY  82601  ...      NaN
# 7440            301 W Cedar St   Rawlins     WY  82301  ...      NaN
# 7441      705 West Lincoln Hwy  Sinclair     WY  82334  ...      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         1.0
# 1              NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              1.0           NaN           NaN         1.0
# ...            ...           ...           ...         ...
# 7437           NaN           NaN           NaN         NaN
# 7438           NaN           NaN           NaN         NaN
# 7439           1.0           NaN           NaN         NaN
# 7440           NaN           NaN           NaN         NaN
# 7441           NaN           NaN           NaN         NaN
#
#                                                  g_maps  g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...         claimed
# 1     https://maps.google.com/maps/place/Arena+Train...         claimed
# 2        https://g.page/southside-slugger-s-boxing-club         claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...       unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...         claimed
# ...                                                 ...             ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...         claimed
# 7438                                    https://g.page/         claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...         claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...       unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...         claimed
#
#       search_keyword    search_city  \
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
#                                             First Name
# 0                 Mayweather Boxing + Fitness Cheyenne
# 1     Arena Training Instituteitute Pink Gloves Boxing
# 2                           Southside Sluggers Boxing
# 3                                     Scars Unlimited
# 4                    Rockbox Fitness Cheyenne Old Town
# ...                                                ...
# 7437                             Casper nastics Center
# 7438                           Bessemer Mountain Lodge
# 7439                             Dance Evolutions Inc.
# 7440                               Cedar Street Studio
# 7441                                      Su Casa Café
#
# [7442 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4               Rockbox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city region    zip  ... ads_facebook  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne     WY  82001  ...          NaN
# 1             509 W Lincolnway  Cheyenne     WY  82001  ...          NaN
# 2            619 S Greeley Hwy  Cheyenne     WY  82007  ...          NaN
# 3                510 W 20th St  Cheyenne     WY  82001  ...          NaN
# 4             1121 Old Town Ln  Cheyenne     WY  82009  ...          1.0
# ...                        ...       ...    ...    ...  ...          ...
# 7437              3524 Burd Rd    Casper     WY  82601  ...          NaN
# 7438              14500 WY-220    Casper     WY  82604  ...          NaN
# 7439         218 E 7th St #106    Casper     WY  82601  ...          1.0
# 7440            301 W Cedar St   Rawlins     WY  82301  ...          NaN
# 7441      705 West Lincoln Hwy  Sinclair     WY  82334  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         1.0
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         1.0
# ...             ...           ...         ...
# 7437            NaN           NaN         NaN
# 7438            NaN           NaN         NaN
# 7439            NaN           NaN         NaN
# 7440            NaN           NaN         NaN
# 7441            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...        claimed
# 1     https://maps.google.com/maps/place/Arena+Train...        claimed
# 2        https://g.page/southside-slugger-s-boxing-club        claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...      unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...        claimed
# ...                                                 ...            ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...        claimed
# 7438                                    https://g.page/        claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...        claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...      unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...        claimed
#
#       search_keyword    search_city  \
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
#                                             First Name  Business Type
# 0                 Mayweather Boxing + Fitness Cheyenne            NaT
# 1     Arena Training Instituteitute Pink Gloves Boxing            NaT
# 2                           Southside Sluggers Boxing             NaT
# 3                                     Scars Unlimited             NaT
# 4                    Rockbox Fitness Cheyenne Old Town            NaT
# ...                                                ...            ...
# 7437                             Casper nastics Center            NaT
# 7438                           Bessemer Mountain Lodge            NaT
# 7439                             Dance Evolutions Inc.            NaT
# 7440                               Cedar Street Studio            NaT
# 7441                                      Su Casa Café            NaT
#
# [7442 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4               Rockbox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city region    zip  ... ads_facebook  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne     WY  82001  ...          NaN
# 1             509 W Lincolnway  Cheyenne     WY  82001  ...          NaN
# 2            619 S Greeley Hwy  Cheyenne     WY  82007  ...          NaN
# 3                510 W 20th St  Cheyenne     WY  82001  ...          NaN
# 4             1121 Old Town Ln  Cheyenne     WY  82009  ...          1.0
# ...                        ...       ...    ...    ...  ...          ...
# 7437              3524 Burd Rd    Casper     WY  82601  ...          NaN
# 7438              14500 WY-220    Casper     WY  82604  ...          NaN
# 7439         218 E 7th St #106    Casper     WY  82601  ...          1.0
# 7440            301 W Cedar St   Rawlins     WY  82301  ...          NaN
# 7441      705 West Lincoln Hwy  Sinclair     WY  82334  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         1.0
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         1.0
# ...             ...           ...         ...
# 7437            NaN           NaN         NaN
# 7438            NaN           NaN         NaN
# 7439            NaN           NaN         NaN
# 7440            NaN           NaN         NaN
# 7441            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...        claimed
# 1     https://maps.google.com/maps/place/Arena+Train...        claimed
# 2        https://g.page/southside-slugger-s-boxing-club        claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...      unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...        claimed
# ...                                                 ...            ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...        claimed
# 7438                                    https://g.page/        claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...        claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...      unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...        claimed
#
#       search_keyword    search_city  \
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
#                                             First Name  Business Type
# 0                 Mayweather Boxing + Fitness Cheyenne        General
# 1     Arena Training Instituteitute Pink Gloves Boxing        General
# 2                           Southside Sluggers Boxing         General
# 3                                     Scars Unlimited         General
# 4                    Rockbox Fitness Cheyenne Old Town        General
# ...                                                ...            ...
# 7437                             Casper nastics Center        General
# 7438                           Bessemer Mountain Lodge        General
# 7439                             Dance Evolutions Inc.        General
# 7440                               Cedar Street Studio        General
# 7441                                      Su Casa Café        General
#
# [7442 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4               Rockbox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city region    zip  ... ads_facebook  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne     WY  82001  ...          NaN
# 1             509 W Lincolnway  Cheyenne     WY  82001  ...          NaN
# 2            619 S Greeley Hwy  Cheyenne     WY  82007  ...          NaN
# 3                510 W 20th St  Cheyenne     WY  82001  ...          NaN
# 4             1121 Old Town Ln  Cheyenne     WY  82009  ...          1.0
# ...                        ...       ...    ...    ...  ...          ...
# 7437              3524 Burd Rd    Casper     WY  82601  ...          NaN
# 7438              14500 WY-220    Casper     WY  82604  ...          NaN
# 7439         218 E 7th St #106    Casper     WY  82601  ...          1.0
# 7440            301 W Cedar St   Rawlins     WY  82301  ...          NaN
# 7441      705 West Lincoln Hwy  Sinclair     WY  82334  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         1.0
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         1.0
# ...             ...           ...         ...
# 7437            NaN           NaN         NaN
# 7438            NaN           NaN         NaN
# 7439            NaN           NaN         NaN
# 7440            NaN           NaN         NaN
# 7441            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...        claimed
# 1     https://maps.google.com/maps/place/Arena+Train...        claimed
# 2        https://g.page/southside-slugger-s-boxing-club        claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...      unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...        claimed
# ...                                                 ...            ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...        claimed
# 7438                                    https://g.page/        claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...        claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...      unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...        claimed
#
#       search_keyword    search_city  \
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
#                                             First Name  Business Type
# 0                 Mayweather Boxing + Fitness Cheyenne         Boxing
# 1     Arena Training Instituteitute Pink Gloves Boxing         Boxing
# 2                           Southside Sluggers Boxing          Boxing
# 3                                     Scars Unlimited         General
# 4                    Rockbox Fitness Cheyenne Old Town        Fitness
# ...                                                ...            ...
# 7437                             Casper nastics Center        fitness
# 7438                           Bessemer Mountain Lodge        General
# 7439                             Dance Evolutions Inc.        General
# 7440                               Cedar Street Studio        General
# 7441                                      Su Casa Café        General
#
# [7442 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#      Business Type                                        First Name  \
# 0           Boxing              Mayweather Boxing + Fitness Cheyenne
# 1           Boxing  Arena Training Instituteitute Pink Gloves Boxing
# 2           Boxing                        Southside Sluggers Boxing
# 3          General                                  Scars Unlimited
# 4          Fitness                 Rockbox Fitness Cheyenne Old Town
# ...            ...                                               ...
# 7437       fitness                             Casper nastics Center
# 7438       General                           Bessemer Mountain Lodge
# 7439       General                             Dance Evolutions Inc.
# 7440       General                               Cedar Street Studio
# 7441       General                                      Su Casa Café
#
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4               Rockbox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city  ... instagram_average_comments  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne  ...                        NaN
# 1             509 W Lincolnway  Cheyenne  ...                        NaN
# 2            619 S Greeley Hwy  Cheyenne  ...                        NaN
# 3                510 W 20th St  Cheyenne  ...                        NaN
# 4             1121 Old Town Ln  Cheyenne  ...                        1.0
# ...                        ...       ...  ...                        ...
# 7437              3524 Burd Rd    Casper  ...                        NaN
# 7438              14500 WY-220    Casper  ...                        NaN
# 7439         218 E 7th St #106    Casper  ...                        NaN
# 7440            301 W Cedar St   Rawlins  ...                        NaN
# 7441      705 West Lincoln Hwy  Sinclair  ...                        NaN
#
#      ads_yelp ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0         NaN          NaN            NaN           NaN         1.0
# 1         NaN          NaN            NaN           NaN         NaN
# 2         NaN          NaN            NaN           NaN         NaN
# 3         NaN          NaN            NaN           NaN         NaN
# 4         NaN          1.0            NaN           NaN         1.0
# ...       ...          ...            ...           ...         ...
# 7437      NaN          NaN            NaN           NaN         NaN
# 7438      NaN          NaN            NaN           NaN         NaN
# 7439      NaN          1.0            NaN           NaN         NaN
# 7440      NaN          NaN            NaN           NaN         NaN
# 7441      NaN          NaN            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...        claimed
# 1     https://maps.google.com/maps/place/Arena+Train...        claimed
# 2        https://g.page/southside-slugger-s-boxing-club        claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...      unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...        claimed
# ...                                                 ...            ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...        claimed
# 7438                                    https://g.page/        claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...        claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...      unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...        claimed
#
#       search_keyword    search_city
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
# [7442 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#      Business Type                                        First Name  \
# 0           Boxing               Mayweather Boxing  Fitness Cheyenne
# 1           Boxing  Arena Training Instituteitute Pink Gloves Boxing
# 2           Boxing                        Southside Sluggers Boxing
# 3          General                                  Scars Unlimited
# 4          Fitness                 Rockbox Fitness Cheyenne Old Town
# ...            ...                                               ...
# 7437       fitness                             Casper nastics Center
# 7438       General                           Bessemer Mountain Lodge
# 7439       General                              Dance Evolutions Inc
# 7440       General                               Cedar Street Studio
# 7441       General                                       Su Casa Caf
#
#                                              name         phone  \
# 0            Mayweather Boxing + Fitness Cheyenne  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4               Rockbox Fitness Cheyenne Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city  ... instagram_average_comments  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne  ...                        NaN
# 1             509 W Lincolnway  Cheyenne  ...                        NaN
# 2            619 S Greeley Hwy  Cheyenne  ...                        NaN
# 3                510 W 20th St  Cheyenne  ...                        NaN
# 4             1121 Old Town Ln  Cheyenne  ...                        1.0
# ...                        ...       ...  ...                        ...
# 7437              3524 Burd Rd    Casper  ...                        NaN
# 7438              14500 WY-220    Casper  ...                        NaN
# 7439         218 E 7th St #106    Casper  ...                        NaN
# 7440            301 W Cedar St   Rawlins  ...                        NaN
# 7441      705 West Lincoln Hwy  Sinclair  ...                        NaN
#
#      ads_yelp ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0         NaN          NaN            NaN           NaN         1.0
# 1         NaN          NaN            NaN           NaN         NaN
# 2         NaN          NaN            NaN           NaN         NaN
# 3         NaN          NaN            NaN           NaN         NaN
# 4         NaN          1.0            NaN           NaN         1.0
# ...       ...          ...            ...           ...         ...
# 7437      NaN          NaN            NaN           NaN         NaN
# 7438      NaN          NaN            NaN           NaN         NaN
# 7439      NaN          1.0            NaN           NaN         NaN
# 7440      NaN          NaN            NaN           NaN         NaN
# 7441      NaN          NaN            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...        claimed
# 1     https://maps.google.com/maps/place/Arena+Train...        claimed
# 2        https://g.page/southside-slugger-s-boxing-club        claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...      unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...        claimed
# ...                                                 ...            ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...        claimed
# 7438                                    https://g.page/        claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...        claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...      unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...        claimed
#
#       search_keyword    search_city
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
# [7442 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#      Business Type                                        First Name  \
# 0           Boxing                       Mayweather Boxing  Fitness
# 1           Boxing  Arena Training Instituteitute Pink Gloves Boxing
# 2           Boxing                        Southside Sluggers Boxing
# 3          General                                  Scars Unlimited
# 4          Fitness                         Rockbox Fitness  Old Town
# ...            ...                                               ...
# 7437       fitness                             Casper nastics Center
# 7438       General                           Bessemer Mountain Lodge
# 7439       General                              Dance Evolutions Inc
# 7440       General                               Cedar Street Studio
# 7441       General                                       Su Casa Caf
#
#                                              name         phone  \
# 0          Mayweather Boxing + Fitness (Cheyenne)  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4             Rockbox Fitness (Cheyenne) Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city  ... instagram_average_comments  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne  ...                        NaN
# 1             509 W Lincolnway  Cheyenne  ...                        NaN
# 2            619 S Greeley Hwy  Cheyenne  ...                        NaN
# 3                510 W 20th St  Cheyenne  ...                        NaN
# 4             1121 Old Town Ln  Cheyenne  ...                        1.0
# ...                        ...       ...  ...                        ...
# 7437              3524 Burd Rd    Casper  ...                        NaN
# 7438              14500 WY-220    Casper  ...                        NaN
# 7439         218 E 7th St #106    Casper  ...                        NaN
# 7440            301 W Cedar St   Rawlins  ...                        NaN
# 7441      705 West Lincoln Hwy  Sinclair  ...                        NaN
#
#      ads_yelp ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0         NaN          NaN            NaN           NaN         1.0
# 1         NaN          NaN            NaN           NaN         NaN
# 2         NaN          NaN            NaN           NaN         NaN
# 3         NaN          NaN            NaN           NaN         NaN
# 4         NaN          1.0            NaN           NaN         1.0
# ...       ...          ...            ...           ...         ...
# 7437      NaN          NaN            NaN           NaN         NaN
# 7438      NaN          NaN            NaN           NaN         NaN
# 7439      NaN          1.0            NaN           NaN         NaN
# 7440      NaN          NaN            NaN           NaN         NaN
# 7441      NaN          NaN            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...        claimed
# 1     https://maps.google.com/maps/place/Arena+Train...        claimed
# 2        https://g.page/southside-slugger-s-boxing-club        claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...      unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...        claimed
# ...                                                 ...            ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...        claimed
# 7438                                    https://g.page/        claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...        claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...      unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...        claimed
#
#       search_keyword    search_city
# 0        Boxing Club       Cheyenne
# 1        Boxing Club       Cheyenne
# 2        Boxing Club       Cheyenne
# 3        Boxing Club       Cheyenne
# 4        Boxing Club       Cheyenne
# ...              ...            ...
# 7437     Yoga Studio  Bessemer Bend
# 7438     Yoga Studio  Bessemer Bend
# 7439     Yoga Studio  Bessemer Bend
# 7440     Yoga Studio       Sinclair
# 7441     Yoga Studio       Sinclair
#
# [7442 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#      Business Type                                        First Name  \
# 0           Boxing                       Mayweather Boxing  Fitness
# 1           Boxing  Arena Training Instituteitute Pink Gloves Boxing
# 2           Boxing                        Southside Sluggers Boxing
# 3          General                                  Scars Unlimited
# 4          Fitness                         Rockbox Fitness  Old Town
# ...            ...                                               ...
# 7437       fitness                             Casper nastics Center
# 7438       General                           Bessemer Mountain Lodge
# 7439       General                              Dance Evolutions Inc
# 7440       General                               Cedar Street Studio
# 7441       General                                       Su Casa Caf
#
#                                              name         phone  \
# 0          Mayweather Boxing + Fitness (Cheyenne)  1.307223e+10
# 1     Arena Training Institute Pink Gloves Boxing  1.307422e+10
# 2                  Southside Sluggers Boxing Club  1.307287e+10
# 3                             Scars Unlimited Llc  1.877469e+10
# 4             Rockbox Fitness (Cheyenne) Old Town  1.307220e+10
# ...                                           ...           ...
# 7437                     Casper Gymnastics Center  1.307268e+10
# 7438                      Bessemer Mountain Lodge  1.307205e+10
# 7439                        Dance Evolutions Inc.  1.307237e+10
# 7440                          Cedar Street Studio  1.307325e+10
# 7441                                 Su Casa Café  1.307328e+10
#
#                                   email   email_host  \
# 0             kirklandwa@mayweather.fit  outlook.com
# 1      arena@arenatraininginstitute.com   google.com
# 2      southcheyennefitnessgym@zoho.com     zoho.com
# 3                markhill2525@gmail.com   google.com
# 4            cypress@rockboxfitness.com   google.com
# ...                                 ...          ...
# 7437        ashlee@caspergymnastics.com   google.com
# 7438  kyrstin@bessemermountainlodge.com   google.com
# 7439     anceevolutionscasper@gmail.com   google.com
# 7440          design@wyomingtrader.info  outlook.com
# 7441                                NaN          NaN
#
#                                                 website            category  \
# 0                      https://mayweather.fit/cheyenne/      Fitness centre
# 1                    http://arenatraininginstitute.com/          Boxing Gym
# 2           http://www.southsidesluggersboxingclub.com/         Boxing club
# 3                    https://marks-fitness.ueniweb.com/          Boxing Gym
# 4     https://www.rockboxfitness.com/cheyenne-old-town/          Boxing Gym
# ...                                                 ...                 ...
# 7437                   http://www.caspergymnastics.com/  Gymnastics academy
# 7438                      http://www.lodgingcasper.com/        Events Venue
# 7439                    http://www.danceevolutions.net/        Dance school
# 7440               http://rawlinscedarstreetstudio.com/         Yoga studio
# 7441                   https://deepsweepjanitorial.com/  Mexican restaurant
#
#                        address      city  ... ads_yelp ads_facebook  \
# 0     2300 Chestnut Dr Suite 1  Cheyenne  ...      NaN          NaN
# 1             509 W Lincolnway  Cheyenne  ...      NaN          NaN
# 2            619 S Greeley Hwy  Cheyenne  ...      NaN          NaN
# 3                510 W 20th St  Cheyenne  ...      NaN          NaN
# 4             1121 Old Town Ln  Cheyenne  ...      NaN          1.0
# ...                        ...       ...  ...      ...          ...
# 7437              3524 Burd Rd    Casper  ...      NaN          NaN
# 7438              14500 WY-220    Casper  ...      NaN          NaN
# 7439         218 E 7th St #106    Casper  ...      NaN          1.0
# 7440            301 W Cedar St   Rawlins  ...      NaN          NaN
# 7441      705 West Lincoln Hwy  Sinclair  ...      NaN          NaN
#
#      ads_instagram  ads_messenger ads_adwords  \
# 0              NaN            NaN         1.0
# 1              NaN            NaN         NaN
# 2              NaN            NaN         NaN
# 3              NaN            NaN         NaN
# 4              NaN            NaN         1.0
# ...            ...            ...         ...
# 7437           NaN            NaN         NaN
# 7438           NaN            NaN         NaN
# 7439           NaN            NaN         NaN
# 7440           NaN            NaN         NaN
# 7441           NaN            NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Mayweather+...        claimed
# 1     https://maps.google.com/maps/place/Arena+Train...        claimed
# 2        https://g.page/southside-slugger-s-boxing-club        claimed
# 3     https://maps.google.com/maps/place/Scars+Unlim...      unclaimed
# 4     https://maps.google.com/maps/place/RockBox+Fit...        claimed
# ...                                                 ...            ...
# 7437  https://maps.google.com/maps/place/Casper+Gymn...        claimed
# 7438                                    https://g.page/        claimed
# 7439  https://maps.google.com/maps/place/Dance+Evolu...        claimed
# 7440  https://maps.google.com/maps/place/Cedar+Stree...      unclaimed
# 7441  https://maps.google.com/maps/place/Su+Casa+Caf...        claimed
#
#      search_keyword    search_city  \
# 0       Boxing Club       Cheyenne
# 1       Boxing Club       Cheyenne
# 2       Boxing Club       Cheyenne
# 3       Boxing Club       Cheyenne
# 4       Boxing Club       Cheyenne
# ...             ...            ...
# 7437    Yoga Studio  Bessemer Bend
# 7438    Yoga Studio  Bessemer Bend
# 7439    Yoga Studio  Bessemer Bend
# 7440    Yoga Studio       Sinclair
# 7441    Yoga Studio       Sinclair
#
#                                             Icebreakers
# 0     I saw B2 has a perfect rating on Google. 5 sta...
# 1     I saw B2 has a perfect rating on Google. 5 sta...
# 2     I saw B2 has a near perfect rating on Google. ...
# 3     I saw your B2 star rating on Facebook. Really ...
# 4     I saw B2 has a near perfect rating on Google. ...
# ...                                                 ...
# 7437  I saw B2 has a near perfect rating on Google. ...
# 7438  I saw B2 has a near perfect rating on Google. ...
# 7439  I saw B2 has a near perfect rating on Google. ...
# 7440  I saw B2 has a perfect rating on Google. 5 sta...
# 7441  I saw B2 has a near perfect rating on Google. ...
#
# [7442 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('WY_combined_leads_duplicates_removed_semiclean.csv', index = False)
