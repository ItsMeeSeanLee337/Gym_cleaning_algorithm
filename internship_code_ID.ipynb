# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("ID_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                              name        phone  \
# 0      Combat Fitness I SBG Idaho  12089356264
# 1               Jack City Fitness  12089991111
# 2            Underground Fit Club  12083660088
# 3                   Axiom Fitness  12089551113
# 4               Crossfit Fireside  12088666076
# ...                           ...          ...
# 10126   Student Recreation Center  15093358732
# 10127         Orofino High School  12084765557
# 10128             Maetche Fitness  12088271551
# 10129             Mani-Yac Center  12084763160
# 10130       Orofino Health Center  12084765777
#
#                                    email      email_host  \
# 0                 info@combatfitness.com  greengeeks.com
# 1                                    NaN             NaN
# 2      undergroundfitclubidaho@gmail.com      google.com
# 3                   joe@axiomfitness.com      google.com
# 4        coachcatie@crossfitfireside.com      google.com
# ...                                  ...             ...
# 10126                                NaN             NaN
# 10127                                NaN             NaN
# 10128               jmaetche@hotmail.com     outlook.com
# 10129                                NaN             NaN
# 10130                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  \
# 0                 Martial Art                 1522 W River St     Boise
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian
# ...                       ...                             ...       ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman
# 10127        Secondary school                   300 Dunlap Rd   Orofino
# 10128                     Gym                     10610 US-12   Orofino
# 10129      Youth organisation                 1115 Shriver Rd   Orofino
# 10130                  Health              1055 Riverside Ave   Orofino
#
#       region    zip  ... instagram_average_comments ads_yelp ads_facebook  \
# 0         ID  83702  ...                          2      NaN          NaN
# 1         ID  83704  ...                          2        1          NaN
# 2         ID  83634  ...                          1      NaN          NaN
# 3         ID  83706  ...                          1      NaN            1
# 4         ID  83646  ...                          1      NaN          NaN
# ...      ...    ...  ...                        ...      ...          ...
# 10126     WA  99163  ...                        NaN      NaN            1
# 10127     ID  83544  ...                        NaN      NaN          NaN
# 10128     ID  83544  ...                        NaN      NaN          NaN
# 10129     ID  83544  ...                        NaN      NaN          NaN
# 10130     ID  83544  ...                        NaN      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3                 1             1         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 10126             1             1         NaN
# 10127           NaN           NaN         NaN
# 10128           NaN           NaN         NaN
# 10129           NaN           NaN         NaN
# 10130           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword search_city
# 0        Boxing Club       Boise
# 1        Boxing Club       Boise
# 2        Boxing Club       Boise
# 3        Boxing Club       Boise
# 4        Boxing Club       Boise
# ...              ...         ...
# 10126    Yoga Studio     Orofino
# 10127    Yoga Studio     Orofino
# 10128    Yoga Studio     Orofino
# 10129    Yoga Studio     Orofino
# 10130    Yoga Studio     Orofino
#
# [10131 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('AL','')
df['First Name'] = df['First Name'].str.replace('Al','')
df['First Name'] = df['First Name'].str.replace('Alabama','')
df
# Out:
#                              name        phone  \
# 0      Combat Fitness I Sbg Idaho  12089356264
# 1               Jack City Fitness  12089991111
# 2            Underground Fit Club  12083660088
# 3                   Axiom Fitness  12089551113
# 4               Crossfit Fireside  12088666076
# ...                           ...          ...
# 10126   Student Recreation Center  15093358732
# 10127         Orofino High School  12084765557
# 10128             Maetche Fitness  12088271551
# 10129             Mani-Yac Center  12084763160
# 10130       Orofino Health Center  12084765777
#
#                                    email      email_host  \
# 0                 info@combatfitness.com  greengeeks.com
# 1                                    NaN             NaN
# 2      undergroundfitclubidaho@gmail.com      google.com
# 3                   joe@axiomfitness.com      google.com
# 4        coachcatie@crossfitfireside.com      google.com
# ...                                  ...             ...
# 10126                                NaN             NaN
# 10127                                NaN             NaN
# 10128               jmaetche@hotmail.com     outlook.com
# 10129                                NaN             NaN
# 10130                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  \
# 0                 Martial Art                 1522 W River St     Boise
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian
# ...                       ...                             ...       ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman
# 10127        Secondary school                   300 Dunlap Rd   Orofino
# 10128                     Gym                     10610 US-12   Orofino
# 10129      Youth organisation                 1115 Shriver Rd   Orofino
# 10130                  Health              1055 Riverside Ave   Orofino
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         ID  83702  ...      NaN          NaN           NaN           NaN
# 1         ID  83704  ...        1          NaN           NaN           NaN
# 2         ID  83634  ...      NaN          NaN           NaN           NaN
# 3         ID  83706  ...      NaN            1             1             1
# 4         ID  83646  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 10126     WA  99163  ...      NaN            1             1             1
# 10127     ID  83544  ...      NaN          NaN           NaN           NaN
# 10128     ID  83544  ...      NaN          NaN           NaN           NaN
# 10129     ID  83544  ...      NaN          NaN           NaN           NaN
# 10130     ID  83544  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN                            https://g.page/sbgidaho
# 1             NaN             https://g.page/jack-city-fitness-boise
# 2             NaN             https://g.page/undergroundfitclubidaho
# 3             NaN  https://maps.google.com/maps/place/Axiom+Fitne...
# 4             NaN  https://maps.google.com/maps/place/Crossfit+Fi...
# ...           ...                                                ...
# 10126         NaN  https://maps.google.com/maps/place/Student+Rec...
# 10127         NaN  https://maps.google.com/maps/place/Orofino+Hig...
# 10128         NaN  https://maps.google.com/maps/place/Maetche+Fit...
# 10129         NaN  https://maps.google.com/maps/place/Mani-Yac+Ce...
# 10130         NaN  https://maps.google.com/maps/place/Orofino+Hea...
#
#       g_maps_claimed search_keyword search_city                  First Name
# 0            claimed    Boxing Club       Boise  Combat Fitness I Sbg Idaho
# 1            claimed    Boxing Club       Boise           Jack City Fitness
# 2            claimed    Boxing Club       Boise            Underground Fit
# 3            claimed    Boxing Club       Boise               Axiom Fitness
# 4            claimed    Boxing Club       Boise           Crossfit Fireside
# ...              ...            ...         ...                         ...
# 10126        claimed    Yoga Studio     Orofino   Student Recreation Center
# 10127      unclaimed    Yoga Studio     Orofino         Orofino High School
# 10128      unclaimed    Yoga Studio     Orofino             Maetche Fitness
# 10129      unclaimed    Yoga Studio     Orofino             Mani-Yac Center
# 10130      unclaimed    Yoga Studio     Orofino       Orofino Health Center
#
# [10131 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                              name        phone  \
# 0      Combat Fitness I Sbg Idaho  12089356264
# 1               Jack City Fitness  12089991111
# 2            Underground Fit Club  12083660088
# 3                   Axiom Fitness  12089551113
# 4               Crossfit Fireside  12088666076
# ...                           ...          ...
# 10126   Student Recreation Center  15093358732
# 10127         Orofino High School  12084765557
# 10128             Maetche Fitness  12088271551
# 10129             Mani-Yac Center  12084763160
# 10130       Orofino Health Center  12084765777
#
#                                    email      email_host  \
# 0                 info@combatfitness.com  greengeeks.com
# 1                                    NaN             NaN
# 2      undergroundfitclubidaho@gmail.com      google.com
# 3                   joe@axiomfitness.com      google.com
# 4        coachcatie@crossfitfireside.com      google.com
# ...                                  ...             ...
# 10126                                NaN             NaN
# 10127                                NaN             NaN
# 10128               jmaetche@hotmail.com     outlook.com
# 10129                                NaN             NaN
# 10130                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  \
# 0                 Martial Art                 1522 W River St     Boise
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian
# ...                       ...                             ...       ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman
# 10127        Secondary school                   300 Dunlap Rd   Orofino
# 10128                     Gym                     10610 US-12   Orofino
# 10129      Youth organisation                 1115 Shriver Rd   Orofino
# 10130                  Health              1055 Riverside Ave   Orofino
#
#       region    zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0         ID  83702  ...      NaN          NaN           NaN           NaN
# 1         ID  83704  ...        1          NaN           NaN           NaN
# 2         ID  83634  ...      NaN          NaN           NaN           NaN
# 3         ID  83706  ...      NaN            1             1             1
# 4         ID  83646  ...      NaN          NaN           NaN           NaN
# ...      ...    ...  ...      ...          ...           ...           ...
# 10126     WA  99163  ...      NaN            1             1             1
# 10127     ID  83544  ...      NaN          NaN           NaN           NaN
# 10128     ID  83544  ...      NaN          NaN           NaN           NaN
# 10129     ID  83544  ...      NaN          NaN           NaN           NaN
# 10130     ID  83544  ...      NaN          NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN                            https://g.page/sbgidaho
# 1             NaN             https://g.page/jack-city-fitness-boise
# 2             NaN             https://g.page/undergroundfitclubidaho
# 3             NaN  https://maps.google.com/maps/place/Axiom+Fitne...
# 4             NaN  https://maps.google.com/maps/place/Crossfit+Fi...
# ...           ...                                                ...
# 10126         NaN  https://maps.google.com/maps/place/Student+Rec...
# 10127         NaN  https://maps.google.com/maps/place/Orofino+Hig...
# 10128         NaN  https://maps.google.com/maps/place/Maetche+Fit...
# 10129         NaN  https://maps.google.com/maps/place/Mani-Yac+Ce...
# 10130         NaN  https://maps.google.com/maps/place/Orofino+Hea...
#
#       g_maps_claimed search_keyword search_city                  First Name
# 0            claimed    Boxing Club       Boise  Combat Fitness I Sbg Idaho
# 1            claimed    Boxing Club       Boise           Jack City Fitness
# 2            claimed    Boxing Club       Boise            Underground Fit
# 3            claimed    Boxing Club       Boise               Axiom Fitness
# 4            claimed    Boxing Club       Boise           Crossfit Fireside
# ...              ...            ...         ...                         ...
# 10126        claimed    Yoga Studio     Orofino   Student Recreation Center
# 10127      unclaimed    Yoga Studio     Orofino         Orofino High School
# 10128      unclaimed    Yoga Studio     Orofino             Maetche Fitness
# 10129      unclaimed    Yoga Studio     Orofino             Mani-Yac Center
# 10130      unclaimed    Yoga Studio     Orofino       Orofino Health Center
#
# [10131 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                              name        phone  \
# 0      Combat Fitness I Sbg Idaho  12089356264
# 1               Jack City Fitness  12089991111
# 2            Underground Fit Club  12083660088
# 3                   Axiom Fitness  12089551113
# 4               Crossfit Fireside  12088666076
# ...                           ...          ...
# 10126   Student Recreation Center  15093358732
# 10127         Orofino High School  12084765557
# 10128             Maetche Fitness  12088271551
# 10129             Mani-Yac Center  12084763160
# 10130       Orofino Health Center  12084765777
#
#                                    email      email_host  \
# 0                 info@combatfitness.com  greengeeks.com
# 1                                    NaN             NaN
# 2      undergroundfitclubidaho@gmail.com      google.com
# 3                   joe@axiomfitness.com      google.com
# 4        coachcatie@crossfitfireside.com      google.com
# ...                                  ...             ...
# 10126                                NaN             NaN
# 10127                                NaN             NaN
# 10128               jmaetche@hotmail.com     outlook.com
# 10129                                NaN             NaN
# 10130                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  \
# 0                 Martial Art                 1522 W River St     Boise
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian
# ...                       ...                             ...       ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman
# 10127        Secondary school                   300 Dunlap Rd   Orofino
# 10128                     Gym                     10610 US-12   Orofino
# 10129      Youth organisation                 1115 Shriver Rd   Orofino
# 10130                  Health              1055 Riverside Ave   Orofino
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         ID  83702  ...          NaN           NaN           NaN         NaN
# 1         ID  83704  ...          NaN           NaN           NaN         NaN
# 2         ID  83634  ...          NaN           NaN           NaN         NaN
# 3         ID  83706  ...            1             1             1         NaN
# 4         ID  83646  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 10126     WA  99163  ...            1             1             1         NaN
# 10127     ID  83544  ...          NaN           NaN           NaN         NaN
# 10128     ID  83544  ...          NaN           NaN           NaN         NaN
# 10129     ID  83544  ...          NaN           NaN           NaN         NaN
# 10130     ID  83544  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword search_city                  First Name Business Type
# 0        Boxing Club       Boise  Combat Fitness I Sbg Idaho           NaT
# 1        Boxing Club       Boise           Jack City Fitness           NaT
# 2        Boxing Club       Boise            Underground Fit            NaT
# 3        Boxing Club       Boise               Axiom Fitness           NaT
# 4        Boxing Club       Boise           Crossfit Fireside           NaT
# ...              ...         ...                         ...           ...
# 10126    Yoga Studio     Orofino   Student Recreation Center           NaT
# 10127    Yoga Studio     Orofino         Orofino High School           NaT
# 10128    Yoga Studio     Orofino             Maetche Fitness           NaT
# 10129    Yoga Studio     Orofino             Mani-Yac Center           NaT
# 10130    Yoga Studio     Orofino       Orofino Health Center           NaT
#
# [10131 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                              name        phone  \
# 0      Combat Fitness I Sbg Idaho  12089356264
# 1               Jack City Fitness  12089991111
# 2            Underground Fit Club  12083660088
# 3                   Axiom Fitness  12089551113
# 4               Crossfit Fireside  12088666076
# ...                           ...          ...
# 10126   Student Recreation Center  15093358732
# 10127         Orofino High School  12084765557
# 10128             Maetche Fitness  12088271551
# 10129             Mani-Yac Center  12084763160
# 10130       Orofino Health Center  12084765777
#
#                                    email      email_host  \
# 0                 info@combatfitness.com  greengeeks.com
# 1                                    NaN             NaN
# 2      undergroundfitclubidaho@gmail.com      google.com
# 3                   joe@axiomfitness.com      google.com
# 4        coachcatie@crossfitfireside.com      google.com
# ...                                  ...             ...
# 10126                                NaN             NaN
# 10127                                NaN             NaN
# 10128               jmaetche@hotmail.com     outlook.com
# 10129                                NaN             NaN
# 10130                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  \
# 0                 Martial Art                 1522 W River St     Boise
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian
# ...                       ...                             ...       ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman
# 10127        Secondary school                   300 Dunlap Rd   Orofino
# 10128                     Gym                     10610 US-12   Orofino
# 10129      Youth organisation                 1115 Shriver Rd   Orofino
# 10130                  Health              1055 Riverside Ave   Orofino
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         ID  83702  ...          NaN           NaN           NaN         NaN
# 1         ID  83704  ...          NaN           NaN           NaN         NaN
# 2         ID  83634  ...          NaN           NaN           NaN         NaN
# 3         ID  83706  ...            1             1             1         NaN
# 4         ID  83646  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 10126     WA  99163  ...            1             1             1         NaN
# 10127     ID  83544  ...          NaN           NaN           NaN         NaN
# 10128     ID  83544  ...          NaN           NaN           NaN         NaN
# 10129     ID  83544  ...          NaN           NaN           NaN         NaN
# 10130     ID  83544  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword search_city                  First Name Business Type
# 0        Boxing Club       Boise  Combat Fitness I Sbg Idaho       General
# 1        Boxing Club       Boise           Jack City Fitness       General
# 2        Boxing Club       Boise            Underground Fit        General
# 3        Boxing Club       Boise               Axiom Fitness       General
# 4        Boxing Club       Boise           Crossfit Fireside       General
# ...              ...         ...                         ...           ...
# 10126    Yoga Studio     Orofino   Student Recreation Center       General
# 10127    Yoga Studio     Orofino         Orofino High School       General
# 10128    Yoga Studio     Orofino             Maetche Fitness       General
# 10129    Yoga Studio     Orofino             Mani-Yac Center       General
# 10130    Yoga Studio     Orofino       Orofino Health Center       General
#
# [10131 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                              name        phone  \
# 0      Combat Fitness I Sbg Idaho  12089356264
# 1               Jack City Fitness  12089991111
# 2            Underground Fit Club  12083660088
# 3                   Axiom Fitness  12089551113
# 4               Crossfit Fireside  12088666076
# ...                           ...          ...
# 10126   Student Recreation Center  15093358732
# 10127         Orofino High School  12084765557
# 10128             Maetche Fitness  12088271551
# 10129             Mani-Yac Center  12084763160
# 10130       Orofino Health Center  12084765777
#
#                                    email      email_host  \
# 0                 info@combatfitness.com  greengeeks.com
# 1                                    NaN             NaN
# 2      undergroundfitclubidaho@gmail.com      google.com
# 3                   joe@axiomfitness.com      google.com
# 4        coachcatie@crossfitfireside.com      google.com
# ...                                  ...             ...
# 10126                                NaN             NaN
# 10127                                NaN             NaN
# 10128               jmaetche@hotmail.com     outlook.com
# 10129                                NaN             NaN
# 10130                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  \
# 0                 Martial Art                 1522 W River St     Boise
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian
# ...                       ...                             ...       ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman
# 10127        Secondary school                   300 Dunlap Rd   Orofino
# 10128                     Gym                     10610 US-12   Orofino
# 10129      Youth organisation                 1115 Shriver Rd   Orofino
# 10130                  Health              1055 Riverside Ave   Orofino
#
#       region    zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         ID  83702  ...          NaN           NaN           NaN         NaN
# 1         ID  83704  ...          NaN           NaN           NaN         NaN
# 2         ID  83634  ...          NaN           NaN           NaN         NaN
# 3         ID  83706  ...            1             1             1         NaN
# 4         ID  83646  ...          NaN           NaN           NaN         NaN
# ...      ...    ...  ...          ...           ...           ...         ...
# 10126     WA  99163  ...            1             1             1         NaN
# 10127     ID  83544  ...          NaN           NaN           NaN         NaN
# 10128     ID  83544  ...          NaN           NaN           NaN         NaN
# 10129     ID  83544  ...          NaN           NaN           NaN         NaN
# 10130     ID  83544  ...          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword search_city                  First Name Business Type
# 0        Boxing Club       Boise  Combat Fitness I Sbg Idaho       Fitness
# 1        Boxing Club       Boise           Jack City Fitness       Fitness
# 2        Boxing Club       Boise            Underground Fit        General
# 3        Boxing Club       Boise               Axiom Fitness       Fitness
# 4        Boxing Club       Boise           Crossfit Fireside      Crossfit
# ...              ...         ...                         ...           ...
# 10126    Yoga Studio     Orofino   Student Recreation Center       General
# 10127    Yoga Studio     Orofino         Orofino High School       General
# 10128    Yoga Studio     Orofino             Maetche Fitness       Fitness
# 10129    Yoga Studio     Orofino             Mani-Yac Center       General
# 10130    Yoga Studio     Orofino       Orofino Health Center       General
#
# [10131 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                  First Name                        name  \
# 0           Fitness  Combat Fitness I Sbg Idaho  Combat Fitness I Sbg Idaho
# 1           Fitness           Jack City Fitness           Jack City Fitness
# 2           General            Underground Fit         Underground Fit Club
# 3           Fitness               Axiom Fitness               Axiom Fitness
# 4          Crossfit           Crossfit Fireside           Crossfit Fireside
# ...             ...                         ...                         ...
# 10126       General   Student Recreation Center   Student Recreation Center
# 10127       General         Orofino High School         Orofino High School
# 10128       Fitness             Maetche Fitness             Maetche Fitness
# 10129       General             Mani-Yac Center             Mani-Yac Center
# 10130       General       Orofino Health Center       Orofino Health Center
#
#              phone                              email      email_host  \
# 0      12089356264             info@combatfitness.com  greengeeks.com
# 1      12089991111                                NaN             NaN
# 2      12083660088  undergroundfitclubidaho@gmail.com      google.com
# 3      12089551113               joe@axiomfitness.com      google.com
# 4      12088666076    coachcatie@crossfitfireside.com      google.com
# ...            ...                                ...             ...
# 10126  15093358732                                NaN             NaN
# 10127  12084765557                                NaN             NaN
# 10128  12088271551               jmaetche@hotmail.com     outlook.com
# 10129  12084763160                                NaN             NaN
# 10130  12084765777                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  ...  \
# 0                 Martial Art                 1522 W River St     Boise  ...
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise  ...
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna  ...
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise  ...
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian  ...
# ...                       ...                             ...       ...  ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman  ...
# 10127        Secondary school                   300 Dunlap Rd   Orofino  ...
# 10128                     Gym                     10610 US-12   Orofino  ...
# 10129      Youth organisation                 1115 Shriver Rd   Orofino  ...
# 10130                  Health              1055 Riverside Ave   Orofino  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                              2      NaN          NaN           NaN
# 1                              2        1          NaN           NaN
# 2                              1      NaN          NaN           NaN
# 3                              1      NaN            1             1
# 4                              1      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 10126                        NaN      NaN            1             1
# 10127                        NaN      NaN          NaN           NaN
# 10128                        NaN      NaN          NaN           NaN
# 10129                        NaN      NaN          NaN           NaN
# 10130                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3                 1         NaN
# 4               NaN         NaN
# ...             ...         ...
# 10126             1         NaN
# 10127           NaN         NaN
# 10128           NaN         NaN
# 10129           NaN         NaN
# 10130           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword search_city
# 0        Boxing Club       Boise
# 1        Boxing Club       Boise
# 2        Boxing Club       Boise
# 3        Boxing Club       Boise
# 4        Boxing Club       Boise
# ...              ...         ...
# 10126    Yoga Studio     Orofino
# 10127    Yoga Studio     Orofino
# 10128    Yoga Studio     Orofino
# 10129    Yoga Studio     Orofino
# 10130    Yoga Studio     Orofino
#
# [10131 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                  First Name                        name  \
# 0           Fitness  Combat Fitness I Sbg Idaho  Combat Fitness I Sbg Idaho
# 1           Fitness           Jack City Fitness           Jack City Fitness
# 2           General            Underground Fit         Underground Fit Club
# 3           Fitness               Axiom Fitness               Axiom Fitness
# 4          Crossfit           Crossfit Fireside           Crossfit Fireside
# ...             ...                         ...                         ...
# 10126       General   Student Recreation Center   Student Recreation Center
# 10127       General         Orofino High School         Orofino High School
# 10128       Fitness             Maetche Fitness             Maetche Fitness
# 10129       General              ManiYac Center             Mani-Yac Center
# 10130       General       Orofino Health Center       Orofino Health Center
#
#              phone                              email      email_host  \
# 0      12089356264             info@combatfitness.com  greengeeks.com
# 1      12089991111                                NaN             NaN
# 2      12083660088  undergroundfitclubidaho@gmail.com      google.com
# 3      12089551113               joe@axiomfitness.com      google.com
# 4      12088666076    coachcatie@crossfitfireside.com      google.com
# ...            ...                                ...             ...
# 10126  15093358732                                NaN             NaN
# 10127  12084765557                                NaN             NaN
# 10128  12088271551               jmaetche@hotmail.com     outlook.com
# 10129  12084763160                                NaN             NaN
# 10130  12084765777                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  ...  \
# 0                 Martial Art                 1522 W River St     Boise  ...
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise  ...
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna  ...
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise  ...
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian  ...
# ...                       ...                             ...       ...  ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman  ...
# 10127        Secondary school                   300 Dunlap Rd   Orofino  ...
# 10128                     Gym                     10610 US-12   Orofino  ...
# 10129      Youth organisation                 1115 Shriver Rd   Orofino  ...
# 10130                  Health              1055 Riverside Ave   Orofino  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                              2      NaN          NaN           NaN
# 1                              2        1          NaN           NaN
# 2                              1      NaN          NaN           NaN
# 3                              1      NaN            1             1
# 4                              1      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 10126                        NaN      NaN            1             1
# 10127                        NaN      NaN          NaN           NaN
# 10128                        NaN      NaN          NaN           NaN
# 10129                        NaN      NaN          NaN           NaN
# 10130                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3                 1         NaN
# 4               NaN         NaN
# ...             ...         ...
# 10126             1         NaN
# 10127           NaN         NaN
# 10128           NaN         NaN
# 10129           NaN         NaN
# 10130           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword search_city
# 0        Boxing Club       Boise
# 1        Boxing Club       Boise
# 2        Boxing Club       Boise
# 3        Boxing Club       Boise
# 4        Boxing Club       Boise
# ...              ...         ...
# 10126    Yoga Studio     Orofino
# 10127    Yoga Studio     Orofino
# 10128    Yoga Studio     Orofino
# 10129    Yoga Studio     Orofino
# 10130    Yoga Studio     Orofino
#
# [10131 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                  First Name                        name  \
# 0           Fitness  Combat Fitness I Sbg Idaho  Combat Fitness I Sbg Idaho
# 1           Fitness           Jack City Fitness           Jack City Fitness
# 2           General            Underground Fit         Underground Fit Club
# 3           Fitness               Axiom Fitness               Axiom Fitness
# 4          Crossfit           Crossfit Fireside           Crossfit Fireside
# ...             ...                         ...                         ...
# 10126       General   Student Recreation Center   Student Recreation Center
# 10127       General                 High School       (Orofino) High School
# 10128       Fitness             Maetche Fitness             Maetche Fitness
# 10129       General              ManiYac Center             Mani-Yac Center
# 10130       General               Health Center     (Orofino) Health Center
#
#              phone                              email      email_host  \
# 0      12089356264             info@combatfitness.com  greengeeks.com
# 1      12089991111                                NaN             NaN
# 2      12083660088  undergroundfitclubidaho@gmail.com      google.com
# 3      12089551113               joe@axiomfitness.com      google.com
# 4      12088666076    coachcatie@crossfitfireside.com      google.com
# ...            ...                                ...             ...
# 10126  15093358732                                NaN             NaN
# 10127  12084765557                                NaN             NaN
# 10128  12088271551               jmaetche@hotmail.com     outlook.com
# 10129  12084763160                                NaN             NaN
# 10130  12084765777                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  ...  \
# 0                 Martial Art                 1522 W River St     Boise  ...
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise  ...
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna  ...
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise  ...
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian  ...
# ...                       ...                             ...       ...  ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman  ...
# 10127        Secondary school                   300 Dunlap Rd   Orofino  ...
# 10128                     Gym                     10610 US-12   Orofino  ...
# 10129      Youth organisation                 1115 Shriver Rd   Orofino  ...
# 10130                  Health              1055 Riverside Ave   Orofino  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                              2      NaN          NaN           NaN
# 1                              2        1          NaN           NaN
# 2                              1      NaN          NaN           NaN
# 3                              1      NaN            1             1
# 4                              1      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 10126                        NaN      NaN            1             1
# 10127                        NaN      NaN          NaN           NaN
# 10128                        NaN      NaN          NaN           NaN
# 10129                        NaN      NaN          NaN           NaN
# 10130                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3                 1         NaN
# 4               NaN         NaN
# ...             ...         ...
# 10126             1         NaN
# 10127           NaN         NaN
# 10128           NaN         NaN
# 10129           NaN         NaN
# 10130           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword search_city
# 0        Boxing Club       Boise
# 1        Boxing Club       Boise
# 2        Boxing Club       Boise
# 3        Boxing Club       Boise
# 4        Boxing Club       Boise
# ...              ...         ...
# 10126    Yoga Studio     Orofino
# 10127    Yoga Studio     Orofino
# 10128    Yoga Studio     Orofino
# 10129    Yoga Studio     Orofino
# 10130    Yoga Studio     Orofino
#
# [10131 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                  First Name                        name  \
# 0           Fitness  Combat Fitness I Sbg Idaho  Combat Fitness I Sbg Idaho
# 1           Fitness           Jack City Fitness           Jack City Fitness
# 2           General            Underground Fit         Underground Fit Club
# 3           Fitness               Axiom Fitness               Axiom Fitness
# 4          Crossfit           Crossfit Fireside           Crossfit Fireside
# ...             ...                         ...                         ...
# 10126       General   Student Recreation Center   Student Recreation Center
# 10127       General                 High School       (Orofino) High School
# 10128       Fitness             Maetche Fitness             Maetche Fitness
# 10129       General              ManiYac Center             Mani-Yac Center
# 10130       General               Health Center     (Orofino) Health Center
#
#              phone                              email      email_host  \
# 0      12089356264             info@combatfitness.com  greengeeks.com
# 1      12089991111                                NaN             NaN
# 2      12083660088  undergroundfitclubidaho@gmail.com      google.com
# 3      12089551113               joe@axiomfitness.com      google.com
# 4      12088666076    coachcatie@crossfitfireside.com      google.com
# ...            ...                                ...             ...
# 10126  15093358732                                NaN             NaN
# 10127  12084765557                                NaN             NaN
# 10128  12088271551               jmaetche@hotmail.com     outlook.com
# 10129  12084763160                                NaN             NaN
# 10130  12084765777                                NaN             NaN
#
#                                                  website  \
# 0                          http://www.combatfitness.com/
# 1                         http://www.jackcityfitness.com
# 2                         https://undergroundfitclub.com
# 3                           https://www.axiomfitness.com
# 4                            http://crossfitfireside.com
# ...                                                  ...
# 10126                               http://urec.wsu.edu/
# 10127  http://orofinojrsrhigh.id.ojsdh.schoolinsites....
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
#
#                      category                         address      city  ...  \
# 0                 Martial Art                 1522 W River St     Boise  ...
# 1       Fitness & Instruction              21 N Allumbaugh St     Boise  ...
# 2       Fitness & Instruction         679 S Best Business Ave      Kuna  ...
# 3       Fitness & Instruction           801 E Parkcenter Blvd     Boise  ...
# 4      Interval Training Gyms               490 E Schiller Ln  Meridian  ...
# ...                       ...                             ...       ...  ...
# 10126       Recreation Centre  1105 NE North Fairway Rd Drive   Pullman  ...
# 10127        Secondary school                   300 Dunlap Rd   Orofino  ...
# 10128                     Gym                     10610 US-12   Orofino  ...
# 10129      Youth organisation                 1115 Shriver Rd   Orofino  ...
# 10130                  Health              1055 Riverside Ave   Orofino  ...
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1            1          NaN           NaN           NaN         NaN
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN            1             1             1         NaN
# 4          NaN          NaN           NaN           NaN         NaN
# ...        ...          ...           ...           ...         ...
# 10126      NaN            1             1             1         NaN
# 10127      NaN          NaN           NaN           NaN         NaN
# 10128      NaN          NaN           NaN           NaN         NaN
# 10129      NaN          NaN           NaN           NaN         NaN
# 10130      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0                                https://g.page/sbgidaho        claimed
# 1                 https://g.page/jack-city-fitness-boise        claimed
# 2                 https://g.page/undergroundfitclubidaho        claimed
# 3      https://maps.google.com/maps/place/Axiom+Fitne...        claimed
# 4      https://maps.google.com/maps/place/Crossfit+Fi...        claimed
# ...                                                  ...            ...
# 10126  https://maps.google.com/maps/place/Student+Rec...        claimed
# 10127  https://maps.google.com/maps/place/Orofino+Hig...      unclaimed
# 10128  https://maps.google.com/maps/place/Maetche+Fit...      unclaimed
# 10129  https://maps.google.com/maps/place/Mani-Yac+Ce...      unclaimed
# 10130  https://maps.google.com/maps/place/Orofino+Hea...      unclaimed
#
#       search_keyword  search_city  \
# 0        Boxing Club        Boise
# 1        Boxing Club        Boise
# 2        Boxing Club        Boise
# 3        Boxing Club        Boise
# 4        Boxing Club        Boise
# ...              ...          ...
# 10126    Yoga Studio      Orofino
# 10127    Yoga Studio      Orofino
# 10128    Yoga Studio      Orofino
# 10129    Yoga Studio      Orofino
# 10130    Yoga Studio      Orofino
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a perfect rating on Google. 5 sta...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 10126  I saw B2 has a near perfect rating on Google. ...
# 10127  I saw B2 has a perfect rating on Google. 5 sta...
# 10128  I saw your B2 star rating on Facebook. Really ...
# 10129  I saw your B2 page on Facebook. You guys have ...
# 10130  I saw your B2 page on Facebook. You guys have ...
#
# [10131 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('ID_combined_leads_duplicates_removed_semiclean.csv', index = False)
