# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("MO_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          TITLE Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    ABBA Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city region    zip  ... instagram_average_comments  \
# 0            Kansas City     MO  64101  ...                        NaN
# 1            Kansas City     MO  64114  ...                          3
# 2      North Kansas City     MO  64116  ...                        NaN
# 3            Kansas City     MO  64102  ...                          2
# 4            Kansas City     MO  64109  ...                        NaN
# ...                  ...    ...    ...  ...                        ...
# 15895       Blue Springs     MO  64015  ...                        NaN
# 15896       Grain Valley     MO  64029  ...                          1
# 15897          Bridgeton     MO  63044  ...                        NaN
# 15898             Affton     MO  63123  ...                        NaN
# 15899        Saint Louis     MO  63129  ...                          1
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN           1
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN          NaN           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN           1
# ...        ...          ...           ...           ...         ...
# 15895      NaN          NaN           NaN           NaN         NaN
# 15896      NaN          NaN           NaN           NaN         NaN
# 15897      NaN          NaN           NaN           NaN         NaN
# 15898      NaN          NaN           NaN           NaN         NaN
# 15899      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city
# 0        Boxing Club   Kansas City
# 1        Boxing Club   Kansas City
# 2        Boxing Club   Kansas City
# 3        Boxing Club   Kansas City
# 4        Boxing Club   Kansas City
# ...              ...           ...
# 15895    Yoga Studio  Grain Valley
# 15896    Yoga Studio  Grain Valley
# 15897    Yoga Studio     Bridgeton
# 15898    Yoga Studio     Mehlville
# 15899    Yoga Studio     Mehlville
#
# [15900 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('MO','')
df['First Name'] = df['First Name'].str.replace('Mo','')
df['First Name'] = df['First Name'].str.replace('Missouri','')
df
# Out:
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          Title Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    Abba Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city region    zip  ... ads_yelp ads_facebook  \
# 0            Kansas City     MO  64101  ...      NaN          NaN
# 1            Kansas City     MO  64114  ...      NaN          NaN
# 2      North Kansas City     MO  64116  ...      NaN          NaN
# 3            Kansas City     MO  64102  ...      NaN          NaN
# 4            Kansas City     MO  64109  ...      NaN          NaN
# ...                  ...    ...    ...  ...      ...          ...
# 15895       Blue Springs     MO  64015  ...      NaN          NaN
# 15896       Grain Valley     MO  64029  ...      NaN          NaN
# 15897          Bridgeton     MO  63044  ...      NaN          NaN
# 15898             Affton     MO  63123  ...      NaN          NaN
# 15899        Saint Louis     MO  63129  ...      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN           1
# ...             ...           ...         ...
# 15895           NaN           NaN         NaN
# 15896           NaN           NaN         NaN
# 15897           NaN           NaN         NaN
# 15898           NaN           NaN         NaN
# 15899           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city                        First Name
# 0        Boxing Club   Kansas City                  Authentic Boxing
# 1        Boxing Club   Kansas City          Title Boxing  State Line
# 2        Boxing Club   Kansas City                    Bricks Fitness
# 3        Boxing Club   Kansas City                     Low Kick Camp
# 4        Boxing Club   Kansas City       Mayweather Boxing + Fitness
# ...              ...           ...                               ...
# 15895    Yoga Studio  Grain Valley                    Abba Wholeness
# 15896    Yoga Studio  Grain Valley  Grain Valley South Middle School
# 15897    Yoga Studio     Bridgeton       Bridgeton Recreation Center
# 15898    Yoga Studio     Mehlville                   Kelly Kauffmann
# 15899    Yoga Studio     Mehlville              Spiritual Human Yoga
#
# [15900 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          Title Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    Abba Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city region    zip  ... ads_yelp ads_facebook  \
# 0            Kansas City     MO  64101  ...      NaN          NaN
# 1            Kansas City     MO  64114  ...      NaN          NaN
# 2      North Kansas City     MO  64116  ...      NaN          NaN
# 3            Kansas City     MO  64102  ...      NaN          NaN
# 4            Kansas City     MO  64109  ...      NaN          NaN
# ...                  ...    ...    ...  ...      ...          ...
# 15895       Blue Springs     MO  64015  ...      NaN          NaN
# 15896       Grain Valley     MO  64029  ...      NaN          NaN
# 15897          Bridgeton     MO  63044  ...      NaN          NaN
# 15898             Affton     MO  63123  ...      NaN          NaN
# 15899        Saint Louis     MO  63129  ...      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN           1
# ...             ...           ...         ...
# 15895           NaN           NaN         NaN
# 15896           NaN           NaN         NaN
# 15897           NaN           NaN         NaN
# 15898           NaN           NaN         NaN
# 15899           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city                        First Name
# 0        Boxing Club   Kansas City                  Authentic Boxing
# 1        Boxing Club   Kansas City          Title Boxing  State Line
# 2        Boxing Club   Kansas City                    Bricks Fitness
# 3        Boxing Club   Kansas City                     Low Kick Camp
# 4        Boxing Club   Kansas City       Mayweather Boxing + Fitness
# ...              ...           ...                               ...
# 15895    Yoga Studio  Grain Valley                    Abba Wholeness
# 15896    Yoga Studio  Grain Valley  Grain Valley South Middle School
# 15897    Yoga Studio     Bridgeton       Bridgeton Recreation Center
# 15898    Yoga Studio     Mehlville                   Kelly Kauffmann
# 15899    Yoga Studio     Mehlville              Spiritual Human Yoga
#
# [15900 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          Title Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    Abba Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city region    zip  ... ads_facebook ads_instagram  \
# 0            Kansas City     MO  64101  ...          NaN           NaN
# 1            Kansas City     MO  64114  ...          NaN           NaN
# 2      North Kansas City     MO  64116  ...          NaN           NaN
# 3            Kansas City     MO  64102  ...          NaN           NaN
# 4            Kansas City     MO  64109  ...          NaN           NaN
# ...                  ...    ...    ...  ...          ...           ...
# 15895       Blue Springs     MO  64015  ...          NaN           NaN
# 15896       Grain Valley     MO  64029  ...          NaN           NaN
# 15897          Bridgeton     MO  63044  ...          NaN           NaN
# 15898             Affton     MO  63123  ...          NaN           NaN
# 15899        Saint Louis     MO  63129  ...          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN           1
# ...             ...         ...
# 15895           NaN         NaN
# 15896           NaN         NaN
# 15897           NaN         NaN
# 15898           NaN         NaN
# 15899           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city                        First Name  \
# 0        Boxing Club   Kansas City                  Authentic Boxing
# 1        Boxing Club   Kansas City          Title Boxing  State Line
# 2        Boxing Club   Kansas City                    Bricks Fitness
# 3        Boxing Club   Kansas City                     Low Kick Camp
# 4        Boxing Club   Kansas City       Mayweather Boxing + Fitness
# ...              ...           ...                               ...
# 15895    Yoga Studio  Grain Valley                    Abba Wholeness
# 15896    Yoga Studio  Grain Valley  Grain Valley South Middle School
# 15897    Yoga Studio     Bridgeton       Bridgeton Recreation Center
# 15898    Yoga Studio     Mehlville                   Kelly Kauffmann
# 15899    Yoga Studio     Mehlville              Spiritual Human Yoga
#
#       Business Type
# 0               NaT
# 1               NaT
# 2               NaT
# 3               NaT
# 4               NaT
# ...             ...
# 15895           NaT
# 15896           NaT
# 15897           NaT
# 15898           NaT
# 15899           NaT
#
# [15900 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          Title Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    Abba Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city region    zip  ... ads_facebook ads_instagram  \
# 0            Kansas City     MO  64101  ...          NaN           NaN
# 1            Kansas City     MO  64114  ...          NaN           NaN
# 2      North Kansas City     MO  64116  ...          NaN           NaN
# 3            Kansas City     MO  64102  ...          NaN           NaN
# 4            Kansas City     MO  64109  ...          NaN           NaN
# ...                  ...    ...    ...  ...          ...           ...
# 15895       Blue Springs     MO  64015  ...          NaN           NaN
# 15896       Grain Valley     MO  64029  ...          NaN           NaN
# 15897          Bridgeton     MO  63044  ...          NaN           NaN
# 15898             Affton     MO  63123  ...          NaN           NaN
# 15899        Saint Louis     MO  63129  ...          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN           1
# ...             ...         ...
# 15895           NaN         NaN
# 15896           NaN         NaN
# 15897           NaN         NaN
# 15898           NaN         NaN
# 15899           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city                        First Name  \
# 0        Boxing Club   Kansas City                  Authentic Boxing
# 1        Boxing Club   Kansas City          Title Boxing  State Line
# 2        Boxing Club   Kansas City                    Bricks Fitness
# 3        Boxing Club   Kansas City                     Low Kick Camp
# 4        Boxing Club   Kansas City       Mayweather Boxing + Fitness
# ...              ...           ...                               ...
# 15895    Yoga Studio  Grain Valley                    Abba Wholeness
# 15896    Yoga Studio  Grain Valley  Grain Valley South Middle School
# 15897    Yoga Studio     Bridgeton       Bridgeton Recreation Center
# 15898    Yoga Studio     Mehlville                   Kelly Kauffmann
# 15899    Yoga Studio     Mehlville              Spiritual Human Yoga
#
#       Business Type
# 0           General
# 1           General
# 2           General
# 3           General
# 4           General
# ...             ...
# 15895       General
# 15896       General
# 15897       General
# 15898       General
# 15899       General
#
# [15900 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          Title Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    Abba Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city region    zip  ... ads_facebook ads_instagram  \
# 0            Kansas City     MO  64101  ...          NaN           NaN
# 1            Kansas City     MO  64114  ...          NaN           NaN
# 2      North Kansas City     MO  64116  ...          NaN           NaN
# 3            Kansas City     MO  64102  ...          NaN           NaN
# 4            Kansas City     MO  64109  ...          NaN           NaN
# ...                  ...    ...    ...  ...          ...           ...
# 15895       Blue Springs     MO  64015  ...          NaN           NaN
# 15896       Grain Valley     MO  64029  ...          NaN           NaN
# 15897          Bridgeton     MO  63044  ...          NaN           NaN
# 15898             Affton     MO  63123  ...          NaN           NaN
# 15899        Saint Louis     MO  63129  ...          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN           1
# ...             ...         ...
# 15895           NaN         NaN
# 15896           NaN         NaN
# 15897           NaN         NaN
# 15898           NaN         NaN
# 15899           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city                        First Name  \
# 0        Boxing Club   Kansas City                  Authentic Boxing
# 1        Boxing Club   Kansas City          Title Boxing  State Line
# 2        Boxing Club   Kansas City                    Bricks Fitness
# 3        Boxing Club   Kansas City                     Low Kick Camp
# 4        Boxing Club   Kansas City       Mayweather Boxing + Fitness
# ...              ...           ...                               ...
# 15895    Yoga Studio  Grain Valley                    Abba Wholeness
# 15896    Yoga Studio  Grain Valley  Grain Valley South Middle School
# 15897    Yoga Studio     Bridgeton       Bridgeton Recreation Center
# 15898    Yoga Studio     Mehlville                   Kelly Kauffmann
# 15899    Yoga Studio     Mehlville              Spiritual Human Yoga
#
#       Business Type
# 0            Boxing
# 1            Boxing
# 2           Fitness
# 3           General
# 4            Boxing
# ...             ...
# 15895       General
# 15896       General
# 15897       General
# 15898       General
# 15899          Yoga
#
# [15900 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                        First Name  \
# 0            Boxing                  Authentic Boxing
# 1            Boxing          Title Boxing  State Line
# 2           Fitness                    Bricks Fitness
# 3           General                     Low Kick Camp
# 4            Boxing       Mayweather Boxing + Fitness
# ...             ...                               ...
# 15895       General                    Abba Wholeness
# 15896       General  Grain Valley South Middle School
# 15897       General       Bridgeton Recreation Center
# 15898       General                   Kelly Kauffmann
# 15899          Yoga              Spiritual Human Yoga
#
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          Title Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    Abba Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city  ... instagram_average_comments ads_yelp  \
# 0            Kansas City  ...                        NaN      NaN
# 1            Kansas City  ...                          3      NaN
# 2      North Kansas City  ...                        NaN      NaN
# 3            Kansas City  ...                          2      NaN
# 4            Kansas City  ...                        NaN      NaN
# ...                  ...  ...                        ...      ...
# 15895       Blue Springs  ...                        NaN      NaN
# 15896       Grain Valley  ...                          1      NaN
# 15897          Bridgeton  ...                        NaN      NaN
# 15898             Affton  ...                        NaN      NaN
# 15899        Saint Louis  ...                          1      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           1
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN           1
# ...            ...           ...           ...         ...
# 15895          NaN           NaN           NaN         NaN
# 15896          NaN           NaN           NaN         NaN
# 15897          NaN           NaN           NaN         NaN
# 15898          NaN           NaN           NaN         NaN
# 15899          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city
# 0        Boxing Club   Kansas City
# 1        Boxing Club   Kansas City
# 2        Boxing Club   Kansas City
# 3        Boxing Club   Kansas City
# 4        Boxing Club   Kansas City
# ...              ...           ...
# 15895    Yoga Studio  Grain Valley
# 15896    Yoga Studio  Grain Valley
# 15897    Yoga Studio     Bridgeton
# 15898    Yoga Studio     Mehlville
# 15899    Yoga Studio     Mehlville
#
# [15900 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                        First Name  \
# 0            Boxing                  Authentic Boxing
# 1            Boxing          Title Boxing  State Line
# 2           Fitness                    Bricks Fitness
# 3           General                     Low Kick Camp
# 4            Boxing        Mayweather Boxing  Fitness
# ...             ...                               ...
# 15895       General                    Abba Wholeness
# 15896       General  Grain Valley South Middle School
# 15897       General       Bridgeton Recreation Center
# 15898       General                   Kelly Kauffmann
# 15899          Yoga              Spiritual Human Yoga
#
#                                    name        phone  \
# 0                      Authentic Boxing  18166959171
# 1          Title Boxing Club State Line  18169979777
# 2                        Bricks Fitness  18165854630
# 3                         Low Kick Camp  18166793689
# 4           Mayweather Boxing + Fitness  18166731158
# ...                                 ...          ...
# 15895                    Abba Wholeness  18169888379
# 15896  Grain Valley South Middle School  18162293499
# 15897       Bridgeton Recreation Center  13147395599
# 15898                   Kelly Kauffmann  13146404295
# 15899              Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city  ... instagram_average_comments ads_yelp  \
# 0            Kansas City  ...                        NaN      NaN
# 1            Kansas City  ...                          3      NaN
# 2      North Kansas City  ...                        NaN      NaN
# 3            Kansas City  ...                          2      NaN
# 4            Kansas City  ...                        NaN      NaN
# ...                  ...  ...                        ...      ...
# 15895       Blue Springs  ...                        NaN      NaN
# 15896       Grain Valley  ...                          1      NaN
# 15897          Bridgeton  ...                        NaN      NaN
# 15898             Affton  ...                        NaN      NaN
# 15899        Saint Louis  ...                          1      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           1
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN           1
# ...            ...           ...           ...         ...
# 15895          NaN           NaN           NaN         NaN
# 15896          NaN           NaN           NaN         NaN
# 15897          NaN           NaN           NaN         NaN
# 15898          NaN           NaN           NaN         NaN
# 15899          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city
# 0        Boxing Club   Kansas City
# 1        Boxing Club   Kansas City
# 2        Boxing Club   Kansas City
# 3        Boxing Club   Kansas City
# 4        Boxing Club   Kansas City
# ...              ...           ...
# 15895    Yoga Studio  Grain Valley
# 15896    Yoga Studio  Grain Valley
# 15897    Yoga Studio     Bridgeton
# 15898    Yoga Studio     Mehlville
# 15899    Yoga Studio     Mehlville
#
# [15900 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                  First Name  \
# 0            Boxing            Authentic Boxing
# 1            Boxing    Title Boxing  State Line
# 2           Fitness              Bricks Fitness
# 3           General               Low Kick Camp
# 4            Boxing  Mayweather Boxing  Fitness
# ...             ...                         ...
# 15895       General              Abba Wholeness
# 15896       General         South Middle School
# 15897       General           Recreation Center
# 15898       General             Kelly Kauffmann
# 15899          Yoga        Spiritual Human Yoga
#
#                                      name        phone  \
# 0                        Authentic Boxing  18166959171
# 1            Title Boxing Club State Line  18169979777
# 2                          Bricks Fitness  18165854630
# 3                           Low Kick Camp  18166793689
# 4             Mayweather Boxing + Fitness  18166731158
# ...                                   ...          ...
# 15895                      Abba Wholeness  18169888379
# 15896  (Grain Valley) South Middle School  18162293499
# 15897       (Bridgeton) Recreation Center  13147395599
# 15898                     Kelly Kauffmann  13146404295
# 15899                Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city  ... instagram_average_comments ads_yelp  \
# 0            Kansas City  ...                        NaN      NaN
# 1            Kansas City  ...                          3      NaN
# 2      North Kansas City  ...                        NaN      NaN
# 3            Kansas City  ...                          2      NaN
# 4            Kansas City  ...                        NaN      NaN
# ...                  ...  ...                        ...      ...
# 15895       Blue Springs  ...                        NaN      NaN
# 15896       Grain Valley  ...                          1      NaN
# 15897          Bridgeton  ...                        NaN      NaN
# 15898             Affton  ...                        NaN      NaN
# 15899        Saint Louis  ...                          1      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           1
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN           1
# ...            ...           ...           ...         ...
# 15895          NaN           NaN           NaN         NaN
# 15896          NaN           NaN           NaN         NaN
# 15897          NaN           NaN           NaN         NaN
# 15898          NaN           NaN           NaN         NaN
# 15899          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city
# 0        Boxing Club   Kansas City
# 1        Boxing Club   Kansas City
# 2        Boxing Club   Kansas City
# 3        Boxing Club   Kansas City
# 4        Boxing Club   Kansas City
# ...              ...           ...
# 15895    Yoga Studio  Grain Valley
# 15896    Yoga Studio  Grain Valley
# 15897    Yoga Studio     Bridgeton
# 15898    Yoga Studio     Mehlville
# 15899    Yoga Studio     Mehlville
#
# [15900 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for CST leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                  First Name  \
# 0            Boxing            Authentic Boxing
# 1            Boxing    Title Boxing  State Line
# 2           Fitness              Bricks Fitness
# 3           General               Low Kick Camp
# 4            Boxing  Mayweather Boxing  Fitness
# ...             ...                         ...
# 15895       General              Abba Wholeness
# 15896       General         South Middle School
# 15897       General           Recreation Center
# 15898       General             Kelly Kauffmann
# 15899          Yoga        Spiritual Human Yoga
#
#                                      name        phone  \
# 0                        Authentic Boxing  18166959171
# 1            Title Boxing Club State Line  18169979777
# 2                          Bricks Fitness  18165854630
# 3                           Low Kick Camp  18166793689
# 4             Mayweather Boxing + Fitness  18166731158
# ...                                   ...          ...
# 15895                      Abba Wholeness  18169888379
# 15896  (Grain Valley) South Middle School  18162293499
# 15897       (Bridgeton) Recreation Center  13147395599
# 15898                     Kelly Kauffmann  13146404295
# 15899                Spiritual Human Yoga  13148925062
#
#                                email       email_host  \
# 0          authenticboxing@yahoo.com        yahoo.com
# 1             tbc534parser@gmail.com       google.com
# 2      jreed@solidbrickspainting.com      outlook.com
# 3            thairoundkick@gmail.com       google.com
# 4       southpaloalto@mayweather.fit      outlook.com
# ...                              ...              ...
# 15895       office@abbawholeness.com       google.com
# 15896              llimberg@gvr5.net       google.com
# 15897          chief@bridgetonmo.com  bridgetonmo.com
# 15898                            NaN              NaN
# 15899           info@hue-faculty.com       google.com
#
#                                           website  \
# 0                 http://www.authenticboxing.com/
# 1      https://titleboxingclub.com/state-line-mo/
# 2                 http://www.bricksfitnesskc.com/
# 3                     http://www.lowkickcamp.com/
# 4          https://mayweather.fit/kansas-city-mo/
# ...                                           ...
# 15895                   http://abbawholeness.com/
# 15896         https://sms.grainvalleyschools.org/
# 15897                 http://www.bridgetonmo.com/
# 15898                  http://kellykauffmann.com/
# 15899                 http://www.hue-faculty.com/
#
#                              category                         address  \
# 0                          Boxing Gym                  1308 W 11th St
# 1                         Boxing ring              8029 State Line Rd
# 2                          Boxing Gym                    1617 Iron St
# 3                Muay Thai boxing gym             1420 W 13th Terrace
# 4                                 Gym                     Gillham Plz
# ...                               ...                             ...
# 15895  Holistic medicine practitioner  1209 NW North Ridge Dr Suite C
# 15896                Secondary School                   901 E Ryan Rd
# 15897               Recreation Centre                 4201 Fee Fee Rd
# 15898                 Yoga instructor               9801 MacKenzie Rd
# 15899  Holistic medicine practitioner               4448 Telegraph Rd
#
#                     city  ... ads_yelp ads_facebook ads_instagram  \
# 0            Kansas City  ...      NaN          NaN           NaN
# 1            Kansas City  ...      NaN          NaN           NaN
# 2      North Kansas City  ...      NaN          NaN           NaN
# 3            Kansas City  ...      NaN          NaN           NaN
# 4            Kansas City  ...      NaN          NaN           NaN
# ...                  ...  ...      ...          ...           ...
# 15895       Blue Springs  ...      NaN          NaN           NaN
# 15896       Grain Valley  ...      NaN          NaN           NaN
# 15897          Bridgeton  ...      NaN          NaN           NaN
# 15898             Affton  ...      NaN          NaN           NaN
# 15899        Saint Louis  ...      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN           1
# ...             ...         ...
# 15895           NaN         NaN
# 15896           NaN         NaN
# 15897           NaN         NaN
# 15898           NaN         NaN
# 15899           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Authentic+B...      unclaimed
# 1            https://g.page/title-boxing-club-state-line        claimed
# 2                           https://g.page/Bricksfitness        claimed
# 3      https://maps.google.com/maps/place/Low+Kick+Ca...        claimed
# 4      https://maps.google.com/maps/place/Mayweather+...        claimed
# ...                                                  ...            ...
# 15895                      https://g.page/abba-wholeness        claimed
# 15896  https://maps.google.com/maps/place/Grain+Valle...        claimed
# 15897  https://maps.google.com/maps/place/Bridgeton+R...        claimed
# 15898  https://maps.google.com/maps/place/Kelly+Kauff...      unclaimed
# 15899  https://maps.google.com/maps/place/Spiritual+H...        claimed
#
#       search_keyword   search_city  \
# 0        Boxing Club   Kansas City
# 1        Boxing Club   Kansas City
# 2        Boxing Club   Kansas City
# 3        Boxing Club   Kansas City
# 4        Boxing Club   Kansas City
# ...              ...           ...
# 15895    Yoga Studio  Grain Valley
# 15896    Yoga Studio  Grain Valley
# 15897    Yoga Studio     Bridgeton
# 15898    Yoga Studio     Mehlville
# 15899    Yoga Studio     Mehlville
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a perfect rating on Google. 5 sta...
# 4      I saw your B2 listing on Google hit double dig...
# ...                                                  ...
# 15895  I saw B2 has a perfect rating on Google. 5 sta...
# 15896  I saw your B2 followers on Instagram got into ...
# 15897  I saw B2 has a near perfect rating on Google. ...
# 15898  I saw B2 has a perfect rating on Google. 5 sta...
# 15899  I saw B2 has a perfect rating on Google. 5 sta...
#
# [15900 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('MO_combined_leads_duplicates_removed_semiclean.csv', index = False)
