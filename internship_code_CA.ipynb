# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("CA_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,11,16,17,18,19,20,21,36,37,38,39,40,41,43,44,45,46,47,48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                     name          phone  \
# 0                                  City of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics LA: Best HIIT MMA & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training and Fitness Center  15626933635.0
# 52751                   Aikido Ai of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city region    zip  ...  \
# 0               3000 S Hill St  Los Angeles     CA  90007  ...
# 1             4500 W Pico Blvd  Los Angeles     CA  90019  ...
# 2             1302 Sunset Blvd  Los Angeles     CA  90026  ...
# 3                    S Hill St  Los Angeles     CA  90014  ...
# 4      6221 Wilshire Blvd #101  Los Angeles     CA  90048  ...
# ...                        ...          ...    ...    ...  ...
# 52748       7652 Greenleaf Ave     Whittier     CA  90602  ...
# 52749         7346 Painter Ave     Whittier     CA  90602  ...
# 52750       6518 Greenleaf Ave     Whittier     CA  90601  ...
# 52751        6725 Comstock Ave     Whittier     CA  90601  ...
# 52752            12360 Penn St     Whittier     CA  90602  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                              5      NaN          NaN           NaN
# 1                              6      NaN          NaN           NaN
# 2                            NaN      NaN          NaN           NaN
# 3                              3      NaN            1           NaN
# 4                            NaN      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 52748                        NaN      NaN          NaN           NaN
# 52749                        6.0      NaN          NaN           NaN
# 52750                        3.0      NaN          NaN           NaN
# 52751                        NaN      NaN          NaN           NaN
# 52752                        3.0      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN           1
# ...             ...         ...
# 52748           NaN         NaN
# 52749           NaN         NaN
# 52750           NaN         NaN
# 52751           NaN         NaN
# 52752           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
# [52753 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('AL','')
df['First Name'] = df['First Name'].str.replace('Al','')
df['First Name'] = df['First Name'].str.replace('Alabama','')
df
# Out:
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city region    zip  ... ads_yelp  \
# 0               3000 S Hill St  Los Angeles     CA  90007  ...      NaN
# 1             4500 W Pico Blvd  Los Angeles     CA  90019  ...      NaN
# 2             1302 Sunset Blvd  Los Angeles     CA  90026  ...      NaN
# 3                    S Hill St  Los Angeles     CA  90014  ...      NaN
# 4      6221 Wilshire Blvd #101  Los Angeles     CA  90048  ...      NaN
# ...                        ...          ...    ...    ...  ...      ...
# 52748       7652 Greenleaf Ave     Whittier     CA  90602  ...      NaN
# 52749         7346 Painter Ave     Whittier     CA  90602  ...      NaN
# 52750       6518 Greenleaf Ave     Whittier     CA  90601  ...      NaN
# 52751        6725 Comstock Ave     Whittier     CA  90601  ...      NaN
# 52752            12360 Penn St     Whittier     CA  90602  ...      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN         NaN
# 3                1           NaN           NaN         NaN
# 4              NaN           NaN           NaN           1
# ...            ...           ...           ...         ...
# 52748          NaN           NaN           NaN         NaN
# 52749          NaN           NaN           NaN         NaN
# 52750          NaN           NaN           NaN         NaN
# 52751          NaN           NaN           NaN         NaN
# 52752          NaN           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
#                                               First Name
# 0                                  City Of Angels Boxing
# 1                                       Westside Boxing
# 2                                       Echo Park Boxing
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...
# 4                Mayweather Boxing + Fitness Los Angeles
# ...                                                  ...
# 52748                                         Maternifit
# 52749                             Back 2 Basics Training
# 52750                Dynamic Training And Fitness Center
# 52751                   Aikido Ai Of Southern California
# 52752                                 Oasis Healing Arts
#
# [52753 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city region    zip  ... ads_yelp  \
# 0               3000 S Hill St  Los Angeles     CA  90007  ...      NaN
# 1             4500 W Pico Blvd  Los Angeles     CA  90019  ...      NaN
# 2             1302 Sunset Blvd  Los Angeles     CA  90026  ...      NaN
# 3                    S Hill St  Los Angeles     CA  90014  ...      NaN
# 4      6221 Wilshire Blvd #101  Los Angeles     CA  90048  ...      NaN
# ...                        ...          ...    ...    ...  ...      ...
# 52748       7652 Greenleaf Ave     Whittier     CA  90602  ...      NaN
# 52749         7346 Painter Ave     Whittier     CA  90602  ...      NaN
# 52750       6518 Greenleaf Ave     Whittier     CA  90601  ...      NaN
# 52751        6725 Comstock Ave     Whittier     CA  90601  ...      NaN
# 52752            12360 Penn St     Whittier     CA  90602  ...      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN         NaN
# 2              NaN           NaN           NaN         NaN
# 3                1           NaN           NaN         NaN
# 4              NaN           NaN           NaN           1
# ...            ...           ...           ...         ...
# 52748          NaN           NaN           NaN         NaN
# 52749          NaN           NaN           NaN         NaN
# 52750          NaN           NaN           NaN         NaN
# 52751          NaN           NaN           NaN         NaN
# 52752          NaN           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
#                                               First Name
# 0                                  City Of Angels Boxing
# 1                                       Westside Boxing
# 2                                       Echo Park Boxing
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...
# 4                Mayweather Boxing + Fitness Los Angeles
# ...                                                  ...
# 52748                                         Maternifit
# 52749                             Back 2 Basics Training
# 52750                Dynamic Training And Fitness Center
# 52751                   Aikido Ai Of Southern California
# 52752                                 Oasis Healing Arts
#
# [52753 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city region    zip  ... ads_facebook  \
# 0               3000 S Hill St  Los Angeles     CA  90007  ...          NaN
# 1             4500 W Pico Blvd  Los Angeles     CA  90019  ...          NaN
# 2             1302 Sunset Blvd  Los Angeles     CA  90026  ...          NaN
# 3                    S Hill St  Los Angeles     CA  90014  ...            1
# 4      6221 Wilshire Blvd #101  Los Angeles     CA  90048  ...          NaN
# ...                        ...          ...    ...    ...  ...          ...
# 52748       7652 Greenleaf Ave     Whittier     CA  90602  ...          NaN
# 52749         7346 Painter Ave     Whittier     CA  90602  ...          NaN
# 52750       6518 Greenleaf Ave     Whittier     CA  90601  ...          NaN
# 52751        6725 Comstock Ave     Whittier     CA  90601  ...          NaN
# 52752            12360 Penn St     Whittier     CA  90602  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN           1
# ...             ...           ...         ...
# 52748           NaN           NaN         NaN
# 52749           NaN           NaN         NaN
# 52750           NaN           NaN         NaN
# 52751           NaN           NaN         NaN
# 52752           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
#                                               First Name Business Type
# 0                                  City Of Angels Boxing           NaT
# 1                                       Westside Boxing            NaT
# 2                                       Echo Park Boxing           NaT
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...           NaT
# 4                Mayweather Boxing + Fitness Los Angeles           NaT
# ...                                                  ...           ...
# 52748                                         Maternifit           NaT
# 52749                             Back 2 Basics Training           NaT
# 52750                Dynamic Training And Fitness Center           NaT
# 52751                   Aikido Ai Of Southern California           NaT
# 52752                                 Oasis Healing Arts           NaT
#
# [52753 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city region    zip  ... ads_facebook  \
# 0               3000 S Hill St  Los Angeles     CA  90007  ...          NaN
# 1             4500 W Pico Blvd  Los Angeles     CA  90019  ...          NaN
# 2             1302 Sunset Blvd  Los Angeles     CA  90026  ...          NaN
# 3                    S Hill St  Los Angeles     CA  90014  ...            1
# 4      6221 Wilshire Blvd #101  Los Angeles     CA  90048  ...          NaN
# ...                        ...          ...    ...    ...  ...          ...
# 52748       7652 Greenleaf Ave     Whittier     CA  90602  ...          NaN
# 52749         7346 Painter Ave     Whittier     CA  90602  ...          NaN
# 52750       6518 Greenleaf Ave     Whittier     CA  90601  ...          NaN
# 52751        6725 Comstock Ave     Whittier     CA  90601  ...          NaN
# 52752            12360 Penn St     Whittier     CA  90602  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN           1
# ...             ...           ...         ...
# 52748           NaN           NaN         NaN
# 52749           NaN           NaN         NaN
# 52750           NaN           NaN         NaN
# 52751           NaN           NaN         NaN
# 52752           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
#                                               First Name Business Type
# 0                                  City Of Angels Boxing       General
# 1                                       Westside Boxing        General
# 2                                       Echo Park Boxing       General
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...       General
# 4                Mayweather Boxing + Fitness Los Angeles       General
# ...                                                  ...           ...
# 52748                                         Maternifit       General
# 52749                             Back 2 Basics Training       General
# 52750                Dynamic Training And Fitness Center       General
# 52751                   Aikido Ai Of Southern California       General
# 52752                                 Oasis Healing Arts       General
#
# [52753 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city region    zip  ... ads_facebook  \
# 0               3000 S Hill St  Los Angeles     CA  90007  ...          NaN
# 1             4500 W Pico Blvd  Los Angeles     CA  90019  ...          NaN
# 2             1302 Sunset Blvd  Los Angeles     CA  90026  ...          NaN
# 3                    S Hill St  Los Angeles     CA  90014  ...            1
# 4      6221 Wilshire Blvd #101  Los Angeles     CA  90048  ...          NaN
# ...                        ...          ...    ...    ...  ...          ...
# 52748       7652 Greenleaf Ave     Whittier     CA  90602  ...          NaN
# 52749         7346 Painter Ave     Whittier     CA  90602  ...          NaN
# 52750       6518 Greenleaf Ave     Whittier     CA  90601  ...          NaN
# 52751        6725 Comstock Ave     Whittier     CA  90601  ...          NaN
# 52752            12360 Penn St     Whittier     CA  90602  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN           1
# ...             ...           ...         ...
# 52748           NaN           NaN         NaN
# 52749           NaN           NaN         NaN
# 52750           NaN           NaN         NaN
# 52751           NaN           NaN         NaN
# 52752           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
#                                               First Name Business Type
# 0                                  City Of Angels Boxing        Boxing
# 1                                       Westside Boxing         Boxing
# 2                                       Echo Park Boxing        Boxing
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    Kickboxing
# 4                Mayweather Boxing + Fitness Los Angeles        Boxing
# ...                                                  ...           ...
# 52748                                         Maternifit       General
# 52749                             Back 2 Basics Training       General
# 52750                Dynamic Training And Fitness Center       Fitness
# 52751                   Aikido Ai Of Southern California        Aikido
# 52752                                 Oasis Healing Arts       General
#
# [52753 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                              City Of Angels Boxing
# 1            Boxing                                   Westside Boxing
# 2            Boxing                                   Echo Park Boxing
# 3        Kickboxing  Rise Athletics La: Best Hiit Mma & Kickboxing ...
# 4            Boxing            Mayweather Boxing + Fitness Los Angeles
# ...             ...                                                ...
# 52748       General                                         Maternifit
# 52749       General                             Back 2 Basics Training
# 52750       Fitness                Dynamic Training And Fitness Center
# 52751        Aikido                   Aikido Ai Of Southern California
# 52752       General                                 Oasis Healing Arts
#
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city  ... instagram_average_comments  \
# 0               3000 S Hill St  Los Angeles  ...                          5
# 1             4500 W Pico Blvd  Los Angeles  ...                          6
# 2             1302 Sunset Blvd  Los Angeles  ...                        NaN
# 3                    S Hill St  Los Angeles  ...                          3
# 4      6221 Wilshire Blvd #101  Los Angeles  ...                        NaN
# ...                        ...          ...  ...                        ...
# 52748       7652 Greenleaf Ave     Whittier  ...                        NaN
# 52749         7346 Painter Ave     Whittier  ...                        6.0
# 52750       6518 Greenleaf Ave     Whittier  ...                        3.0
# 52751        6725 Comstock Ave     Whittier  ...                        NaN
# 52752            12360 Penn St     Whittier  ...                        3.0
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN         NaN
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN            1           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN           1
# ...        ...          ...           ...           ...         ...
# 52748      NaN          NaN           NaN           NaN         NaN
# 52749      NaN          NaN           NaN           NaN         NaN
# 52750      NaN          NaN           NaN           NaN         NaN
# 52751      NaN          NaN           NaN           NaN         NaN
# 52752      NaN          NaN           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
# [52753 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                              City Of Angels Boxing
# 1            Boxing                                   Westside Boxing
# 2            Boxing                                   Echo Park Boxing
# 3        Kickboxing  Rise Athletics La Best Hiit Mma & Kickboxing C...
# 4            Boxing             Mayweather Boxing  Fitness Los Angeles
# ...             ...                                                ...
# 52748       General                                         Maternifit
# 52749       General                             Back 2 Basics Training
# 52750       Fitness                Dynamic Training And Fitness Center
# 52751        Aikido                   Aikido Ai Of Southern California
# 52752       General                                 Oasis Healing Arts
#
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4                Mayweather Boxing + Fitness Los Angeles    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city  ... instagram_average_comments  \
# 0               3000 S Hill St  Los Angeles  ...                          5
# 1             4500 W Pico Blvd  Los Angeles  ...                          6
# 2             1302 Sunset Blvd  Los Angeles  ...                        NaN
# 3                    S Hill St  Los Angeles  ...                          3
# 4      6221 Wilshire Blvd #101  Los Angeles  ...                        NaN
# ...                        ...          ...  ...                        ...
# 52748       7652 Greenleaf Ave     Whittier  ...                        NaN
# 52749         7346 Painter Ave     Whittier  ...                        6.0
# 52750       6518 Greenleaf Ave     Whittier  ...                        3.0
# 52751        6725 Comstock Ave     Whittier  ...                        NaN
# 52752            12360 Penn St     Whittier  ...                        3.0
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN         NaN
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN            1           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN           1
# ...        ...          ...           ...           ...         ...
# 52748      NaN          NaN           NaN           NaN         NaN
# 52749      NaN          NaN           NaN           NaN         NaN
# 52750      NaN          NaN           NaN           NaN         NaN
# 52751      NaN          NaN           NaN           NaN         NaN
# 52752      NaN          NaN           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
# [52753 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                              City Of Angels Boxing
# 1            Boxing                                   Westside Boxing
# 2            Boxing                                   Echo Park Boxing
# 3        Kickboxing  Rise Athletics La Best Hiit Mma & Kickboxing C...
# 4            Boxing                        Mayweather Boxing  Fitness
# ...             ...                                                ...
# 52748       General                                         Maternifit
# 52749       General                             Back 2 Basics Training
# 52750       Fitness                Dynamic Training And Fitness Center
# 52751        Aikido                   Aikido Ai Of Southern California
# 52752       General                                 Oasis Healing Arts
#
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4              Mayweather Boxing + Fitness (Los Angeles)    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city  ... instagram_average_comments  \
# 0               3000 S Hill St  Los Angeles  ...                          5
# 1             4500 W Pico Blvd  Los Angeles  ...                          6
# 2             1302 Sunset Blvd  Los Angeles  ...                        NaN
# 3                    S Hill St  Los Angeles  ...                          3
# 4      6221 Wilshire Blvd #101  Los Angeles  ...                        NaN
# ...                        ...          ...  ...                        ...
# 52748       7652 Greenleaf Ave     Whittier  ...                        NaN
# 52749         7346 Painter Ave     Whittier  ...                        6.0
# 52750       6518 Greenleaf Ave     Whittier  ...                        3.0
# 52751        6725 Comstock Ave     Whittier  ...                        NaN
# 52752            12360 Penn St     Whittier  ...                        3.0
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN         NaN
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN            1           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN           1
# ...        ...          ...           ...           ...         ...
# 52748      NaN          NaN           NaN           NaN         NaN
# 52749      NaN          NaN           NaN           NaN         NaN
# 52750      NaN          NaN           NaN           NaN         NaN
# 52751      NaN          NaN           NaN           NaN         NaN
# 52752      NaN          NaN           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
# [52753 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                                         First Name  \
# 0            Boxing                              City Of Angels Boxing
# 1            Boxing                                   Westside Boxing
# 2            Boxing                                   Echo Park Boxing
# 3        Kickboxing  Rise Athletics La Best Hiit Mma & Kickboxing C...
# 4            Boxing                        Mayweather Boxing  Fitness
# ...             ...                                                ...
# 52748       General                                         Maternifit
# 52749       General                             Back 2 Basics Training
# 52750       Fitness                Dynamic Training And Fitness Center
# 52751        Aikido                   Aikido Ai Of Southern California
# 52752       General                                 Oasis Healing Arts
#
#                                                     name          phone  \
# 0                                  City Of Angels Boxing    13236301974
# 1                                   Westside Boxing Club    13105695503
# 2                                       Echo Park Boxing    13237909300
# 3      Rise Athletics La: Best Hiit Mma & Kickboxing ...    18186605830
# 4              Mayweather Boxing + Fitness (Los Angeles)    14243203212
# ...                                                  ...            ...
# 52748                                         Maternifit  18183782075.0
# 52749                             Back 2 Basics Training  13238961344.0
# 52750                Dynamic Training And Fitness Center  15626933635.0
# 52751                   Aikido Ai Of Southern California  15626961838.0
# 52752                                 Oasis Healing Arts  15627891588.0
#
#                                 email    email_host  \
# 0         alex@cityofangelsboxing.com   outlook.com
# 1      westsideboxingclub@hotmail.com   outlook.com
# 2            echoparkboxing@gmail.com    google.com
# 3         contact@riseathleticsla.com  bluehost.com
# 4       northbrunswick@mayweather.fit   outlook.com
# ...                               ...           ...
# 52748                             NaN           NaN
# 52749        btbtraininginc@gmail.com    google.com
# 52750                  info@dtnfc.com  bluehost.com
# 52751            contact@aikidoai.com    google.com
# 52752     heal@oasishealingforyou.com    google.com
#
#                                       website                    category  \
# 0          http://www.cityofangelsboxing.com/                  Boxing Gym
# 1              http://www.westsideboxing.com/                  Boxing Gym
# 2                  http://echoparkboxing.com/                  Boxing Gym
# 3                https://riseathleticsla.com/                  Boxing Gym
# 4      https://www.mayweather.fit/los-angeles                  Boxing Gym
# ...                                       ...                         ...
# 52748              http://www.trevormone.com/  Physical Fitness Programme
# 52749     http://www.back2basicstraining.com/            Personal trainer
# 52750                       http://dtnfc.com/                         Gym
# 52751                http://www.aikidoai.com/         Martial arts school
# 52752          https://oasishealingforyou.com             Massage Therapy
#
#                        address         city  ... ads_yelp ads_facebook  \
# 0               3000 S Hill St  Los Angeles  ...      NaN          NaN
# 1             4500 W Pico Blvd  Los Angeles  ...      NaN          NaN
# 2             1302 Sunset Blvd  Los Angeles  ...      NaN          NaN
# 3                    S Hill St  Los Angeles  ...      NaN            1
# 4      6221 Wilshire Blvd #101  Los Angeles  ...      NaN          NaN
# ...                        ...          ...  ...      ...          ...
# 52748       7652 Greenleaf Ave     Whittier  ...      NaN          NaN
# 52749         7346 Painter Ave     Whittier  ...      NaN          NaN
# 52750       6518 Greenleaf Ave     Whittier  ...      NaN          NaN
# 52751        6725 Comstock Ave     Whittier  ...      NaN          NaN
# 52752            12360 Penn St     Whittier  ...      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN           1
# ...             ...           ...         ...
# 52748           NaN           NaN         NaN
# 52749           NaN           NaN         NaN
# 52750           NaN           NaN         NaN
# 52751           NaN           NaN         NaN
# 52752           NaN           NaN         NaN
#
#                                           g_maps_claimed     g_maps  \
# 0      https://maps.google.com/maps/place/City+of+Ang...  unclaimed
# 1      https://maps.google.com/maps/place/Westside+Bo...    claimed
# 2      https://maps.google.com/maps/place/Echo+Park+B...    claimed
# 3                         https://g.page/riseathleticsla    claimed
# 4      https://maps.google.com/maps/place/Mayweather+...    claimed
# ...                                                  ...        ...
# 52748  https://maps.google.com/maps/place/Maternifit/...  unclaimed
# 52749  https://maps.google.com/maps/place/Back+2+Basi...    claimed
# 52750  https://maps.google.com/maps/place/Dynamic+Tra...  unclaimed
# 52751                            https://g.page/AikidoAi    claimed
# 52752  https://maps.google.com/maps/place/Oasis+Heali...    claimed
#
#       search_keyword  search_city  \
# 0        Boxing Club  Los Angeles
# 1        Boxing Club  Los Angeles
# 2        Boxing Club  Los Angeles
# 3        Boxing Club  Los Angeles
# 4        Boxing Club  Los Angeles
# ...              ...          ...
# 52748    Yoga Studio     Whittier
# 52749    Yoga Studio     Whittier
# 52750    Yoga Studio     Whittier
# 52751    Yoga Studio     Whittier
# 52752    Yoga Studio     Whittier
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw B2 has a near perfect rating on Google. ...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 52748  I saw B2 has a perfect rating on Google. 5 sta...
# 52749  I saw B2 has a perfect rating on Google. 5 sta...
# 52750  I saw B2 has a near perfect rating on Google. ...
# 52751  I saw B2 has a perfect rating on Google. 5 sta...
# 52752  I saw B2 has a near perfect rating on Google. ...
#
# [52753 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('CA_combined_leads_duplicates_removed_semiclean.csv', index = False)
