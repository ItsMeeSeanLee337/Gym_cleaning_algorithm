# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("ND_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo BJJ & Kickboxing Academy  1.701236e+10
# 4                                          9round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & RV Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city region  \
# 0                   Boxing Gym          3324 39th St S     Fargo     ND
# 1          Martial arts school  3332 4th Ave S suite d     Fargo     ND
# 2                          Gym           4041 Main Ave     Fargo     ND
# 3          Martial arts school          1335 2nd Ave N     Fargo     ND
# 4                          Gym       2553 Kirsten Ln S     Fargo     ND
# ...                        ...                     ...       ...    ...
# 6170                     Motel         14010 Highway 5   Fortuna     ND
# 6171                    Welder             103 Main St    Bisbee     ND
# 6172  Well drilling contractor            6 Lasalle St    Bisbee     ND
# 6173                  Campsite                 ND-1804  Hazelton     ND
# 6174            Primary school             501 Main St   Emerado     ND
#
#         zip  ... instagram_average_comments  ads_yelp ads_facebook  \
# 0     58104  ...                        NaN       NaN          NaN
# 1     58103  ...                        5.0       NaN          NaN
# 2     58103  ...                        NaN       NaN          NaN
# 3     58102  ...                        1.0       NaN          NaN
# 4     58104  ...                        7.0       NaN          NaN
# ...     ...  ...                        ...       ...          ...
# 6170  58844  ...                        NaN       NaN          NaN
# 6171  58317  ...                        NaN       NaN          NaN
# 6172  58317  ...                        NaN       NaN          NaN
# 6173  58544  ...                        NaN       NaN          NaN
# 6174  58228  ...                        NaN       NaN          NaN
#
#      ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN         NaN
# 1              NaN           NaN         NaN
# 2              1.0           NaN         NaN
# 3              NaN           NaN         NaN
# 4              NaN           NaN         1.0
# ...            ...           ...         ...
# 6170           NaN           NaN         NaN
# 6171           NaN           NaN         NaN
# 6172           NaN           NaN         NaN
# 6173           NaN           NaN         NaN
# 6174           NaN           NaN         NaN
#
#                                                  g_maps  g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...         claimed
# 1     https://maps.google.com/maps/place/Academy+of+...         claimed
# 2                         https://g.page/metroflexfargo         claimed
# 3                               https://g.page/FargoBJJ         claimed
# 4                       https://g.page/9RoundBulverdeRd         claimed
# ...                                                 ...             ...
# 6170  https://maps.google.com/maps/place/Old+School+...         claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...       unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...       unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...       unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...       unclaimed
#
#       search_keyword  search_city
# 0        Boxing Club        Fargo
# 1        Boxing Club        Fargo
# 2        Boxing Club        Fargo
# 3        Boxing Club        Fargo
# 4        Boxing Club        Fargo
# ...              ...          ...
# 6170     Yoga Studio      Fortuna
# 6171     Yoga Studio       Bisbee
# 6172     Yoga Studio       Bisbee
# 6173     Yoga Studio     Hazelton
# 6174     Yoga Studio      Emerado
#
# [6175 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('ND','')
df['First Name'] = df['First Name'].str.replace('Nd','')
df['First Name'] = df['First Name'].str.replace('North Dakota','')
df
# Out:
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo Bjj & Kickboxing Academy  1.701236e+10
# 4                                          9Round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & Rv Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city region  \
# 0                   Boxing Gym          3324 39th St S     Fargo     ND
# 1          Martial arts school  3332 4th Ave S suite d     Fargo     ND
# 2                          Gym           4041 Main Ave     Fargo     ND
# 3          Martial arts school          1335 2nd Ave N     Fargo     ND
# 4                          Gym       2553 Kirsten Ln S     Fargo     ND
# ...                        ...                     ...       ...    ...
# 6170                     Motel         14010 Highway 5   Fortuna     ND
# 6171                    Welder             103 Main St    Bisbee     ND
# 6172  Well drilling contractor            6 Lasalle St    Bisbee     ND
# 6173                  Campsite                 ND-1804  Hazelton     ND
# 6174            Primary school             501 Main St   Emerado     ND
#
#         zip  ... ads_yelp  ads_facebook ads_instagram ads_messenger  \
# 0     58104  ...      NaN           NaN           NaN           NaN
# 1     58103  ...      NaN           NaN           NaN           NaN
# 2     58103  ...      NaN           NaN           1.0           NaN
# 3     58102  ...      NaN           NaN           NaN           NaN
# 4     58104  ...      NaN           NaN           NaN           NaN
# ...     ...  ...      ...           ...           ...           ...
# 6170  58844  ...      NaN           NaN           NaN           NaN
# 6171  58317  ...      NaN           NaN           NaN           NaN
# 6172  58317  ...      NaN           NaN           NaN           NaN
# 6173  58544  ...      NaN           NaN           NaN           NaN
# 6174  58228  ...      NaN           NaN           NaN           NaN
#
#      ads_adwords                                             g_maps  \
# 0            NaN  https://maps.google.com/maps/place/Rogue+Boxin...
# 1            NaN  https://maps.google.com/maps/place/Academy+of+...
# 2            NaN                      https://g.page/metroflexfargo
# 3            NaN                            https://g.page/FargoBJJ
# 4            1.0                    https://g.page/9RoundBulverdeRd
# ...          ...                                                ...
# 6170         NaN  https://maps.google.com/maps/place/Old+School+...
# 6171         NaN  https://maps.google.com/maps/place/Vulcan+Iron...
# 6172         NaN  https://maps.google.com/maps/place/Bursinger+D...
# 6173         NaN  https://maps.google.com/maps/place/Hazelton+Re...
# 6174         NaN  https://maps.google.com/maps/place/Emerado+Ele...
#
#       g_maps_claimed  search_keyword  search_city  \
# 0            claimed     Boxing Club        Fargo
# 1            claimed     Boxing Club        Fargo
# 2            claimed     Boxing Club        Fargo
# 3            claimed     Boxing Club        Fargo
# 4            claimed     Boxing Club        Fargo
# ...              ...             ...          ...
# 6170         claimed     Yoga Studio      Fortuna
# 6171       unclaimed     Yoga Studio       Bisbee
# 6172       unclaimed     Yoga Studio       Bisbee
# 6173       unclaimed     Yoga Studio     Hazelton
# 6174       unclaimed     Yoga Studio      Emerado
#
#                                     First Name
# 0                       Rogue Boxing & Fitness
# 1                         Of Combat Arts Fargo
# 2     Metroflex -Fargo / H&I Nutrition (North)
# 3                      Fargo Bjj & Kickboxing
# 4                                       9Round
# ...                                        ...
# 6170         Old School Center Motel & Rv Park
# 6171                    Vulcan Iron Works Inc.
# 6172                        Bursinger Drilling
# 6173                  Hazelton Recreation Area
# 6174                 Emerado Elementary School
#
# [6175 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo Bjj & Kickboxing Academy  1.701236e+10
# 4                                          9Round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & Rv Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city region  \
# 0                   Boxing Gym          3324 39th St S     Fargo     ND
# 1          Martial arts school  3332 4th Ave S suite d     Fargo     ND
# 2                          Gym           4041 Main Ave     Fargo     ND
# 3          Martial arts school          1335 2nd Ave N     Fargo     ND
# 4                          Gym       2553 Kirsten Ln S     Fargo     ND
# ...                        ...                     ...       ...    ...
# 6170                     Motel         14010 Highway 5   Fortuna     ND
# 6171                    Welder             103 Main St    Bisbee     ND
# 6172  Well drilling contractor            6 Lasalle St    Bisbee     ND
# 6173                  Campsite                 ND-1804  Hazelton     ND
# 6174            Primary school             501 Main St   Emerado     ND
#
#         zip  ... ads_yelp  ads_facebook ads_instagram ads_messenger  \
# 0     58104  ...      NaN           NaN           NaN           NaN
# 1     58103  ...      NaN           NaN           NaN           NaN
# 2     58103  ...      NaN           NaN           1.0           NaN
# 3     58102  ...      NaN           NaN           NaN           NaN
# 4     58104  ...      NaN           NaN           NaN           NaN
# ...     ...  ...      ...           ...           ...           ...
# 6170  58844  ...      NaN           NaN           NaN           NaN
# 6171  58317  ...      NaN           NaN           NaN           NaN
# 6172  58317  ...      NaN           NaN           NaN           NaN
# 6173  58544  ...      NaN           NaN           NaN           NaN
# 6174  58228  ...      NaN           NaN           NaN           NaN
#
#      ads_adwords                                             g_maps  \
# 0            NaN  https://maps.google.com/maps/place/Rogue+Boxin...
# 1            NaN  https://maps.google.com/maps/place/Academy+of+...
# 2            NaN                      https://g.page/metroflexfargo
# 3            NaN                            https://g.page/FargoBJJ
# 4            1.0                    https://g.page/9RoundBulverdeRd
# ...          ...                                                ...
# 6170         NaN  https://maps.google.com/maps/place/Old+School+...
# 6171         NaN  https://maps.google.com/maps/place/Vulcan+Iron...
# 6172         NaN  https://maps.google.com/maps/place/Bursinger+D...
# 6173         NaN  https://maps.google.com/maps/place/Hazelton+Re...
# 6174         NaN  https://maps.google.com/maps/place/Emerado+Ele...
#
#       g_maps_claimed  search_keyword  search_city  \
# 0            claimed     Boxing Club        Fargo
# 1            claimed     Boxing Club        Fargo
# 2            claimed     Boxing Club        Fargo
# 3            claimed     Boxing Club        Fargo
# 4            claimed     Boxing Club        Fargo
# ...              ...             ...          ...
# 6170         claimed     Yoga Studio      Fortuna
# 6171       unclaimed     Yoga Studio       Bisbee
# 6172       unclaimed     Yoga Studio       Bisbee
# 6173       unclaimed     Yoga Studio     Hazelton
# 6174       unclaimed     Yoga Studio      Emerado
#
#                                     First Name
# 0                       Rogue Boxing & Fitness
# 1                         Of Combat Arts Fargo
# 2     Metroflex -Fargo / H&I Nutrition (North)
# 3                      Fargo Bjj & Kickboxing
# 4                                       9Round
# ...                                        ...
# 6170         Old School Center Motel & Rv Park
# 6171                    Vulcan Iron Works Inc.
# 6172                        Bursinger Drilling
# 6173                  Hazelton Recreation Area
# 6174                 Emerado Elementary School
#
# [6175 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo Bjj & Kickboxing Academy  1.701236e+10
# 4                                          9Round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & Rv Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city region  \
# 0                   Boxing Gym          3324 39th St S     Fargo     ND
# 1          Martial arts school  3332 4th Ave S suite d     Fargo     ND
# 2                          Gym           4041 Main Ave     Fargo     ND
# 3          Martial arts school          1335 2nd Ave N     Fargo     ND
# 4                          Gym       2553 Kirsten Ln S     Fargo     ND
# ...                        ...                     ...       ...    ...
# 6170                     Motel         14010 Highway 5   Fortuna     ND
# 6171                    Welder             103 Main St    Bisbee     ND
# 6172  Well drilling contractor            6 Lasalle St    Bisbee     ND
# 6173                  Campsite                 ND-1804  Hazelton     ND
# 6174            Primary school             501 Main St   Emerado     ND
#
#         zip  ... ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0     58104  ...          NaN            NaN           NaN         NaN
# 1     58103  ...          NaN            NaN           NaN         NaN
# 2     58103  ...          NaN            1.0           NaN         NaN
# 3     58102  ...          NaN            NaN           NaN         NaN
# 4     58104  ...          NaN            NaN           NaN         1.0
# ...     ...  ...          ...            ...           ...         ...
# 6170  58844  ...          NaN            NaN           NaN         NaN
# 6171  58317  ...          NaN            NaN           NaN         NaN
# 6172  58317  ...          NaN            NaN           NaN         NaN
# 6173  58544  ...          NaN            NaN           NaN         NaN
# 6174  58228  ...          NaN            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...        claimed
# 1     https://maps.google.com/maps/place/Academy+of+...        claimed
# 2                         https://g.page/metroflexfargo        claimed
# 3                               https://g.page/FargoBJJ        claimed
# 4                       https://g.page/9RoundBulverdeRd        claimed
# ...                                                 ...            ...
# 6170  https://maps.google.com/maps/place/Old+School+...        claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...      unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...      unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...      unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...      unclaimed
#
#       search_keyword  search_city                                First Name  \
# 0        Boxing Club        Fargo                    Rogue Boxing & Fitness
# 1        Boxing Club        Fargo                      Of Combat Arts Fargo
# 2        Boxing Club        Fargo  Metroflex -Fargo / H&I Nutrition (North)
# 3        Boxing Club        Fargo                   Fargo Bjj & Kickboxing
# 4        Boxing Club        Fargo                                    9Round
# ...              ...          ...                                       ...
# 6170     Yoga Studio      Fortuna         Old School Center Motel & Rv Park
# 6171     Yoga Studio       Bisbee                    Vulcan Iron Works Inc.
# 6172     Yoga Studio       Bisbee                        Bursinger Drilling
# 6173     Yoga Studio     Hazelton                  Hazelton Recreation Area
# 6174     Yoga Studio      Emerado                 Emerado Elementary School
#
#       Business Type
# 0               NaT
# 1               NaT
# 2               NaT
# 3               NaT
# 4               NaT
# ...             ...
# 6170            NaT
# 6171            NaT
# 6172            NaT
# 6173            NaT
# 6174            NaT
#
# [6175 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo Bjj & Kickboxing Academy  1.701236e+10
# 4                                          9Round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & Rv Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city region  \
# 0                   Boxing Gym          3324 39th St S     Fargo     ND
# 1          Martial arts school  3332 4th Ave S suite d     Fargo     ND
# 2                          Gym           4041 Main Ave     Fargo     ND
# 3          Martial arts school          1335 2nd Ave N     Fargo     ND
# 4                          Gym       2553 Kirsten Ln S     Fargo     ND
# ...                        ...                     ...       ...    ...
# 6170                     Motel         14010 Highway 5   Fortuna     ND
# 6171                    Welder             103 Main St    Bisbee     ND
# 6172  Well drilling contractor            6 Lasalle St    Bisbee     ND
# 6173                  Campsite                 ND-1804  Hazelton     ND
# 6174            Primary school             501 Main St   Emerado     ND
#
#         zip  ... ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0     58104  ...          NaN            NaN           NaN         NaN
# 1     58103  ...          NaN            NaN           NaN         NaN
# 2     58103  ...          NaN            1.0           NaN         NaN
# 3     58102  ...          NaN            NaN           NaN         NaN
# 4     58104  ...          NaN            NaN           NaN         1.0
# ...     ...  ...          ...            ...           ...         ...
# 6170  58844  ...          NaN            NaN           NaN         NaN
# 6171  58317  ...          NaN            NaN           NaN         NaN
# 6172  58317  ...          NaN            NaN           NaN         NaN
# 6173  58544  ...          NaN            NaN           NaN         NaN
# 6174  58228  ...          NaN            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...        claimed
# 1     https://maps.google.com/maps/place/Academy+of+...        claimed
# 2                         https://g.page/metroflexfargo        claimed
# 3                               https://g.page/FargoBJJ        claimed
# 4                       https://g.page/9RoundBulverdeRd        claimed
# ...                                                 ...            ...
# 6170  https://maps.google.com/maps/place/Old+School+...        claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...      unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...      unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...      unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...      unclaimed
#
#       search_keyword  search_city                                First Name  \
# 0        Boxing Club        Fargo                    Rogue Boxing & Fitness
# 1        Boxing Club        Fargo                      Of Combat Arts Fargo
# 2        Boxing Club        Fargo  Metroflex -Fargo / H&I Nutrition (North)
# 3        Boxing Club        Fargo                   Fargo Bjj & Kickboxing
# 4        Boxing Club        Fargo                                    9Round
# ...              ...          ...                                       ...
# 6170     Yoga Studio      Fortuna         Old School Center Motel & Rv Park
# 6171     Yoga Studio       Bisbee                    Vulcan Iron Works Inc.
# 6172     Yoga Studio       Bisbee                        Bursinger Drilling
# 6173     Yoga Studio     Hazelton                  Hazelton Recreation Area
# 6174     Yoga Studio      Emerado                 Emerado Elementary School
#
#       Business Type
# 0           General
# 1           General
# 2           General
# 3           General
# 4           General
# ...             ...
# 6170        General
# 6171        General
# 6172        General
# 6173        General
# 6174        General
#
# [6175 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo Bjj & Kickboxing Academy  1.701236e+10
# 4                                          9Round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & Rv Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city region  \
# 0                   Boxing Gym          3324 39th St S     Fargo     ND
# 1          Martial arts school  3332 4th Ave S suite d     Fargo     ND
# 2                          Gym           4041 Main Ave     Fargo     ND
# 3          Martial arts school          1335 2nd Ave N     Fargo     ND
# 4                          Gym       2553 Kirsten Ln S     Fargo     ND
# ...                        ...                     ...       ...    ...
# 6170                     Motel         14010 Highway 5   Fortuna     ND
# 6171                    Welder             103 Main St    Bisbee     ND
# 6172  Well drilling contractor            6 Lasalle St    Bisbee     ND
# 6173                  Campsite                 ND-1804  Hazelton     ND
# 6174            Primary school             501 Main St   Emerado     ND
#
#         zip  ... ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0     58104  ...          NaN            NaN           NaN         NaN
# 1     58103  ...          NaN            NaN           NaN         NaN
# 2     58103  ...          NaN            1.0           NaN         NaN
# 3     58102  ...          NaN            NaN           NaN         NaN
# 4     58104  ...          NaN            NaN           NaN         1.0
# ...     ...  ...          ...            ...           ...         ...
# 6170  58844  ...          NaN            NaN           NaN         NaN
# 6171  58317  ...          NaN            NaN           NaN         NaN
# 6172  58317  ...          NaN            NaN           NaN         NaN
# 6173  58544  ...          NaN            NaN           NaN         NaN
# 6174  58228  ...          NaN            NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...        claimed
# 1     https://maps.google.com/maps/place/Academy+of+...        claimed
# 2                         https://g.page/metroflexfargo        claimed
# 3                               https://g.page/FargoBJJ        claimed
# 4                       https://g.page/9RoundBulverdeRd        claimed
# ...                                                 ...            ...
# 6170  https://maps.google.com/maps/place/Old+School+...        claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...      unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...      unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...      unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...      unclaimed
#
#       search_keyword  search_city                                First Name  \
# 0        Boxing Club        Fargo                    Rogue Boxing & Fitness
# 1        Boxing Club        Fargo                      Of Combat Arts Fargo
# 2        Boxing Club        Fargo  Metroflex -Fargo / H&I Nutrition (North)
# 3        Boxing Club        Fargo                   Fargo Bjj & Kickboxing
# 4        Boxing Club        Fargo                                    9Round
# ...              ...          ...                                       ...
# 6170     Yoga Studio      Fortuna         Old School Center Motel & Rv Park
# 6171     Yoga Studio       Bisbee                    Vulcan Iron Works Inc.
# 6172     Yoga Studio       Bisbee                        Bursinger Drilling
# 6173     Yoga Studio     Hazelton                  Hazelton Recreation Area
# 6174     Yoga Studio      Emerado                 Emerado Elementary School
#
#       Business Type
# 0            Boxing
# 1           General
# 2           fitness
# 3        Kickboxing
# 4           General
# ...             ...
# 6170        General
# 6171        General
# 6172        General
# 6173        General
# 6174        General
#
# [6175 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#      Business Type                                First Name  \
# 0           Boxing                    Rogue Boxing & Fitness
# 1          General                      Of Combat Arts Fargo
# 2          fitness  Metroflex -Fargo / H&I Nutrition (North)
# 3       Kickboxing                   Fargo Bjj & Kickboxing
# 4          General                                    9Round
# ...            ...                                       ...
# 6170       General         Old School Center Motel & Rv Park
# 6171       General                    Vulcan Iron Works Inc.
# 6172       General                        Bursinger Drilling
# 6173       General                  Hazelton Recreation Area
# 6174       General                 Emerado Elementary School
#
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo Bjj & Kickboxing Academy  1.701236e+10
# 4                                          9Round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & Rv Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city  ...  \
# 0                   Boxing Gym          3324 39th St S     Fargo  ...
# 1          Martial arts school  3332 4th Ave S suite d     Fargo  ...
# 2                          Gym           4041 Main Ave     Fargo  ...
# 3          Martial arts school          1335 2nd Ave N     Fargo  ...
# 4                          Gym       2553 Kirsten Ln S     Fargo  ...
# ...                        ...                     ...       ...  ...
# 6170                     Motel         14010 Highway 5   Fortuna  ...
# 6171                    Welder             103 Main St    Bisbee  ...
# 6172  Well drilling contractor            6 Lasalle St    Bisbee  ...
# 6173                  Campsite                 ND-1804  Hazelton  ...
# 6174            Primary school             501 Main St   Emerado  ...
#
#      instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                           NaN      NaN          NaN            NaN
# 1                           5.0      NaN          NaN            NaN
# 2                           NaN      NaN          NaN            1.0
# 3                           1.0      NaN          NaN            NaN
# 4                           7.0      NaN          NaN            NaN
# ...                         ...      ...          ...            ...
# 6170                        NaN      NaN          NaN            NaN
# 6171                        NaN      NaN          NaN            NaN
# 6172                        NaN      NaN          NaN            NaN
# 6173                        NaN      NaN          NaN            NaN
# 6174                        NaN      NaN          NaN            NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         1.0
# ...            ...         ...
# 6170           NaN         NaN
# 6171           NaN         NaN
# 6172           NaN         NaN
# 6173           NaN         NaN
# 6174           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...        claimed
# 1     https://maps.google.com/maps/place/Academy+of+...        claimed
# 2                         https://g.page/metroflexfargo        claimed
# 3                               https://g.page/FargoBJJ        claimed
# 4                       https://g.page/9RoundBulverdeRd        claimed
# ...                                                 ...            ...
# 6170  https://maps.google.com/maps/place/Old+School+...        claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...      unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...      unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...      unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...      unclaimed
#
#       search_keyword  search_city
# 0        Boxing Club        Fargo
# 1        Boxing Club        Fargo
# 2        Boxing Club        Fargo
# 3        Boxing Club        Fargo
# 4        Boxing Club        Fargo
# ...              ...          ...
# 6170     Yoga Studio      Fortuna
# 6171     Yoga Studio       Bisbee
# 6172     Yoga Studio       Bisbee
# 6173     Yoga Studio     Hazelton
# 6174     Yoga Studio      Emerado
#
# [6175 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#      Business Type                            First Name  \
# 0           Boxing                Rogue Boxing & Fitness
# 1          General                  Of Combat Arts Fargo
# 2          fitness  Metroflex Fargo  H&I Nutrition North
# 3       Kickboxing               Fargo Bjj & Kickboxing
# 4          General                                9Round
# ...            ...                                   ...
# 6170       General     Old School Center Motel & Rv Park
# 6171       General                 Vulcan Iron Works Inc
# 6172       General                    Bursinger Drilling
# 6173       General              Hazelton Recreation Area
# 6174       General             Emerado Elementary School
#
#                                              name         phone  \
# 0                          Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts Fargo  1.701478e+10
# 2     Metroflex Gym-Fargo / H&I Nutrition (North)  1.701356e+10
# 3                  Fargo Bjj & Kickboxing Academy  1.701236e+10
# 4                                          9Round  1.701479e+10
# ...                                           ...           ...
# 6170            Old School Center Motel & Rv Park  1.701834e+10
# 6171                       Vulcan Iron Works Inc.  1.701656e+10
# 6172                           Bursinger Drilling  1.701656e+10
# 6173                     Hazelton Recreation Area  1.701255e+10
# 6174                    Emerado Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city  ...  \
# 0                   Boxing Gym          3324 39th St S     Fargo  ...
# 1          Martial arts school  3332 4th Ave S suite d     Fargo  ...
# 2                          Gym           4041 Main Ave     Fargo  ...
# 3          Martial arts school          1335 2nd Ave N     Fargo  ...
# 4                          Gym       2553 Kirsten Ln S     Fargo  ...
# ...                        ...                     ...       ...  ...
# 6170                     Motel         14010 Highway 5   Fortuna  ...
# 6171                    Welder             103 Main St    Bisbee  ...
# 6172  Well drilling contractor            6 Lasalle St    Bisbee  ...
# 6173                  Campsite                 ND-1804  Hazelton  ...
# 6174            Primary school             501 Main St   Emerado  ...
#
#      instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                           NaN      NaN          NaN            NaN
# 1                           5.0      NaN          NaN            NaN
# 2                           NaN      NaN          NaN            1.0
# 3                           1.0      NaN          NaN            NaN
# 4                           7.0      NaN          NaN            NaN
# ...                         ...      ...          ...            ...
# 6170                        NaN      NaN          NaN            NaN
# 6171                        NaN      NaN          NaN            NaN
# 6172                        NaN      NaN          NaN            NaN
# 6173                        NaN      NaN          NaN            NaN
# 6174                        NaN      NaN          NaN            NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         1.0
# ...            ...         ...
# 6170           NaN         NaN
# 6171           NaN         NaN
# 6172           NaN         NaN
# 6173           NaN         NaN
# 6174           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...        claimed
# 1     https://maps.google.com/maps/place/Academy+of+...        claimed
# 2                         https://g.page/metroflexfargo        claimed
# 3                               https://g.page/FargoBJJ        claimed
# 4                       https://g.page/9RoundBulverdeRd        claimed
# ...                                                 ...            ...
# 6170  https://maps.google.com/maps/place/Old+School+...        claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...      unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...      unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...      unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...      unclaimed
#
#       search_keyword  search_city
# 0        Boxing Club        Fargo
# 1        Boxing Club        Fargo
# 2        Boxing Club        Fargo
# 3        Boxing Club        Fargo
# 4        Boxing Club        Fargo
# ...              ...          ...
# 6170     Yoga Studio      Fortuna
# 6171     Yoga Studio       Bisbee
# 6172     Yoga Studio       Bisbee
# 6173     Yoga Studio     Hazelton
# 6174     Yoga Studio      Emerado
#
# [6175 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#      Business Type                         First Name  \
# 0           Boxing             Rogue Boxing & Fitness
# 1          General                    Of Combat Arts
# 2          fitness    Metroflex   H&I Nutrition North
# 3       Kickboxing                  Bjj & Kickboxing
# 4          General                             9Round
# ...            ...                                ...
# 6170       General  Old School Center Motel & Rv Park
# 6171       General              Vulcan Iron Works Inc
# 6172       General                 Bursinger Drilling
# 6173       General                    Recreation Area
# 6174       General                  Elementary School
#
#                                                name         phone  \
# 0                            Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts (Fargo)  1.701478e+10
# 2     Metroflex Gym-(Fargo) / H&I Nutrition (North)  1.701356e+10
# 3                  (Fargo) Bjj & Kickboxing Academy  1.701236e+10
# 4                                            9Round  1.701479e+10
# ...                                             ...           ...
# 6170              Old School Center Motel & Rv Park  1.701834e+10
# 6171                         Vulcan Iron Works Inc.  1.701656e+10
# 6172                             Bursinger Drilling  1.701656e+10
# 6173                     (Hazelton) Recreation Area  1.701255e+10
# 6174                    (Emerado) Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city  ...  \
# 0                   Boxing Gym          3324 39th St S     Fargo  ...
# 1          Martial arts school  3332 4th Ave S suite d     Fargo  ...
# 2                          Gym           4041 Main Ave     Fargo  ...
# 3          Martial arts school          1335 2nd Ave N     Fargo  ...
# 4                          Gym       2553 Kirsten Ln S     Fargo  ...
# ...                        ...                     ...       ...  ...
# 6170                     Motel         14010 Highway 5   Fortuna  ...
# 6171                    Welder             103 Main St    Bisbee  ...
# 6172  Well drilling contractor            6 Lasalle St    Bisbee  ...
# 6173                  Campsite                 ND-1804  Hazelton  ...
# 6174            Primary school             501 Main St   Emerado  ...
#
#      instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                           NaN      NaN          NaN            NaN
# 1                           5.0      NaN          NaN            NaN
# 2                           NaN      NaN          NaN            1.0
# 3                           1.0      NaN          NaN            NaN
# 4                           7.0      NaN          NaN            NaN
# ...                         ...      ...          ...            ...
# 6170                        NaN      NaN          NaN            NaN
# 6171                        NaN      NaN          NaN            NaN
# 6172                        NaN      NaN          NaN            NaN
# 6173                        NaN      NaN          NaN            NaN
# 6174                        NaN      NaN          NaN            NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         1.0
# ...            ...         ...
# 6170           NaN         NaN
# 6171           NaN         NaN
# 6172           NaN         NaN
# 6173           NaN         NaN
# 6174           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...        claimed
# 1     https://maps.google.com/maps/place/Academy+of+...        claimed
# 2                         https://g.page/metroflexfargo        claimed
# 3                               https://g.page/FargoBJJ        claimed
# 4                       https://g.page/9RoundBulverdeRd        claimed
# ...                                                 ...            ...
# 6170  https://maps.google.com/maps/place/Old+School+...        claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...      unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...      unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...      unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...      unclaimed
#
#       search_keyword  search_city
# 0        Boxing Club        Fargo
# 1        Boxing Club        Fargo
# 2        Boxing Club        Fargo
# 3        Boxing Club        Fargo
# 4        Boxing Club        Fargo
# ...              ...          ...
# 6170     Yoga Studio      Fortuna
# 6171     Yoga Studio       Bisbee
# 6172     Yoga Studio       Bisbee
# 6173     Yoga Studio     Hazelton
# 6174     Yoga Studio      Emerado
#
# [6175 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#      Business Type                         First Name  \
# 0           Boxing             Rogue Boxing & Fitness
# 1          General                    Of Combat Arts
# 2          fitness    Metroflex   H&I Nutrition North
# 3       Kickboxing                  Bjj & Kickboxing
# 4          General                             9Round
# ...            ...                                ...
# 6170       General  Old School Center Motel & Rv Park
# 6171       General              Vulcan Iron Works Inc
# 6172       General                 Bursinger Drilling
# 6173       General                    Recreation Area
# 6174       General                  Elementary School
#
#                                                name         phone  \
# 0                            Rogue Boxing & Fitness  1.701532e+10
# 1                    Academy Of Combat Arts (Fargo)  1.701478e+10
# 2     Metroflex Gym-(Fargo) / H&I Nutrition (North)  1.701356e+10
# 3                  (Fargo) Bjj & Kickboxing Academy  1.701236e+10
# 4                                            9Round  1.701479e+10
# ...                                             ...           ...
# 6170              Old School Center Motel & Rv Park  1.701834e+10
# 6171                         Vulcan Iron Works Inc.  1.701656e+10
# 6172                             Bursinger Drilling  1.701656e+10
# 6173                     (Hazelton) Recreation Area  1.701255e+10
# 6174                    (Emerado) Elementary School  1.701595e+10
#
#                                      email      email_host  \
# 0                   jake@rogueboxingfm.com     outlook.com
# 1                          dylan@fmaca.com      google.com
# 2     metroflexfargo@illegoenterprises.com  proofpoint.com
# 3                       fargobjj@yahoo.com       yahoo.com
# 4      wonderworlddrsanmarcostx@9round.com   rackspace.com
# ...                                    ...             ...
# 6170                deborahlamb333@msn.com     outlook.com
# 6171                       vulcan@utma.com        gwtc.net
# 6172             info@generalroofingnd.com     outlook.com
# 6173                                   NaN             NaN
# 6174               kendi.loy@emeradok8.com      google.com
#
#                                                 website  \
# 0                         http://www.rogueboxingfm.com/
# 1                                 http://www.fmaca.com/
# 2                        http://www.metroflexfargo.com/
# 3                              http://www.fargobjj.com/
# 4                                http://www.9round.com/
# ...                                                 ...
# 6170                 http://www.theoldschoolcenter.com/
# 6171                     http://vulcanironworksinc.com/
# 6172                       http://generalroofingnd.com/
# 6173  https://www.recreation.gov/camping/hazelton-re...
# 6174                         https://www.emeradok8.com/
#
#                       category                 address      city  ...  \
# 0                   Boxing Gym          3324 39th St S     Fargo  ...
# 1          Martial arts school  3332 4th Ave S suite d     Fargo  ...
# 2                          Gym           4041 Main Ave     Fargo  ...
# 3          Martial arts school          1335 2nd Ave N     Fargo  ...
# 4                          Gym       2553 Kirsten Ln S     Fargo  ...
# ...                        ...                     ...       ...  ...
# 6170                     Motel         14010 Highway 5   Fortuna  ...
# 6171                    Welder             103 Main St    Bisbee  ...
# 6172  Well drilling contractor            6 Lasalle St    Bisbee  ...
# 6173                  Campsite                 ND-1804  Hazelton  ...
# 6174            Primary school             501 Main St   Emerado  ...
#
#      ads_yelp ads_facebook ads_instagram  ads_messenger ads_adwords  \
# 0         NaN          NaN           NaN            NaN         NaN
# 1         NaN          NaN           NaN            NaN         NaN
# 2         NaN          NaN           1.0            NaN         NaN
# 3         NaN          NaN           NaN            NaN         NaN
# 4         NaN          NaN           NaN            NaN         1.0
# ...       ...          ...           ...            ...         ...
# 6170      NaN          NaN           NaN            NaN         NaN
# 6171      NaN          NaN           NaN            NaN         NaN
# 6172      NaN          NaN           NaN            NaN         NaN
# 6173      NaN          NaN           NaN            NaN         NaN
# 6174      NaN          NaN           NaN            NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Rogue+Boxin...        claimed
# 1     https://maps.google.com/maps/place/Academy+of+...        claimed
# 2                         https://g.page/metroflexfargo        claimed
# 3                               https://g.page/FargoBJJ        claimed
# 4                       https://g.page/9RoundBulverdeRd        claimed
# ...                                                 ...            ...
# 6170  https://maps.google.com/maps/place/Old+School+...        claimed
# 6171  https://maps.google.com/maps/place/Vulcan+Iron...      unclaimed
# 6172  https://maps.google.com/maps/place/Bursinger+D...      unclaimed
# 6173  https://maps.google.com/maps/place/Hazelton+Re...      unclaimed
# 6174  https://maps.google.com/maps/place/Emerado+Ele...      unclaimed
#
#      search_keyword  search_city  \
# 0       Boxing Club        Fargo
# 1       Boxing Club        Fargo
# 2       Boxing Club        Fargo
# 3       Boxing Club        Fargo
# 4       Boxing Club        Fargo
# ...             ...          ...
# 6170    Yoga Studio      Fortuna
# 6171    Yoga Studio       Bisbee
# 6172    Yoga Studio       Bisbee
# 6173    Yoga Studio     Hazelton
# 6174    Yoga Studio      Emerado
#
#                                             Icebreakers
# 0     I saw B2 has a perfect rating on Google. 5 sta...
# 1     I saw B2 has a near perfect rating on Google. ...
# 2     I saw B2 has a near perfect rating on Google. ...
# 3     I saw B2 has a near perfect rating on Google. ...
# 4     I saw B2 has a perfect rating on Google. 5 sta...
# ...                                                 ...
# 6170  I saw B2 has a near perfect rating on Google. ...
# 6171  I saw your B2 page on Facebook. You guys have ...
# 6172  I was looking at the B2 website on my phone an...
# 6173  I saw B2 has a near perfect rating on Google. ...
# 6174  I saw B2 has a perfect rating on Google. 5 sta...
#
# [6175 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('ND_combined_leads_duplicates_removed_semiclean.csv', index = False)
