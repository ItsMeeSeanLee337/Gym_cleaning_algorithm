# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("OK_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                             name        phone  \
# 0      Western Avenue Boxing Gym  14055323204
# 1       TITLE Boxing Club Edmond  14055138180
# 2      Park Harvey Athletic Club  14056067100
# 3                      Solid MMA  14055776411
# 4        Academy of Martial Arts  14052056342
# ...                          ...          ...
# 13442                     SD Gym  15806228675
# 13443               Dance Center  15806226775
# 13444             Allure Studios  15806187350
# 13445  Sulphur Hills Golf Course  15806225057
# 13446   Travertine Nature Center  15806227234
#
#                                    email      email_host  \
# 0       westernavenueboxinggym@gmail.com      google.com
# 1      ashlee.doheny@titleboxingclub.com   rackspace.com
# 2                        smph@gthokc.com  proofpoint.com
# 3                   solidmma@hotmail.com     outlook.com
# 4                   365amawork@gmail.com      google.com
# ...                                  ...             ...
# 13442                                NaN             NaN
# 13443                                NaN             NaN
# 13444                                NaN             NaN
# 13445                                NaN             NaN
# 13446                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city region    zip  ...  \
# 0        4408 N Western Ave  Oklahoma City     OK  73118  ...
# 1       1389 E 15th St #144         Edmond     OK  73013  ...
# 2          200 N Harvey Ave  Oklahoma City     OK  73102  ...
# 3         12301 Merritt Ave          Yukon     OK  73099  ...
# 4       7315 S Shields Blvd  Oklahoma City     OK  73149  ...
# ...                     ...            ...    ...    ...  ...
# 13442    202 W Muskogee Ave        Sulphur     OK  73086  ...
# 13443          917 W 5th St        Sulphur     OK  73086  ...
# 13444   2112 W Broadway Ave        Sulphur     OK  73086  ...
# 13445  2001 Country Club Dr        Sulphur     OK  73086  ...
# 13446     1504 Perimeter Rd        Sulphur     OK  73086  ...
#
#       instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                            NaN      NaN          NaN           NaN
# 1                              3      NaN          NaN           NaN
# 2                            NaN      NaN          NaN           NaN
# 3                              1      NaN          NaN           NaN
# 4                            NaN      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
# 13442                        NaN      NaN          NaN           NaN
# 13443                        NaN      NaN          NaN           NaN
# 13444                        NaN      NaN          NaN           NaN
# 13445                        NaN      NaN          NaN           NaN
# 13446                        NaN      NaN          NaN           NaN
#
#       ads_messenger ads_adwords  \
# 0               NaN         NaN
# 1               NaN           1
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 13442           NaN         NaN
# 13443           NaN         NaN
# 13444           NaN         NaN
# 13445           NaN         NaN
# 13446           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city
# 0        Boxing Club  Oklahoma City
# 1        Boxing Club  Oklahoma City
# 2        Boxing Club  Oklahoma City
# 3        Boxing Club  Oklahoma City
# 4        Boxing Club  Oklahoma City
# ...              ...            ...
# 13442    Yoga Studio        Sulphur
# 13443    Yoga Studio        Sulphur
# 13444    Yoga Studio        Sulphur
# 13445    Yoga Studio        Sulphur
# 13446    Yoga Studio        Sulphur
#
# [13447 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('OK','')
df['First Name'] = df['First Name'].str.replace('Ok','')
df['First Name'] = df['First Name'].str.replace('Oklahoma','')
df
# Out:
#                             name        phone  \
# 0      Western Avenue Boxing Gym  14055323204
# 1       Title Boxing Club Edmond  14055138180
# 2      Park Harvey Athletic Club  14056067100
# 3                      Solid Mma  14055776411
# 4        Academy Of Martial Arts  14052056342
# ...                          ...          ...
# 13442                     Sd Gym  15806228675
# 13443               Dance Center  15806226775
# 13444             Allure Studios  15806187350
# 13445  Sulphur Hills Golf Course  15806225057
# 13446   Travertine Nature Center  15806227234
#
#                                    email      email_host  \
# 0       westernavenueboxinggym@gmail.com      google.com
# 1      ashlee.doheny@titleboxingclub.com   rackspace.com
# 2                        smph@gthokc.com  proofpoint.com
# 3                   solidmma@hotmail.com     outlook.com
# 4                   365amawork@gmail.com      google.com
# ...                                  ...             ...
# 13442                                NaN             NaN
# 13443                                NaN             NaN
# 13444                                NaN             NaN
# 13445                                NaN             NaN
# 13446                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city region    zip  ... ads_yelp  \
# 0        4408 N Western Ave  Oklahoma City     OK  73118  ...      NaN
# 1       1389 E 15th St #144         Edmond     OK  73013  ...      NaN
# 2          200 N Harvey Ave  Oklahoma City     OK  73102  ...      NaN
# 3         12301 Merritt Ave          Yukon     OK  73099  ...      NaN
# 4       7315 S Shields Blvd  Oklahoma City     OK  73149  ...      NaN
# ...                     ...            ...    ...    ...  ...      ...
# 13442    202 W Muskogee Ave        Sulphur     OK  73086  ...      NaN
# 13443          917 W 5th St        Sulphur     OK  73086  ...      NaN
# 13444   2112 W Broadway Ave        Sulphur     OK  73086  ...      NaN
# 13445  2001 Country Club Dr        Sulphur     OK  73086  ...      NaN
# 13446     1504 Perimeter Rd        Sulphur     OK  73086  ...      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           1
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN         NaN
# ...            ...           ...           ...         ...
# 13442          NaN           NaN           NaN         NaN
# 13443          NaN           NaN           NaN         NaN
# 13444          NaN           NaN           NaN         NaN
# 13445          NaN           NaN           NaN         NaN
# 13446          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city                 First Name
# 0        Boxing Club  Oklahoma City     Western Avenue Boxing
# 1        Boxing Club  Oklahoma City       Title Boxing  Edmond
# 2        Boxing Club  Oklahoma City      Park Harvey Athletic
# 3        Boxing Club  Oklahoma City                  Solid Mma
# 4        Boxing Club  Oklahoma City            Of Martial Arts
# ...              ...            ...                        ...
# 13442    Yoga Studio        Sulphur                        Sd
# 13443    Yoga Studio        Sulphur               Dance Center
# 13444    Yoga Studio        Sulphur             Allure Studios
# 13445    Yoga Studio        Sulphur  Sulphur Hills Golf Course
# 13446    Yoga Studio        Sulphur   Travertine Nature Center
#
# [13447 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                             name        phone  \
# 0      Western Avenue Boxing Gym  14055323204
# 1       Title Boxing Club Edmond  14055138180
# 2      Park Harvey Athletic Club  14056067100
# 3                      Solid Mma  14055776411
# 4        Academy Of Martial Arts  14052056342
# ...                          ...          ...
# 13442                     Sd Gym  15806228675
# 13443               Dance Center  15806226775
# 13444             Allure Studios  15806187350
# 13445  Sulphur Hills Golf Course  15806225057
# 13446   Travertine Nature Center  15806227234
#
#                                    email      email_host  \
# 0       westernavenueboxinggym@gmail.com      google.com
# 1      ashlee.doheny@titleboxingclub.com   rackspace.com
# 2                        smph@gthokc.com  proofpoint.com
# 3                   solidmma@hotmail.com     outlook.com
# 4                   365amawork@gmail.com      google.com
# ...                                  ...             ...
# 13442                                NaN             NaN
# 13443                                NaN             NaN
# 13444                                NaN             NaN
# 13445                                NaN             NaN
# 13446                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city region    zip  ... ads_yelp  \
# 0        4408 N Western Ave  Oklahoma City     OK  73118  ...      NaN
# 1       1389 E 15th St #144         Edmond     OK  73013  ...      NaN
# 2          200 N Harvey Ave  Oklahoma City     OK  73102  ...      NaN
# 3         12301 Merritt Ave          Yukon     OK  73099  ...      NaN
# 4       7315 S Shields Blvd  Oklahoma City     OK  73149  ...      NaN
# ...                     ...            ...    ...    ...  ...      ...
# 13442    202 W Muskogee Ave        Sulphur     OK  73086  ...      NaN
# 13443          917 W 5th St        Sulphur     OK  73086  ...      NaN
# 13444   2112 W Broadway Ave        Sulphur     OK  73086  ...      NaN
# 13445  2001 Country Club Dr        Sulphur     OK  73086  ...      NaN
# 13446     1504 Perimeter Rd        Sulphur     OK  73086  ...      NaN
#
#       ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           NaN         NaN
# 1              NaN           NaN           NaN           1
# 2              NaN           NaN           NaN         NaN
# 3              NaN           NaN           NaN         NaN
# 4              NaN           NaN           NaN         NaN
# ...            ...           ...           ...         ...
# 13442          NaN           NaN           NaN         NaN
# 13443          NaN           NaN           NaN         NaN
# 13444          NaN           NaN           NaN         NaN
# 13445          NaN           NaN           NaN         NaN
# 13446          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city                 First Name
# 0        Boxing Club  Oklahoma City     Western Avenue Boxing
# 1        Boxing Club  Oklahoma City       Title Boxing  Edmond
# 2        Boxing Club  Oklahoma City      Park Harvey Athletic
# 3        Boxing Club  Oklahoma City                  Solid Mma
# 4        Boxing Club  Oklahoma City            Of Martial Arts
# ...              ...            ...                        ...
# 13442    Yoga Studio        Sulphur                        Sd
# 13443    Yoga Studio        Sulphur               Dance Center
# 13444    Yoga Studio        Sulphur             Allure Studios
# 13445    Yoga Studio        Sulphur  Sulphur Hills Golf Course
# 13446    Yoga Studio        Sulphur   Travertine Nature Center
#
# [13447 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                             name        phone  \
# 0      Western Avenue Boxing Gym  14055323204
# 1       Title Boxing Club Edmond  14055138180
# 2      Park Harvey Athletic Club  14056067100
# 3                      Solid Mma  14055776411
# 4        Academy Of Martial Arts  14052056342
# ...                          ...          ...
# 13442                     Sd Gym  15806228675
# 13443               Dance Center  15806226775
# 13444             Allure Studios  15806187350
# 13445  Sulphur Hills Golf Course  15806225057
# 13446   Travertine Nature Center  15806227234
#
#                                    email      email_host  \
# 0       westernavenueboxinggym@gmail.com      google.com
# 1      ashlee.doheny@titleboxingclub.com   rackspace.com
# 2                        smph@gthokc.com  proofpoint.com
# 3                   solidmma@hotmail.com     outlook.com
# 4                   365amawork@gmail.com      google.com
# ...                                  ...             ...
# 13442                                NaN             NaN
# 13443                                NaN             NaN
# 13444                                NaN             NaN
# 13445                                NaN             NaN
# 13446                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city region    zip  ... ads_facebook  \
# 0        4408 N Western Ave  Oklahoma City     OK  73118  ...          NaN
# 1       1389 E 15th St #144         Edmond     OK  73013  ...          NaN
# 2          200 N Harvey Ave  Oklahoma City     OK  73102  ...          NaN
# 3         12301 Merritt Ave          Yukon     OK  73099  ...          NaN
# 4       7315 S Shields Blvd  Oklahoma City     OK  73149  ...          NaN
# ...                     ...            ...    ...    ...  ...          ...
# 13442    202 W Muskogee Ave        Sulphur     OK  73086  ...          NaN
# 13443          917 W 5th St        Sulphur     OK  73086  ...          NaN
# 13444   2112 W Broadway Ave        Sulphur     OK  73086  ...          NaN
# 13445  2001 Country Club Dr        Sulphur     OK  73086  ...          NaN
# 13446     1504 Perimeter Rd        Sulphur     OK  73086  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 13442           NaN           NaN         NaN
# 13443           NaN           NaN         NaN
# 13444           NaN           NaN         NaN
# 13445           NaN           NaN         NaN
# 13446           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city                 First Name Business Type
# 0        Boxing Club  Oklahoma City     Western Avenue Boxing            NaT
# 1        Boxing Club  Oklahoma City       Title Boxing  Edmond           NaT
# 2        Boxing Club  Oklahoma City      Park Harvey Athletic            NaT
# 3        Boxing Club  Oklahoma City                  Solid Mma           NaT
# 4        Boxing Club  Oklahoma City            Of Martial Arts           NaT
# ...              ...            ...                        ...           ...
# 13442    Yoga Studio        Sulphur                        Sd            NaT
# 13443    Yoga Studio        Sulphur               Dance Center           NaT
# 13444    Yoga Studio        Sulphur             Allure Studios           NaT
# 13445    Yoga Studio        Sulphur  Sulphur Hills Golf Course           NaT
# 13446    Yoga Studio        Sulphur   Travertine Nature Center           NaT
#
# [13447 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                             name        phone  \
# 0      Western Avenue Boxing Gym  14055323204
# 1       Title Boxing Club Edmond  14055138180
# 2      Park Harvey Athletic Club  14056067100
# 3                      Solid Mma  14055776411
# 4        Academy Of Martial Arts  14052056342
# ...                          ...          ...
# 13442                     Sd Gym  15806228675
# 13443               Dance Center  15806226775
# 13444             Allure Studios  15806187350
# 13445  Sulphur Hills Golf Course  15806225057
# 13446   Travertine Nature Center  15806227234
#
#                                    email      email_host  \
# 0       westernavenueboxinggym@gmail.com      google.com
# 1      ashlee.doheny@titleboxingclub.com   rackspace.com
# 2                        smph@gthokc.com  proofpoint.com
# 3                   solidmma@hotmail.com     outlook.com
# 4                   365amawork@gmail.com      google.com
# ...                                  ...             ...
# 13442                                NaN             NaN
# 13443                                NaN             NaN
# 13444                                NaN             NaN
# 13445                                NaN             NaN
# 13446                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city region    zip  ... ads_facebook  \
# 0        4408 N Western Ave  Oklahoma City     OK  73118  ...          NaN
# 1       1389 E 15th St #144         Edmond     OK  73013  ...          NaN
# 2          200 N Harvey Ave  Oklahoma City     OK  73102  ...          NaN
# 3         12301 Merritt Ave          Yukon     OK  73099  ...          NaN
# 4       7315 S Shields Blvd  Oklahoma City     OK  73149  ...          NaN
# ...                     ...            ...    ...    ...  ...          ...
# 13442    202 W Muskogee Ave        Sulphur     OK  73086  ...          NaN
# 13443          917 W 5th St        Sulphur     OK  73086  ...          NaN
# 13444   2112 W Broadway Ave        Sulphur     OK  73086  ...          NaN
# 13445  2001 Country Club Dr        Sulphur     OK  73086  ...          NaN
# 13446     1504 Perimeter Rd        Sulphur     OK  73086  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 13442           NaN           NaN         NaN
# 13443           NaN           NaN         NaN
# 13444           NaN           NaN         NaN
# 13445           NaN           NaN         NaN
# 13446           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city                 First Name Business Type
# 0        Boxing Club  Oklahoma City     Western Avenue Boxing        General
# 1        Boxing Club  Oklahoma City       Title Boxing  Edmond       General
# 2        Boxing Club  Oklahoma City      Park Harvey Athletic        General
# 3        Boxing Club  Oklahoma City                  Solid Mma       General
# 4        Boxing Club  Oklahoma City            Of Martial Arts       General
# ...              ...            ...                        ...           ...
# 13442    Yoga Studio        Sulphur                        Sd        General
# 13443    Yoga Studio        Sulphur               Dance Center       General
# 13444    Yoga Studio        Sulphur             Allure Studios       General
# 13445    Yoga Studio        Sulphur  Sulphur Hills Golf Course       General
# 13446    Yoga Studio        Sulphur   Travertine Nature Center       General
#
# [13447 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                             name        phone  \
# 0      Western Avenue Boxing Gym  14055323204
# 1       Title Boxing Club Edmond  14055138180
# 2      Park Harvey Athletic Club  14056067100
# 3                      Solid Mma  14055776411
# 4        Academy Of Martial Arts  14052056342
# ...                          ...          ...
# 13442                     Sd Gym  15806228675
# 13443               Dance Center  15806226775
# 13444             Allure Studios  15806187350
# 13445  Sulphur Hills Golf Course  15806225057
# 13446   Travertine Nature Center  15806227234
#
#                                    email      email_host  \
# 0       westernavenueboxinggym@gmail.com      google.com
# 1      ashlee.doheny@titleboxingclub.com   rackspace.com
# 2                        smph@gthokc.com  proofpoint.com
# 3                   solidmma@hotmail.com     outlook.com
# 4                   365amawork@gmail.com      google.com
# ...                                  ...             ...
# 13442                                NaN             NaN
# 13443                                NaN             NaN
# 13444                                NaN             NaN
# 13445                                NaN             NaN
# 13446                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city region    zip  ... ads_facebook  \
# 0        4408 N Western Ave  Oklahoma City     OK  73118  ...          NaN
# 1       1389 E 15th St #144         Edmond     OK  73013  ...          NaN
# 2          200 N Harvey Ave  Oklahoma City     OK  73102  ...          NaN
# 3         12301 Merritt Ave          Yukon     OK  73099  ...          NaN
# 4       7315 S Shields Blvd  Oklahoma City     OK  73149  ...          NaN
# ...                     ...            ...    ...    ...  ...          ...
# 13442    202 W Muskogee Ave        Sulphur     OK  73086  ...          NaN
# 13443          917 W 5th St        Sulphur     OK  73086  ...          NaN
# 13444   2112 W Broadway Ave        Sulphur     OK  73086  ...          NaN
# 13445  2001 Country Club Dr        Sulphur     OK  73086  ...          NaN
# 13446     1504 Perimeter Rd        Sulphur     OK  73086  ...          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 13442           NaN           NaN         NaN
# 13443           NaN           NaN         NaN
# 13444           NaN           NaN         NaN
# 13445           NaN           NaN         NaN
# 13446           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city                 First Name Business Type
# 0        Boxing Club  Oklahoma City     Western Avenue Boxing         Boxing
# 1        Boxing Club  Oklahoma City       Title Boxing  Edmond        Boxing
# 2        Boxing Club  Oklahoma City      Park Harvey Athletic        General
# 3        Boxing Club  Oklahoma City                  Solid Mma       General
# 4        Boxing Club  Oklahoma City            Of Martial Arts  Martial Arts
# ...              ...            ...                        ...           ...
# 13442    Yoga Studio        Sulphur                        Sd        fitness
# 13443    Yoga Studio        Sulphur               Dance Center       General
# 13444    Yoga Studio        Sulphur             Allure Studios       General
# 13445    Yoga Studio        Sulphur  Sulphur Hills Golf Course       General
# 13446    Yoga Studio        Sulphur   Travertine Nature Center       General
#
# [13447 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                 First Name                       name  \
# 0            Boxing     Western Avenue Boxing   Western Avenue Boxing Gym
# 1            Boxing       Title Boxing  Edmond   Title Boxing Club Edmond
# 2           General      Park Harvey Athletic   Park Harvey Athletic Club
# 3           General                  Solid Mma                  Solid Mma
# 4      Martial Arts            Of Martial Arts    Academy Of Martial Arts
# ...             ...                        ...                        ...
# 13442       fitness                        Sd                      Sd Gym
# 13443       General               Dance Center               Dance Center
# 13444       General             Allure Studios             Allure Studios
# 13445       General  Sulphur Hills Golf Course  Sulphur Hills Golf Course
# 13446       General   Travertine Nature Center   Travertine Nature Center
#
#              phone                              email      email_host  \
# 0      14055323204   westernavenueboxinggym@gmail.com      google.com
# 1      14055138180  ashlee.doheny@titleboxingclub.com   rackspace.com
# 2      14056067100                    smph@gthokc.com  proofpoint.com
# 3      14055776411               solidmma@hotmail.com     outlook.com
# 4      14052056342               365amawork@gmail.com      google.com
# ...            ...                                ...             ...
# 13442  15806228675                                NaN             NaN
# 13443  15806226775                                NaN             NaN
# 13444  15806187350                                NaN             NaN
# 13445  15806225057                                NaN             NaN
# 13446  15806227234                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city  ... instagram_average_comments  \
# 0        4408 N Western Ave  Oklahoma City  ...                        NaN
# 1       1389 E 15th St #144         Edmond  ...                          3
# 2          200 N Harvey Ave  Oklahoma City  ...                        NaN
# 3         12301 Merritt Ave          Yukon  ...                          1
# 4       7315 S Shields Blvd  Oklahoma City  ...                        NaN
# ...                     ...            ...  ...                        ...
# 13442    202 W Muskogee Ave        Sulphur  ...                        NaN
# 13443          917 W 5th St        Sulphur  ...                        NaN
# 13444   2112 W Broadway Ave        Sulphur  ...                        NaN
# 13445  2001 Country Club Dr        Sulphur  ...                        NaN
# 13446     1504 Perimeter Rd        Sulphur  ...                        NaN
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN           1
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN          NaN           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN         NaN
# ...        ...          ...           ...           ...         ...
# 13442      NaN          NaN           NaN           NaN         NaN
# 13443      NaN          NaN           NaN           NaN         NaN
# 13444      NaN          NaN           NaN           NaN         NaN
# 13445      NaN          NaN           NaN           NaN         NaN
# 13446      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city
# 0        Boxing Club  Oklahoma City
# 1        Boxing Club  Oklahoma City
# 2        Boxing Club  Oklahoma City
# 3        Boxing Club  Oklahoma City
# 4        Boxing Club  Oklahoma City
# ...              ...            ...
# 13442    Yoga Studio        Sulphur
# 13443    Yoga Studio        Sulphur
# 13444    Yoga Studio        Sulphur
# 13445    Yoga Studio        Sulphur
# 13446    Yoga Studio        Sulphur
#
# [13447 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                 First Name                       name  \
# 0            Boxing     Western Avenue Boxing   Western Avenue Boxing Gym
# 1            Boxing       Title Boxing  Edmond   Title Boxing Club Edmond
# 2           General      Park Harvey Athletic   Park Harvey Athletic Club
# 3           General                  Solid Mma                  Solid Mma
# 4      Martial Arts            Of Martial Arts    Academy Of Martial Arts
# ...             ...                        ...                        ...
# 13442       fitness                        Sd                      Sd Gym
# 13443       General               Dance Center               Dance Center
# 13444       General             Allure Studios             Allure Studios
# 13445       General  Sulphur Hills Golf Course  Sulphur Hills Golf Course
# 13446       General   Travertine Nature Center   Travertine Nature Center
#
#              phone                              email      email_host  \
# 0      14055323204   westernavenueboxinggym@gmail.com      google.com
# 1      14055138180  ashlee.doheny@titleboxingclub.com   rackspace.com
# 2      14056067100                    smph@gthokc.com  proofpoint.com
# 3      14055776411               solidmma@hotmail.com     outlook.com
# 4      14052056342               365amawork@gmail.com      google.com
# ...            ...                                ...             ...
# 13442  15806228675                                NaN             NaN
# 13443  15806226775                                NaN             NaN
# 13444  15806187350                                NaN             NaN
# 13445  15806225057                                NaN             NaN
# 13446  15806227234                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city  ... instagram_average_comments  \
# 0        4408 N Western Ave  Oklahoma City  ...                        NaN
# 1       1389 E 15th St #144         Edmond  ...                          3
# 2          200 N Harvey Ave  Oklahoma City  ...                        NaN
# 3         12301 Merritt Ave          Yukon  ...                          1
# 4       7315 S Shields Blvd  Oklahoma City  ...                        NaN
# ...                     ...            ...  ...                        ...
# 13442    202 W Muskogee Ave        Sulphur  ...                        NaN
# 13443          917 W 5th St        Sulphur  ...                        NaN
# 13444   2112 W Broadway Ave        Sulphur  ...                        NaN
# 13445  2001 Country Club Dr        Sulphur  ...                        NaN
# 13446     1504 Perimeter Rd        Sulphur  ...                        NaN
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN           1
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN          NaN           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN         NaN
# ...        ...          ...           ...           ...         ...
# 13442      NaN          NaN           NaN           NaN         NaN
# 13443      NaN          NaN           NaN           NaN         NaN
# 13444      NaN          NaN           NaN           NaN         NaN
# 13445      NaN          NaN           NaN           NaN         NaN
# 13446      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city
# 0        Boxing Club  Oklahoma City
# 1        Boxing Club  Oklahoma City
# 2        Boxing Club  Oklahoma City
# 3        Boxing Club  Oklahoma City
# 4        Boxing Club  Oklahoma City
# ...              ...            ...
# 13442    Yoga Studio        Sulphur
# 13443    Yoga Studio        Sulphur
# 13444    Yoga Studio        Sulphur
# 13445    Yoga Studio        Sulphur
# 13446    Yoga Studio        Sulphur
#
# [13447 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                First Name                         name  \
# 0            Boxing    Western Avenue Boxing     Western Avenue Boxing Gym
# 1            Boxing      Title Boxing  Edmond     Title Boxing Club Edmond
# 2           General     Park Harvey Athletic     Park Harvey Athletic Club
# 3           General                 Solid Mma                    Solid Mma
# 4      Martial Arts           Of Martial Arts      Academy Of Martial Arts
# ...             ...                       ...                          ...
# 13442       fitness                       Sd                        Sd Gym
# 13443       General              Dance Center                 Dance Center
# 13444       General            Allure Studios               Allure Studios
# 13445       General         Hills Golf Course  (Sulphur) Hills Golf Course
# 13446       General  Travertine Nature Center     Travertine Nature Center
#
#              phone                              email      email_host  \
# 0      14055323204   westernavenueboxinggym@gmail.com      google.com
# 1      14055138180  ashlee.doheny@titleboxingclub.com   rackspace.com
# 2      14056067100                    smph@gthokc.com  proofpoint.com
# 3      14055776411               solidmma@hotmail.com     outlook.com
# 4      14052056342               365amawork@gmail.com      google.com
# ...            ...                                ...             ...
# 13442  15806228675                                NaN             NaN
# 13443  15806226775                                NaN             NaN
# 13444  15806187350                                NaN             NaN
# 13445  15806225057                                NaN             NaN
# 13446  15806227234                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city  ... instagram_average_comments  \
# 0        4408 N Western Ave  Oklahoma City  ...                        NaN
# 1       1389 E 15th St #144         Edmond  ...                          3
# 2          200 N Harvey Ave  Oklahoma City  ...                        NaN
# 3         12301 Merritt Ave          Yukon  ...                          1
# 4       7315 S Shields Blvd  Oklahoma City  ...                        NaN
# ...                     ...            ...  ...                        ...
# 13442    202 W Muskogee Ave        Sulphur  ...                        NaN
# 13443          917 W 5th St        Sulphur  ...                        NaN
# 13444   2112 W Broadway Ave        Sulphur  ...                        NaN
# 13445  2001 Country Club Dr        Sulphur  ...                        NaN
# 13446     1504 Perimeter Rd        Sulphur  ...                        NaN
#
#       ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN           NaN           1
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN          NaN           NaN           NaN         NaN
# 4          NaN          NaN           NaN           NaN         NaN
# ...        ...          ...           ...           ...         ...
# 13442      NaN          NaN           NaN           NaN         NaN
# 13443      NaN          NaN           NaN           NaN         NaN
# 13444      NaN          NaN           NaN           NaN         NaN
# 13445      NaN          NaN           NaN           NaN         NaN
# 13446      NaN          NaN           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city
# 0        Boxing Club  Oklahoma City
# 1        Boxing Club  Oklahoma City
# 2        Boxing Club  Oklahoma City
# 3        Boxing Club  Oklahoma City
# 4        Boxing Club  Oklahoma City
# ...              ...            ...
# 13442    Yoga Studio        Sulphur
# 13443    Yoga Studio        Sulphur
# 13444    Yoga Studio        Sulphur
# 13445    Yoga Studio        Sulphur
# 13446    Yoga Studio        Sulphur
#
# [13447 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                First Name                         name  \
# 0            Boxing    Western Avenue Boxing     Western Avenue Boxing Gym
# 1            Boxing      Title Boxing  Edmond     Title Boxing Club Edmond
# 2           General     Park Harvey Athletic     Park Harvey Athletic Club
# 3           General                 Solid Mma                    Solid Mma
# 4      Martial Arts           Of Martial Arts      Academy Of Martial Arts
# ...             ...                       ...                          ...
# 13442       fitness                       Sd                        Sd Gym
# 13443       General              Dance Center                 Dance Center
# 13444       General            Allure Studios               Allure Studios
# 13445       General         Hills Golf Course  (Sulphur) Hills Golf Course
# 13446       General  Travertine Nature Center     Travertine Nature Center
#
#              phone                              email      email_host  \
# 0      14055323204   westernavenueboxinggym@gmail.com      google.com
# 1      14055138180  ashlee.doheny@titleboxingclub.com   rackspace.com
# 2      14056067100                    smph@gthokc.com  proofpoint.com
# 3      14055776411               solidmma@hotmail.com     outlook.com
# 4      14052056342               365amawork@gmail.com      google.com
# ...            ...                                ...             ...
# 13442  15806228675                                NaN             NaN
# 13443  15806226775                                NaN             NaN
# 13444  15806187350                                NaN             NaN
# 13445  15806225057                                NaN             NaN
# 13446  15806227234                                NaN             NaN
#
#                                         website                    category  \
# 0        http://www.westernavenueboxinggym.com/                  Boxing Gym
# 1        https://titleboxingclub.com/edmond-ok/                  Boxing Gym
# 2      https://theparkharvey.com/athletic-club/                         Gym
# 3                      http://www.solidmma.pro/         Martial arts school
# 4                        http://www.okcama.com/         Martial arts school
# ...                                         ...                         ...
# 13442                                       NaN                         Gym
# 13443                                       NaN                Dance school
# 13444                                       NaN               Tanning salon
# 13445                                       NaN                 Golf course
# 13446                                       NaN  Tourist Information Centre
#
#                     address           city  ... ads_yelp ads_facebook  \
# 0        4408 N Western Ave  Oklahoma City  ...      NaN          NaN
# 1       1389 E 15th St #144         Edmond  ...      NaN          NaN
# 2          200 N Harvey Ave  Oklahoma City  ...      NaN          NaN
# 3         12301 Merritt Ave          Yukon  ...      NaN          NaN
# 4       7315 S Shields Blvd  Oklahoma City  ...      NaN          NaN
# ...                     ...            ...  ...      ...          ...
# 13442    202 W Muskogee Ave        Sulphur  ...      NaN          NaN
# 13443          917 W 5th St        Sulphur  ...      NaN          NaN
# 13444   2112 W Broadway Ave        Sulphur  ...      NaN          NaN
# 13445  2001 Country Club Dr        Sulphur  ...      NaN          NaN
# 13446     1504 Perimeter Rd        Sulphur  ...      NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               NaN           NaN         NaN
# 1               NaN           NaN           1
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               NaN           NaN         NaN
# ...             ...           ...         ...
# 13442           NaN           NaN         NaN
# 13443           NaN           NaN         NaN
# 13444           NaN           NaN         NaN
# 13445           NaN           NaN         NaN
# 13446           NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Western+Ave...        claimed
# 1                https://g.page/title-boxing-club-edmond        claimed
# 2      https://maps.google.com/maps/place/Park+Harvey...        claimed
# 3      https://maps.google.com/maps/place/Solid+MMA/@...        claimed
# 4      https://maps.google.com/maps/place/Academy+of+...        claimed
# ...                                                  ...            ...
# 13442  https://maps.google.com/maps/place/SD+Gym/@34....      unclaimed
# 13443  https://maps.google.com/maps/place/Dance+Cente...      unclaimed
# 13444  https://maps.google.com/maps/place/Allure+Stud...        claimed
# 13445  https://maps.google.com/maps/place/Sulphur+Hil...        claimed
# 13446  https://maps.google.com/maps/place/Travertine+...      unclaimed
#
#       search_keyword    search_city  \
# 0        Boxing Club  Oklahoma City
# 1        Boxing Club  Oklahoma City
# 2        Boxing Club  Oklahoma City
# 3        Boxing Club  Oklahoma City
# 4        Boxing Club  Oklahoma City
# ...              ...            ...
# 13442    Yoga Studio        Sulphur
# 13443    Yoga Studio        Sulphur
# 13444    Yoga Studio        Sulphur
# 13445    Yoga Studio        Sulphur
# 13446    Yoga Studio        Sulphur
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw your B2 listing on Google hit double dig...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a near perfect rating on Google. ...
# 4      I saw B2 has a perfect rating on Google. 5 sta...
# ...                                                  ...
# 13442  I saw your B2 page is in the triple digits for...
# 13443  I saw B2 has a perfect rating on Google. 5 sta...
# 13444  I saw B2 has a perfect rating on Google. 5 sta...
# 13445  I saw B2 has a near perfect rating on Google. ...
# 13446  I saw B2 has a near perfect rating on Google. ...
#
# [13447 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('OK_combined_leads_duplicates_removed_semiclean.csv', index = False)
