# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("NE_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               JACKSONS BOXING  14027079834
# 2     Mick Doyles Kickboxing and Fitness Center  14024989592
# 3                                   B&B academy  14029130633
# 4                          CKO Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar and Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city region    zip  \
# 0                   Boxing Gym        3009 R St        Omaha     NE  68107
# 1                  Boxing club   2505 N 24th St        Omaha     NE  68110
# 2          Martial arts school  10801 Blondo St        Omaha     NE  68164
# 3                  Boxing club  3030 Sprague St        Omaha     NE  68111
# 4                          Gym  2615 S 144th St        Omaha     NE  68144
# ...                        ...              ...          ...    ...    ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago     NE  68071
# 8345                Restaurant       210 1st St  Morse Bluff     NE  68648
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff     NE  68648
# 8347         Elementary school      Morse Bluff          NaN     NE  68648
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff     NE  68648
#
#       ... instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0     ...                        NaN      NaN          NaN           NaN
# 1     ...                        NaN      NaN          NaN           NaN
# 2     ...                          1      NaN          NaN           NaN
# 3     ...                          2      NaN          NaN           NaN
# 4     ...                          3      NaN          NaN             1
# ...   ...                        ...      ...          ...           ...
# 8344  ...                        NaN      NaN          NaN           NaN
# 8345  ...                        NaN      NaN          NaN           NaN
# 8346  ...                        NaN      NaN          NaN           NaN
# 8347  ...                        NaN      NaN          NaN           NaN
# 8348  ...                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4                1         NaN
# ...            ...         ...
# 8344           NaN         NaN
# 8345           NaN         NaN
# 8346           NaN         NaN
# 8347           NaN         NaN
# 8348           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club        Omaha
# 1       Boxing Club        Omaha
# 2       Boxing Club        Omaha
# 3       Boxing Club        Omaha
# 4       Boxing Club        Omaha
# ...             ...          ...
# 8344    Yoga Studio    Winnebago
# 8345    Yoga Studio  Morse Bluff
# 8346    Yoga Studio  Morse Bluff
# 8347    Yoga Studio  Morse Bluff
# 8348    Yoga Studio  Morse Bluff
#
# [8349 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('NE','')
df['First Name'] = df['First Name'].str.replace('Ne','')
df['First Name'] = df['First Name'].str.replace('Nebraska','')
df
# Out:
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                          Cko Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city region    zip  \
# 0                   Boxing Gym        3009 R St        Omaha     NE  68107
# 1                  Boxing club   2505 N 24th St        Omaha     NE  68110
# 2          Martial arts school  10801 Blondo St        Omaha     NE  68164
# 3                  Boxing club  3030 Sprague St        Omaha     NE  68111
# 4                          Gym  2615 S 144th St        Omaha     NE  68144
# ...                        ...              ...          ...    ...    ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago     NE  68071
# 8345                Restaurant       210 1st St  Morse Bluff     NE  68648
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff     NE  68648
# 8347         Elementary school      Morse Bluff          NaN     NE  68648
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff     NE  68648
#
#       ... ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...      NaN          NaN           NaN           NaN         NaN
# 1     ...      NaN          NaN           NaN           NaN         NaN
# 2     ...      NaN          NaN           NaN           NaN         NaN
# 3     ...      NaN          NaN           NaN           NaN         NaN
# 4     ...      NaN          NaN             1             1         NaN
# ...   ...      ...          ...           ...           ...         ...
# 8344  ...      NaN          NaN           NaN           NaN         NaN
# 8345  ...      NaN          NaN           NaN           NaN         NaN
# 8346  ...      NaN          NaN           NaN           NaN         NaN
# 8347  ...      NaN          NaN           NaN           NaN         NaN
# 8348  ...      NaN          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city                                 First Name
# 0       Boxing Club        Omaha            Victory Boxing Community Center
# 1       Boxing Club        Omaha                            Jacksons Boxing
# 2       Boxing Club        Omaha  Mick Doyles Kickboxing And Fitness Center
# 3       Boxing Club        Omaha                                       B&B
# 4       Boxing Club        Omaha                       Cko Kickboxing Omaha
# ...             ...          ...                                        ...
# 8344    Yoga Studio    Winnebago                       Winnebago Eye Clinic
# 8345    Yoga Studio  Morse Bluff                  Bottom Road Bar And Grill
# 8346    Yoga Studio  Morse Bluff                            Bluff Gravel Co
# 8347    Yoga Studio  Morse Bluff              Morse Bluff Elementary School
# 8348    Yoga Studio  Morse Bluff                       Morse Industries Inc
#
# [8349 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                          Cko Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city region    zip  \
# 0                   Boxing Gym        3009 R St        Omaha     NE  68107
# 1                  Boxing club   2505 N 24th St        Omaha     NE  68110
# 2          Martial arts school  10801 Blondo St        Omaha     NE  68164
# 3                  Boxing club  3030 Sprague St        Omaha     NE  68111
# 4                          Gym  2615 S 144th St        Omaha     NE  68144
# ...                        ...              ...          ...    ...    ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago     NE  68071
# 8345                Restaurant       210 1st St  Morse Bluff     NE  68648
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff     NE  68648
# 8347         Elementary school      Morse Bluff          NaN     NE  68648
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff     NE  68648
#
#       ... ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...      NaN          NaN           NaN           NaN         NaN
# 1     ...      NaN          NaN           NaN           NaN         NaN
# 2     ...      NaN          NaN           NaN           NaN         NaN
# 3     ...      NaN          NaN           NaN           NaN         NaN
# 4     ...      NaN          NaN             1             1         NaN
# ...   ...      ...          ...           ...           ...         ...
# 8344  ...      NaN          NaN           NaN           NaN         NaN
# 8345  ...      NaN          NaN           NaN           NaN         NaN
# 8346  ...      NaN          NaN           NaN           NaN         NaN
# 8347  ...      NaN          NaN           NaN           NaN         NaN
# 8348  ...      NaN          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city                                 First Name
# 0       Boxing Club        Omaha            Victory Boxing Community Center
# 1       Boxing Club        Omaha                            Jacksons Boxing
# 2       Boxing Club        Omaha  Mick Doyles Kickboxing And Fitness Center
# 3       Boxing Club        Omaha                                       B&B
# 4       Boxing Club        Omaha                       Cko Kickboxing Omaha
# ...             ...          ...                                        ...
# 8344    Yoga Studio    Winnebago                       Winnebago Eye Clinic
# 8345    Yoga Studio  Morse Bluff                  Bottom Road Bar And Grill
# 8346    Yoga Studio  Morse Bluff                            Bluff Gravel Co
# 8347    Yoga Studio  Morse Bluff              Morse Bluff Elementary School
# 8348    Yoga Studio  Morse Bluff                       Morse Industries Inc
#
# [8349 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                          Cko Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city region    zip  \
# 0                   Boxing Gym        3009 R St        Omaha     NE  68107
# 1                  Boxing club   2505 N 24th St        Omaha     NE  68110
# 2          Martial arts school  10801 Blondo St        Omaha     NE  68164
# 3                  Boxing club  3030 Sprague St        Omaha     NE  68111
# 4                          Gym  2615 S 144th St        Omaha     NE  68144
# ...                        ...              ...          ...    ...    ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago     NE  68071
# 8345                Restaurant       210 1st St  Morse Bluff     NE  68648
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff     NE  68648
# 8347         Elementary school      Morse Bluff          NaN     NE  68648
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff     NE  68648
#
#       ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...          NaN           NaN           NaN         NaN
# 1     ...          NaN           NaN           NaN         NaN
# 2     ...          NaN           NaN           NaN         NaN
# 3     ...          NaN           NaN           NaN         NaN
# 4     ...          NaN             1             1         NaN
# ...   ...          ...           ...           ...         ...
# 8344  ...          NaN           NaN           NaN         NaN
# 8345  ...          NaN           NaN           NaN         NaN
# 8346  ...          NaN           NaN           NaN         NaN
# 8347  ...          NaN           NaN           NaN         NaN
# 8348  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city                                 First Name  \
# 0       Boxing Club        Omaha            Victory Boxing Community Center
# 1       Boxing Club        Omaha                            Jacksons Boxing
# 2       Boxing Club        Omaha  Mick Doyles Kickboxing And Fitness Center
# 3       Boxing Club        Omaha                                       B&B
# 4       Boxing Club        Omaha                       Cko Kickboxing Omaha
# ...             ...          ...                                        ...
# 8344    Yoga Studio    Winnebago                       Winnebago Eye Clinic
# 8345    Yoga Studio  Morse Bluff                  Bottom Road Bar And Grill
# 8346    Yoga Studio  Morse Bluff                            Bluff Gravel Co
# 8347    Yoga Studio  Morse Bluff              Morse Bluff Elementary School
# 8348    Yoga Studio  Morse Bluff                       Morse Industries Inc
#
#      Business Type
# 0              NaT
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
# ...            ...
# 8344           NaT
# 8345           NaT
# 8346           NaT
# 8347           NaT
# 8348           NaT
#
# [8349 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                          Cko Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city region    zip  \
# 0                   Boxing Gym        3009 R St        Omaha     NE  68107
# 1                  Boxing club   2505 N 24th St        Omaha     NE  68110
# 2          Martial arts school  10801 Blondo St        Omaha     NE  68164
# 3                  Boxing club  3030 Sprague St        Omaha     NE  68111
# 4                          Gym  2615 S 144th St        Omaha     NE  68144
# ...                        ...              ...          ...    ...    ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago     NE  68071
# 8345                Restaurant       210 1st St  Morse Bluff     NE  68648
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff     NE  68648
# 8347         Elementary school      Morse Bluff          NaN     NE  68648
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff     NE  68648
#
#       ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...          NaN           NaN           NaN         NaN
# 1     ...          NaN           NaN           NaN         NaN
# 2     ...          NaN           NaN           NaN         NaN
# 3     ...          NaN           NaN           NaN         NaN
# 4     ...          NaN             1             1         NaN
# ...   ...          ...           ...           ...         ...
# 8344  ...          NaN           NaN           NaN         NaN
# 8345  ...          NaN           NaN           NaN         NaN
# 8346  ...          NaN           NaN           NaN         NaN
# 8347  ...          NaN           NaN           NaN         NaN
# 8348  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city                                 First Name  \
# 0       Boxing Club        Omaha            Victory Boxing Community Center
# 1       Boxing Club        Omaha                            Jacksons Boxing
# 2       Boxing Club        Omaha  Mick Doyles Kickboxing And Fitness Center
# 3       Boxing Club        Omaha                                       B&B
# 4       Boxing Club        Omaha                       Cko Kickboxing Omaha
# ...             ...          ...                                        ...
# 8344    Yoga Studio    Winnebago                       Winnebago Eye Clinic
# 8345    Yoga Studio  Morse Bluff                  Bottom Road Bar And Grill
# 8346    Yoga Studio  Morse Bluff                            Bluff Gravel Co
# 8347    Yoga Studio  Morse Bluff              Morse Bluff Elementary School
# 8348    Yoga Studio  Morse Bluff                       Morse Industries Inc
#
#      Business Type
# 0          General
# 1          General
# 2          General
# 3          General
# 4          General
# ...            ...
# 8344       General
# 8345       General
# 8346       General
# 8347       General
# 8348       General
#
# [8349 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                          Cko Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city region    zip  \
# 0                   Boxing Gym        3009 R St        Omaha     NE  68107
# 1                  Boxing club   2505 N 24th St        Omaha     NE  68110
# 2          Martial arts school  10801 Blondo St        Omaha     NE  68164
# 3                  Boxing club  3030 Sprague St        Omaha     NE  68111
# 4                          Gym  2615 S 144th St        Omaha     NE  68144
# ...                        ...              ...          ...    ...    ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago     NE  68071
# 8345                Restaurant       210 1st St  Morse Bluff     NE  68648
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff     NE  68648
# 8347         Elementary school      Morse Bluff          NaN     NE  68648
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff     NE  68648
#
#       ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     ...          NaN           NaN           NaN         NaN
# 1     ...          NaN           NaN           NaN         NaN
# 2     ...          NaN           NaN           NaN         NaN
# 3     ...          NaN           NaN           NaN         NaN
# 4     ...          NaN             1             1         NaN
# ...   ...          ...           ...           ...         ...
# 8344  ...          NaN           NaN           NaN         NaN
# 8345  ...          NaN           NaN           NaN         NaN
# 8346  ...          NaN           NaN           NaN         NaN
# 8347  ...          NaN           NaN           NaN         NaN
# 8348  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city                                 First Name  \
# 0       Boxing Club        Omaha            Victory Boxing Community Center
# 1       Boxing Club        Omaha                            Jacksons Boxing
# 2       Boxing Club        Omaha  Mick Doyles Kickboxing And Fitness Center
# 3       Boxing Club        Omaha                                       B&B
# 4       Boxing Club        Omaha                       Cko Kickboxing Omaha
# ...             ...          ...                                        ...
# 8344    Yoga Studio    Winnebago                       Winnebago Eye Clinic
# 8345    Yoga Studio  Morse Bluff                  Bottom Road Bar And Grill
# 8346    Yoga Studio  Morse Bluff                            Bluff Gravel Co
# 8347    Yoga Studio  Morse Bluff              Morse Bluff Elementary School
# 8348    Yoga Studio  Morse Bluff                       Morse Industries Inc
#
#      Business Type
# 0           Boxing
# 1           Boxing
# 2       Kickboxing
# 3          General
# 4       Kickboxing
# ...            ...
# 8344       General
# 8345       General
# 8346       General
# 8347       General
# 8348       General
#
# [8349 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#      Business Type                                 First Name  \
# 0           Boxing            Victory Boxing Community Center
# 1           Boxing                            Jacksons Boxing
# 2       Kickboxing  Mick Doyles Kickboxing And Fitness Center
# 3          General                                       B&B
# 4       Kickboxing                       Cko Kickboxing Omaha
# ...            ...                                        ...
# 8344       General                       Winnebago Eye Clinic
# 8345       General                  Bottom Road Bar And Grill
# 8346       General                            Bluff Gravel Co
# 8347       General              Morse Bluff Elementary School
# 8348       General                       Morse Industries Inc
#
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                          Cko Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city  ...  \
# 0                   Boxing Gym        3009 R St        Omaha  ...
# 1                  Boxing club   2505 N 24th St        Omaha  ...
# 2          Martial arts school  10801 Blondo St        Omaha  ...
# 3                  Boxing club  3030 Sprague St        Omaha  ...
# 4                          Gym  2615 S 144th St        Omaha  ...
# ...                        ...              ...          ...  ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago  ...
# 8345                Restaurant       210 1st St  Morse Bluff  ...
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff  ...
# 8347         Elementary school      Morse Bluff          NaN  ...
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                           NaN      NaN          NaN           NaN
# 1                           NaN      NaN          NaN           NaN
# 2                             1      NaN          NaN           NaN
# 3                             2      NaN          NaN           NaN
# 4                             3      NaN          NaN             1
# ...                         ...      ...          ...           ...
# 8344                        NaN      NaN          NaN           NaN
# 8345                        NaN      NaN          NaN           NaN
# 8346                        NaN      NaN          NaN           NaN
# 8347                        NaN      NaN          NaN           NaN
# 8348                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4                1         NaN
# ...            ...         ...
# 8344           NaN         NaN
# 8345           NaN         NaN
# 8346           NaN         NaN
# 8347           NaN         NaN
# 8348           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club        Omaha
# 1       Boxing Club        Omaha
# 2       Boxing Club        Omaha
# 3       Boxing Club        Omaha
# 4       Boxing Club        Omaha
# ...             ...          ...
# 8344    Yoga Studio    Winnebago
# 8345    Yoga Studio  Morse Bluff
# 8346    Yoga Studio  Morse Bluff
# 8347    Yoga Studio  Morse Bluff
# 8348    Yoga Studio  Morse Bluff
#
# [8349 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#      Business Type                                 First Name  \
# 0           Boxing            Victory Boxing Community Center
# 1           Boxing                            Jacksons Boxing
# 2       Kickboxing  Mick Doyles Kickboxing And Fitness Center
# 3          General                                       B&B
# 4       Kickboxing                       Cko Kickboxing Omaha
# ...            ...                                        ...
# 8344       General                       Winnebago Eye Clinic
# 8345       General                  Bottom Road Bar And Grill
# 8346       General                            Bluff Gravel Co
# 8347       General              Morse Bluff Elementary School
# 8348       General                       Morse Industries Inc
#
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                          Cko Kickboxing Omaha  14023307256
# ...                                         ...          ...
# 8344                       Winnebago Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347              Morse Bluff Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city  ...  \
# 0                   Boxing Gym        3009 R St        Omaha  ...
# 1                  Boxing club   2505 N 24th St        Omaha  ...
# 2          Martial arts school  10801 Blondo St        Omaha  ...
# 3                  Boxing club  3030 Sprague St        Omaha  ...
# 4                          Gym  2615 S 144th St        Omaha  ...
# ...                        ...              ...          ...  ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago  ...
# 8345                Restaurant       210 1st St  Morse Bluff  ...
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff  ...
# 8347         Elementary school      Morse Bluff          NaN  ...
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                           NaN      NaN          NaN           NaN
# 1                           NaN      NaN          NaN           NaN
# 2                             1      NaN          NaN           NaN
# 3                             2      NaN          NaN           NaN
# 4                             3      NaN          NaN             1
# ...                         ...      ...          ...           ...
# 8344                        NaN      NaN          NaN           NaN
# 8345                        NaN      NaN          NaN           NaN
# 8346                        NaN      NaN          NaN           NaN
# 8347                        NaN      NaN          NaN           NaN
# 8348                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4                1         NaN
# ...            ...         ...
# 8344           NaN         NaN
# 8345           NaN         NaN
# 8346           NaN         NaN
# 8347           NaN         NaN
# 8348           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club        Omaha
# 1       Boxing Club        Omaha
# 2       Boxing Club        Omaha
# 3       Boxing Club        Omaha
# 4       Boxing Club        Omaha
# ...             ...          ...
# 8344    Yoga Studio    Winnebago
# 8345    Yoga Studio  Morse Bluff
# 8346    Yoga Studio  Morse Bluff
# 8347    Yoga Studio  Morse Bluff
# 8348    Yoga Studio  Morse Bluff
#
# [8349 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#      Business Type                                 First Name  \
# 0           Boxing            Victory Boxing Community Center
# 1           Boxing                            Jacksons Boxing
# 2       Kickboxing  Mick Doyles Kickboxing And Fitness Center
# 3          General                                       B&B
# 4       Kickboxing                            Cko Kickboxing
# ...            ...                                        ...
# 8344       General                                 Eye Clinic
# 8345       General                  Bottom Road Bar And Grill
# 8346       General                            Bluff Gravel Co
# 8347       General                          Elementary School
# 8348       General                       Morse Industries Inc
#
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                        Cko Kickboxing (Omaha)  14023307256
# ...                                         ...          ...
# 8344                     (Winnebago) Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347            (Morse Bluff) Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city  ...  \
# 0                   Boxing Gym        3009 R St        Omaha  ...
# 1                  Boxing club   2505 N 24th St        Omaha  ...
# 2          Martial arts school  10801 Blondo St        Omaha  ...
# 3                  Boxing club  3030 Sprague St        Omaha  ...
# 4                          Gym  2615 S 144th St        Omaha  ...
# ...                        ...              ...          ...  ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago  ...
# 8345                Restaurant       210 1st St  Morse Bluff  ...
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff  ...
# 8347         Elementary school      Morse Bluff          NaN  ...
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                           NaN      NaN          NaN           NaN
# 1                           NaN      NaN          NaN           NaN
# 2                             1      NaN          NaN           NaN
# 3                             2      NaN          NaN           NaN
# 4                             3      NaN          NaN             1
# ...                         ...      ...          ...           ...
# 8344                        NaN      NaN          NaN           NaN
# 8345                        NaN      NaN          NaN           NaN
# 8346                        NaN      NaN          NaN           NaN
# 8347                        NaN      NaN          NaN           NaN
# 8348                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4                1         NaN
# ...            ...         ...
# 8344           NaN         NaN
# 8345           NaN         NaN
# 8346           NaN         NaN
# 8347           NaN         NaN
# 8348           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city
# 0       Boxing Club        Omaha
# 1       Boxing Club        Omaha
# 2       Boxing Club        Omaha
# 3       Boxing Club        Omaha
# 4       Boxing Club        Omaha
# ...             ...          ...
# 8344    Yoga Studio    Winnebago
# 8345    Yoga Studio  Morse Bluff
# 8346    Yoga Studio  Morse Bluff
# 8347    Yoga Studio  Morse Bluff
# 8348    Yoga Studio  Morse Bluff
#
# [8349 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#      Business Type                                 First Name  \
# 0           Boxing            Victory Boxing Community Center
# 1           Boxing                            Jacksons Boxing
# 2       Kickboxing  Mick Doyles Kickboxing And Fitness Center
# 3          General                                       B&B
# 4       Kickboxing                            Cko Kickboxing
# ...            ...                                        ...
# 8344       General                                 Eye Clinic
# 8345       General                  Bottom Road Bar And Grill
# 8346       General                            Bluff Gravel Co
# 8347       General                          Elementary School
# 8348       General                       Morse Industries Inc
#
#                                            name        phone  \
# 0               Victory Boxing Community Center  14026128491
# 1                               Jacksons Boxing  14027079834
# 2     Mick Doyles Kickboxing And Fitness Center  14024989592
# 3                                   B&B Academy  14029130633
# 4                        Cko Kickboxing (Omaha)  14023307256
# ...                                         ...          ...
# 8344                     (Winnebago) Eye Clinic  14028782428
# 8345                  Bottom Road Bar And Grill  14026669226
# 8346                            Bluff Gravel Co  14026665265
# 8347            (Morse Bluff) Elementary School  14026665503
# 8348                       Morse Industries Inc  14026665265
#
#                                email   email_host  \
# 0     servando@victoryboxingclub.org   google.com
# 1            mmasportpicks@gmail.com   google.com
# 2                 cody@mickdoyle.com   google.com
# 3           contact@bandbacademy.org  opensrs.com
# 4          michele@ckokickboxing.com  outlook.com
# ...                              ...          ...
# 8344                             NaN          NaN
# 8345                             NaN          NaN
# 8346        planowest@cardmyyard.com   google.com
# 8347         bellcreeksoap@gmail.com   google.com
# 8348            walldr2418@gmail.com   google.com
#
#                                                 website  \
# 0                http://victoryboxingclub.org/about-us/
# 1                             http://mmasportpicks.com/
# 2                                 http://mickdoyle.com/
# 3                          http://www.bandbacademy.org/
# 4               https://www.ckokickboxing.com/ne-omaha/
# ...                                                 ...
# 8344                                                NaN
# 8345  https://secure2.store.apple.com/shop/order/gue...
# 8346                  https://www.cardmyyard.com/omaha/
# 8347                          http://bellcreeksoap.com/
# 8348        https://www.hamiltongeneralcontracting.net/
#
#                       category          address         city  ... ads_yelp  \
# 0                   Boxing Gym        3009 R St        Omaha  ...      NaN
# 1                  Boxing club   2505 N 24th St        Omaha  ...      NaN
# 2          Martial arts school  10801 Blondo St        Omaha  ...      NaN
# 3                  Boxing club  3030 Sprague St        Omaha  ...      NaN
# 4                          Gym  2615 S 144th St        Omaha  ...      NaN
# ...                        ...              ...          ...  ...      ...
# 8344           Eye Care Clinic    US-75 & US-77    Winnebago  ...      NaN
# 8345                Restaurant       210 1st St  Morse Bluff  ...      NaN
# 8346  Sand and Gravel Supplier       211 Ann St  Morse Bluff  ...      NaN
# 8347         Elementary school      Morse Bluff          NaN  ...      NaN
# 8348    Sheet metal contractor       211 Ann St  Morse Bluff  ...      NaN
#
#      ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0             NaN           NaN           NaN         NaN
# 1             NaN           NaN           NaN         NaN
# 2             NaN           NaN           NaN         NaN
# 3             NaN           NaN           NaN         NaN
# 4             NaN             1             1         NaN
# ...           ...           ...           ...         ...
# 8344          NaN           NaN           NaN         NaN
# 8345          NaN           NaN           NaN         NaN
# 8346          NaN           NaN           NaN         NaN
# 8347          NaN           NaN           NaN         NaN
# 8348          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0     https://maps.google.com/maps/place/Victory+Box...      unclaimed
# 1     https://maps.google.com/maps/place/JACKSONS+BO...      unclaimed
# 2                             https://g.page/mickdoyles        claimed
# 3     https://maps.google.com/maps/place/B&B+academy...      unclaimed
# 4                     https://g.page/CKOKickboxingOmaha        claimed
# ...                                                 ...            ...
# 8344  https://maps.google.com/maps/place/Winnebago+E...      unclaimed
# 8345  https://maps.google.com/maps/place/Bottom+Road...      unclaimed
# 8346  https://maps.google.com/maps/place/Bluff+Grave...      unclaimed
# 8347  https://maps.google.com/maps/place/Morse+Bluff...      unclaimed
# 8348  https://maps.google.com/maps/place/Morse+Indus...      unclaimed
#
#      search_keyword  search_city  \
# 0       Boxing Club        Omaha
# 1       Boxing Club        Omaha
# 2       Boxing Club        Omaha
# 3       Boxing Club        Omaha
# 4       Boxing Club        Omaha
# ...             ...          ...
# 8344    Yoga Studio    Winnebago
# 8345    Yoga Studio  Morse Bluff
# 8346    Yoga Studio  Morse Bluff
# 8347    Yoga Studio  Morse Bluff
# 8348    Yoga Studio  Morse Bluff
#
#                                             Icebreakers
# 0     I saw B2 has a near perfect rating on Google. ...
# 1     I saw your B2 star rating on Facebook. Really ...
# 2     I saw B2 has a perfect rating on Google. 5 sta...
# 3     I saw B2 has a perfect rating on Google. 5 sta...
# 4     I saw B2 has a perfect rating on Google. 5 sta...
# ...                                                 ...
# 8344  I saw your B2 page on Facebook. You guys have ...
# 8345  I saw B2 has a near perfect rating on Google. ...
# 8346  I saw B2 has a perfect rating on Google. 5 sta...
# 8347  I was looking at the B2 website on my phone an...
# 8348  I saw your B2 star rating on Facebook. Really ...
#
# [8349 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('NE_combined_leads_duplicates_removed_semiclean.csv', index = False)
