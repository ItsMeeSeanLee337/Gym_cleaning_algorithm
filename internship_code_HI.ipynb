# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("HI_combined_leads_duplicates_removed.csv")
df #dataFrame
# Out:
#                                           name        phone  \
# 0                             UFC GYM Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              PUNCHFIT HAWAII  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (HMC) Academy  18088415144
# ...                                        ...          ...
# 6130                      REPS Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    CrossFit West Oahu LLC  18083535240
# 6134              StayFIT Physical Therapy LLC  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city region  \
# 0                         Gym              805 Pohukaina St  Honolulu     HI
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu     HI
# 2             Training centre           1646 Kapiolani Blvd  Honolulu     HI
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe     HI
# 4         Martial arts school                 555 N King St  Honolulu     HI
# ...                       ...                           ...       ...    ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei     HI
# 6131         Health & Medical               1215 S Kihei Rd     Kihei     HI
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue     HI
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei     HI
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei     HI
#
#         zip  ... instagram_average_comments ads_yelp ads_facebook  \
# 0     96813  ...                          5      NaN          NaN
# 1     96813  ...                          4      NaN          NaN
# 2     96814  ...                        NaN      NaN          NaN
# 3     96744  ...                        NaN      NaN          NaN
# 4     96817  ...                        NaN      NaN          NaN
# ...     ...  ...                        ...      ...          ...
# 6130  96753  ...                          4      NaN          NaN
# 6131  96753  ...                        NaN      NaN          NaN
# 6132  96766  ...                        NaN      NaN          NaN
# 6133  96707  ...                          4      NaN          NaN
# 6134  96707  ...                        NaN      NaN          NaN
#
#      ads_instagram ads_messenger ads_adwords  \
# 0              NaN           NaN           1
# 1              NaN           NaN         NaN
# 2              NaN           NaN         NaN
# 3              NaN           NaN         NaN
# 4              NaN           NaN         NaN
# ...            ...           ...         ...
# 6130           NaN           NaN         NaN
# 6131           NaN           NaN         NaN
# 6132           NaN           NaN         NaN
# 6133           NaN           NaN         NaN
# 6134           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city
# 0       Boxing Club       Honolulu
# 1       Boxing Club       Honolulu
# 2       Boxing Club       Honolulu
# 3       Boxing Club       Honolulu
# 4       Boxing Club       Honolulu
# ...             ...            ...
# 6130    Yoga Studio  Wailea-Makena
# 6131    Yoga Studio  Wailea-Makena
# 6132    Yoga Studio         Wailua
# 6133    Yoga Studio  Makakilo City
# 6134    Yoga Studio  Makakilo City
#
# [6135 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('HI','')
df['First Name'] = df['First Name'].str.replace('Hi','')
df['First Name'] = df['First Name'].str.replace('Hawaii','')
df
# Out:
#                                           name        phone  \
# 0                             Ufc Gym Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city region  \
# 0                         Gym              805 Pohukaina St  Honolulu     HI
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu     HI
# 2             Training centre           1646 Kapiolani Blvd  Honolulu     HI
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe     HI
# 4         Martial arts school                 555 N King St  Honolulu     HI
# ...                       ...                           ...       ...    ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei     HI
# 6131         Health & Medical               1215 S Kihei Rd     Kihei     HI
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue     HI
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei     HI
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei     HI
#
#         zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0     96813  ...      NaN          NaN           NaN           NaN
# 1     96813  ...      NaN          NaN           NaN           NaN
# 2     96814  ...      NaN          NaN           NaN           NaN
# 3     96744  ...      NaN          NaN           NaN           NaN
# 4     96817  ...      NaN          NaN           NaN           NaN
# ...     ...  ...      ...          ...           ...           ...
# 6130  96753  ...      NaN          NaN           NaN           NaN
# 6131  96753  ...      NaN          NaN           NaN           NaN
# 6132  96766  ...      NaN          NaN           NaN           NaN
# 6133  96707  ...      NaN          NaN           NaN           NaN
# 6134  96707  ...      NaN          NaN           NaN           NaN
#
#      ads_adwords                                             g_maps  \
# 0              1                    https://g.page/ufc-gym-honolulu
# 1            NaN                     https://g.page/muayboranhawaii
# 2            NaN  https://maps.google.com/maps/place/PUNCHFIT+HA...
# 3            NaN  https://maps.google.com/maps/place/Koolauloa+B...
# 4            NaN  https://maps.google.com/maps/place/Hawaii+Mart...
# ...          ...                                                ...
# 6130         NaN  https://maps.google.com/maps/place/REPS+Traini...
# 6131         NaN  https://maps.google.com/maps/place/Sabai+Massa...
# 6132         NaN  https://maps.google.com/maps/place/Hoola+Fitne...
# 6133         NaN  https://maps.google.com/maps/place/CrossFit+We...
# 6134         NaN  https://maps.google.com/maps/place/StayFIT+Phy...
#
#      g_maps_claimed search_keyword    search_city                   First Name
# 0           claimed    Boxing Club       Honolulu                Ufc  Honolulu
# 1           claimed    Boxing Club       Honolulu                  Muay Boran
# 2           claimed    Boxing Club       Honolulu                    Punchfit
# 3           claimed    Boxing Club       Honolulu            Koolauloa Boxing
# 4           claimed    Boxing Club       Honolulu   Martial Arts Center (Hmc)
# ...             ...            ...            ...                          ...
# 6130        claimed    Yoga Studio  Wailea-Makena         Reps Training Center
# 6131        claimed    Yoga Studio  Wailea-Makena        Sabai Massage Therapy
# 6132      unclaimed    Yoga Studio         Wailua         Hoola Fitness Center
# 6133        claimed    Yoga Studio  Makakilo City          Crossfit West Oahu
# 6134        claimed    Yoga Studio  Makakilo City    Stayfit Physical Therapy
#
# [6135 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                           name        phone  \
# 0                             Ufc Gym Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city region  \
# 0                         Gym              805 Pohukaina St  Honolulu     HI
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu     HI
# 2             Training centre           1646 Kapiolani Blvd  Honolulu     HI
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe     HI
# 4         Martial arts school                 555 N King St  Honolulu     HI
# ...                       ...                           ...       ...    ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei     HI
# 6131         Health & Medical               1215 S Kihei Rd     Kihei     HI
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue     HI
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei     HI
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei     HI
#
#         zip  ... ads_yelp ads_facebook ads_instagram ads_messenger  \
# 0     96813  ...      NaN          NaN           NaN           NaN
# 1     96813  ...      NaN          NaN           NaN           NaN
# 2     96814  ...      NaN          NaN           NaN           NaN
# 3     96744  ...      NaN          NaN           NaN           NaN
# 4     96817  ...      NaN          NaN           NaN           NaN
# ...     ...  ...      ...          ...           ...           ...
# 6130  96753  ...      NaN          NaN           NaN           NaN
# 6131  96753  ...      NaN          NaN           NaN           NaN
# 6132  96766  ...      NaN          NaN           NaN           NaN
# 6133  96707  ...      NaN          NaN           NaN           NaN
# 6134  96707  ...      NaN          NaN           NaN           NaN
#
#      ads_adwords                                             g_maps  \
# 0              1                    https://g.page/ufc-gym-honolulu
# 1            NaN                     https://g.page/muayboranhawaii
# 2            NaN  https://maps.google.com/maps/place/PUNCHFIT+HA...
# 3            NaN  https://maps.google.com/maps/place/Koolauloa+B...
# 4            NaN  https://maps.google.com/maps/place/Hawaii+Mart...
# ...          ...                                                ...
# 6130         NaN  https://maps.google.com/maps/place/REPS+Traini...
# 6131         NaN  https://maps.google.com/maps/place/Sabai+Massa...
# 6132         NaN  https://maps.google.com/maps/place/Hoola+Fitne...
# 6133         NaN  https://maps.google.com/maps/place/CrossFit+We...
# 6134         NaN  https://maps.google.com/maps/place/StayFIT+Phy...
#
#      g_maps_claimed search_keyword    search_city                   First Name
# 0           claimed    Boxing Club       Honolulu                Ufc  Honolulu
# 1           claimed    Boxing Club       Honolulu                  Muay Boran
# 2           claimed    Boxing Club       Honolulu                    Punchfit
# 3           claimed    Boxing Club       Honolulu            Koolauloa Boxing
# 4           claimed    Boxing Club       Honolulu   Martial Arts Center (Hmc)
# ...             ...            ...            ...                          ...
# 6130        claimed    Yoga Studio  Wailea-Makena         Reps Training Center
# 6131        claimed    Yoga Studio  Wailea-Makena        Sabai Massage Therapy
# 6132      unclaimed    Yoga Studio         Wailua         Hoola Fitness Center
# 6133        claimed    Yoga Studio  Makakilo City          Crossfit West Oahu
# 6134        claimed    Yoga Studio  Makakilo City    Stayfit Physical Therapy
#
# [6135 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                           name        phone  \
# 0                             Ufc Gym Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city region  \
# 0                         Gym              805 Pohukaina St  Honolulu     HI
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu     HI
# 2             Training centre           1646 Kapiolani Blvd  Honolulu     HI
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe     HI
# 4         Martial arts school                 555 N King St  Honolulu     HI
# ...                       ...                           ...       ...    ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei     HI
# 6131         Health & Medical               1215 S Kihei Rd     Kihei     HI
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue     HI
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei     HI
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei     HI
#
#         zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     96813  ...          NaN           NaN           NaN           1
# 1     96813  ...          NaN           NaN           NaN         NaN
# 2     96814  ...          NaN           NaN           NaN         NaN
# 3     96744  ...          NaN           NaN           NaN         NaN
# 4     96817  ...          NaN           NaN           NaN         NaN
# ...     ...  ...          ...           ...           ...         ...
# 6130  96753  ...          NaN           NaN           NaN         NaN
# 6131  96753  ...          NaN           NaN           NaN         NaN
# 6132  96766  ...          NaN           NaN           NaN         NaN
# 6133  96707  ...          NaN           NaN           NaN         NaN
# 6134  96707  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city                   First Name Business Type
# 0       Boxing Club       Honolulu                Ufc  Honolulu           NaT
# 1       Boxing Club       Honolulu                  Muay Boran            NaT
# 2       Boxing Club       Honolulu                    Punchfit            NaT
# 3       Boxing Club       Honolulu            Koolauloa Boxing            NaT
# 4       Boxing Club       Honolulu   Martial Arts Center (Hmc)            NaT
# ...             ...            ...                          ...           ...
# 6130    Yoga Studio  Wailea-Makena         Reps Training Center           NaT
# 6131    Yoga Studio  Wailea-Makena        Sabai Massage Therapy           NaT
# 6132    Yoga Studio         Wailua         Hoola Fitness Center           NaT
# 6133    Yoga Studio  Makakilo City          Crossfit West Oahu            NaT
# 6134    Yoga Studio  Makakilo City    Stayfit Physical Therapy            NaT
#
# [6135 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                           name        phone  \
# 0                             Ufc Gym Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city region  \
# 0                         Gym              805 Pohukaina St  Honolulu     HI
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu     HI
# 2             Training centre           1646 Kapiolani Blvd  Honolulu     HI
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe     HI
# 4         Martial arts school                 555 N King St  Honolulu     HI
# ...                       ...                           ...       ...    ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei     HI
# 6131         Health & Medical               1215 S Kihei Rd     Kihei     HI
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue     HI
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei     HI
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei     HI
#
#         zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     96813  ...          NaN           NaN           NaN           1
# 1     96813  ...          NaN           NaN           NaN         NaN
# 2     96814  ...          NaN           NaN           NaN         NaN
# 3     96744  ...          NaN           NaN           NaN         NaN
# 4     96817  ...          NaN           NaN           NaN         NaN
# ...     ...  ...          ...           ...           ...         ...
# 6130  96753  ...          NaN           NaN           NaN         NaN
# 6131  96753  ...          NaN           NaN           NaN         NaN
# 6132  96766  ...          NaN           NaN           NaN         NaN
# 6133  96707  ...          NaN           NaN           NaN         NaN
# 6134  96707  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city                   First Name Business Type
# 0       Boxing Club       Honolulu                Ufc  Honolulu       General
# 1       Boxing Club       Honolulu                  Muay Boran        General
# 2       Boxing Club       Honolulu                    Punchfit        General
# 3       Boxing Club       Honolulu            Koolauloa Boxing        General
# 4       Boxing Club       Honolulu   Martial Arts Center (Hmc)        General
# ...             ...            ...                          ...           ...
# 6130    Yoga Studio  Wailea-Makena         Reps Training Center       General
# 6131    Yoga Studio  Wailea-Makena        Sabai Massage Therapy       General
# 6132    Yoga Studio         Wailua         Hoola Fitness Center       General
# 6133    Yoga Studio  Makakilo City          Crossfit West Oahu        General
# 6134    Yoga Studio  Makakilo City    Stayfit Physical Therapy        General
#
# [6135 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                           name        phone  \
# 0                             Ufc Gym Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city region  \
# 0                         Gym              805 Pohukaina St  Honolulu     HI
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu     HI
# 2             Training centre           1646 Kapiolani Blvd  Honolulu     HI
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe     HI
# 4         Martial arts school                 555 N King St  Honolulu     HI
# ...                       ...                           ...       ...    ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei     HI
# 6131         Health & Medical               1215 S Kihei Rd     Kihei     HI
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue     HI
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei     HI
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei     HI
#
#         zip  ... ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0     96813  ...          NaN           NaN           NaN           1
# 1     96813  ...          NaN           NaN           NaN         NaN
# 2     96814  ...          NaN           NaN           NaN         NaN
# 3     96744  ...          NaN           NaN           NaN         NaN
# 4     96817  ...          NaN           NaN           NaN         NaN
# ...     ...  ...          ...           ...           ...         ...
# 6130  96753  ...          NaN           NaN           NaN         NaN
# 6131  96753  ...          NaN           NaN           NaN         NaN
# 6132  96766  ...          NaN           NaN           NaN         NaN
# 6133  96707  ...          NaN           NaN           NaN         NaN
# 6134  96707  ...          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city                   First Name Business Type
# 0       Boxing Club       Honolulu                Ufc  Honolulu       fitness
# 1       Boxing Club       Honolulu                  Muay Boran        General
# 2       Boxing Club       Honolulu                    Punchfit        General
# 3       Boxing Club       Honolulu            Koolauloa Boxing         Boxing
# 4       Boxing Club       Honolulu   Martial Arts Center (Hmc)   Martial Arts
# ...             ...            ...                          ...           ...
# 6130    Yoga Studio  Wailea-Makena         Reps Training Center       General
# 6131    Yoga Studio  Wailea-Makena        Sabai Massage Therapy       General
# 6132    Yoga Studio         Wailua         Hoola Fitness Center       Fitness
# 6133    Yoga Studio  Makakilo City          Crossfit West Oahu       Crossfit
# 6134    Yoga Studio  Makakilo City    Stayfit Physical Therapy        General
#
# [6135 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#      Business Type                   First Name  \
# 0          fitness                Ufc  Honolulu
# 1          General                  Muay Boran
# 2          General                    Punchfit
# 3           Boxing            Koolauloa Boxing
# 4     Martial Arts   Martial Arts Center (Hmc)
# ...            ...                          ...
# 6130       General         Reps Training Center
# 6131       General        Sabai Massage Therapy
# 6132       Fitness         Hoola Fitness Center
# 6133      Crossfit          Crossfit West Oahu
# 6134       General    Stayfit Physical Therapy
#
#                                           name        phone  \
# 0                             Ufc Gym Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city  ...  \
# 0                         Gym              805 Pohukaina St  Honolulu  ...
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu  ...
# 2             Training centre           1646 Kapiolani Blvd  Honolulu  ...
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe  ...
# 4         Martial arts school                 555 N King St  Honolulu  ...
# ...                       ...                           ...       ...  ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei  ...
# 6131         Health & Medical               1215 S Kihei Rd     Kihei  ...
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue  ...
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei  ...
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                             5      NaN          NaN           NaN
# 1                             4      NaN          NaN           NaN
# 2                           NaN      NaN          NaN           NaN
# 3                           NaN      NaN          NaN           NaN
# 4                           NaN      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 6130                          4      NaN          NaN           NaN
# 6131                        NaN      NaN          NaN           NaN
# 6132                        NaN      NaN          NaN           NaN
# 6133                          4      NaN          NaN           NaN
# 6134                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN           1
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 6130           NaN         NaN
# 6131           NaN         NaN
# 6132           NaN         NaN
# 6133           NaN         NaN
# 6134           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city
# 0       Boxing Club       Honolulu
# 1       Boxing Club       Honolulu
# 2       Boxing Club       Honolulu
# 3       Boxing Club       Honolulu
# 4       Boxing Club       Honolulu
# ...             ...            ...
# 6130    Yoga Studio  Wailea-Makena
# 6131    Yoga Studio  Wailea-Makena
# 6132    Yoga Studio         Wailua
# 6133    Yoga Studio  Makakilo City
# 6134    Yoga Studio  Makakilo City
#
# [6135 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#      Business Type                 First Name  \
# 0          fitness              Ufc  Honolulu
# 1          General                Muay Boran
# 2          General                  Punchfit
# 3           Boxing          Koolauloa Boxing
# 4     Martial Arts   Martial Arts Center Hmc
# ...            ...                        ...
# 6130       General       Reps Training Center
# 6131       General      Sabai Massage Therapy
# 6132       Fitness       Hoola Fitness Center
# 6133      Crossfit        Crossfit West Oahu
# 6134       General  Stayfit Physical Therapy
#
#                                           name        phone  \
# 0                             Ufc Gym Honolulu  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city  ...  \
# 0                         Gym              805 Pohukaina St  Honolulu  ...
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu  ...
# 2             Training centre           1646 Kapiolani Blvd  Honolulu  ...
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe  ...
# 4         Martial arts school                 555 N King St  Honolulu  ...
# ...                       ...                           ...       ...  ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei  ...
# 6131         Health & Medical               1215 S Kihei Rd     Kihei  ...
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue  ...
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei  ...
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                             5      NaN          NaN           NaN
# 1                             4      NaN          NaN           NaN
# 2                           NaN      NaN          NaN           NaN
# 3                           NaN      NaN          NaN           NaN
# 4                           NaN      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 6130                          4      NaN          NaN           NaN
# 6131                        NaN      NaN          NaN           NaN
# 6132                        NaN      NaN          NaN           NaN
# 6133                          4      NaN          NaN           NaN
# 6134                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN           1
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 6130           NaN         NaN
# 6131           NaN         NaN
# 6132           NaN         NaN
# 6133           NaN         NaN
# 6134           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city
# 0       Boxing Club       Honolulu
# 1       Boxing Club       Honolulu
# 2       Boxing Club       Honolulu
# 3       Boxing Club       Honolulu
# 4       Boxing Club       Honolulu
# ...             ...            ...
# 6130    Yoga Studio  Wailea-Makena
# 6131    Yoga Studio  Wailea-Makena
# 6132    Yoga Studio         Wailua
# 6133    Yoga Studio  Makakilo City
# 6134    Yoga Studio  Makakilo City
#
# [6135 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#      Business Type                 First Name  \
# 0          fitness                      Ufc
# 1          General                Muay Boran
# 2          General                  Punchfit
# 3           Boxing          Koolauloa Boxing
# 4     Martial Arts   Martial Arts Center Hmc
# ...            ...                        ...
# 6130       General       Reps Training Center
# 6131       General      Sabai Massage Therapy
# 6132       Fitness       Hoola Fitness Center
# 6133      Crossfit        Crossfit West Oahu
# 6134       General  Stayfit Physical Therapy
#
#                                           name        phone  \
# 0                           Ufc Gym (Honolulu)  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city  ...  \
# 0                         Gym              805 Pohukaina St  Honolulu  ...
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu  ...
# 2             Training centre           1646 Kapiolani Blvd  Honolulu  ...
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe  ...
# 4         Martial arts school                 555 N King St  Honolulu  ...
# ...                       ...                           ...       ...  ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei  ...
# 6131         Health & Medical               1215 S Kihei Rd     Kihei  ...
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue  ...
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei  ...
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei  ...
#
#      instagram_average_comments ads_yelp ads_facebook ads_instagram  \
# 0                             5      NaN          NaN           NaN
# 1                             4      NaN          NaN           NaN
# 2                           NaN      NaN          NaN           NaN
# 3                           NaN      NaN          NaN           NaN
# 4                           NaN      NaN          NaN           NaN
# ...                         ...      ...          ...           ...
# 6130                          4      NaN          NaN           NaN
# 6131                        NaN      NaN          NaN           NaN
# 6132                        NaN      NaN          NaN           NaN
# 6133                          4      NaN          NaN           NaN
# 6134                        NaN      NaN          NaN           NaN
#
#      ads_messenger ads_adwords  \
# 0              NaN           1
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 6130           NaN         NaN
# 6131           NaN         NaN
# 6132           NaN         NaN
# 6133           NaN         NaN
# 6134           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city
# 0       Boxing Club       Honolulu
# 1       Boxing Club       Honolulu
# 2       Boxing Club       Honolulu
# 3       Boxing Club       Honolulu
# 4       Boxing Club       Honolulu
# ...             ...            ...
# 6130    Yoga Studio  Wailea-Makena
# 6131    Yoga Studio  Wailea-Makena
# 6132    Yoga Studio         Wailua
# 6133    Yoga Studio  Makakilo City
# 6134    Yoga Studio  Makakilo City
#
# [6135 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
# Convert all data types to correct type to be compared, worked before in EST
# Does not work for current leads for some reason, needs to be tested
df['googlestars'] = pd.to_numeric(df['googlestars'],errors='coerce')
df['facebookreviewscount'] = pd.to_numeric(df['facebookreviewscount'],errors='coerce')
df['facebookstars'] = pd.to_numeric(df['facebookstars'],errors='coerce')
df['googlereviewscount'] = pd.to_numeric(df['googlereviewscount'],errors='coerce')
df['instagram_followers'] = pd.to_numeric(df['instagram_followers'],errors='coerce')
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#      Business Type                 First Name  \
# 0          fitness                      Ufc
# 1          General                Muay Boran
# 2          General                  Punchfit
# 3           Boxing          Koolauloa Boxing
# 4     Martial Arts   Martial Arts Center Hmc
# ...            ...                        ...
# 6130       General       Reps Training Center
# 6131       General      Sabai Massage Therapy
# 6132       Fitness       Hoola Fitness Center
# 6133      Crossfit        Crossfit West Oahu
# 6134       General  Stayfit Physical Therapy
#
#                                           name        phone  \
# 0                           Ufc Gym (Honolulu)  18086722655
# 1                            Muay Boran Hawaii  18082248874
# 2                              Punchfit Hawaii  18087218957
# 3                        Koolauloa Boxing Club          NaN
# 4     Hawaii Martial Arts Center (Hmc) Academy  18088415144
# ...                                        ...          ...
# 6130                      Reps Training Center  18088751066
# 6131                     Sabai Massage Therapy  18084637734
# 6132                      Hoola Fitness Center  18082458933
# 6133                    Crossfit West Oahu Llc  18083535240
# 6134              Stayfit Physical Therapy Llc  18086740500
#
#                                 email     email_host  \
# 0                  contact@ufcgym.com    outlook.com
# 1                   dkaetsu@gmail.com     google.com
# 2                                 NaN            NaN
# 3                 jomauai@hotmail.com    outlook.com
# 4                                 NaN            NaN
# ...                               ...            ...
# 6130              info4reps@gmail.com     google.com
# 6131               info@sabaimaui.com    godaddy.com
# 6132      waimeadental@hoolalahui.org  barracuda.com
# 6133  membership@crossfitwestoahu.com     google.com
# 6134                mtenajc@gmail.com     google.com
#
#                                                 website  \
# 0            https://www.ufcgym.com/locations/honolulu/
# 1                    http://muayboranhawaii.weebly.com/
# 2                            http://punchfithawaii.com/
# 3                https://jomauaihotmailcom.ueniweb.com/
# 4                                http://hmcacademy.com/
# ...                                                 ...
# 6130                            http://repsfitness.com/
# 6131                           http://www.sabaimaui.com
# 6132  https://www.hoolalahui.org/hoolafitnessprogram...
# 6133                   http://www.crossfitwestoahu.com/
# 6134                 http://stayfitphysicaltherapy.com/
#
#                      category                       address      city  ...  \
# 0                         Gym              805 Pohukaina St  Honolulu  ...
# 1        Muay Thai boxing gym                  505 Coral St  Honolulu  ...
# 2             Training centre           1646 Kapiolani Blvd  Honolulu  ...
# 3                  Boxing Gym            45-691 Keaahala Rd   Kaneohe  ...
# 4         Martial arts school                 555 N King St  Honolulu  ...
# ...                       ...                           ...       ...  ...
# 6130          Cycling Classes               1847 S Kihei Rd     Kihei  ...
# 6131         Health & Medical               1215 S Kihei Rd     Kihei  ...
# 6132                     Gyms              3-3204 Kuhio Hwy     Lihue  ...
# 6133           Fitness centre  2045 Lauwiliwili St Ste. 802   Kapolei  ...
# 6134  Physical Therapy Clinic  1001 Kamokila Blvd Suite 114   Kapolei  ...
#
#      ads_yelp ads_facebook ads_instagram ads_messenger ads_adwords  \
# 0         NaN          NaN           NaN           NaN           1
# 1         NaN          NaN           NaN           NaN         NaN
# 2         NaN          NaN           NaN           NaN         NaN
# 3         NaN          NaN           NaN           NaN         NaN
# 4         NaN          NaN           NaN           NaN         NaN
# ...       ...          ...           ...           ...         ...
# 6130      NaN          NaN           NaN           NaN         NaN
# 6131      NaN          NaN           NaN           NaN         NaN
# 6132      NaN          NaN           NaN           NaN         NaN
# 6133      NaN          NaN           NaN           NaN         NaN
# 6134      NaN          NaN           NaN           NaN         NaN
#
#                                                  g_maps g_maps_claimed  \
# 0                       https://g.page/ufc-gym-honolulu        claimed
# 1                        https://g.page/muayboranhawaii        claimed
# 2     https://maps.google.com/maps/place/PUNCHFIT+HA...        claimed
# 3     https://maps.google.com/maps/place/Koolauloa+B...        claimed
# 4     https://maps.google.com/maps/place/Hawaii+Mart...        claimed
# ...                                                 ...            ...
# 6130  https://maps.google.com/maps/place/REPS+Traini...        claimed
# 6131  https://maps.google.com/maps/place/Sabai+Massa...        claimed
# 6132  https://maps.google.com/maps/place/Hoola+Fitne...      unclaimed
# 6133  https://maps.google.com/maps/place/CrossFit+We...        claimed
# 6134  https://maps.google.com/maps/place/StayFIT+Phy...        claimed
#
#      search_keyword    search_city  \
# 0       Boxing Club       Honolulu
# 1       Boxing Club       Honolulu
# 2       Boxing Club       Honolulu
# 3       Boxing Club       Honolulu
# 4       Boxing Club       Honolulu
# ...             ...            ...
# 6130    Yoga Studio  Wailea-Makena
# 6131    Yoga Studio  Wailea-Makena
# 6132    Yoga Studio         Wailua
# 6133    Yoga Studio  Makakilo City
# 6134    Yoga Studio  Makakilo City
#
#                                             Icebreakers
# 0     I saw your B2 page is in the triple digits for...
# 1     I saw B2 has a near perfect rating on Google. ...
# 2     I saw B2 has a perfect rating on Google. 5 sta...
# 3     I saw B2 has a perfect rating on Google. 5 sta...
# 4     I saw B2 has a perfect rating on Google. 5 sta...
# ...                                                 ...
# 6130  I saw B2 has a perfect rating on Google. 5 sta...
# 6131  I saw B2 has a near perfect rating on Google. ...
# 6132  I saw B2 has a perfect rating on Google. 5 sta...
# 6133  I saw B2 has a near perfect rating on Google. ...
# 6134  I saw B2 has a near perfect rating on Google. ...
#
# [6135 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('HI_combined_leads_duplicates_removed_semiclean.csv', index = False)
