# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
df = pd.read_csv("NJ Sample List - Raw.csv")
df #dataFrame
# Out:
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro USA  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city region  \
# 0                       Gym               2-14 Ferry St        Newark     NJ
# 1                       Gym                520 Broad St        Newark     NJ
# 2                       Gym               102 Monroe St        Newark     NJ
# 3                       Gym                87 Halsey St        Newark     NJ
# 4            Fitness centre                18 Oliver St        Newark     NJ
# ...                     ...                         ...           ...    ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville     NJ
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville     NJ
# 21240   Martial arts school               8 Girard Rd S     Glassboro     NJ
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown     NJ
# 21242  Chinese Martial Arts                444 New St E     Glassboro     NJ
#
#         zip  ... instagram_average_comments  ads_yelp ads_facebook  \
# 0      7105  ...                        4.0       NaN          1.0
# 1      7102  ...                       60.0       NaN          1.0
# 2      7105  ...                        2.0       NaN          NaN
# 3      7102  ...                        2.0       NaN          NaN
# 4      7102  ...                        1.0       NaN          NaN
# ...     ...  ...                        ...       ...          ...
# 21238  8081  ...                        4.0       NaN          NaN
# 21239  8081  ...                        NaN       NaN          NaN
# 21240  8028  ...                        NaN       NaN          NaN
# 21241  8094  ...                        NaN       NaN          NaN
# 21242  8028  ...                        NaN       NaN          NaN
#
#       ads_instagram ads_messenger ads_adwords  \
# 0               1.0           1.0         NaN
# 1               1.0           NaN         NaN
# 2               NaN           NaN         NaN
# 3               NaN           NaN         NaN
# 4               1.0           1.0         NaN
# ...             ...           ...         ...
# 21238           NaN           NaN         NaN
# 21239           NaN           NaN         NaN
# 21240           NaN           NaN         NaN
# 21241           NaN           NaN         NaN
# 21242           NaN           NaN         NaN
#
#                                                   g_maps  g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...         claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...         claimed
# 2           https://g.page/evolutionfitnessnewarkreviews         claimed
# 3                          https://g.page/ArrivalFitness         claimed
# 4                         https://g.page/ClubMetroNewark         claimed
# ...                                                  ...             ...
# 21238             https://g.page/danieltavaresbjjacademy         claimed
# 21239                            https://g.page/Wolf-BJJ         claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...       unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...       unclaimed
# 21242                                                NaN             NaN
#
#        search_keyword  search_city
# 0                Gyms       Newark
# 1                Gyms       Newark
# 2                Gyms       Newark
# 3                Gyms       Newark
# 4                Gyms       Newark
# ...               ...          ...
# 21238    Martial Arts    Glassboro
# 21239    Martial Arts    Glassboro
# 21240    Martial Arts    Glassboro
# 21241    Martial Arts    Glassboro
# 21242    Martial Arts    Glassboro
#
# [21243 rows x 54 columns]

# %%
#1) Change Names of Gyms to shorter versions
#Mixed Martial Arts = MMA
#Brazilian Jiu Jitsu = BJJ
#Tae Kwon Do = TKD
#Remove Academy from names ("Academy/academy" = "")
#Must do upper and lower case versions
df['First Name'] = df['name'] #This line creates a new column that allows us to compare the old name to the new name
df['First Name'] = df['First Name'].str.lower() #This line capitalizes all the words in the string
df['name'] = df['name'].str.lower()
df['First Name'] = df['First Name'].str.title() #This line capitalizes all the words in the string
df['name'] = df['name'].str.title()
df['First Name'] = df['First Name'].str.replace('Mixed Martial Arts','MMA')
df['First Name'] = df['First Name'].str.replace('Jiu Jitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('JiuJitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiujitsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Jiu-jitsu','Jiu-Jitsu')
#df['First Name'] = df['First Name'].str.replace('Ju Jutsu','Jiu-Jitsu') Need to ask about "Ju Jutsu"
#df['First Name'] = df['First Name'].str.replace('Ju-Jutsu','Jiu-Jitsu')
df['First Name'] = df['First Name'].str.replace('Brazilian Jiu-Jitsu','BJJ')
df['First Name'] = df['First Name'].str.replace('Tae Kwon Do','TKD')
df['First Name'] = df['First Name'].str.replace('TaeKwonDo','TKD')
df['First Name'] = df['First Name'].str.replace('Taekwondo','TKD')
df['First Name'] = df['First Name'].str.replace('Academy','')
df['First Name'] = df['First Name'].str.replace('Club','')
df['First Name'] = df['First Name'].str.replace('Gym','')
df['First Name'] = df['First Name'].str.replace('LLC','')
df['First Name'] = df['First Name'].str.replace('LLc','')
df['First Name'] = df['First Name'].str.replace('Llc','')
df['First Name'] = df['First Name'].str.replace('Corp','')
df['First Name'] = df['First Name'].str.replace('Std','')
df['First Name'] = df['First Name'].str.replace('Inst','Institute')
df['First Name'] = df['First Name'].str.replace('CT','')
df['First Name'] = df['First Name'].str.replace('Ct','')
df['First Name'] = df['First Name'].str.replace('Connecticut','')
df
# Out:
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city region  \
# 0                       Gym               2-14 Ferry St        Newark     NJ
# 1                       Gym                520 Broad St        Newark     NJ
# 2                       Gym               102 Monroe St        Newark     NJ
# 3                       Gym                87 Halsey St        Newark     NJ
# 4            Fitness centre                18 Oliver St        Newark     NJ
# ...                     ...                         ...           ...    ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville     NJ
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville     NJ
# 21240   Martial arts school               8 Girard Rd S     Glassboro     NJ
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown     NJ
# 21242  Chinese Martial Arts                444 New St E     Glassboro     NJ
#
#         zip  ... ads_yelp  ads_facebook ads_instagram ads_messenger  \
# 0      7105  ...      NaN           1.0           1.0           1.0
# 1      7102  ...      NaN           1.0           1.0           NaN
# 2      7105  ...      NaN           NaN           NaN           NaN
# 3      7102  ...      NaN           NaN           NaN           NaN
# 4      7102  ...      NaN           NaN           1.0           1.0
# ...     ...  ...      ...           ...           ...           ...
# 21238  8081  ...      NaN           NaN           NaN           NaN
# 21239  8081  ...      NaN           NaN           NaN           NaN
# 21240  8028  ...      NaN           NaN           NaN           NaN
# 21241  8094  ...      NaN           NaN           NaN           NaN
# 21242  8028  ...      NaN           NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Blink+Fitne...
# 1             NaN  https://maps.google.com/maps/place/Planet+Fitn...
# 2             NaN       https://g.page/evolutionfitnessnewarkreviews
# 3             NaN                      https://g.page/ArrivalFitness
# 4             NaN                     https://g.page/ClubMetroNewark
# ...           ...                                                ...
# 21238         NaN             https://g.page/danieltavaresbjjacademy
# 21239         NaN                            https://g.page/Wolf-BJJ
# 21240         NaN  https://maps.google.com/maps/place/Shotokan+Ka...
# 21241         NaN  https://maps.google.com/maps/place/Universal+W...
# 21242         NaN                                                NaN
#
#        g_maps_claimed  search_keyword  search_city  \
# 0             claimed            Gyms       Newark
# 1             claimed            Gyms       Newark
# 2             claimed            Gyms       Newark
# 3             claimed            Gyms       Newark
# 4             claimed            Gyms       Newark
# ...               ...             ...          ...
# 21238         claimed    Martial Arts    Glassboro
# 21239         claimed    Martial Arts    Glassboro
# 21240       unclaimed    Martial Arts    Glassboro
# 21241       unclaimed    Martial Arts    Glassboro
# 21242             NaN    Martial Arts    Glassboro
#
#                         First Name
# 0                    Blink Fitness
# 1                   Planet Fitness
# 2                Evolution Fitness
# 3                  Arrival Fitness
# 4                        Metro Usa
# ...                            ...
# 21238             Daniel Tavares 🔥
# 21239                     Wolf BJJ
# 21240         Shotokan Karate  Inc
# 21241  Universal Way Martial Arts
# 21242  South Jersey Kung Fu School
#
# [21243 rows x 55 columns]

# %%
#2)
#Remove "The" or "A" at the beginning of the name
df['First Name'] = df['First Name'].str.replace('^The ','', regex=True) #"Replaces 'The ' if it is the start of the string"
df['First Name'] = df['First Name'].str.replace('^A\s','', regex=True) #"Replaces 'A ' if it is the start of the string"
df
# Out:
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city region  \
# 0                       Gym               2-14 Ferry St        Newark     NJ
# 1                       Gym                520 Broad St        Newark     NJ
# 2                       Gym               102 Monroe St        Newark     NJ
# 3                       Gym                87 Halsey St        Newark     NJ
# 4            Fitness centre                18 Oliver St        Newark     NJ
# ...                     ...                         ...           ...    ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville     NJ
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville     NJ
# 21240   Martial arts school               8 Girard Rd S     Glassboro     NJ
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown     NJ
# 21242  Chinese Martial Arts                444 New St E     Glassboro     NJ
#
#         zip  ... ads_yelp  ads_facebook ads_instagram ads_messenger  \
# 0      7105  ...      NaN           1.0           1.0           1.0
# 1      7102  ...      NaN           1.0           1.0           NaN
# 2      7105  ...      NaN           NaN           NaN           NaN
# 3      7102  ...      NaN           NaN           NaN           NaN
# 4      7102  ...      NaN           NaN           1.0           1.0
# ...     ...  ...      ...           ...           ...           ...
# 21238  8081  ...      NaN           NaN           NaN           NaN
# 21239  8081  ...      NaN           NaN           NaN           NaN
# 21240  8028  ...      NaN           NaN           NaN           NaN
# 21241  8094  ...      NaN           NaN           NaN           NaN
# 21242  8028  ...      NaN           NaN           NaN           NaN
#
#       ads_adwords                                             g_maps  \
# 0             NaN  https://maps.google.com/maps/place/Blink+Fitne...
# 1             NaN  https://maps.google.com/maps/place/Planet+Fitn...
# 2             NaN       https://g.page/evolutionfitnessnewarkreviews
# 3             NaN                      https://g.page/ArrivalFitness
# 4             NaN                     https://g.page/ClubMetroNewark
# ...           ...                                                ...
# 21238         NaN             https://g.page/danieltavaresbjjacademy
# 21239         NaN                            https://g.page/Wolf-BJJ
# 21240         NaN  https://maps.google.com/maps/place/Shotokan+Ka...
# 21241         NaN  https://maps.google.com/maps/place/Universal+W...
# 21242         NaN                                                NaN
#
#        g_maps_claimed  search_keyword  search_city  \
# 0             claimed            Gyms       Newark
# 1             claimed            Gyms       Newark
# 2             claimed            Gyms       Newark
# 3             claimed            Gyms       Newark
# 4             claimed            Gyms       Newark
# ...               ...             ...          ...
# 21238         claimed    Martial Arts    Glassboro
# 21239         claimed    Martial Arts    Glassboro
# 21240       unclaimed    Martial Arts    Glassboro
# 21241       unclaimed    Martial Arts    Glassboro
# 21242             NaN    Martial Arts    Glassboro
#
#                         First Name
# 0                    Blink Fitness
# 1                   Planet Fitness
# 2                Evolution Fitness
# 3                  Arrival Fitness
# 4                        Metro Usa
# ...                            ...
# 21238             Daniel Tavares 🔥
# 21239                     Wolf BJJ
# 21240         Shotokan Karate  Inc
# 21241  Universal Way Martial Arts
# 21242  South Jersey Kung Fu School
#
# [21243 rows x 55 columns]

# %%
#4) Change Business type to appropriate type
#First add a new column called business type, all values are set to null
df['Business Type'] = pd.NaT
df
# Out:
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city region  \
# 0                       Gym               2-14 Ferry St        Newark     NJ
# 1                       Gym                520 Broad St        Newark     NJ
# 2                       Gym               102 Monroe St        Newark     NJ
# 3                       Gym                87 Halsey St        Newark     NJ
# 4            Fitness centre                18 Oliver St        Newark     NJ
# ...                     ...                         ...           ...    ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville     NJ
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville     NJ
# 21240   Martial arts school               8 Girard Rd S     Glassboro     NJ
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown     NJ
# 21242  Chinese Martial Arts                444 New St E     Glassboro     NJ
#
#         zip  ... ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0      7105  ...          1.0            1.0           1.0         NaN
# 1      7102  ...          1.0            1.0           NaN         NaN
# 2      7105  ...          NaN            NaN           NaN         NaN
# 3      7102  ...          NaN            NaN           NaN         NaN
# 4      7102  ...          NaN            1.0           1.0         NaN
# ...     ...  ...          ...            ...           ...         ...
# 21238  8081  ...          NaN            NaN           NaN         NaN
# 21239  8081  ...          NaN            NaN           NaN         NaN
# 21240  8028  ...          NaN            NaN           NaN         NaN
# 21241  8094  ...          NaN            NaN           NaN         NaN
# 21242  8028  ...          NaN            NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...        claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...        claimed
# 2           https://g.page/evolutionfitnessnewarkreviews        claimed
# 3                          https://g.page/ArrivalFitness        claimed
# 4                         https://g.page/ClubMetroNewark        claimed
# ...                                                  ...            ...
# 21238             https://g.page/danieltavaresbjjacademy        claimed
# 21239                            https://g.page/Wolf-BJJ        claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...      unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...      unclaimed
# 21242                                                NaN            NaN
#
#        search_keyword  search_city                   First Name  Business Type
# 0                Gyms       Newark                Blink Fitness            NaT
# 1                Gyms       Newark               Planet Fitness            NaT
# 2                Gyms       Newark            Evolution Fitness            NaT
# 3                Gyms       Newark              Arrival Fitness            NaT
# 4                Gyms       Newark                    Metro Usa            NaT
# ...               ...          ...                          ...            ...
# 21238    Martial Arts    Glassboro             Daniel Tavares 🔥            NaT
# 21239    Martial Arts    Glassboro                     Wolf BJJ            NaT
# 21240    Martial Arts    Glassboro         Shotokan Karate  Inc            NaT
# 21241    Martial Arts    Glassboro  Universal Way Martial Arts             NaT
# 21242    Martial Arts    Glassboro  South Jersey Kung Fu School            NaT
#
# [21243 rows x 56 columns]

# %%
#Then we must change the business type to the correct type, if no type is correct just set to general
def setToGeneral(x):
    return 'General' 
df['Business Type'] = df['Business Type'].apply(setToGeneral)
df
# Out:
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city region  \
# 0                       Gym               2-14 Ferry St        Newark     NJ
# 1                       Gym                520 Broad St        Newark     NJ
# 2                       Gym               102 Monroe St        Newark     NJ
# 3                       Gym                87 Halsey St        Newark     NJ
# 4            Fitness centre                18 Oliver St        Newark     NJ
# ...                     ...                         ...           ...    ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville     NJ
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville     NJ
# 21240   Martial arts school               8 Girard Rd S     Glassboro     NJ
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown     NJ
# 21242  Chinese Martial Arts                444 New St E     Glassboro     NJ
#
#         zip  ... ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0      7105  ...          1.0            1.0           1.0         NaN
# 1      7102  ...          1.0            1.0           NaN         NaN
# 2      7105  ...          NaN            NaN           NaN         NaN
# 3      7102  ...          NaN            NaN           NaN         NaN
# 4      7102  ...          NaN            1.0           1.0         NaN
# ...     ...  ...          ...            ...           ...         ...
# 21238  8081  ...          NaN            NaN           NaN         NaN
# 21239  8081  ...          NaN            NaN           NaN         NaN
# 21240  8028  ...          NaN            NaN           NaN         NaN
# 21241  8094  ...          NaN            NaN           NaN         NaN
# 21242  8028  ...          NaN            NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...        claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...        claimed
# 2           https://g.page/evolutionfitnessnewarkreviews        claimed
# 3                          https://g.page/ArrivalFitness        claimed
# 4                         https://g.page/ClubMetroNewark        claimed
# ...                                                  ...            ...
# 21238             https://g.page/danieltavaresbjjacademy        claimed
# 21239                            https://g.page/Wolf-BJJ        claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...      unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...      unclaimed
# 21242                                                NaN            NaN
#
#        search_keyword  search_city                   First Name  Business Type
# 0                Gyms       Newark                Blink Fitness        General
# 1                Gyms       Newark               Planet Fitness        General
# 2                Gyms       Newark            Evolution Fitness        General
# 3                Gyms       Newark              Arrival Fitness        General
# 4                Gyms       Newark                    Metro Usa        General
# ...               ...          ...                          ...            ...
# 21238    Martial Arts    Glassboro             Daniel Tavares 🔥        General
# 21239    Martial Arts    Glassboro                     Wolf BJJ        General
# 21240    Martial Arts    Glassboro         Shotokan Karate  Inc        General
# 21241    Martial Arts    Glassboro  Universal Way Martial Arts         General
# 21242    Martial Arts    Glassboro  South Jersey Kung Fu School        General
#
# [21243 rows x 56 columns]

# %%
#Changing Business Type for all types of businesses, needs work because changes correct business types to general
df.loc[df["First Name"].str.contains("Fitness"), "Business Type"] = "Fitness"
df.loc[df["First Name"].str.contains("Crossfit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("CrossFit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Cross Fit"), "Business Type"] = "Crossfit"
df.loc[df["First Name"].str.contains("Yoga"), "Business Type"] = "Yoga"
df.loc[df["First Name"].str.contains("Association"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Supplier"), "Business Type"] = "non-profit"
df.loc[df["First Name"].str.contains("Combat Sports"), "Business Type"] = "Jiu Jitsu"
df.loc[df["name"].str.contains("Gym"), "Business Type"] = "fitness"
df.loc[df["First Name"].str.contains("Martial Art"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("MMA"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Dojo"), "Business Type"] = "Martial Arts"
df.loc[df["First Name"].str.contains("Kickboxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Kick Boxing"), "Business Type"] = "Kickboxing"
df.loc[df["First Name"].str.contains("Boxing"), "Business Type"] = "Boxing"
df.loc[df["First Name"].str.contains("TKD"), "Business Type"] = "Tae Kwon Do"
df.loc[df["First Name"].str.contains("Judo"), "Business Type"] = "Judo"
df.loc[df["First Name"].str.contains("Krav"), "Business Type"] = "Krav Maga"
df.loc[df["First Name"].str.contains("Aikido"), "Business Type"] = "Aikido"
df.loc[df["First Name"].str.contains("Karate"), "Business Type"] = "Karate"
df.loc[df["First Name"].str.contains("Muay Thai"), "Business Type"] = "Muay Thai"
df.loc[df["First Name"].str.contains("Capoeira"), "Business Type"] = "Capoeira"
df.loc[df["First Name"].str.contains("Hapkido"), "Business Type"] = "Hapkido"
df.loc[df["First Name"].str.contains("Kung"), "Business Type"] = "Kung Fu"
df.loc[df["First Name"].str.contains("Wrestling"), "Business Type"] = "Wrestling"
df.loc[df["First Name"].str.contains("Tai Chi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("TaiChi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("Taichi"), "Business Type"] = "Tai Chi"
df.loc[df["First Name"].str.contains("JJ"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiu-Jitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("JiuJitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jiujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujitsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("Jujutsu"), "Business Type"] = "Jiu Jitsu"
df.loc[df["First Name"].str.contains("jiu jitsu"), "Business Type"] = "Jiu Jitsu"
df
# Out:
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city region  \
# 0                       Gym               2-14 Ferry St        Newark     NJ
# 1                       Gym                520 Broad St        Newark     NJ
# 2                       Gym               102 Monroe St        Newark     NJ
# 3                       Gym                87 Halsey St        Newark     NJ
# 4            Fitness centre                18 Oliver St        Newark     NJ
# ...                     ...                         ...           ...    ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville     NJ
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville     NJ
# 21240   Martial arts school               8 Girard Rd S     Glassboro     NJ
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown     NJ
# 21242  Chinese Martial Arts                444 New St E     Glassboro     NJ
#
#         zip  ... ads_facebook  ads_instagram ads_messenger ads_adwords  \
# 0      7105  ...          1.0            1.0           1.0         NaN
# 1      7102  ...          1.0            1.0           NaN         NaN
# 2      7105  ...          NaN            NaN           NaN         NaN
# 3      7102  ...          NaN            NaN           NaN         NaN
# 4      7102  ...          NaN            1.0           1.0         NaN
# ...     ...  ...          ...            ...           ...         ...
# 21238  8081  ...          NaN            NaN           NaN         NaN
# 21239  8081  ...          NaN            NaN           NaN         NaN
# 21240  8028  ...          NaN            NaN           NaN         NaN
# 21241  8094  ...          NaN            NaN           NaN         NaN
# 21242  8028  ...          NaN            NaN           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...        claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...        claimed
# 2           https://g.page/evolutionfitnessnewarkreviews        claimed
# 3                          https://g.page/ArrivalFitness        claimed
# 4                         https://g.page/ClubMetroNewark        claimed
# ...                                                  ...            ...
# 21238             https://g.page/danieltavaresbjjacademy        claimed
# 21239                            https://g.page/Wolf-BJJ        claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...      unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...      unclaimed
# 21242                                                NaN            NaN
#
#        search_keyword  search_city                   First Name  Business Type
# 0                Gyms       Newark                Blink Fitness        Fitness
# 1                Gyms       Newark               Planet Fitness        Fitness
# 2                Gyms       Newark            Evolution Fitness        Fitness
# 3                Gyms       Newark              Arrival Fitness        Fitness
# 4                Gyms       Newark                    Metro Usa        General
# ...               ...          ...                          ...            ...
# 21238    Martial Arts    Glassboro             Daniel Tavares 🔥        General
# 21239    Martial Arts    Glassboro                     Wolf BJJ      Jiu Jitsu
# 21240    Martial Arts    Glassboro         Shotokan Karate  Inc         Karate
# 21241    Martial Arts    Glassboro  Universal Way Martial Arts    Martial Arts
# 21242    Martial Arts    Glassboro  South Jersey Kung Fu School        Kung Fu
#
# [21243 rows x 56 columns]

# %%
#Rearranging columns
#Business type first column
#Clean name second column
#All names should be only alphanumeric
df = df[['First Name'] + [col for col in df.columns if col != 'First Name']]
df = df[['Business Type'] + [col for col in df.columns if col != 'Business Type']]
df
# Out:
#       Business Type                   First Name  \
# 0           Fitness                Blink Fitness
# 1           Fitness               Planet Fitness
# 2           Fitness            Evolution Fitness
# 3           Fitness              Arrival Fitness
# 4           General                    Metro Usa
# ...             ...                          ...
# 21238       General             Daniel Tavares 🔥
# 21239     Jiu Jitsu                     Wolf BJJ
# 21240        Karate         Shotokan Karate  Inc
# 21241  Martial Arts  Universal Way Martial Arts
# 21242       Kung Fu  South Jersey Kung Fu School
#
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city  ...  \
# 0                       Gym               2-14 Ferry St        Newark  ...
# 1                       Gym                520 Broad St        Newark  ...
# 2                       Gym               102 Monroe St        Newark  ...
# 3                       Gym                87 Halsey St        Newark  ...
# 4            Fitness centre                18 Oliver St        Newark  ...
# ...                     ...                         ...           ...  ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville  ...
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville  ...
# 21240   Martial arts school               8 Girard Rd S     Glassboro  ...
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown  ...
# 21242  Chinese Martial Arts                444 New St E     Glassboro  ...
#
#       instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                            4.0      NaN          1.0            1.0
# 1                           60.0      NaN          1.0            1.0
# 2                            2.0      NaN          NaN            NaN
# 3                            2.0      NaN          NaN            NaN
# 4                            1.0      NaN          NaN            1.0
# ...                          ...      ...          ...            ...
# 21238                        4.0      NaN          NaN            NaN
# 21239                        NaN      NaN          NaN            NaN
# 21240                        NaN      NaN          NaN            NaN
# 21241                        NaN      NaN          NaN            NaN
# 21242                        NaN      NaN          NaN            NaN
#
#       ads_messenger ads_adwords  \
# 0               1.0         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               1.0         NaN
# ...             ...         ...
# 21238           NaN         NaN
# 21239           NaN         NaN
# 21240           NaN         NaN
# 21241           NaN         NaN
# 21242           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...        claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...        claimed
# 2           https://g.page/evolutionfitnessnewarkreviews        claimed
# 3                          https://g.page/ArrivalFitness        claimed
# 4                         https://g.page/ClubMetroNewark        claimed
# ...                                                  ...            ...
# 21238             https://g.page/danieltavaresbjjacademy        claimed
# 21239                            https://g.page/Wolf-BJJ        claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...      unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...      unclaimed
# 21242                                                NaN            NaN
#
#        search_keyword  search_city
# 0                Gyms       Newark
# 1                Gyms       Newark
# 2                Gyms       Newark
# 3                Gyms       Newark
# 4                Gyms       Newark
# ...               ...          ...
# 21238    Martial Arts    Glassboro
# 21239    Martial Arts    Glassboro
# 21240    Martial Arts    Glassboro
# 21241    Martial Arts    Glassboro
# 21242    Martial Arts    Glassboro
#
# [21243 rows x 56 columns]

# %%
#All names should be only alphanumeric
df['First Name'] = df['First Name'].str.replace("[^A-Za-z0-9 &']", "", regex=True)
df
# Out:
#       Business Type                   First Name  \
# 0           Fitness                Blink Fitness
# 1           Fitness               Planet Fitness
# 2           Fitness            Evolution Fitness
# 3           Fitness              Arrival Fitness
# 4           General                    Metro Usa
# ...             ...                          ...
# 21238       General              Daniel Tavares
# 21239     Jiu Jitsu                     Wolf BJJ
# 21240        Karate         Shotokan Karate  Inc
# 21241  Martial Arts  Universal Way Martial Arts
# 21242       Kung Fu  South Jersey Kung Fu School
#
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city  ...  \
# 0                       Gym               2-14 Ferry St        Newark  ...
# 1                       Gym                520 Broad St        Newark  ...
# 2                       Gym               102 Monroe St        Newark  ...
# 3                       Gym                87 Halsey St        Newark  ...
# 4            Fitness centre                18 Oliver St        Newark  ...
# ...                     ...                         ...           ...  ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville  ...
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville  ...
# 21240   Martial arts school               8 Girard Rd S     Glassboro  ...
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown  ...
# 21242  Chinese Martial Arts                444 New St E     Glassboro  ...
#
#       instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                            4.0      NaN          1.0            1.0
# 1                           60.0      NaN          1.0            1.0
# 2                            2.0      NaN          NaN            NaN
# 3                            2.0      NaN          NaN            NaN
# 4                            1.0      NaN          NaN            1.0
# ...                          ...      ...          ...            ...
# 21238                        4.0      NaN          NaN            NaN
# 21239                        NaN      NaN          NaN            NaN
# 21240                        NaN      NaN          NaN            NaN
# 21241                        NaN      NaN          NaN            NaN
# 21242                        NaN      NaN          NaN            NaN
#
#       ads_messenger ads_adwords  \
# 0               1.0         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               1.0         NaN
# ...             ...         ...
# 21238           NaN         NaN
# 21239           NaN         NaN
# 21240           NaN         NaN
# 21241           NaN         NaN
# 21242           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...        claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...        claimed
# 2           https://g.page/evolutionfitnessnewarkreviews        claimed
# 3                          https://g.page/ArrivalFitness        claimed
# 4                         https://g.page/ClubMetroNewark        claimed
# ...                                                  ...            ...
# 21238             https://g.page/danieltavaresbjjacademy        claimed
# 21239                            https://g.page/Wolf-BJJ        claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...      unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...      unclaimed
# 21242                                                NaN            NaN
#
#        search_keyword  search_city
# 0                Gyms       Newark
# 1                Gyms       Newark
# 2                Gyms       Newark
# 3                Gyms       Newark
# 4                Gyms       Newark
# ...               ...          ...
# 21238    Martial Arts    Glassboro
# 21239    Martial Arts    Glassboro
# 21240    Martial Arts    Glassboro
# 21241    Martial Arts    Glassboro
# 21242    Martial Arts    Glassboro
#
# [21243 rows x 56 columns]

# %%
#Remove city from the name
#First name should not have the city name, name should have the city name in parenthesis
def findLocationFirstName(First_Name, search_city):
    if (search_city in First_Name):
        First_Name = First_Name.replace(search_city, '')
        return First_Name
    else:
        return First_Name
def findLocationName(name, search_city):
    if (search_city in name):
        name = name.replace(search_city, '(' + search_city + ')')
        return name
    else:
        return name
df['First Name'] = df.apply(lambda row: findLocationFirstName(row['First Name'], row['search_city']), axis = 1)
df['name'] = df.apply(lambda row: findLocationName(row['name'], row['search_city']), axis = 1)
df
# Out:
#       Business Type                   First Name  \
# 0           Fitness                Blink Fitness
# 1           Fitness               Planet Fitness
# 2           Fitness            Evolution Fitness
# 3           Fitness              Arrival Fitness
# 4           General                    Metro Usa
# ...             ...                          ...
# 21238       General              Daniel Tavares
# 21239     Jiu Jitsu                     Wolf BJJ
# 21240        Karate         Shotokan Karate  Inc
# 21241  Martial Arts  Universal Way Martial Arts
# 21242       Kung Fu  South Jersey Kung Fu School
#
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city  ...  \
# 0                       Gym               2-14 Ferry St        Newark  ...
# 1                       Gym                520 Broad St        Newark  ...
# 2                       Gym               102 Monroe St        Newark  ...
# 3                       Gym                87 Halsey St        Newark  ...
# 4            Fitness centre                18 Oliver St        Newark  ...
# ...                     ...                         ...           ...  ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville  ...
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville  ...
# 21240   Martial arts school               8 Girard Rd S     Glassboro  ...
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown  ...
# 21242  Chinese Martial Arts                444 New St E     Glassboro  ...
#
#       instagram_average_comments ads_yelp ads_facebook  ads_instagram  \
# 0                            4.0      NaN          1.0            1.0
# 1                           60.0      NaN          1.0            1.0
# 2                            2.0      NaN          NaN            NaN
# 3                            2.0      NaN          NaN            NaN
# 4                            1.0      NaN          NaN            1.0
# ...                          ...      ...          ...            ...
# 21238                        4.0      NaN          NaN            NaN
# 21239                        NaN      NaN          NaN            NaN
# 21240                        NaN      NaN          NaN            NaN
# 21241                        NaN      NaN          NaN            NaN
# 21242                        NaN      NaN          NaN            NaN
#
#       ads_messenger ads_adwords  \
# 0               1.0         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               1.0         NaN
# ...             ...         ...
# 21238           NaN         NaN
# 21239           NaN         NaN
# 21240           NaN         NaN
# 21241           NaN         NaN
# 21242           NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...        claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...        claimed
# 2           https://g.page/evolutionfitnessnewarkreviews        claimed
# 3                          https://g.page/ArrivalFitness        claimed
# 4                         https://g.page/ClubMetroNewark        claimed
# ...                                                  ...            ...
# 21238             https://g.page/danieltavaresbjjacademy        claimed
# 21239                            https://g.page/Wolf-BJJ        claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...      unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...      unclaimed
# 21242                                                NaN            NaN
#
#        search_keyword  search_city
# 0                Gyms       Newark
# 1                Gyms       Newark
# 2                Gyms       Newark
# 3                Gyms       Newark
# 4                Gyms       Newark
# ...               ...          ...
# 21238    Martial Arts    Glassboro
# 21239    Martial Arts    Glassboro
# 21240    Martial Arts    Glassboro
# 21241    Martial Arts    Glassboro
# 21242    Martial Arts    Glassboro
#
# [21243 rows x 56 columns]

# %%
#Icebreakers:
#Need to ask about how to tell if location is on facebook
#Need to ask about how to tell if location is on Google
#Need to ask about how to tell if Google is unclaimed
#Need to ask about how to tell if website is not working
df['Icebreakers'] = pd.NaT
def setIcebreakers(googlestars, facebookreviewscount, facebookstars, googlereviewscount, instagram_followers, mobilefriendly, facebook, g_maps_claimed, ):
    if (googlestars == 5):
        return "I saw B2 has a perfect rating on Google. 5 stars is a big deal. Congratulations!"
    elif (googlestars >= 4):
        return "I saw B2 has a near perfect rating on Google. Congratulations!"
    elif (facebookreviewscount >= 100):
        return "I saw your B2 page is in the triple digits for reviews on Facebook. That's amazing!"
    elif (facebookstars >= 4):
        return "I saw your B2 star rating on Facebook. Really great work keeping it so high!"
    elif (googlereviewscount >= 10):
        return "I saw your B2 listing on Google hit double digit reviews. That's really great!"
    elif (instagram_followers >= 1000):
        return "I saw your B2 followers on Instagram got into the quadruple digits. Congratulations!"
    elif (instagram_followers >= 100):
        return "I saw your B2 followers on Instagram got into the triple digits. Congratulations!"
    elif (mobilefriendly == "y"):
        return "I was looking at the B2 website on my phone and it looked great! Very mobile friendly!"
    elif (facebook != ""):
        return "I saw your B2 page on Facebook. You guys have a really nice gym!"
    elif (googlestars != ""):
        return "I saw your B2 website in a Google search. You guys have a really nice gym!"
    elif (g_maps_claimed != "claimed"):
        return "I noticed that you don't own the B2 listing on Google. Is it a mistake? One quick change could help your gym a huge amount."
    #elif (website != "working"):
        #return "I clicked into your B2 website on my phone, but it wasn't working too well. Was it a mistake?"
    else:
        return "I looked up your B2 listing online, but I couldn't find much. One quick change could help your gym in a big way."
df['Icebreakers'] = df.apply(lambda row: setIcebreakers(row['googlestars'], row['facebookreviewscount'], row['facebookstars'], row['googlereviewscount'], row['instagram_followers'], row['mobilefriendly'], row['facebook'], row['g_maps_claimed']), axis = 1)
df
# Out:
#       Business Type                   First Name  \
# 0           Fitness                Blink Fitness
# 1           Fitness               Planet Fitness
# 2           Fitness            Evolution Fitness
# 3           Fitness              Arrival Fitness
# 4           General                    Metro Usa
# ...             ...                          ...
# 21238       General              Daniel Tavares
# 21239     Jiu Jitsu                     Wolf BJJ
# 21240        Karate         Shotokan Karate  Inc
# 21241  Martial Arts  Universal Way Martial Arts
# 21242       Kung Fu  South Jersey Kung Fu School
#
#                                      name         phone  \
# 0                           Blink Fitness  1.973564e+10
# 1                          Planet Fitness  1.973273e+10
# 2                       Evolution Fitness  1.973732e+10
# 3                         Arrival Fitness  1.862232e+10
# 4                          Club Metro Usa  1.973732e+10
# ...                                   ...           ...
# 21238             Daniel Tavares Academy🔥  1.856885e+10
# 21239            Wolf Brazilian Jiu Jitsu  1.856353e+10
# 21240         Shotokan Karate Academy Inc  1.856864e+10
# 21241  Universal Way Martial Arts Academy  1.856875e+10
# 21242         South Jersey Kung Fu School  1.856940e+10
#
#                                email     email_host  \
# 0       farmingdale@blinkfitness.com     google.com
# 1      gulfport.ms@planetfitness.com  rackspace.com
# 2               gustavo@evofitnj.com  hostgator.com
# 3                info@arrivalfit.com     google.com
# 4         elizabeth@clubmetrousa.com  rackspace.com
# ...                              ...            ...
# 21238       teamtavaresbjj@gmail.com     google.com
# 21239        private@teamwolfbjj.com     google.com
# 21240                            NaN            NaN
# 21241                            NaN            NaN
# 21242                            NaN            NaN
#
#                                                  website  \
# 0      https://locations.blinkfitness.com/nj/new-jers...
# 1       http://www.planetfitness.com/gyms/newark-nj-1533
# 2                               http://www.evofitnj.com/
# 3                             http://www.arrivalfit.com/
# 4                   https://www.clubmetrousa.com/newark/
# ...                                                  ...
# 21238            http://www.danieltavaresbjjacademy.com/
# 21239                            http://teamwolfbjj.com/
# 21240                                                NaN
# 21241                                                NaN
# 21242                                                NaN
#
#                    category                     address          city  ...  \
# 0                       Gym               2-14 Ferry St        Newark  ...
# 1                       Gym                520 Broad St        Newark  ...
# 2                       Gym               102 Monroe St        Newark  ...
# 3                       Gym                87 Halsey St        Newark  ...
# 4            Fitness centre                18 Oliver St        Newark  ...
# ...                     ...                         ...           ...  ...
# 21238   Martial arts school  2903 New Brooklyn Erial Rd  Sicklerville  ...
# 21239   Martial arts school        1707 Sicklerville Rd  Sicklerville  ...
# 21240   Martial arts school               8 Girard Rd S     Glassboro  ...
# 21241   Martial arts school     1951 N Black Horse Pike  Williamstown  ...
# 21242  Chinese Martial Arts                444 New St E     Glassboro  ...
#
#       ads_yelp ads_facebook ads_instagram  ads_messenger ads_adwords  \
# 0          NaN          1.0           1.0            1.0         NaN
# 1          NaN          1.0           1.0            NaN         NaN
# 2          NaN          NaN           NaN            NaN         NaN
# 3          NaN          NaN           NaN            NaN         NaN
# 4          NaN          NaN           1.0            1.0         NaN
# ...        ...          ...           ...            ...         ...
# 21238      NaN          NaN           NaN            NaN         NaN
# 21239      NaN          NaN           NaN            NaN         NaN
# 21240      NaN          NaN           NaN            NaN         NaN
# 21241      NaN          NaN           NaN            NaN         NaN
# 21242      NaN          NaN           NaN            NaN         NaN
#
#                                                   g_maps g_maps_claimed  \
# 0      https://maps.google.com/maps/place/Blink+Fitne...        claimed
# 1      https://maps.google.com/maps/place/Planet+Fitn...        claimed
# 2           https://g.page/evolutionfitnessnewarkreviews        claimed
# 3                          https://g.page/ArrivalFitness        claimed
# 4                         https://g.page/ClubMetroNewark        claimed
# ...                                                  ...            ...
# 21238             https://g.page/danieltavaresbjjacademy        claimed
# 21239                            https://g.page/Wolf-BJJ        claimed
# 21240  https://maps.google.com/maps/place/Shotokan+Ka...      unclaimed
# 21241  https://maps.google.com/maps/place/Universal+W...      unclaimed
# 21242                                                NaN            NaN
#
#       search_keyword  search_city  \
# 0               Gyms       Newark
# 1               Gyms       Newark
# 2               Gyms       Newark
# 3               Gyms       Newark
# 4               Gyms       Newark
# ...              ...          ...
# 21238   Martial Arts    Glassboro
# 21239   Martial Arts    Glassboro
# 21240   Martial Arts    Glassboro
# 21241   Martial Arts    Glassboro
# 21242   Martial Arts    Glassboro
#
#                                              Icebreakers
# 0      I saw B2 has a near perfect rating on Google. ...
# 1      I saw your B2 followers on Instagram got into ...
# 2      I saw B2 has a near perfect rating on Google. ...
# 3      I saw B2 has a perfect rating on Google. 5 sta...
# 4      I saw B2 has a near perfect rating on Google. ...
# ...                                                  ...
# 21238  I saw B2 has a near perfect rating on Google. ...
# 21239  I saw B2 has a perfect rating on Google. 5 sta...
# 21240  I saw B2 has a perfect rating on Google. 5 sta...
# 21241  I saw B2 has a perfect rating on Google. 5 sta...
# 21242  I saw your B2 page on Facebook. You guys have ...
#
# [21243 rows x 57 columns]

# %%
#Export to final csv file
df.to_csv('CT Sample List - Raw semiclean.csv', index = False)
